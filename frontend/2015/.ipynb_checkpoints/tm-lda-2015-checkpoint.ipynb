# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned2015.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                    text
# 0     kajian virtual private network vpn sistem peng...
# 1     analisis qos quality service jaringan kampus m...
# 2     model average fts markov chain peramalan pengg...
# 3     pengembangan media e modul mata pelajaran prod...
# 4     perangkat pendukung forensik lalu lintas jaringan
# 5     analisa implementasi jaringan internet menggab...
# 6     analisa quality service qos jaringan internet ...
# 7     keamanan jaringan komputer metode blocking por...
# 8     analisa pemanfaatan proxy server media filteri...
# 9     intrusion detection system ids metode deteksi ...
# 10    pengaruh promosi online persepsi harga keputus...
# 11    rancang bangun jaringan komunikasi voip server...
# 12                belajar jaringan komputer mikrotik os
# 13    sistem penjualan web e commerce tata distro ka...
# 14    perancangan jaringan komputer aplikasi vhp onl...
# 15    rancang bangun jaringan hotspot kampus niversi...
# 16    perancangan implementasi jaringan komputer stu...
# 17    efektifitas wireless lan 11 b g solusi jaringa...
# 18    perancangan sistem otomatisasi backup data fil...
# 19    simulasi jaringan multiprotocol label switchin...
# 20    analisis konsep cara kerja serangan komputer d...
# 21    perancangan pengembangan sistem informasi perp...
# 22    implementasi vpn akses server melalui perangka...
# 23    perbandingan metode pcq sfq red fifo mikrotik ...
# 24    teknologi 4g jaringan gsm kebutuhan mobile int...
# 25    model pembelajaran konstruktivis mata pelajara...
# 26    perancangan implementasi instrusion detection ...
# 27    kontribusi minat belajar e learning media pemb...
# 28            sniffing spoofing aspek keamanan komputer
# 29    optimalisasi macromedia flash mendukung pembel...
# ...                                                 ...
# 9046  lkp instalasi konfigurasi symantec endpoint pr...
# 9047  implementasi intrusion detection system ids lo...
# 9048  intrusion detection prevention system idps loc...
# 9049  pengaruh media pembelajaran internet media kon...
# 9050  engamanan data steganography metode least sign...
# 9051  kejahatan defecting studi perbandingan antara ...
# 9052  analisis pattern minutiae matching fingerprint...
# 9053  faktor faktor china mendirikan online blue arm...
# 9054  information management system website server p...
# 9055  mengoptimalkan sistem firewall jaringan skala ...
# 9056  implementasi sistem pengamanan data barang mat...
# 9057  pencegahan ancaman reverse engineering source ...
# 9058               pengembangan antivirus client server
# 9059  sistem informasi akuntansi elektronik lembaga ...
# 9060  perancangan aplikasi pembuatan kartu tanda pen...
# 9061  analisis yuridis mengenai cyber attack cyber w...
# 9062  pemanfaatan sharing folder pengelolaan arsip p...
# 9063  sanksi hukum kejahatan peretasan website presi...
# 9064                rekapitulasi data keragaan koperasi
# 9065      aplikasi secure message algoritma cr6 android
# 9066  aplikasi e commerce penjualan keramik studi ka...
# 9067  pengaruh layanan e banking kepuasan nasabah bn...
# 9068  pengembangan sistem informasi administrasi per...
# 9069  segmentasi pelanggan som algoritma k means ana...
# 9070  dunia komunikasi gadget evolusi alat komunikas...
# 9071  kompetensi teknologi informasi mahasiswa jurus...
# 9072  prosiding seminar nasional matematika sains in...
# 9073  simulation laser thermal interaction with tita...
# 9074                     panduan praktis arduino pemula
# 9075  program studi pendidikan teknik informatika fa...
#
# [9076 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 9076
# [['kajian', 'virtual', 'private', 'network', 'vpn', 'sistem', 'pengamanan', 'data', 'jaringan', 'komputer', 'studi', 'kasus', 'jaringan', 'komputer', 'unikom']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# [['kajian', 'virtual', 'private', 'network', 'vpn', 'sistem', 'pengamanan', 'data', 'jaringan', 'komputer', 'studi', 'kasus', 'jaringan', 'komputer', 'unikom', 'virtual_private', 'network_vpn', 'jaringan_komputer', 'studi_kasus', 'jaringan_komputer', 'virtual_private', 'network_vpn', 'jaringan_komputer', 'studi_kasus', 'jaringan_komputer', 'virtual_private_network_vpn', 'jaringan_komputer', 'studi_kasus', 'jaringan_komputer'], ['analisis', 'qos', 'quality', 'service', 'jaringan', 'kampus', 'microtic', 'routerboard', 'quality_service', 'quality_service', 'quality_service'], ['model', 'average', 'fts', 'markov', 'chain', 'peramalan', 'penggunaan', 'bandwidth', 'jaringan', 'komputer', 'bandwidth_jaringan', 'bandwidth_jaringan', 'bandwidth_jaringan'], ['pengembangan', 'media', 'e', 'modul', 'mata', 'pelajaran', 'produktif', 'pokok', 'bahasan', 'instalasi', 'jaringan', 'lan', 'local', 'area', 'network', 'siswa', 'kelas', 'xi', 'jurusan', 'teknik', 'pengembangan_media', 'mata_pelajaran', 'pokok_bahasan', 'jaringan_lan', 'local_area', 'siswa_kelas', 'jurusan_teknik', 'pengembangan_media', 'mata_pelajaran', 'pokok_bahasan', 'jaringan_lan', 'local_area', 'siswa_kelas', 'jurusan_teknik', 'pengembangan_media', 'mata_pelajaran', 'pokok_bahasan', 'jaringan_lan', 'local_area', 'siswa_kelas', 'jurusan_teknik'], ['perangkat', 'pendukung', 'forensik', 'lalu', 'lintas', 'jaringan', 'lalu_lintas', 'lalu_lintas'], ['analisa', 'implementasi', 'jaringan', 'internet', 'menggabungkan', 'jaringan', 'lan', 'wlan', 'desa', 'kawangkoan', 'bawah', 'wilayah', 'amurang', 'ii', 'jaringan_lan', 'jaringan_internet', 'jaringan_lan', 'jaringan_lan'], ['analisa', 'quality', 'service', 'qos', 'jaringan', 'internet', 'kampus', 'studi', 'kasus', 'uin', 'suska', 'riau', 'quality_service', 'studi_kasus', 'uin_suska', 'quality_service', 'jaringan_internet', 'studi_kasus', 'quality_service', 'studi_kasus', 'uin_suska'], ['keamanan', 'jaringan', 'komputer', 'metode', 'blocking', 'port', 'laboratorium', 'komputer', 'program', 'diploma', 'iii', 'sistem', 'informasi', 'universitas', 'muhammadiyah', 'metro', 'keamanan_jaringan', 'laboratorium_komputer', 'universitas_muhammadiyah', 'keamanan_jaringan', 'laboratorium_komputer', 'sistem_informasi', 'universitas_muhammadiyah', 'keamanan_jaringan', 'laboratorium_komputer', 'universitas_muhammadiyah'], ['analisa', 'pemanfaatan', 'proxy', 'server', 'media', 'filtering', 'caching', 'jaringan', 'komputer', 'proxy_server', 'jaringan_komputer', 'proxy_server', 'jaringan_komputer', 'proxy_server', 'jaringan_komputer'], ['intrusion', 'detection', 'system', 'ids', 'metode', 'deteksi', 'port', 'scanning', 'jaringan', 'komputer', 'politeknik', 'negeri', 'semarang', 'intrusion_detection', 'system_ids', 'jaringan_komputer', 'politeknik_negeri', 'intrusion_detection', 'system_ids', 'jaringan_komputer', 'politeknik_negeri', 'intrusion_detection_system_ids', 'jaringan_komputer', 'politeknik_negeri'], ['pengaruh', 'promosi', 'online', 'persepsi', 'harga', 'keputusan', 'pembelian', 'survei', 'pelanggan', 'aryka', 'shop', 'kota', 'malang', 'keputusan_pembelian', 'kota_malang', 'keputusan_pembelian', 'kota_malang', 'keputusan_pembelian', 'kota_malang'], ['rancang', 'bangun', 'jaringan', 'komunikasi', 'voip', 'server', 'portable', 'raspberry', 'pi', 'rancang_bangun', 'raspberry_pi', 'rancang_bangun', 'rancang_bangun', 'raspberry_pi'], ['belajar', 'jaringan', 'komputer', 'mikrotik', 'os', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['sistem', 'penjualan', 'web', 'e', 'commerce', 'tata', 'distro', 'kabupaten', 'pacitan', 'e_commerce', 'e_commerce', 'e_commerce'], ['perancangan', 'jaringan', 'komputer', 'aplikasi', 'vhp', 'online', 'reporting', 'system', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['rancang', 'bangun', 'jaringan', 'hotspot', 'kampus', 'niversitas', 'nusantara', 'manado', 'router', 'mikrotik', 'rancang_bangun', 'rancang_bangun', 'jaringan_hotspot', 'rancang_bangun'], ['perancangan', 'implementasi', ...

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                   0             1              2             3   \
# 0             kajian       virtual        private       network
# 1           analisis           qos        quality       service
# 2              model       average            fts        markov
# 3       pengembangan         media              e         modul
# 4          perangkat     pendukung       forensik          lalu
# 5            analisa  implementasi       jaringan      internet
# 6            analisa       quality        service           qos
# 7           keamanan      jaringan       komputer        metode
# 8            analisa   pemanfaatan          proxy        server
# 9          intrusion     detection         system           ids
# 10          pengaruh       promosi         online      persepsi
# 11           rancang        bangun       jaringan    komunikasi
# 12           belajar      jaringan       komputer      mikrotik
# 13            sistem     penjualan            web             e
# 14       perancangan      jaringan       komputer      aplikasi
# 15           rancang        bangun       jaringan       hotspot
# 16       perancangan  implementasi       jaringan      komputer
# 17       efektifitas      wireless            lan            11
# 18       perancangan        sistem    otomatisasi        backup
# 19          simulasi      jaringan  multiprotocol         label
# 20          analisis        konsep           cara         kerja
# 21       perancangan  pengembangan         sistem     informasi
# 22      implementasi           vpn          akses        server
# 23      perbandingan        metode            pcq           sfq
# 24         teknologi            4g       jaringan           gsm
# 25             model  pembelajaran  konstruktivis          mata
# 26       perancangan  implementasi     instrusion     detection
# 27        kontribusi         minat        belajar             e
# 28          sniffing      spoofing          aspek      keamanan
# 29      optimalisasi    macromedia          flash     mendukung
# ...              ...           ...            ...           ...
# 9046             lkp     instalasi    konfigurasi      symantec
# 9047    implementasi     intrusion      detection        system
# 9048       intrusion     detection     prevention        system
# 9049        pengaruh         media   pembelajaran      internet
# 9050       engamanan          data  steganography        metode
# 9051       kejahatan     defecting          studi  perbandingan
# 9052        analisis       pattern       minutiae      matching
# 9053          faktor        faktor          china    mendirikan
# 9054     information    management         system       website
# 9055  mengoptimalkan        sistem       firewall      jaringan
# 9056    implementasi        sistem     pengamanan          data
# 9057      pencegahan       ancaman        reverse   engineering
# 9058    pengembangan     antivirus         client        server
# 9059          sistem     informasi      akuntansi    elektronik
# 9060     perancangan      aplikasi      pembuatan         kartu
# 9061        analisis       yuridis       mengenai         cyber
# 9062     pemanfaatan       sharing         folder   pengelolaan
# 9063          sanksi         hukum      kejahatan     peretasan
# 9064    rekapitulasi          data       keragaan      koperasi
# 9065        aplikasi        secure        message     algoritma
# 9066        aplikasi             e       commerce     penjualan
# 9067        pengaruh       layanan              e       banking
# 9068    pengembangan        sistem      informasi  administrasi
# 9069      segmentasi     pelanggan            som     algoritma
# 9070           dunia    komunikasi         gadget       evolusi
# 9071      kompetensi     teknologi      informasi     mahasiswa
# 9072       prosiding       seminar       nasional    matematika
# 9073      simulation         laser        thermal   interaction
# 9074         panduan       praktis        arduino        pemula
# 9075         program         studi     pendidikan        teknik
#
#                  4                  5                  6                  7   \
# 0               vpn             sistem         pengamanan               data
# 1          jaringan             kampus           microtic        routerboard
# 2             chain          peramalan         penggunaan          bandwidth
# 3              mata          pelajaran          produktif              pokok
# 4            lintas           jaringan        lalu_lintas        lalu_lintas
# 5     menggabungkan           jaringan                lan               wlan
# 6          jaringan           internet             kampus              studi
# 7          blocking               port       laboratorium           komputer
# 8             media          filtering            caching           jaringan
# 9            metode            deteksi               port           scanning
# 10            harga          keputusan          pembelian             survei
# 11             voip             server           portable          raspberry
# 12               os  jaringan_komputer  jaringan_komputer  jaringan_komputer
# 13         commerce               tata             distro          kabupaten
# 14              vhp             online          reporting             system
# 15           kampus         niversitas          nusantara             manado
# 16            studi              kasus                smk       muhammadiyah
# 17                b                  g             solusi           jaringan
# 18             data               file           transfer           protocol
# 19        switching               mpls          graphical            network
# 20         serangan           komputer        distributed             denial
# 21     perpustakaan                web              studi              kasus
# 22          melalui          perangkat             mobile           jaringan
# 23              red               fifo           mikrotik              upaya
# 24        kebutuhan             mobile           internet               kota
# 25        pelajaran           jaringan           komputer         berbantuan
# 26           system           jaringan        universitas         diponegoro
# 27         learning              media       pembelajaran              hasil
# 28         komputer               None               None               None
# 29     pembelajaran           komputer            program              studi
# ...             ...                ...                ...                ...
# 9046       endpoint         protection            manager             server
# 9047            ids              local               area            network
# 9048           idps              local               area            network
# 9049          media       konvensional            pretasi            belajar
# 9050          least        significant                bit            nielsen
# 9051         antara             undang             undang             itedan
# 9052    fingerprint                 jm             metode          biometrik
# 9053         online               blue               army          instrumen
# 9054         server        penetration            testing               case
# 9055          skala             global               None               None
# 9056         barang           matahari              putra              prima
# 9057         source               code                php             teknik
# 9058  client_server      client_server      client_server               None
# 9059        lembaga           keuangan              mikro            syariah
# 9060          tanda           penduduk        berbasiskan                web
# 9061         attack              cyber            warfare              hukum
# 9062          arsip          pertamina         geothermal             energy
# 9063        website           presiden           republik          indonesia
# 9064           None               None               None               None
# 9065            cr6            android               None               None
# 9066        keramik              studi              kasus               maha
# 9067       kepuasan            nasabah                bni            syariah
# 9068     pergerakan                sar          pengujian         usabilitas
# 9069              k              means           analisis               lrfm
# 9070           alat         komunikasi         menjelajah              jarak
# 9071        jurusan               ilmu       perpustakaan           fakultas
# 9072          sains        informatika        saintekinfo              fmipa
# 9073           with           titanium            dioxide          polyvinyl
# 9074           None               None               None               None
# 9075    informatika           fakultas             teknik        universitas
#
#                        8                       9        ...        \
# 0                jaringan                komputer       ...
# 1         quality_service         quality_service       ...
# 2                jaringan                komputer       ...
# 3                 bahasan               instalasi       ...
# 4                    None                    None       ...
# 5                    desa              kawangkoan       ...
# 6                   kasus                     uin       ...
# 7                 program                 diploma       ...
# 8                komputer            proxy_server       ...
# 9                jaringan                komputer       ...
# 10              pelanggan                   aryka       ...
# 11                     pi          rancang_bangun       ...
# 12                   None                    None       ...
# 13                pacitan              e_commerce       ...
# 14      jaringan_komputer       jaringan_komputer       ...
# 15                 router                mikrotik       ...
# 16                 sragen       jaringan_komputer       ...
# 17                 kampus                   studi       ...
# 18               jaringan                     lan       ...
# 19              simulator                    gns3       ...
# 20                service                    ddos       ...
# 21                jurusan                  sistem       ...
# 22               komputer                     smk       ...
# 23           optimalisasi                 layanan       ...
# 24             yogyakarta         kota_yogyakarta       ...
# 25                  modul                    ajar       ...
# 26       detection_system  universitas_diponegoro       ...
# 27                belajar                   siswa       ...
# 28                   None                    None       ...
# 29                   ilmu                komputer       ...
# ...                   ...                     ...       ...
# 9046                 None                    None       ...
# 9047                  lan                    smkn       ...
# 9048                  lan     intrusion_detection       ...
# 9049                siswa                   kelas       ...
# 9050              company               indonesia       ...
# 9051                hukum                  pidana       ...
# 9052                 None                    None       ...
# 9053                cyber                security       ...
# 9054           university       management_system       ...
# 9055                 None                    None       ...
# 9056                  tbk                    None       ...
# 9057          obfuscation                    code       ...
# 9058                 None                    None       ...
# 9059  informasi_akuntansi        sistem_informasi       ...
# 9060                kodya                  bekasi       ...
# 9061            humaniter           internasional       ...
# 9062                 area               lahendong       ...
# 9063                 None                    None       ...
# 9064                 None                    None       ...
# 9065                 None                    None       ...
# 9066             kramindo                 perkasa       ...
# 9067               cabang                pembantu       ...
# 9068           pendekatan              technology       ...
# 9069           penyusunan             rekomendasi       ...
# 9070               gadget                    None       ...
# 9071                 adab               humaniora       ...
# 9072                  uns                   april       ...
# 9073              alcohol           nanocomposite       ...
# 9074                 None                    None       ...
# 9075               negeri              yogyakarta       ...
#
#                       31                         32              33  \
# 0                   None                       None            None
# 1                   None                       None            None
# 2                   None                       None            None
# 3             local_area                siswa_kelas  jurusan_teknik
# 4                   None                       None            None
# 5                   None                       None            None
# 6                   None                       None            None
# 7                   None                       None            None
# 8                   None                       None            None
# 9                   None                       None            None
# 10                  None                       None            None
# 11                  None                       None            None
# 12                  None                       None            None
# 13                  None                       None            None
# 14                  None                       None            None
# 15                  None                       None            None
# 16                  None                       None            None
# 17                  None                       None            None
# 18                  None                       None            None
# 19                  None                       None            None
# 20                  None                       None            None
# 21                  None                       None            None
# 22                  None                       None            None
# 23                  None                       None            None
# 24                  None                       None            None
# 25            smk_negeri                       None            None
# 26                  None                       None            None
# 27    media_pembelajaran  hasil_belajar_siswa_kelas  jurusan_teknik
# 28                  None                       None            None
# 29                  None                       None            None
# ...                  ...                        ...             ...
# 9046                None                       None            None
# 9047                None                       None            None
# 9048                None                       None            None
# 9049                None                       None            None
# 9050                None                       None            None
# 9051                None                       None            None
# 9052                None                       None            None
# 9053                None                       None            None
# 9054                None                       None            None
# 9055                None                       None            None
# 9056                None                       None            None
# 9057                None                       None            None
# 9058                None                       None            None
# 9059                None                       None            None
# 9060                None                       None            None
# 9061                None                       None            None
# 9062                None                       None            None
# 9063                None                       None            None
# 9064                None                       None            None
# 9065                None                       None            None
# 9066                None                       None            None
# 9067                None                       None            None
# 9068                None                       None            None
# 9069                None                       None            None
# 9070                None                       None            None
# 9071                None                       None            None
# 9072                None                       None            None
# 9073                None                       None            None
# 9074                None                       None            None
# 9075                None                       None            None
#
#                       34              35             36            37  \
# 0                   None            None           None          None
# 1                   None            None           None          None
# 2                   None            None           None          None
# 3     pengembangan_media  mata_pelajaran  pokok_bahasan  jaringan_lan
# 4                   None            None           None          None
# 5                   None            None           None          None
# 6                   None            None           None          None
# 7                   None            None           None          None
# 8                   None            None           None          None
# 9                   None            None           None          None
# 10                  None            None           None          None
# 11                  None            None           None          None
# 12                  None            None           None          None
# 13                  None            None           None          None
# 14                  None            None           None          None
# 15                  None            None           None          None
# 16                  None            None           None          None
# 17                  None            None           None          None
# 18                  None            None           None          None
# 19                  None            None           None          None
# 20                  None            None           None          None
# 21                  None            None           None          None
# 22                  None            None           None          None
# 23                  None            None           None          None
# 24                  None            None           None          None
# 25                  None            None           None          None
# 26                  None            None           None          None
# 27            smk_negeri            None           None          None
# 28                  None            None           None          None
# 29                  None            None           None          None
# ...                  ...             ...            ...           ...
# 9046                None            None           None          None
# 9047                None            None           None          None
# 9048                None            None           None          None
# 9049                None            None           None          None
# 9050                None            None           None          None
# 9051                None            None           None          None
# 9052                None            None           None          None
# 9053                None            None           None          None
# 9054                None            None           None          None
# 9055                None            None           None          None
# 9056                None            None           None          None
# 9057                None            None           None          None
# 9058                None            None           None          None
# 9059                None            None           None          None
# 9060                None            None           None          None
# 9061                None            None           None          None
# 9062                None            None           None          None
# 9063                None            None           None          None
# 9064                None            None           None          None
# 9065                None            None           None          None
# 9066                None            None           None          None
# 9067                None            None           None          None
# 9068                None            None           None          None
# 9069                None            None           None          None
# 9070                None            None           None          None
# 9071                None            None           None          None
# 9072                None            None           None          None
# 9073                None            None           None          None
# 9074                None            None           None          None
# 9075                None            None           None          None
#
#               38           39              40
# 0           None         None            None
# 1           None         None            None
# 2           None         None            None
# 3     local_area  siswa_kelas  jurusan_teknik
# 4           None         None            None
# 5           None         None            None
# 6           None         None            None
# 7           None         None            None
# 8           None         None            None
# 9           None         None            None
# 10          None         None            None
# 11          None         None            None
# 12          None         None            None
# 13          None         None            None
# 14          None         None            None
# 15          None         None            None
# 16          None         None            None
# 17          None         None            None
# 18          None         None            None
# 19          None         None            None
# 20          None         None            None
# 21          None         None            None
# 22          None         None            None
# 23          None         None            None
# 24          None         None            None
# 25          None         None            None
# 26          None         None            None
# 27          None         None            None
# 28          None         None            None
# 29          None         None            None
# ...          ...          ...             ...
# 9046        None         None            None
# 9047        None         None            None
# 9048        None         None            None
# 9049        None         None            None
# 9050        None         None            None
# 9051        None         None            None
# 9052        None         None            None
# 9053        None         None            None
# 9054        None         None            None
# 9055        None         None            None
# 9056        None         None            None
# 9057        None         None            None
# 9058        None         None            None
# 9059        None         None            None
# 9060        None         None            None
# 9061        None         None            None
# 9062        None         None            None
# 9063        None         None            None
# 9064        None         None            None
# 9065        None         None            None
# 9066        None         None            None
# 9067        None         None            None
# 9068        None         None            None
# 9069        None         None            None
# 9070        None         None            None
# 9071        None         None            None
# 9072        None         None            None
# 9073        None         None            None
# 9074        None         None            None
# 9075        None         None            None
#
# [9076 rows x 41 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(11680 unique tokens: ['data', 'jaringan', 'jaringan_komputer', 'kajian', 'kasus']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 9076

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=6)
pprint(model.print_topics())

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=6)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-2015.html')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model2015.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned2017.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                     text
# 0      manajemen jaringan komputer mikrotik router co...
# 1      rancang bangun keamanan jaringan wireless stip...
# 2      asesmen otentik pendukung desain instruksional...
# 3      implementasi intrusion detection system rule s...
# 4      pengembangan sistem pengamanan jaringan komput...
# 5      simulasi alat bantu pembelajaran topologi jari...
# 6      quality service jaringan internet metode hiera...
# 7      pemanfaatan telegram notifikasi serangan keper...
# 8      konfigurasi server cloud storage jaringan lan ...
# 9      implementasi controller access point system ma...
# 10     aplikasi e commerce web mobile industri konvek...
# 11     membangun aplikasi e library html php script m...
# 12     simulasi perancangan sistem jaringan inter vla...
# 13        optimasi jaringan local area network vlan voip
# 14     perancangan e commerce penjualan komputer alat...
# 15     zabbix network monitoring perangkat monitoring...
# 16     aplikasi pemantau perangkat jaringan web proto...
# 17     evaluasi jaringan internet perguruan tinggi sw...
# 18     evaluasi kualitas aplikasi mobile kamus istila...
# 19     implementasi mikrotik router board firewall bl...
# 20     simulasi jaringan virtual local area network v...
# 21           penggunaan internet media baru pembelajaran
# 22       aplikasi monitoring akses shutdown komputer sms
# 23     voice over internet protocol voip jaringan nir...
# 24     analisis kinerja teknologi jaringan wireless f...
# 25     sistem kriptografi citra digital jaringan intr...
# 26        implementasi monitoring jaringan komputer dude
# 27     perancangan implementasi e commerce penjualan ...
# 28     efisiensi maintenance laboratorium komputer ja...
# 29     virtualisasi router metarouter mikrotik studi ...
# ...                                                  ...
# 10234  pengaruh lingkungan kerja pemberian insentif k...
# 10235  upaya perlindungan hukum konsumen transaksi e ...
# 10236  implementasi one time password mobile token al...
# 10237   pengembangan web online shop butik azzalea store
# 10238  analisis laporan keuangan menilai kinerja mana...
# 10239          laporan pengabdian masyarakat ganjil 2018
# 10240  analisa manajemen bandwidth mkrotik departemen...
# 10241  implementasi hybrid cryptosystem algoritma aff...
# 10242      rancang bangun kendali off lampu raspberry pi
# 10243  tinjauan steganography layanan voip voice over...
# 10244  budaya cari untung pemicu terjadinya fraud seb...
# 10245  sistem pengujian kadar logam berat krom vi air...
# 10246  pengujian kepuasan sistem informasi end user c...
# 10247  peran e satisfaction e trust pengembangan e lo...
# 10248  implementasi kriptografi hybrid algoritma one ...
# 10249  kajian mengenai kepuasan nasabah bank syariah ...
# 10250             tingkat kecanduan internet remaja awal
# 10251  analisis wacana cyberwar artikel situs kompasiana
# 10252  kebijakan integral hukum pidana techno prevent...
# 10253             mata kuliah sistem informasi kesehatan
# 10254  pengaruh kapasitas sumber daya manusia pemanfa...
# 10255  perlindungan hukum nasabah bankpengguna intern...
# 10256  sanksi pidanan tindak pidana judi bola online ...
# 10257  dashboard monitoring system web pemantau layan...
# 10258  hubungan self efficacy perilaku penemuan infor...
# 10259  naskah akademik rancangan pengembangan kelemba...
# 10260  pengaruh internet mahasiswa studi tim sepak bo...
# 10261  analisa strategi implementasi green computing ...
# 10262  peran pemerintah daerah menjamin ketertiban um...
# 10263  ternyata mendidik anak cara rasulullah mudah e...
#
# [10264 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 10264
# [['manajemen', 'jaringan', 'komputer', 'mikrotik', 'router', 'computer', 'network', 'management', 'used', 'with', 'microtic', 'router']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# [['manajemen', 'jaringan', 'komputer', 'mikrotik', 'router', 'computer', 'network', 'management', 'used', 'with', 'microtic', 'router', 'jaringan_komputer', 'mikrotik_router', 'jaringan_komputer', 'mikrotik_router', 'jaringan_komputer', 'mikrotik_router'], ['rancang', 'bangun', 'keamanan', 'jaringan', 'wireless', 'stiper', 'sriwigama', 'palembang', 'radius', 'server', 'rancang_bangun', 'keamanan_jaringan', 'rancang_bangun', 'keamanan_jaringan', 'rancang_bangun', 'keamanan_jaringan'], ['asesmen', 'otentik', 'pendukung', 'desain', 'instruksional', 'jaringan', 'komputer', 'berstrategi', 'blended', 'learning', 'pendekatan', 'konstruktivistik', 'jaringan_komputer', 'blended_learning', 'jaringan_komputer', 'jaringan_komputer', 'blended_learning'], ['implementasi', 'intrusion', 'detection', 'system', 'rule', 'system', 'sniffer', 'mode', 'jaringan', 'lokal', 'intrusion_detection', 'intrusion_detection', 'rule_system', 'intrusion_detection'], ['pengembangan', 'sistem', 'pengamanan', 'jaringan', 'komputer', 'analisis', 'forensik', 'jaringan', 'jaringan_komputer', 'jaringan_komputer', 'forensik_jaringan', 'jaringan_komputer'], ['simulasi', 'alat', 'bantu', 'pembelajaran', 'topologi', 'jaringan', 'visual', 'alat_bantu', 'alat_bantu', 'topologi_jaringan', 'alat_bantu'], ['quality', 'service', 'jaringan', 'internet', 'metode', 'hierarchical', 'token', 'bucket', 'quality_service', 'jaringan_internet', 'hierarchical_token', 'quality_service', 'jaringan_internet', 'hierarchical_token', 'quality_service', 'jaringan_internet', 'hierarchical_token'], ['pemanfaatan', 'telegram', 'notifikasi', 'serangan', 'keperluan', 'forensik', 'jaringan', 'forensik_jaringan'], ['konfigurasi', 'server', 'cloud', 'storage', 'jaringan', 'lan', 'lab', 'diploma', 'iii', 'manajemen', 'informatika', 'um', 'metro', 'server_cloud', 'manajemen_informatika', 'server_cloud', 'jaringan_lan', 'manajemen_informatika', 'server_cloud', 'manajemen_informatika'], ['implementasi', 'controller', 'access', 'point', 'system', 'manager', 'capsman', 'wireless', 'distribution', 'system', 'wds', 'jaringan', 'wireless', 'smk', 'terpadu', 'al', 'ishlahiyah', 'access_point', 'wireless_distribution', 'jaringan_wireless', 'access_point', 'wireless_distribution', 'jaringan_wireless', 'access_point', 'wireless_distribution', 'jaringan_wireless'], ['aplikasi', 'e', 'commerce', 'web', 'mobile', 'industri', 'konveksi', 'seragam', 'drumband', 'pekon', 'klaten', 'gadingrejo', 'kabupaten', 'pringsewu', 'e_commerce', 'kabupaten_pringsewu', 'e_commerce', 'kabupaten_pringsewu', 'e_commerce', 'kabupaten_pringsewu'], ['membangun', 'aplikasi', 'e', 'library', 'html', 'php', 'script', 'mysql', 'database', 'e_library', 'e_library', 'e_library'], ['simulasi', 'perancangan', 'sistem', 'jaringan', 'inter', 'vlan', 'routing', 'universitas', 'negeri', 'medan', 'universitas_negeri', 'universitas_negeri', 'universitas_negeri'], ['optimasi', 'jaringan', 'local', 'area', 'network', 'vlan', 'voip', 'local_area', 'network_vlan', 'local_area', 'local_area', 'network_vlan'], ['perancangan', 'e', 'commerce', 'penjualan', 'komputer', 'alat', 'elektronik', 'web', 'toko', 'damar', 'komputer', 'pringsewu', 'e_commerce', 'e_commerce', 'e_commerce'], ['zabbix', 'network', 'monitoring', 'perangkat', 'monitoring', 'jaringan', 'skpd', 'kota', 'malang', 'kota_malang', 'kota_malang', 'kota_malang'], ['aplikasi', 'pemantau', 'perangkat', 'jaringan', 'web', 'protokol', 'snmp', 'notifikasi', 'sms'], ['evaluasi', 'jaringan', 'internet', 'perguruan', 'tinggi', 'swasta', 'kota', 'palembang', 'jaringan_internet', 'perguruan_tinggi', 'kota_palembang', 'jaringan_internet', 'perguruan_tinggi', 'kota_palembang', 'jaringan_internet', 'perguruan_tinggi', 'kota_palembang'], ['evaluasi', 'kualitas', 'aplikasi', 'mobile', 'kamus', 'istilah', 'jaringan', 'platform', 'android', 'standar', 'iso', 'iec', 'kamus_istilah', 'platform_android', 'iso_iec', 'platform_android', 'kamus_istilah', 'platform_android', 'iso_iec'], ['implementasi', 'mikrotik', 'rout ...

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                  0              1             2             3              4   \
# 0         manajemen       jaringan      komputer      mikrotik         router
# 1           rancang         bangun      keamanan      jaringan       wireless
# 2           asesmen        otentik     pendukung        desain  instruksional
# 3      implementasi      intrusion     detection        system           rule
# 4      pengembangan         sistem    pengamanan      jaringan       komputer
# 5          simulasi           alat         bantu  pembelajaran       topologi
# 6           quality        service      jaringan      internet         metode
# 7       pemanfaatan       telegram    notifikasi      serangan      keperluan
# 8       konfigurasi         server         cloud       storage       jaringan
# 9      implementasi     controller        access         point         system
# 10         aplikasi              e      commerce           web         mobile
# 11        membangun       aplikasi             e       library           html
# 12         simulasi    perancangan        sistem      jaringan          inter
# 13         optimasi       jaringan         local          area        network
# 14      perancangan              e      commerce     penjualan       komputer
# 15           zabbix        network    monitoring     perangkat     monitoring
# 16         aplikasi       pemantau     perangkat      jaringan            web
# 17         evaluasi       jaringan      internet     perguruan         tinggi
# 18         evaluasi       kualitas      aplikasi        mobile          kamus
# 19     implementasi       mikrotik        router         board       firewall
# 20         simulasi       jaringan       virtual         local           area
# 21       penggunaan       internet         media          baru   pembelajaran
# 22         aplikasi     monitoring         akses      shutdown       komputer
# 23            voice           over      internet      protocol           voip
# 24         analisis        kinerja     teknologi      jaringan       wireless
# 25           sistem    kriptografi         citra       digital       jaringan
# 26     implementasi     monitoring      jaringan      komputer           dude
# 27      perancangan   implementasi             e      commerce      penjualan
# 28        efisiensi    maintenance  laboratorium      komputer       jaringan
# 29     virtualisasi         router    metarouter      mikrotik          studi
# ...             ...            ...           ...           ...            ...
# 10234      pengaruh     lingkungan         kerja     pemberian       insentif
# 10235         upaya   perlindungan         hukum      konsumen      transaksi
# 10236  implementasi            one          time      password         mobile
# 10237  pengembangan            web        online          shop          butik
# 10238      analisis        laporan      keuangan       menilai        kinerja
# 10239       laporan     pengabdian    masyarakat        ganjil           2018
# 10240       analisa      manajemen     bandwidth       mkrotik    departement
# 10241  implementasi         hybrid  cryptosystem     algoritma         affine
# 10242       rancang         bangun       kendali           off          lampu
# 10243      tinjauan  steganography       layanan          voip          voice
# 10244        budaya           cari        untung        pemicu     terjadinya
# 10245        sistem      pengujian         kadar         logam          berat
# 10246     pengujian       kepuasan        sistem     informasi            end
# 10247         peran              e  satisfaction             e          trust
# 10248  implementasi    kriptografi        hybrid     algoritma            one
# 10249        kajian       mengenai      kepuasan       nasabah           bank
# 10250       tingkat      kecanduan      internet        remaja           awal
# 10251      analisis         wacana      cyberwar       artikel          situs
# 10252     kebijakan       integral         hukum        pidana         techno
# 10253          mata         kuliah        sistem     informasi      kesehatan
# 10254      pengaruh      kapasitas        sumber          daya        manusia
# 10255  perlindungan          hukum       nasabah  bankpengguna       internet
# 10256        sanksi        pidanan        tindak        pidana           judi
# 10257     dashboard     monitoring        system           web       pemantau
# 10258      hubungan           self      efficacy      perilaku       penemuan
# 10259        naskah       akademik     rancangan  pengembangan    kelembagaan
# 10260      pengaruh       internet     mahasiswa         studi            tim
# 10261       analisa       strategi  implementasi         green      computing
# 10262         peran     pemerintah        daerah      menjamin     ketertiban
# 10263      ternyata       mendidik          anak          cara     rasulullah
#
#                              5                      6                      7   \
# 0                      computer                network             management
# 1                        stiper              sriwigama              palembang
# 2                      jaringan               komputer            berstrategi
# 3                        system                sniffer                   mode
# 4                      analisis               forensik               jaringan
# 5                      jaringan                 visual             alat_bantu
# 6                  hierarchical                  token                 bucket
# 7                      forensik               jaringan      forensik_jaringan
# 8                           lan                    lab                diploma
# 9                       manager                capsman               wireless
# 10                     industri               konveksi                seragam
# 11                          php                 script                  mysql
# 12                         vlan                routing            universitas
# 13                         vlan                   voip             local_area
# 14                         alat             elektronik                    web
# 15                     jaringan                   skpd                   kota
# 16                     protokol                   snmp             notifikasi
# 17                       swasta                   kota              palembang
# 18                      istilah               jaringan               platform
# 19                         blok                  situs               jaringan
# 20                      network                   vlan                    pox
# 21          penggunaan_internet                   None                   None
# 22                          sms                   None                   None
# 23                     jaringan               nirkabel              raspberry
# 24                    frekuensi                      4                    ghz
# 25                     intranet                 metode              kombinasi
# 26            jaringan_komputer      jaringan_komputer      jaringan_komputer
# 27                         baju                 online                android
# 28        laboratorium_komputer  laboratorium_komputer  laboratorium_komputer
# 29                        kasus           laboratorium               jaringan
# ...                         ...                    ...                    ...
# 10234                  kepuasan                  kerja                perawat
# 10235                         e               commerce              mendukung
# 10236                     token              algoritma                 secure
# 10237                   azzalea                  store            online_shop
# 10238                 manajemen         telekomunikasi              indonesia
# 10239     pengabdian_masyarakat  pengabdian_masyarakat                   None
# 10240              radiotherapy                  rumah                  sakit
# 10241                    cipher              algoritma                    luc
# 10242                 raspberry                     pi         rancang_bangun
# 10243                      over               internet               protocol
# 10244                     fraud                 sebuah                  studi
# 10245                      krom                     vi                    air
# 10246                      user              computing           satisfaction
# 10247              pengembangan                      e                loyalty
# 10248                      time                    pad                    otp
# 10249                   syariah                   kota               makassar
# 10250                      None                   None                   None
# 10251                kompasiana                   None                   None
# 10252                prevention                  upaya             pencegahan
# 10253               mata_kuliah            mata_kuliah       sistem_informasi
# 10254               pemanfaatan              teknologi              informasi
# 10255  bankingterhadapkejahatan                    ite     perlindungan_hukum
# 10256                      bola                 online                 tindak
# 10257                   layanan                litebig                instant
# 10258                 informasi                  studi            eksplanatif
# 10259               kementerian             komunikasi            informatika
# 10260                     sepak                   bola                    mon
# 10261                 perguruan                 tinggi       perguruan_tinggi
# 10262                      umum           perlindungan           pengembangan
# 10263                     mudah                efektif                   None
#
#                            8                   9   ...     28    29    30  \
# 0                        used                with  ...   None  None  None
# 1                      radius              server  ...   None  None  None
# 2                     blended            learning  ...   None  None  None
# 3                    jaringan               lokal  ...   None  None  None
# 4           jaringan_komputer   jaringan_komputer  ...   None  None  None
# 5                  alat_bantu   topologi_jaringan  ...   None  None  None
# 6             quality_service   jaringan_internet  ...   None  None  None
# 7                        None                None  ...   None  None  None
# 8                         iii           manajemen  ...   None  None  None
# 9                distribution              system  ...   None  None  None
# 10                   drumband               pekon  ...   None  None  None
# 11                   database           e_library  ...   None  None  None
# 12                     negeri               medan  ...   None  None  None
# 13               network_vlan          local_area  ...   None  None  None
# 14                       toko               damar  ...   None  None  None
# 15                     malang         kota_malang  ...   None  None  None
# 16                        sms                None  ...   None  None  None
# 17          jaringan_internet    perguruan_tinggi  ...   None  None  None
# 18                    android             standar  ...   None  None  None
# 19                        lan     mikrotik_router  ...   None  None  None
# 20                 controller       virtual_local  ...   None  None  None
# 21                       None                None  ...   None  None  None
# 22                       None                None  ...   None  None  None
# 23                         pi   jaringan_nirkabel  ...   None  None  None
# 24                    kondisi             ruangan  ...   None  None  None
# 25                      chaos                 map  ...   None  None  None
# 26                       None                None  ...   None  None  None
# 27                 e_commerce          e_commerce  ...   None  None  None
# 28                       None                None  ...   None  None  None
# 29                   komputer          politeknik  ...   None  None  None
# ...                       ...                 ...  ...    ...   ...   ...
# 10234                   rumah               sakit  ...   None  None  None
# 10235             pertumbuhan             ekonomi  ...   None  None  None
# 10236                    hash           algorithm  ...   None  None  None
# 10237             online_shop                None  ...   None  None  None
# 10238                     tbk    laporan_keuangan  ...   None  None  None
# 10239                    None                None  ...   None  None  None
# 10240     manajemen_bandwidth         rumah_sakit  ...   None  None  None
# 10241              pengamanan                file  ...   None  None  None
# 10242            raspberry_pi      rancang_bangun  ...   None  None  None
# 10243                    None                None  ...   None  None  None
# 10244               etnografi                None  ...   None  None  None
# 10245                  sensor              cahaya  ...   None  None  None
# 10246                   studi               kasus  ...   None  None  None
# 10247               pembelian              online  ...   None  None  None
# 10248               algoritma              micali  ...   None  None  None
# 10249           kota_makassar                None  ...   None  None  None
# 10250                    None                None  ...   None  None  None
# 10251                    None                None  ...   None  None  None
# 10252               kejahatan       cyberbullying  ...   None  None  None
# 10253             mata_kuliah                None  ...   None  None  None
# 10254            pengendalian              intern  ...   None  None  None
# 10255      perlindungan_hukum  perlindungan_hukum  ...   None  None  None
# 10256                  pidana               cyber  ...   None  None  None
# 10257               messenger   instant_messenger  ...   None  None  None
# 10258                 tentang            hubungan  ...   None  None  None
# 10259  komunikasi_informatika                None  ...   None  None  None
# 10260                   malem          sepak_bola  ...   None  None  None
# 10261        perguruan_tinggi    perguruan_tinggi  ...   None  None  None
# 10262               investasi               studi  ...   None  None  None
# 10263                    None                None  ...   None  None  None
#
#          31    32    33    34    35    36    37
# 0      None  None  None  None  None  None  None
# 1      None  None  None  None  None  None  None
# 2      None  None  None  None  None  None  None
# 3      None  None  None  None  None  None  None
# 4      None  None  None  None  None  None  None
# 5      None  None  None  None  None  None  None
# 6      None  None  None  None  None  None  None
# 7      None  None  None  None  None  None  None
# 8      None  None  None  None  None  None  None
# 9      None  None  None  None  None  None  None
# 10     None  None  None  None  None  None  None
# 11     None  None  None  None  None  None  None
# 12     None  None  None  None  None  None  None
# 13     None  None  None  None  None  None  None
# 14     None  None  None  None  None  None  None
# 15     None  None  None  None  None  None  None
# 16     None  None  None  None  None  None  None
# 17     None  None  None  None  None  None  None
# 18     None  None  None  None  None  None  None
# 19     None  None  None  None  None  None  None
# 20     None  None  None  None  None  None  None
# 21     None  None  None  None  None  None  None
# 22     None  None  None  None  None  None  None
# 23     None  None  None  None  None  None  None
# 24     None  None  None  None  None  None  None
# 25     None  None  None  None  None  None  None
# 26     None  None  None  None  None  None  None
# 27     None  None  None  None  None  None  None
# 28     None  None  None  None  None  None  None
# 29     None  None  None  None  None  None  None
# ...     ...   ...   ...   ...   ...   ...   ...
# 10234  None  None  None  None  None  None  None
# 10235  None  None  None  None  None  None  None
# 10236  None  None  None  None  None  None  None
# 10237  None  None  None  None  None  None  None
# 10238  None  None  None  None  None  None  None
# 10239  None  None  None  None  None  None  None
# 10240  None  None  None  None  None  None  None
# 10241  None  None  None  None  None  None  None
# 10242  None  None  None  None  None  None  None
# 10243  None  None  None  None  None  None  None
# 10244  None  None  None  None  None  None  None
# 10245  None  None  None  None  None  None  None
# 10246  None  None  None  None  None  None  None
# 10247  None  None  None  None  None  None  None
# 10248  None  None  None  None  None  None  None
# 10249  None  None  None  None  None  None  None
# 10250  None  None  None  None  None  None  None
# 10251  None  None  None  None  None  None  None
# 10252  None  None  None  None  None  None  None
# 10253  None  None  None  None  None  None  None
# 10254  None  None  None  None  None  None  None
# 10255  None  None  None  None  None  None  None
# 10256  None  None  None  None  None  None  None
# 10257  None  None  None  None  None  None  None
# 10258  None  None  None  None  None  None  None
# 10259  None  None  None  None  None  None  None
# 10260  None  None  None  None  None  None  None
# 10261  None  None  None  None  None  None  None
# 10262  None  None  None  None  None  None  None
# 10263  None  None  None  None  None  None  None
#
# [10264 rows x 38 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(12855 unique tokens: ['computer', 'jaringan', 'jaringan_komputer', 'komputer', 'management']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 10264

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=16)
pprint(model.print_topics())

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=16)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-2017.html')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model2017.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

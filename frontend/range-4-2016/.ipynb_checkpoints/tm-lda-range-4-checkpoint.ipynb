# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned-range4.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                                                                      text
# 0                                                         cara mudah membangun jaringan komputer internet
# 1                                                                                jaringan komputer tcp ip
# 2                              parallel programming teknik aplikasi jaringan workstation komputer paralel
# 3                                                                        tip jitu optimasi jaringan wi fi
# 4                                                     pengembangan media pembelajaran teknologi informasi
# 5                                       autentikasi kendali akses audit sistem keamanan jaringan komputer
# 6                                                                            cisco ccna jaringan komputer
# 7                                                       koneksi jaringan antar sekolah teknologi wireless
# 8     analisis tingkat penggunaan internet dikalangan mahasiswa hubungannya peningkatan nilai akademik...
# 9     implementasi intrusion detection system ids snort laboratorium jaringan komputer lepkom universi...
# 10                                     rancang bangun analisa qos audio video streaming jaringan mpls vpn
# 11                                                            analisa qos jaringan mpls ipv6 routing ospf
# 12    monitoring sistem kerja pengembangan jaringan komputer networking rumah sakit dr moewardi reside...
# 13                      langsung praktik mengelola jaringan lebih efektif efisien linux fedora windows xp
# 14                                  studi implementasi voip sip jaringan kampus universitas sam ratulangi
# 15                                                        cara mudah membangun jaringan komputer internet
# 16                                                                    desain standar perpustakaan digital
# 17                                                                     panduan praktis menguasai komputer
# 18                                                    merakit sendiri komputer tahan banting modal jutaan
# 19           analisis perancangan sistem komputerisasi jaringan komunikasi data radio karysma fm boyolali
# 20                                   optimasi routing pengaturan route advertisement jaringan mobile ipv6
# 21     perancangan sistem keamanan jaringan komputer snort intrussion detection system ip tables firewall
# 22                                                                        sistem jaringan komputer pemula
# 23                                                           bahasa pemrograman python platform gnu linux
# 24                                                                     optimasi bandwith traffic shapping
# 25                                       rancang bangun sistem pencegahan data flooding jaringan komputer
# 26                                                        cara mudah membangun jaringan komputer internet
# 27                                   cara jitu pengelolaan jaringan windows remote desktop administration
# 28                                                       membangun software monitoring jaringan sms alert
# 29            implementasi sistem autentikasi jaringan hotspot universitas udayana open source freeradius
# ...                                                                                                   ...
# 4881                       fuzzy logic diagnosis tata laksana penyakit demam berdarah dengue demam tifoid
# 4882                     pengaruh model problem learning pbl hasil belajar kimia siswa konsep laju reaksi
# 4883  pengaruh pertisipasi anggaran kinerja manajerial gaya kepemimpinan iklim organisasi variabel mod...
# 4884     adopsi e commerce pendekatan technology acceptance model tam ukm studi kasus ukm kota solo tahun
# 4885  advertising board djarum super analisis deskriptif kualitatif tv value advertising board djarum ...
# 4886  eksplorasi metode bar chart cpm pdm pert line balance time chainage diagram penjadwalan proyek k...
# 4887  sistem pendukung keputusan pemilihan supplier obat metode electre elimination et choix traduisan...
# 4888                                  analisa perancangan e marketing studi kasus bajaj persada nusantara
# 4889        analisa perancangan sistem informasi pengelolaan biaya proyek konstruksi metode cost schedule
# 4890        e learning penunjang pembelajaran konvensional pokok bahasan listrik dinamis kelas x sma yppi
# 4891  sistem informasi monitoring korosi pipa minyak web studi kasus stasiun rawa conocophilips indone...
# 4892  pengaruh faktor demografi personality stres kerja penggunaan sistem informasi komputer kinerja k...
# 4893  pembuatan aplikasi digital library studi kasus perpustakaan sains teknologi universitas islam ne...
# 4894                                                                 sistem informasi manajemen buku ajar
# 4895  pengaruh partisipasi penganggaran kinerja aparat integrasi variabel intervening variabel moderat...
# 4896  efektivitas pembelajaran kontekstual kemampuan menyelesaikan soal aljabar soal cerita ditinjau gaya
# 4897                       analisis efisiensi koperasi pegawai negeri republik indonesia kabupaten klaten
# 4898                                           pemberdayaan sekolah menengah kejuruan smk melalui smm iso
# 4899  pelaksanaan kurikulum tingkat satuan pendidikan prestasi belajar siswa smk negeri i sragen tahun...
# 4900                         revitalisasi benteng vastenburg surakarta pusat seni museum seni kontemporer
# 4901                   identifikasi bakat siswa sekolah dasar negeri se kecamatan ngemplak boyolali tahun
# 4902  analisisi model simple criteria optimal portofolioselection scops pembentukan portofolio optimal...
# 4903        pembuatan aplikasi penyebaran informasi short message service sms lingkungan program studi ti
# 4904  pembelajaran fisika masalah melalui metode proyek pemberian tugas ditinjau gaya berpikir kreativ...
# 4905  pengaruh service quality satisfaction expertise costumer loyalty studi peserta didik lembaga pen...
# 4906          pengaruh total quality management kinerja manajerial empiris manajer perhotelan dipekanbaru
# 4907                                              lokalitas televisi lokal menonton orang ngapak jogja tv
# 4908        pembelajaran fisika metode demonstrasi melalui pendekatan quantum ketrampilan proses ditinjau
# 4909   analisis efisiensi bank bumn bank swasta setelah merger tinjauan bank mandiri tbk bank permata tbk
# 4910              puppet show inovasi metode pengajaran bahasa inggris upaya kemampuan berbicara siswa sd
#
# [4911 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 4911
# [['cara', 'mudah', 'membangun', 'jaringan', 'komputer', 'internet']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# [['cara', 'mudah', 'membangun', 'jaringan', 'komputer', 'internet', 'cara_mudah', 'membangun_jaringan', 'cara_mudah', 'membangun_jaringan', 'cara_mudah', 'membangun_jaringan'], ['jaringan', 'komputer', 'tcp', 'ip', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['parallel', 'programming', 'teknik', 'aplikasi', 'jaringan', 'workstation', 'komputer', 'paralel'], ['tip', 'jitu', 'optimasi', 'jaringan', 'wi', 'fi'], ['pengembangan', 'media', 'pembelajaran', 'teknologi', 'informasi', 'media_pembelajaran', 'teknologi_informasi', 'media_pembelajaran', 'teknologi_informasi', 'media_pembelajaran', 'teknologi_informasi'], ['autentikasi', 'kendali', 'akses', 'audit', 'sistem', 'keamanan', 'jaringan', 'komputer', 'jaringan_komputer', 'sistem_keamanan', 'jaringan_komputer', 'jaringan_komputer'], ['cisco', 'ccna', 'jaringan', 'komputer', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['koneksi', 'jaringan', 'antar', 'sekolah', 'teknologi', 'wireless'], ['analisis', 'tingkat', 'penggunaan', 'internet', 'dikalangan', 'mahasiswa', 'hubungannya', 'peningkatan', 'nilai', 'akademik', 'studi', 'kasus', 'mahasiswa', 'kota', 'penggunaan_internet', 'studi_kasus', 'penggunaan_internet', 'studi_kasus', 'penggunaan_internet', 'studi_kasus'], ['implementasi', 'intrusion', 'detection', 'system', 'ids', 'snort', 'laboratorium', 'jaringan', 'komputer', 'lepkom', 'universitas', 'gunadarma', 'implementasi_intrusion', 'detection_system', 'jaringan_komputer', 'implementasi_intrusion', 'detection_system', 'jaringan_komputer', 'implementasi_intrusion', 'detection_system', 'jaringan_komputer'], ['rancang', 'bangun', 'analisa', 'qos', 'audio', 'video', 'streaming', 'jaringan', 'mpls', 'vpn', 'rancang_bangun', 'rancang_bangun', 'rancang_bangun'], ['analisa', 'qos', 'jaringan', 'mpls', 'ipv6', 'routing', 'ospf'], ['monitoring', 'sistem', 'kerja', 'pengembangan', 'jaringan', 'komputer', 'networking', 'rumah', 'sakit', 'dr', 'moewardi', 'residen', 'bedah', 'simulasi', 'dude', 'jaringan_komputer', 'rumah_sakit', 'jaringan_komputer', 'rumah_sakit', 'jaringan_komputer', 'rumah_sakit'], ['langsung', 'praktik', 'mengelola', 'jaringan', 'lebih', 'efektif', 'efisien', 'linux', 'fedora', 'windows', 'xp', 'windows_xp', 'windows_xp', 'windows_xp'], ['studi', 'implementasi', 'voip', 'sip', 'jaringan', 'kampus', 'universitas', 'sam', 'ratulangi'], ['cara', 'mudah', 'membangun', 'jaringan', 'komputer', 'internet', 'cara_mudah', 'membangun_jaringan', 'cara_mudah', 'membangun_jaringan', 'cara_mudah', 'membangun_jaringan'], ['desain', 'standar', 'perpustakaan', 'digital', 'perpustakaan_digital', 'perpustakaan_digital', 'perpustakaan_digital'], ['panduan', 'praktis', 'menguasai', 'komputer'], ['merakit', 'sendiri', 'komputer', 'tahan', 'banting', 'modal', 'jutaan'], ['analisis', 'perancangan', 'sistem', 'komputerisasi', 'jaringan', 'komunikasi', 'data', 'radio', 'karysma', 'fm', 'boyolali', 'analisis_perancangan', 'analisis_perancangan', 'komunikasi_data', 'analisis_perancangan'], ['optimasi', 'routing', 'pengaturan', 'route', 'advertisement', 'jaringan', 'mobile', 'ipv6'], ['perancangan', 'sistem', 'keamanan', 'jaringan', 'komputer', 'snort', 'intrussion', 'detection', 'system', 'ip', 'tables', 'firewall', 'jaringan_komputer', 'detection_system', 'sistem_keamanan', 'jaringan_komputer', 'detection_system', 'jaringan_komputer', 'detection_system'], ['sistem', 'jaringan', 'komputer', 'pemula', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['bahasa', 'pemrograman', 'python', 'platform', 'gnu', 'linux', 'bahasa_pemrograman', 'gnu_linux', 'bahasa_pemrograman', 'gnu_linux', 'bahasa_pemrograman', 'gnu_linux'], ['optimasi', 'bandwith', 'traffic', 'shapping'], ['rancang', 'bangun', 'sistem', 'pencegahan', 'data', 'flooding', 'jaringan', 'komputer', 'rancang_bangun', 'jaringan_komputer', 'rancang_bangun', 'jaringan_komputer', 'rancang_bangun', 'jaringan_komputer'], ['cara', 'mudah', 'membangun', 'jaringan', 'komputer', 'internet', 'cara_mudah', ...

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                 0             1             2              3   \
# 0             cara         mudah     membangun       jaringan
# 1         jaringan      komputer           tcp             ip
# 2         parallel   programming        teknik       aplikasi
# 3              tip          jitu      optimasi       jaringan
# 4     pengembangan         media  pembelajaran      teknologi
# 5      autentikasi       kendali         akses          audit
# 6            cisco          ccna      jaringan       komputer
# 7          koneksi      jaringan         antar        sekolah
# 8         analisis       tingkat    penggunaan       internet
# 9     implementasi     intrusion     detection         system
# 10         rancang        bangun       analisa            qos
# 11         analisa           qos      jaringan           mpls
# 12      monitoring        sistem         kerja   pengembangan
# 13        langsung       praktik     mengelola       jaringan
# 14           studi  implementasi          voip            sip
# 15            cara         mudah     membangun       jaringan
# 16          desain       standar  perpustakaan        digital
# 17         panduan       praktis     menguasai       komputer
# 18         merakit       sendiri      komputer          tahan
# 19        analisis   perancangan        sistem  komputerisasi
# 20        optimasi       routing    pengaturan          route
# 21     perancangan        sistem      keamanan       jaringan
# 22          sistem      jaringan      komputer         pemula
# 23          bahasa   pemrograman        python       platform
# 24        optimasi      bandwith       traffic       shapping
# 25         rancang        bangun        sistem     pencegahan
# 26            cara         mudah     membangun       jaringan
# 27            cara          jitu   pengelolaan       jaringan
# 28       membangun      software    monitoring       jaringan
# 29    implementasi        sistem   autentikasi       jaringan
# ...            ...           ...           ...            ...
# 4881         fuzzy         logic     diagnosis           tata
# 4882      pengaruh         model       problem       learning
# 4883      pengaruh   pertisipasi      anggaran        kinerja
# 4884        adopsi             e      commerce     pendekatan
# 4885   advertising         board        djarum          super
# 4886    eksplorasi        metode           bar          chart
# 4887        sistem     pendukung     keputusan      pemilihan
# 4888       analisa   perancangan             e      marketing
# 4889       analisa   perancangan        sistem      informasi
# 4890             e      learning     penunjang   pembelajaran
# 4891        sistem     informasi    monitoring         korosi
# 4892      pengaruh        faktor     demografi    personality
# 4893     pembuatan      aplikasi       digital        library
# 4894        sistem     informasi     manajemen           buku
# 4895      pengaruh   partisipasi  penganggaran        kinerja
# 4896   efektivitas  pembelajaran   kontekstual      kemampuan
# 4897      analisis     efisiensi      koperasi        pegawai
# 4898  pemberdayaan       sekolah      menengah       kejuruan
# 4899   pelaksanaan     kurikulum       tingkat         satuan
# 4900  revitalisasi       benteng    vastenburg      surakarta
# 4901  identifikasi         bakat         siswa        sekolah
# 4902     analisisi         model        simple       criteria
# 4903     pembuatan      aplikasi    penyebaran      informasi
# 4904  pembelajaran        fisika       masalah        melalui
# 4905      pengaruh       service       quality   satisfaction
# 4906      pengaruh         total       quality     management
# 4907     lokalitas      televisi         lokal       menonton
# 4908  pembelajaran        fisika        metode    demonstrasi
# 4909      analisis     efisiensi          bank           bumn
# 4910        puppet          show       inovasi         metode
#
#                         4                     5                     6   \
# 0                 komputer              internet            cara_mudah
# 1        jaringan_komputer     jaringan_komputer     jaringan_komputer
# 2                 jaringan           workstation              komputer
# 3                       wi                    fi                  None
# 4                informasi    media_pembelajaran   teknologi_informasi
# 5                   sistem              keamanan              jaringan
# 6        jaringan_komputer     jaringan_komputer     jaringan_komputer
# 7                teknologi              wireless                  None
# 8               dikalangan             mahasiswa           hubungannya
# 9                      ids                 snort          laboratorium
# 10                   audio                 video             streaming
# 11                    ipv6               routing                  ospf
# 12                jaringan              komputer            networking
# 13                   lebih               efektif               efisien
# 14                jaringan                kampus           universitas
# 15                komputer              internet            cara_mudah
# 16    perpustakaan_digital  perpustakaan_digital  perpustakaan_digital
# 17                    None                  None                  None
# 18                 banting                 modal                jutaan
# 19                jaringan            komunikasi                  data
# 20           advertisement              jaringan                mobile
# 21                komputer                 snort            intrussion
# 22       jaringan_komputer     jaringan_komputer     jaringan_komputer
# 23                     gnu                 linux    bahasa_pemrograman
# 24                    None                  None                  None
# 25                    data              flooding              jaringan
# 26                komputer              internet            cara_mudah
# 27                 windows                remote               desktop
# 28                     sms                 alert                  None
# 29                 hotspot           universitas               udayana
# ...                    ...                   ...                   ...
# 4881               laksana              penyakit                 demam
# 4882                   pbl                 hasil               belajar
# 4883            manajerial                  gaya          kepemimpinan
# 4884            technology            acceptance                 model
# 4885              analisis            deskriptif            kualitatif
# 4886                   cpm                   pdm                  pert
# 4887              supplier                  obat                metode
# 4888                 studi                 kasus                 bajaj
# 4889           pengelolaan                 biaya                proyek
# 4890          konvensional                 pokok               bahasan
# 4891                  pipa                minyak                   web
# 4892                 stres                 kerja            penggunaan
# 4893                 studi                 kasus          perpustakaan
# 4894                  ajar      sistem_informasi      sistem_informasi
# 4895                aparat             integrasi              variabel
# 4896         menyelesaikan                  soal               aljabar
# 4897                negeri              republik             indonesia
# 4898                   smk               melalui                   smm
# 4899            pendidikan              prestasi               belajar
# 4900                 pusat                  seni                museum
# 4901                 dasar                negeri                    se
# 4902               optimal   portofolioselection                 scops
# 4903                 short               message               service
# 4904                metode                proyek             pemberian
# 4905             expertise              costumer               loyalty
# 4906               kinerja            manajerial               empiris
# 4907                 orang                ngapak                 jogja
# 4908               melalui            pendekatan               quantum
# 4909                  bank                swasta               setelah
# 4910            pengajaran                bahasa               inggris
#
#                       7                    8                    9   ...   \
# 0     membangun_jaringan           cara_mudah   membangun_jaringan  ...
# 1                   None                 None                 None  ...
# 2                paralel                 None                 None  ...
# 3                   None                 None                 None  ...
# 4     media_pembelajaran  teknologi_informasi   media_pembelajaran  ...
# 5               komputer    jaringan_komputer      sistem_keamanan  ...
# 6                   None                 None                 None  ...
# 7                   None                 None                 None  ...
# 8            peningkatan                nilai             akademik  ...
# 9               jaringan             komputer               lepkom  ...
# 10              jaringan                 mpls                  vpn  ...
# 11                  None                 None                 None  ...
# 12                 rumah                sakit                   dr  ...
# 13                 linux               fedora              windows  ...
# 14                   sam            ratulangi                 None  ...
# 15    membangun_jaringan           cara_mudah   membangun_jaringan  ...
# 16                  None                 None                 None  ...
# 17                  None                 None                 None  ...
# 18                  None                 None                 None  ...
# 19                 radio              karysma                   fm  ...
# 20                  ipv6                 None                 None  ...
# 21             detection               system                   ip  ...
# 22                  None                 None                 None  ...
# 23             gnu_linux   bahasa_pemrograman            gnu_linux  ...
# 24                  None                 None                 None  ...
# 25              komputer       rancang_bangun    jaringan_komputer  ...
# 26    membangun_jaringan           cara_mudah   membangun_jaringan  ...
# 27        administration                 None                 None  ...
# 28                  None                 None                 None  ...
# 29                  open               source           freeradius  ...
# ...                  ...                  ...                  ...  ...
# 4881            berdarah               dengue                demam  ...
# 4882               kimia                siswa               konsep  ...
# 4883               iklim           organisasi             variabel  ...
# 4884                 tam                  ukm                studi  ...
# 4885                  tv                value          advertising  ...
# 4886                line              balance                 time  ...
# 4887             electre          elimination                   et  ...
# 4888             persada            nusantara  analisa_perancangan  ...
# 4889          konstruksi               metode                 cost  ...
# 4890             listrik              dinamis                kelas  ...
# 4891               studi                kasus              stasiun  ...
# 4892              sistem            informasi             komputer  ...
# 4893               sains            teknologi          universitas  ...
# 4894    sistem_informasi                 None                 None  ...
# 4895         intervening             variabel           moderating  ...
# 4896                soal               cerita             ditinjau  ...
# 4897           kabupaten               klaten                 None  ...
# 4898                 iso     sekolah_menengah     sekolah_menengah  ...
# 4899               siswa                  smk               negeri  ...
# 4900                seni          kontemporer                 None  ...
# 4901           kecamatan             ngemplak             boyolali  ...
# 4902         pembentukan           portofolio              optimal  ...
# 4903                 sms           lingkungan              program  ...
# 4904               tugas             ditinjau                 gaya  ...
# 4905               studi              peserta                didik  ...
# 4906             manajer           perhotelan          dipekanbaru  ...
# 4907                  tv                 None                 None  ...
# 4908         ketrampilan               proses             ditinjau  ...
# 4909              merger             tinjauan                 bank  ...
# 4910               upaya            kemampuan            berbicara  ...
#
#                  26               27           28               29  \
# 0              None             None         None             None
# 1              None             None         None             None
# 2              None             None         None             None
# 3              None             None         None             None
# 4              None             None         None             None
# 5              None             None         None             None
# 6              None             None         None             None
# 7              None             None         None             None
# 8              None             None         None             None
# 9              None             None         None             None
# 10             None             None         None             None
# 11             None             None         None             None
# 12             None             None         None             None
# 13             None             None         None             None
# 14             None             None         None             None
# 15             None             None         None             None
# 16             None             None         None             None
# 17             None             None         None             None
# 18             None             None         None             None
# 19             None             None         None             None
# 20             None             None         None             None
# 21             None             None         None             None
# 22             None             None         None             None
# 23             None             None         None             None
# 24             None             None         None             None
# 25             None             None         None             None
# 26             None             None         None             None
# 27             None             None         None             None
# 28             None             None         None             None
# 29             None             None         None             None
# ...             ...              ...          ...              ...
# 4881           None             None         None             None
# 4882           None             None         None             None
# 4883           None             None         None             None
# 4884           None             None         None             None
# 4885           None             None         None             None
# 4886           None             None         None             None
# 4887           None             None         None             None
# 4888           None             None         None             None
# 4889           None             None         None             None
# 4890           None             None         None             None
# 4891           None             None         None             None
# 4892           None             None         None             None
# 4893  negeri_syarif  digital_library  studi_kasus  sains_teknologi
# 4894           None             None         None             None
# 4895           None             None         None             None
# 4896           None             None         None             None
# 4897           None             None         None             None
# 4898           None             None         None             None
# 4899           None             None         None             None
# 4900           None             None         None             None
# 4901           None             None         None             None
# 4902           None             None         None             None
# 4903           None             None         None             None
# 4904           None             None         None             None
# 4905           None             None         None             None
# 4906           None             None         None             None
# 4907           None             None         None             None
# 4908           None             None         None             None
# 4909           None             None         None             None
# 4910           None             None         None             None
#
#                                    30                    31    32    33    34  \
# 0                                None                  None  None  None  None
# 1                                None                  None  None  None  None
# 2                                None                  None  None  None  None
# 3                                None                  None  None  None  None
# 4                                None                  None  None  None  None
# 5                                None                  None  None  None  None
# 6                                None                  None  None  None  None
# 7                                None                  None  None  None  None
# 8                                None                  None  None  None  None
# 9                                None                  None  None  None  None
# 10                               None                  None  None  None  None
# 11                               None                  None  None  None  None
# 12                               None                  None  None  None  None
# 13                               None                  None  None  None  None
# 14                               None                  None  None  None  None
# 15                               None                  None  None  None  None
# 16                               None                  None  None  None  None
# 17                               None                  None  None  None  None
# 18                               None                  None  None  None  None
# 19                               None                  None  None  None  None
# 20                               None                  None  None  None  None
# 21                               None                  None  None  None  None
# 22                               None                  None  None  None  None
# 23                               None                  None  None  None  None
# 24                               None                  None  None  None  None
# 25                               None                  None  None  None  None
# 26                               None                  None  None  None  None
# 27                               None                  None  None  None  None
# 28                               None                  None  None  None  None
# 29                               None                  None  None  None  None
# ...                               ...                   ...   ...   ...   ...
# 4881                             None                  None  None  None  None
# 4882                             None                  None  None  None  None
# 4883                             None                  None  None  None  None
# 4884                             None                  None  None  None  None
# 4885                             None                  None  None  None  None
# 4886                             None                  None  None  None  None
# 4887                             None                  None  None  None  None
# 4888                             None                  None  None  None  None
# 4889                             None                  None  None  None  None
# 4890                             None                  None  None  None  None
# 4891                             None                  None  None  None  None
# 4892                             None                  None  None  None  None
# 4893  universitas_islam_negeri_syarif  hidayatullah_jakarta  None  None  None
# 4894                             None                  None  None  None  None
# 4895                             None                  None  None  None  None
# 4896                             None                  None  None  None  None
# 4897                             None                  None  None  None  None
# 4898                             None                  None  None  None  None
# 4899                             None                  None  None  None  None
# 4900                             None                  None  None  None  None
# 4901                             None                  None  None  None  None
# 4902                             None                  None  None  None  None
# 4903                             None                  None  None  None  None
# 4904                             None                  None  None  None  None
# 4905                             None                  None  None  None  None
# 4906                             None                  None  None  None  None
# 4907                             None                  None  None  None  None
# 4908                             None                  None  None  None  None
# 4909                             None                  None  None  None  None
# 4910                             None                  None  None  None  None
#
#         35
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# ...    ...
# 4881  None
# 4882  None
# 4883  None
# 4884  None
# 4885  None
# 4886  None
# 4887  None
# 4888  None
# 4889  None
# 4890  None
# 4891  None
# 4892  None
# 4893  None
# 4894  None
# 4895  None
# 4896  None
# 4897  None
# 4898  None
# 4899  None
# 4900  None
# 4901  None
# 4902  None
# 4903  None
# 4904  None
# 4905  None
# 4906  None
# 4907  None
# 4908  None
# 4909  None
# 4910  None
#
# [4911 rows x 36 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(7977 unique tokens: ['cara', 'cara_mudah', 'internet', 'jaringan', 'komputer']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 4911

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))
# Out:
# Num Topics = 2  has Coherence Value of 0.38045848
# Num Topics = 4  has Coherence Value of 0.4021779938
# Num Topics = 6  has Coherence Value of 0.4453480274
# Num Topics = 8  has Coherence Value of 0.494962478
# Num Topics = 10  has Coherence Value of 0.5227859604
# Num Topics = 12  has Coherence Value of 0.5100114031
# Num Topics = 14  has Coherence Value of 0.5205330873
# Num Topics = 16  has Coherence Value of 0.5592981226
# Num Topics = 18  has Coherence Value of 0.5331236419

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=18)
pprint(model.print_topics())
# Out:
# [(0,
#   '0.020*"e_commerce" + 0.014*"sma_negeri" + 0.012*"studi_kasus" + '
#   '0.008*"sistem_informasi" + 0.008*"e" + 0.007*"e_learning" + '
#   '0.007*"commerce" + 0.006*"kinerja_manajerial" + 0.005*"motivasi_prestasi" + '
#   '0.005*"pelayanan_puskesmas"'),
#  (1,
#   '0.012*"hasil_belajar" + 0.008*"studi_kasus" + 0.006*"sistem_pendukung" + '
#   '0.006*"sistem_informasi" + 0.006*"analisis_perancangan" + '
#   '0.005*"matematika_siswa" + 0.005*"shortest_path" + 0.004*"kelas_viii" + '
#   '0.004*"pattern" + 0.004*"hasil"'),
#  (2,
#   '0.015*"rekayasa_perangkat" + 0.014*"rumah_sakit" + 0.009*"data_warehouse" + '
#   '0.009*"perguruan_tinggi" + 0.009*"penerimaan_siswa" + '
#   '0.008*"sistem_informasi" + 0.007*"metode_analytical" + 0.006*"pemberian" + '
#   '0.006*"software" + 0.006*"rekayasa"'),
#  (3,
#   '0.013*"sistem_informasi" + 0.011*"rancang_bangun" + 0.010*"studi_kasus" + '
#   '0.008*"smart" + 0.007*"game" + 0.007*"penilaian_kinerja" + '
#   '0.005*"biaya_proyek" + 0.005*"e_commerce" + 0.005*"pembuatan_website" + '
#   '0.005*"smart_card"'),
#  (4,
#   '0.010*"bahan_ajar" + 0.009*"rawat_inap" + 0.006*"kota_surakarta" + '
#   '0.006*"netbeans_5" + 0.006*"kota_semarang" + 0.006*"delphi_0" + '
#   '0.005*"rawat" + 0.004*"statistik" + 0.004*"kota" + 0.004*"inap"'),
#  (5,
#   '0.012*"sistem_informasi" + 0.011*"studi_kasus" + 0.009*"matriks" + '
#   '0.009*"universitas_islam" + 0.007*"sistem_pakar" + 0.007*"negeri_syarif" + '
#   '0.007*"fakultas_sains" + 0.006*"rancang_bangun" + '
#   '0.006*"hidayatullah_jakarta" + 0.005*"universitas"'),
#  (6,
#   '0.008*"studi_kasus" + 0.007*"analisis_perancangan" + 0.005*"al_qur" + '
#   '0.005*"pengamanan_data" + 0.005*"sistem_pendukung" + 0.005*"eksplorasi" + '
#   '0.004*"transfer" + 0.004*"hari" + 0.004*"share" + 0.004*"tutorial"'),
#  (7,
#   '0.011*"sistem_informasi" + 0.010*"load_balancing" + '
#   '0.007*"sekolah_menengah" + 0.007*"proxy_server" + 0.006*"local_area" + '
#   '0.006*"mobile" + 0.005*"mata_kuliah" + 0.005*"data_mining" + '
#   '0.005*"aplikasi_pemantau" + 0.005*"membangun"'),
#  (8,
#   '0.011*"flash" + 0.011*"sistem_pendukung" + 0.009*"rancang_bangun" + '
#   '0.008*"sistem_informasi" + 0.008*"teknologi_informasi" + '
#   '0.008*"siswa_kelas" + 0.007*"j2me" + 0.007*"belajar_siswa" + '
#   '0.007*"bahasa_indonesia" + 0.006*"pembelajaran"'),
#  (9,
#   '0.010*"keputusan_pemilihan" + 0.009*"rancang_bangun" + '
#   '0.008*"internet_protocol" + 0.007*"sistem_pendukung" + 0.006*"studi_kasus" '
#   '+ 0.006*"a" + 0.005*"metode_ahp" + 0.005*"e_learning" + 0.005*"pemilihan" + '
#   '0.005*"sistem_pendukung_keputusan_pemilihan"'),
#  (10,
#   '0.019*"sms_gateway" + 0.014*"smp_negeri" + 0.013*"sistem_informasi" + '
#   '0.010*"sistem_pakar" + 0.009*"pembuatan_cd" + 0.007*"gateway" + 0.007*"sms" '
#   '+ 0.006*"toko_buku" + 0.006*"kinerja_karyawan" + 0.006*"membangun"'),
#  (11,
#   '0.014*"sistem_informasi" + 0.010*"model_pembelajaran" + '
#   '0.010*"media_pembelajaran" + 0.008*"pembelajaran" + '
#   '0.008*"prestasi_belajar" + 0.006*"kelas_vii" + 0.006*"kelas" + '
#   '0.006*"belajar" + 0.006*"matematika" + 0.005*"studi_kasus"'),
#  (12,
#   '0.014*"sistem_informasi" + 0.011*"analisis_perancangan" + '
#   '0.009*"studi_kasus" + 0.008*"analisa_perancangan" + 0.008*"short_message" + '
#   '0.008*"server" + 0.008*"basis_data" + 0.008*"client_server" + '
#   '0.007*"jaringan_komputer" + 0.006*"perancangan"'),
#  (13,
#   '0.014*"pc_router" + 0.008*"power_system" + 0.008*"siswa_kelas" + '
#   '0.006*"pengolahan_data" + 0.006*"diagnosa_penyakit" + 0.006*"pc" + '
#   '0.006*"sejati" + 0.005*"sistem_pakar" + 0.005*"router" + '
#   '0.004*"sistem_informasi"'),
#  (14,
#   '0.024*"perangkat_lunak" + 0.014*"sistem_informasi" + 0.007*"lunak" + '
#   '0.006*"perangkat" + 0.006*"dasar" + 0.006*"jawa_barat" + 0.006*"listrik" + '
#   '0.006*"lokasi" + 0.005*"pengiriman_barang" + 0.005*"informasi"'),
#  (15,
#   '0.009*"usaha_kecil" + 0.007*"seleksi_penerimaan" + 0.007*"visual_basic" + '
#   '0.007*"gnu_linux" + 0.006*"jaringan_saraf" + 0.006*"sistem_informasi" + '
#   '0.006*"implementasi_ip" + 0.005*"bahasa_pemrograman" + '
#   '0.005*"pembelian_penjualan" + 0.005*"lokal"'),
#  (16,
#   '0.009*"sistem_informasi" + 0.008*"php_mysql" + 0.007*"penentuan" + '
#   '0.007*"keputusan_penentuan" + 0.007*"php" + 0.007*"kurikulum_program" + '
#   '0.006*"rancang_bangun" + 0.006*"sistem_pakar" + '
#   '0.006*"mendiagnosa_penyakit" + 0.006*"cara_mudah"'),
#  (17,
#   '0.012*"hasil_belajar" + 0.011*"siswa_kelas" + 0.010*"pokok_bahasan" + '
#   '0.006*"e_government" + 0.006*"pengendalian_persediaan" + 0.005*"hasil" + '
#   '0.005*"perguruan_tinggi" + 0.005*"pembelajaran_kooperatif" + '
#   '0.005*"bahasan" + 0.005*"lalu_lintas"')]

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=18)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.009*"smp_negeri" + 0.009*"pc_router" + 0.007*"system" + 0.006*"usaha_kecil" + 0.006*"sistem_informasi" + 0.006*"power_system" + 0.005*"control" + 0.005*"a" + 0.004*"power" + 0.004*"metode_forward"
# Topic: 1 Word: 0.013*"sekolah_menengah" + 0.008*"penerimaan_siswa" + 0.008*"smk_negeri" + 0.007*"rancang_bangun" + 0.007*"0" + 0.007*"kelas_vii" + 0.006*"microsoft_visual" + 0.006*"menjadi" + 0.005*"negeri" + 0.005*"microsoft"
# Topic: 2 Word: 0.023*"sistem_informasi" + 0.012*"sma_negeri" + 0.011*"studi_kasus" + 0.010*"rancang_bangun" + 0.008*"informasi" + 0.008*"perguruan_tinggi" + 0.007*"php_mysql" + 0.007*"universitas_islam" + 0.006*"sistem" + 0.006*"smart"
# Topic: 3 Word: 0.013*"siswa_kelas" + 0.011*"prestasi_belajar" + 0.008*"kelas" + 0.008*"basis_data" + 0.007*"siswa" + 0.007*"alat_bantu" + 0.007*"implementasi_ip" + 0.006*"proxy_server" + 0.005*"prestasi" + 0.005*"persamaan_garis"
# Topic: 4 Word: 0.012*"matriks" + 0.009*"implementasi_algoritma" + 0.009*"game" + 0.008*"analisa_perancangan" + 0.006*"studi_kasus" + 0.006*"aplikasi" + 0.005*"android" + 0.005*"two" + 0.005*"membandingkan" + 0.004*"pekanbaru"
# Topic: 5 Word: 0.019*"rumah_sakit" + 0.011*"sistem_pakar" + 0.010*"sekolah_dasar" + 0.008*"rawat_inap" + 0.008*"studi_kasus" + 0.007*"radio" + 0.006*"sakit" + 0.006*"multimedia_interaktif" + 0.006*"rawat" + 0.006*"dasar"
# Topic: 6 Word: 0.023*"e_commerce" + 0.012*"e" + 0.009*"siswa_kelas" + 0.008*"belajar_siswa" + 0.008*"commerce" + 0.007*"motivasi_hasil" + 0.006*"e_government" + 0.006*"perangkat_lunak" + 0.006*"motivasi_belajar" + 0.006*"pembelajaran_matematika"
# Topic: 7 Word: 0.009*"open_source" + 0.008*"linier" + 0.007*"persamaan" + 0.007*"studi_kasus" + 0.007*"sistem_informasi" + 0.006*"seleksi_penerimaan" + 0.006*"sistem_pendukung" + 0.005*"program_studi" + 0.005*"pengambilan_keputusan" + 0.004*"pengolahan_data"
# Topic: 8 Word: 0.010*"load_balancing" + 0.007*"bahan_ajar" + 0.007*"pembuatan_cd" + 0.007*"sistem_informasi" + 0.006*"cd" + 0.006*"data_warehouse" + 0.006*"short_message" + 0.006*"pembelajaran" + 0.005*"interaktif" + 0.005*"analisa_perancangan"
# Topic: 9 Word: 0.017*"hasil_belajar" + 0.011*"sistem_informasi" + 0.009*"model_pembelajaran" + 0.007*"buku" + 0.007*"matematika_siswa" + 0.006*"belajar" + 0.006*"studi_kasus" + 0.006*"real_time" + 0.006*"toko_buku" + 0.005*"hasil"
# Topic: 10 Word: 0.021*"sistem_pendukung" + 0.011*"perangkat_lunak" + 0.008*"pendukung" + 0.007*"keputusan" + 0.007*"studi_kasus" + 0.007*"web_service" + 0.006*"micro_edition" + 0.006*"metode_ahp" + 0.006*"j2me" + 0.006*"sistem_informasi"
# Topic: 11 Word: 0.022*"sistem_informasi" + 0.008*"pokok_bahasan" + 0.007*"informasi" + 0.007*"internet_protocol" + 0.006*"sistem_pakar" + 0.006*"sistem" + 0.006*"studi_kasus" + 0.005*"perangkat_lunak" + 0.005*"metode_analytical" + 0.005*"kota_semarang"
# Topic: 12 Word: 0.011*"sistem_informasi" + 0.009*"client_server" + 0.007*"mendiagnosa_penyakit" + 0.007*"sistem_pakar" + 0.007*"bahasa_inggris" + 0.007*"rancang_bangun" + 0.006*"local_area" + 0.005*"jawa" + 0.005*"eksplorasi" + 0.005*"perangkat_lunak"
# Topic: 13 Word: 0.009*"media_pembelajaran" + 0.006*"sistem_informasi" + 0.006*"sistem_pakar" + 0.005*"rancang_bangun" + 0.005*"tipe" + 0.005*"via" + 0.004*"internet" + 0.004*"analytic_hierarchy" + 0.004*"interaksi_manusia" + 0.004*"media"
# Topic: 14 Word: 0.011*"keputusan_pemilihan" + 0.010*"sistem_pendukung" + 0.007*"windows_server" + 0.006*"problem_learning" + 0.006*"keputusan_penentuan" + 0.006*"pemilihan" + 0.006*"sistem_pakar" + 0.006*"e_learning" + 0.006*"sistem_pendukung_keputusan_pemilihan" + 0.005*"keputusan"
# Topic: 15 Word: 0.020*"sms_gateway" + 0.012*"sistem_informasi" + 0.009*"studi_kasus" + 0.007*"kota_surakarta" + 0.006*"gateway" + 0.006*"sms" + 0.005*"dinas_pendidikan" + 0.005*"kinerja_manajerial" + 0.005*"sejati" + 0.005*"customer_relationship"
# Topic: 16 Word: 0.010*"analisis_perancangan" + 0.007*"studi_kasus" + 0.007*"sistem_informasi" + 0.007*"rancang_bangun" + 0.006*"eksekutif" + 0.005*"penjualan" + 0.005*"mikrotik_smk" + 0.004*"cinta" + 0.004*"hasil" + 0.004*"swing"
# Topic: 17 Word: 0.011*"sistem_informasi" + 0.010*"teknologi_informasi" + 0.009*"pembuatan_website" + 0.008*"rancang_bangun" + 0.008*"bahasa_pemrograman" + 0.006*"information_system" + 0.005*"informasi" + 0.005*"gnu_linux" + 0.005*"teknik_informatika" + 0.005*"computer"

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)
# Out:
#      No_Dokumen  Topik_Dominan  Persentase_Kontribusi  \
# 0             0            2.0                 0.9274
# 1             1           17.0                 0.6109
# 2             2           13.0                 0.4522
# 3             3            7.0                 0.5285
# 4             4           17.0                 0.5172
# 5             5           17.0                 0.4703
# 6             6           17.0                 0.6192
# 7             7           10.0                 0.3660
# 8             8            2.0                 0.9550
# 9             9            9.0                 0.7477
# 10           10            2.0                 0.4034
# 11           11            3.0                 0.8819
# 12           12            5.0                 0.3500
# 13           13            7.0                 0.5135
# 14           14           16.0                 0.2990
# 15           15            2.0                 0.9274
# 16           16            6.0                 0.6854
# 17           17            8.0                 0.8111
# 18           18            6.0                 0.8819
# 19           19           16.0                 0.4649
# 20           20            3.0                 0.4772
# 21           21            9.0                 0.6521
# 22           22           17.0                 0.7324
# 23           23           17.0                 0.9274
# 24           24           13.0                 0.8111
# 25           25           17.0                 0.9370
# 26           26            2.0                 0.9274
# 27           27            2.0                 0.7771
# 28           28            3.0                 0.8651
# 29           29            7.0                 0.9325
# ..          ...            ...                    ...
# 217         217           17.0                 0.8651
# 218         218            8.0                 0.4679
# 219         219            5.0                 0.6137
# 220         220           16.0                 0.5700
# 221         221           12.0                 0.4093
# 222         222           14.0                 0.9213
# 223         223           10.0                 0.5793
# 224         224            0.0                 0.7297
# 225         225           16.0                 0.8426
# 226         226           13.0                 0.5100
# 227         227            0.0                 0.5120
# 228         228            2.0                 0.5634
# 229         229            2.0                 0.6969
# 230         230           10.0                 0.5793
# 231         231           12.0                 0.6673
# 232         232           16.0                 0.9056
# 233         233            4.0                 0.9444
# 234         234            7.0                 0.9589
# 235         235            6.0                 0.4728
# 236         236            0.0                 0.9475
# 237         237           15.0                 0.3884
# 238         238           17.0                 0.9528
# 239         239           10.0                 0.8951
# 240         240           17.0                 0.4563
# 241         241           16.0                 0.6678
# 242         242           11.0                 0.6568
# 243         243           12.0                 0.4152
# 244         244            3.0                 0.4964
# 245         245            0.0                 0.8856
# 246         246            1.0                 0.3501
#
#                                                                                               Kata_Kunci  \
# 0    sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 1    sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 2    media_pembelajaran, sistem_informasi, sistem_pakar, rancang_bangun, tipe, via, internet, analyti...
# 3    open_source, linier, persamaan, studi_kasus, sistem_informasi, seleksi_penerimaan, sistem_penduk...
# 4    sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 5    sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 6    sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 7    sistem_pendukung, perangkat_lunak, pendukung, keputusan, studi_kasus, web_service, micro_edition...
# 8    sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 9    hasil_belajar, sistem_informasi, model_pembelajaran, buku, matematika_siswa, belajar, studi_kasu...
# 10   sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 11   siswa_kelas, prestasi_belajar, kelas, basis_data, siswa, alat_bantu, implementasi_ip, proxy_serv...
# 12   rumah_sakit, sistem_pakar, sekolah_dasar, rawat_inap, studi_kasus, radio, sakit, multimedia_inte...
# 13   open_source, linier, persamaan, studi_kasus, sistem_informasi, seleksi_penerimaan, sistem_penduk...
# 14   analisis_perancangan, studi_kasus, sistem_informasi, rancang_bangun, eksekutif, penjualan, mikro...
# 15   sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 16   e_commerce, e, siswa_kelas, belajar_siswa, commerce, motivasi_hasil, e_government, perangkat_lun...
# 17   load_balancing, bahan_ajar, pembuatan_cd, sistem_informasi, cd, data_warehouse, short_message, p...
# 18   e_commerce, e, siswa_kelas, belajar_siswa, commerce, motivasi_hasil, e_government, perangkat_lun...
# 19   analisis_perancangan, studi_kasus, sistem_informasi, rancang_bangun, eksekutif, penjualan, mikro...
# 20   siswa_kelas, prestasi_belajar, kelas, basis_data, siswa, alat_bantu, implementasi_ip, proxy_serv...
# 21   hasil_belajar, sistem_informasi, model_pembelajaran, buku, matematika_siswa, belajar, studi_kasu...
# 22   sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 23   sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 24   media_pembelajaran, sistem_informasi, sistem_pakar, rancang_bangun, tipe, via, internet, analyti...
# 25   sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 26   sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 27   sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 28   siswa_kelas, prestasi_belajar, kelas, basis_data, siswa, alat_bantu, implementasi_ip, proxy_serv...
# 29   open_source, linier, persamaan, studi_kasus, sistem_informasi, seleksi_penerimaan, sistem_penduk...
# ..                                                                                                   ...
# 217  sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 218  load_balancing, bahan_ajar, pembuatan_cd, sistem_informasi, cd, data_warehouse, short_message, p...
# 219  rumah_sakit, sistem_pakar, sekolah_dasar, rawat_inap, studi_kasus, radio, sakit, multimedia_inte...
# 220  analisis_perancangan, studi_kasus, sistem_informasi, rancang_bangun, eksekutif, penjualan, mikro...
# 221  sistem_informasi, client_server, mendiagnosa_penyakit, sistem_pakar, bahasa_inggris, rancang_ban...
# 222  keputusan_pemilihan, sistem_pendukung, windows_server, problem_learning, keputusan_penentuan, pe...
# 223  sistem_pendukung, perangkat_lunak, pendukung, keputusan, studi_kasus, web_service, micro_edition...
# 224  smp_negeri, pc_router, system, usaha_kecil, sistem_informasi, power_system, control, a, power, m...
# 225  analisis_perancangan, studi_kasus, sistem_informasi, rancang_bangun, eksekutif, penjualan, mikro...
# 226  media_pembelajaran, sistem_informasi, sistem_pakar, rancang_bangun, tipe, via, internet, analyti...
# 227  smp_negeri, pc_router, system, usaha_kecil, sistem_informasi, power_system, control, a, power, m...
# 228  sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 229  sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 230  sistem_pendukung, perangkat_lunak, pendukung, keputusan, studi_kasus, web_service, micro_edition...
# 231  sistem_informasi, client_server, mendiagnosa_penyakit, sistem_pakar, bahasa_inggris, rancang_ban...
# 232  analisis_perancangan, studi_kasus, sistem_informasi, rancang_bangun, eksekutif, penjualan, mikro...
# 233  matriks, implementasi_algoritma, game, analisa_perancangan, studi_kasus, aplikasi, android, two,...
# 234  open_source, linier, persamaan, studi_kasus, sistem_informasi, seleksi_penerimaan, sistem_penduk...
# 235  e_commerce, e, siswa_kelas, belajar_siswa, commerce, motivasi_hasil, e_government, perangkat_lun...
# 236  smp_negeri, pc_router, system, usaha_kecil, sistem_informasi, power_system, control, a, power, m...
# 237  sms_gateway, sistem_informasi, studi_kasus, kota_surakarta, gateway, sms, dinas_pendidikan, kine...
# 238  sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 239  sistem_pendukung, perangkat_lunak, pendukung, keputusan, studi_kasus, web_service, micro_edition...
# 240  sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
# 241  analisis_perancangan, studi_kasus, sistem_informasi, rancang_bangun, eksekutif, penjualan, mikro...
# 242  sistem_informasi, pokok_bahasan, informasi, internet_protocol, sistem_pakar, sistem, studi_kasus...
# 243  sistem_informasi, client_server, mendiagnosa_penyakit, sistem_pakar, bahasa_inggris, rancang_ban...
# 244  siswa_kelas, prestasi_belajar, kelas, basis_data, siswa, alat_bantu, implementasi_ip, proxy_serv...
# 245  smp_negeri, pc_router, system, usaha_kecil, sistem_informasi, power_system, control, a, power, m...
# 246  sekolah_menengah, penerimaan_siswa, smk_negeri, rancang_bangun, 0, kelas_vii, microsoft_visual, ...
#
#                                                                                                     Teks
# 0    [cara, mudah, membangun, jaringan, komputer, internet, cara_mudah, membangun_jaringan, cara_muda...
# 1                 [jaringan, komputer, tcp, ip, jaringan_komputer, jaringan_komputer, jaringan_komputer]
# 2                    [parallel, programming, teknik, aplikasi, jaringan, workstation, komputer, paralel]
# 3                                                                [tip, jitu, optimasi, jaringan, wi, fi]
# 4    [pengembangan, media, pembelajaran, teknologi, informasi, media_pembelajaran, teknologi_informas...
# 5    [autentikasi, kendali, akses, audit, sistem, keamanan, jaringan, komputer, jaringan_komputer, si...
# 6             [cisco, ccna, jaringan, komputer, jaringan_komputer, jaringan_komputer, jaringan_komputer]
# 7                                               [koneksi, jaringan, antar, sekolah, teknologi, wireless]
# 8    [analisis, tingkat, penggunaan, internet, dikalangan, mahasiswa, hubungannya, peningkatan, nilai...
# 9    [implementasi, intrusion, detection, system, ids, snort, laboratorium, jaringan, komputer, lepko...
# 10   [rancang, bangun, analisa, qos, audio, video, streaming, jaringan, mpls, vpn, rancang_bangun, ra...
# 11                                                   [analisa, qos, jaringan, mpls, ipv6, routing, ospf]
# 12   [monitoring, sistem, kerja, pengembangan, jaringan, komputer, networking, rumah, sakit, dr, moew...
# 13   [langsung, praktik, mengelola, jaringan, lebih, efektif, efisien, linux, fedora, windows, xp, wi...
# 14                       [studi, implementasi, voip, sip, jaringan, kampus, universitas, sam, ratulangi]
# 15   [cara, mudah, membangun, jaringan, komputer, internet, cara_mudah, membangun_jaringan, cara_muda...
# 16   [desain, standar, perpustakaan, digital, perpustakaan_digital, perpustakaan_digital, perpustakaa...
# 17                                                               [panduan, praktis, menguasai, komputer]
# 18                                           [merakit, sendiri, komputer, tahan, banting, modal, jutaan]
# 19   [analisis, perancangan, sistem, komputerisasi, jaringan, komunikasi, data, radio, karysma, fm, b...
# 20                         [optimasi, routing, pengaturan, route, advertisement, jaringan, mobile, ipv6]
# 21   [perancangan, sistem, keamanan, jaringan, komputer, snort, intrussion, detection, system, ip, ta...
# 22         [sistem, jaringan, komputer, pemula, jaringan_komputer, jaringan_komputer, jaringan_komputer]
# 23   [bahasa, pemrograman, python, platform, gnu, linux, bahasa_pemrograman, gnu_linux, bahasa_pemrog...
# 24                                                               [optimasi, bandwith, traffic, shapping]
# 25   [rancang, bangun, sistem, pencegahan, data, flooding, jaringan, komputer, rancang_bangun, jaring...
# 26   [cara, mudah, membangun, jaringan, komputer, internet, cara_mudah, membangun_jaringan, cara_muda...
# 27                         [cara, jitu, pengelolaan, jaringan, windows, remote, desktop, administration]
# 28                                               [membangun, software, monitoring, jaringan, sms, alert]
# 29   [implementasi, sistem, autentikasi, jaringan, hotspot, universitas, udayana, open, source, freer...
# ..                                                                                                   ...
# 217                                                 [manajemen, backup, data, otomatis, jaringan, rsync]
# 218                   [analisis, kinerja, level, komponen, protokol, jaringan, server, telkom, divre, v]
# 219            [modul, ajar, komunikasi, data, antar, komputer, pemaketan, data, flash, komunikasi_data]
# 220                                                                     [berbagi, data, antar, jaringan]
# 221                                        [algoritma, routing, lingkungan, jaringan, grid, teori, graf]
# 222  [sistem, pakar, solusi, penyelesaian, masalah, konektivitas, jaringan, windows, sistem_pakar, si...
# 223  [jurusan, teknik, informatika, sekolah, tinggi, manajemen, informatika, komputer, amikom, yogyak...
# 224  [membangun, jaringan, lan, file, sharing, printer, sharing, smp, muhammadiyah, kokap, kulon, pro...
# 225                                                              [koneksi, jaringan, nat, publik, lokal]
# 226  [membangun, firewall, jaringan, windows, server, sma, islam, kota, pasuruan, membangun_firewall,...
# 227  [implementasi, konfigurasi, jaringan, lokal, fasilitas, sharing, data, printer, sistem, operasi,...
# 228  [pembuatan, perangkat, lunak, sistem, telemetri, suhu, kelembaban, gas, h2s, kawah, geothermal, ...
# 229                           [algoritma, paralel, odd, even, transposition, model, jaringan, nonlinier]
# 230  [jurusan, teknik, informatika, sekolah, tinggi, manajemen, informatika, komputer, amikom, yogyak...
# 231  [rancang, bangun, aplikasi, netcare, manager, membantu, pemeliharaan, komputer, jaringan, rancan...
# 232                [implementasi, sentral, komunikasi, telepon, internet, sip, jaringan, kampus, unsrat]
# 233  [virtual, private, network, protokol, ipsec, freebsd, studi, kasus, jaringan, fkip, uns, virtual...
# 234  [membangun, jaringan, internet, pc, router, vyatta, vc5, 2, laboratorium, komputer, sdn, sawojaj...
# 235  [mengembangkan, jaringan, mendukung, aplikasi, moodle, pembelajaran, e, learning, smk, negeri, m...
# 236  [pemanfaatan, komputer, pentium, ii, pc, router, linux, freesco, smk, negeri, bawang, pc_router,...
# 237                         [perencanaan, jaringan, akses, mobile, wimax, ghz, wilayah, kota, palembang]
# 238  [prototipe, ruting, dinamik, protokol, ibgp, aplikasi, quangga, sistem, operasi, bsd, studi, kas...
# 239                        [analisis, jaringan, wireless, universitas, gadjah, mada, metode, wardriving]
# 240  [analisis, perancangan, jaringan, ip, telephony, lingkungan, kampus, uin, suska, riau, analisis_...
# 241  [optimalisasi, bandwidth, jaringan, internet, mikrotik, smk, negeri, baureno, mikrotik_smk, mikr...
# 242  [perancangan, jaringan, komunikasi, voip, voive, over, internet, protocol, sip, session, initiat...
# 243  [membangun, jaringan, client, server, microsoft, back, office, server, 5, membangun_jaringan, cl...
# 244                           [kajian, pengembangan, jaringan, komunikasi, data, lapan, komunikasi_data]
# 245  [membangun, jaringan, local, area, network, lan, smp, negeri, malang, membangun_jaringan, local_...
# 246  [perancangan, sistem, aplikasi, komputer, alat, bantu, proses, pembelajaran, praktikum, elektron...
#
# [247 rows x 5 columns]

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics
# Out:
# 2.0     628
# 11.0    504
# 10.0    304
# 15.0    280
# 14.0    279
# 0.0     266
# 17.0    263
# 9.0     261
# 8.0     257
# 7.0     255
# 6.0     246
# 5.0     220
# 3.0     219
# 12.0    211
# 1.0     205
# 13.0    188
# 4.0     180
# 16.0    145
# Name: Topik_Dominan, dtype: int64

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')
# Out:
# Text(0.5,1,'Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.9589
# 1         1.0              0.9674
# 2         2.0              0.9745
# 3         3.0              0.9503
# 4         4.0              0.9622
# 5         5.0              0.9571
# 6         6.0              0.9550
# 7         7.0              0.9589
# 8         8.0              0.9637
# 9         9.0              0.9410
# 10       10.0              0.9650
# 11       11.0              0.9650
# 12       12.0              0.9550
# 13       13.0              0.9444
# 14       14.0              0.9589
# 15       15.0              0.9650
# 16       16.0              0.9503
# 17       17.0              0.9550
#
#                                                                                                Keywords  \
# 0   smp_negeri, pc_router, system, usaha_kecil, sistem_informasi, power_system, control, a, power, m...
# 1   sekolah_menengah, penerimaan_siswa, smk_negeri, rancang_bangun, 0, kelas_vii, microsoft_visual, ...
# 2   sistem_informasi, sma_negeri, studi_kasus, rancang_bangun, informasi, perguruan_tinggi, php_mysq...
# 3   siswa_kelas, prestasi_belajar, kelas, basis_data, siswa, alat_bantu, implementasi_ip, proxy_serv...
# 4   matriks, implementasi_algoritma, game, analisa_perancangan, studi_kasus, aplikasi, android, two,...
# 5   rumah_sakit, sistem_pakar, sekolah_dasar, rawat_inap, studi_kasus, radio, sakit, multimedia_inte...
# 6   e_commerce, e, siswa_kelas, belajar_siswa, commerce, motivasi_hasil, e_government, perangkat_lun...
# 7   open_source, linier, persamaan, studi_kasus, sistem_informasi, seleksi_penerimaan, sistem_penduk...
# 8   load_balancing, bahan_ajar, pembuatan_cd, sistem_informasi, cd, data_warehouse, short_message, p...
# 9   hasil_belajar, sistem_informasi, model_pembelajaran, buku, matematika_siswa, belajar, studi_kasu...
# 10  sistem_pendukung, perangkat_lunak, pendukung, keputusan, studi_kasus, web_service, micro_edition...
# 11  sistem_informasi, pokok_bahasan, informasi, internet_protocol, sistem_pakar, sistem, studi_kasus...
# 12  sistem_informasi, client_server, mendiagnosa_penyakit, sistem_pakar, bahasa_inggris, rancang_ban...
# 13  media_pembelajaran, sistem_informasi, sistem_pakar, rancang_bangun, tipe, via, internet, analyti...
# 14  keputusan_pemilihan, sistem_pendukung, windows_server, problem_learning, keputusan_penentuan, pe...
# 15  sms_gateway, sistem_informasi, studi_kasus, kota_surakarta, gateway, sms, dinas_pendidikan, kine...
# 16  analisis_perancangan, studi_kasus, sistem_informasi, rancang_bangun, eksekutif, penjualan, mikro...
# 17  sistem_informasi, teknologi_informasi, pembuatan_website, rancang_bangun, bahasa_pemrograman, in...
#
#                                                                                     Representative Text
# 0   [security, a, nuclear, material, an, installation, is, determined, by, how, far, installation, i...
# 1   [aplikasi, ujian, madrasah, lokal, area, network, lan, studi, kasus, mata, pelajaran, tik, madra...
# 2   [aplikasi, smart, card, electronic, medical, record, emr, smart, card, application, electronic, ...
# 3   [analisis, sistem, keamanan, jaringan, demilitarized, zone, dmz, dirjen, hak, kekayaan, intelekt...
# 4   [analisa, perancangan, sistem, manajemen, pengetahuan, knowzedge, menegemnt, system, departemen,...
# 5   [aplikasi, jaringan, syaraf, tiruan, memprediksi, prestasi, siswa, smu, metode, backpropagation,...
# 6   [perancangan, implementasi, perangkat, lunak, pengelompokkan, daerah, produksi, minyak, bumi, me...
# 7   [membangun, jaringan, internet, pc, router, vyatta, vc5, 2, interkoneksi, laboratorium, komputer...
# 8   [sistem, informasi, penerimaan, penyaluran, zakat, distribusi, konsumtif, produktif, studi, kasu...
# 9   [aplikasi, pelayanan, puskesmas, web, studi, kasus, puskesmas, kec, maja, pelayanan_puskesmas, s...
# 10  [sistem, pendukung, keputusan, seleksi, penerima, beasiswa, metode, ahp, topsis, studi, kasus, f...
# 11  [rekayasa, perangkat, lunak, pengambilan, keputusan, penerimaan, dosen, yayasan, pendidikan, dip...
# 12  [rancang, bangun, sistem, informasi, pemasangan, penayangan, iklan, rtv, konsep, customer, relat...
# 13  [penggunaan, sistem, pakar, pengembangan, portal, informasi, spesifikasi, jenis, penyakit, infek...
# 14  [perancangan, sistem, pendukung, keputusan, pemilihan, pemasok, pendekatan, fuzzy, analytical, h...
# 15  [aplikasi, data, mining, menampilkan, informasi, tingkat, kelulusan, mahasiswa, studi, kasus, fa...
# 16  [analisis, perancangan, sistem, informasi, perawatan, pasien, rumah, sakit, putri, surabaya, ana...
# 17  [analisis, perancangan, sistem, informasi, website, klub, sepeda, motor, jpn, jogja, punya, ninj...

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-2010.html')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 2     -0.164857  0.014247       1        1  8.024916
# 11    -0.101842 -0.088068       2        1  7.904720
# 14     0.014943 -0.031342       3        1  6.108862
# 15    -0.038310  0.050698       4        1  5.932711
# 10    -0.042491 -0.039655       5        1  5.803938
# 9      0.035711 -0.010919       6        1  5.698085
# 0      0.035131  0.082562       7        1  5.565830
# 8      0.053766  0.055047       8        1  5.548007
# 6      0.034768 -0.139308       9        1  5.521451
# 7     -0.002558  0.041195      10        1  5.493720
# 17    -0.018722  0.065280      11        1  5.276849
# 5      0.015509  0.010620      12        1  5.135469
# 1      0.046269 -0.034496      13        1  5.112897
# 3      0.082421 -0.055111      14        1  5.112485
# 12     0.021621 -0.004216      15        1  4.913669
# 13    -0.013081  0.030029      16        1  4.678983
# 4      0.031432  0.033774      17        1  4.379703
# 16     0.010289  0.019662      18        1  3.787702, topic_info=     Category       Freq                             Term       Total  \
# term
# 520   Default  21.000000                       e_commerce   21.000000
# 183   Default  45.000000                 sistem_pendukung   45.000000
# 509   Default  24.000000                      sms_gateway   24.000000
# 2043  Default  23.000000                      siswa_kelas   23.000000
# 90    Default  19.000000                      rumah_sakit   19.000000
# 429   Default  23.000000                    hasil_belajar   23.000000
# 788   Default  18.000000                       sma_negeri   18.000000
# 761   Default  29.000000                  perangkat_lunak   29.000000
# 2976  Default  11.000000              keputusan_pemilihan   11.000000
# 859   Default  12.000000                 sekolah_menengah   12.000000
# 765   Default  11.000000               model_pembelajaran   11.000000
# 3039  Default   8.000000                          matriks    8.000000
# 220   Default  17.000000                                e   17.000000
# 309   Default  10.000000                 prestasi_belajar   10.000000
# 640   Default   9.000000                    sekolah_dasar    9.000000
# 24    Default  10.000000               media_pembelajaran   10.000000
# 204   Default   8.000000                   load_balancing    8.000000
# 930   Default  12.000000                       smp_negeri   12.000000
# 336   Default  43.000000                     sistem_pakar   43.000000
# 301   Default  14.000000                            kelas   14.000000
# 163   Default   7.000000                      open_source    7.000000
# 2747  Default  10.000000                    pokok_bahasan   10.000000
# 433   Default  14.000000              analisa_perancangan   14.000000
# 28    Default  19.000000              teknologi_informasi   19.000000
# 562   Default  13.000000                        pc_router   13.000000
# 731   Default   7.000000                pembuatan_website    7.000000
# 123   Default  28.000000             analisis_perancangan   28.000000
# 1102  Default   9.000000                    client_server    9.000000
# 2464  Default  13.000000               rekayasa_perangkat   13.000000
# 2161  Default   8.000000                universitas_islam    8.000000
# ...       ...        ...                              ...         ...
# 1061  Topic18   0.976819                          sentral    1.580456
# 980   Topic18   0.961619                           header    1.565255
# 4729  Topic18   0.955678                          student    1.559315
# 1117  Topic18   2.231269                            jalan    3.653373
# 2101  Topic18   1.037361                          manfaat    1.699315
# 5346  Topic18   1.075148                       pemotongan    1.774462
# 2469  Topic18   1.202052                              non    2.075304
# 1580  Topic18   1.764127                      perhitungan    3.383927
# 563   Topic18   1.272596                             pgri    2.368856
# 4850  Topic18   1.340594                           jurnal    2.617376
# 123   Topic18   5.134020             analisis_perancangan   28.988850
# 558   Topic18   2.142055                    kota_pasuruan    6.084350
# 474   Topic18   1.825923                          potensi    4.943741
# 1712  Topic18   1.738503                            ruang    4.601921
# 438   Topic18   2.787824                        penjualan   14.518232
# 3224  Topic18   1.533724                            garis    3.976280
# 1107  Topic18   1.773583                         industri    6.368840
# 404   Topic18   2.321866                            hasil   14.173096
# 74    Topic18   3.505027                   rancang_bangun   56.357727
# 54    Topic18   3.761295                      studi_kasus   73.248154
# 191   Topic18   3.588465                 sistem_informasi  131.870010
# 1262  Topic18   2.008644  rancang_bangun_sistem_informasi   12.214001
# 386   Topic18   1.999457                       perusahaan   12.067673
# 43    Topic18   1.924678                         analisis   28.717745
# 193   Topic18   1.880519                              web   35.050945
# 131   Topic18   1.751252                      perancangan   33.505001
# 1239  Topic18   1.593701                  jaringan_syaraf    9.455572
# 73    Topic18   1.645508                          rancang   22.132971
# 70    Topic18   1.626025                           bangun   23.088665
# 22    Topic18   1.627934                        informasi   49.210186
#
#       loglift  logprob
# term
# 520   30.0000  30.0000
# 183   29.0000  29.0000
# 509   28.0000  28.0000
# 2043  27.0000  27.0000
# 90    26.0000  26.0000
# 429   25.0000  25.0000
# 788   24.0000  24.0000
# 761   23.0000  23.0000
# 2976  22.0000  22.0000
# 859   21.0000  21.0000
# 765   20.0000  20.0000
# 3039  19.0000  19.0000
# 220   18.0000  18.0000
# 309   17.0000  17.0000
# 640   16.0000  16.0000
# 24    15.0000  15.0000
# 204   14.0000  14.0000
# 930   13.0000  13.0000
# 336   12.0000  12.0000
# 301   11.0000  11.0000
# 163   10.0000  10.0000
# 2747   9.0000   9.0000
# 433    8.0000   8.0000
# 28     7.0000   7.0000
# 562    6.0000   6.0000
# 731    5.0000   5.0000
# 123    4.0000   4.0000
# 1102   3.0000   3.0000
# 2464   2.0000   2.0000
# 2161   1.0000   1.0000
# ...       ...      ...
# 1061   2.7922  -6.3096
# 980    2.7862  -6.3253
# 4729   2.7838  -6.3315
# 1117   2.7803  -5.4836
# 2101   2.7799  -6.2495
# 5346   2.7724  -6.2137
# 2469   2.7273  -6.1021
# 1580   2.6220  -5.7185
# 563    2.6521  -6.0451
# 4850   2.6044  -5.9930
# 123    1.5424  -4.6503
# 558    2.2295  -5.5244
# 474    2.2774  -5.6841
# 1712   2.3000  -5.7331
# 438    1.6233  -5.2609
# 3224   2.3208  -5.8585
# 1107   1.9950  -5.7132
# 404    1.4644  -5.4438
# 74     0.4959  -5.0320
# 54     0.3043  -4.9614
# 191   -0.3307  -5.0084
# 1262   1.4683  -5.5887
# 386    1.4758  -5.5933
# 43     0.5707  -5.6314
# 193    0.3482  -5.6546
# 131    0.3220  -5.7258
# 1239   1.4929  -5.8201
# 73     0.6744  -5.7881
# 70     0.6202  -5.8000
# 22    -0.1354  -5.7988
#
# [996 rows x 6 columns], token_table=      Topic      Freq                   Term
# term
# 475       8  0.137004                      0
# 475      13  0.685020                      0
# 4286     16  0.803371                     3d
# 701       3  0.107380                      a
# 701       5  0.107380                      a
# 701       6  0.107380                      a
# 701       7  0.429522                      a
# 701      11  0.107380                      a
# 701      18  0.107380                      a
# 1401      5  0.681877                absensi
# 2538     16  0.513074             acceptance
# 1254      5  0.814553                     ad
# 1694      1  0.736426  adisucipto_yogyakarta
# 7156      9  0.483121                  adobe
# 1661     10  0.877919            advertising
# 2560      9  0.800685                    aes
# 7071      9  0.766699           agribusiness
# 5804      5  0.752368           agroindustri
# 1025      6  0.542997                   ajar
# 1025      8  0.361998                   ajar
# 1025     14  0.180999                   ajar
# 2132     12  0.879458              aktivitas
# 1960      1  0.086301              akuntansi
# 1960      2  0.172601              akuntansi
# 1960      4  0.258902              akuntansi
# 1960      6  0.086301              akuntansi
# 1960      7  0.086301              akuntansi
# 1960     13  0.086301              akuntansi
# 1960     15  0.086301              akuntansi
# 1960     16  0.086301              akuntansi
# ...     ...       ...                    ...
# 193      16  0.057060                    web
# 193      17  0.028530                    web
# 193      18  0.057060                    web
# 314       5  0.951217            web_service
# 733       1  0.095754                website
# 733       2  0.095754                website
# 733       3  0.095754                website
# 733       4  0.095754                website
# 733      11  0.191508                website
# 733      14  0.095754                website
# 733      15  0.095754                website
# 733      17  0.095754                website
# 6908     15  0.815427                   wind
# 212       3  0.674945         windows_server
# 212      11  0.112491         windows_server
# 212      15  0.112491         windows_server
# 102       5  0.669459             windows_xp
# 271      13  0.684299           wireless_lan
# 1409      3  0.949954                   worm
# 1166      5  0.129615                      x
# 1166      7  0.129615                      x
# 1166      9  0.388846                      x
# 1166     10  0.129615                      x
# 1166     15  0.129615                      x
# 6760      9  0.681418                  x_sma
# 7756     11  0.483691                    xen
# 2045     14  0.779829                     xi
# 1435     13  0.766337                    xml
# 3604      7  0.536904                 yadika
# 3396     15  0.512429                      z
#
# [1834 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 12, 15, 16, 11, 10, 1, 9, 7, 8, 18, 6, 2, 4, 13, 14, 5, 17])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model-range4.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned-range4.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                     text
# 0      pendeteksi gangguan jaringan lokal metode cert...
# 1      eksistensi penggunaan wi fi warung kopi kota b...
# 2      pengaruh internet financial reporting tingkat ...
# 3      security function analysis performance high sp...
# 4      implementation top down approach method redesi...
# 5      optimization wireless network performance hier...
# 6      analysis qos vlan djikstra s algorithm open sh...
# 7      link performance improvement sananibun bts wit...
# 8      legal protection efforts patent holders indonesia
# 9      use e learning by teachers teaching learning p...
# 10     definition patent rights examples case studies...
# 11     analysis implementation backup line network br...
# 12     classification principles legal basis intellec...
# 13     attendance system automatic door locks laborat...
# 14          registration requirements application rights
# 15     patentability block chain technology future in...
# 16     influence speed user mobility qos wireless lan...
# 17     4 ghz omnidirectional antenna design with micr...
# 18     pemanfaatan telepon pintar informasi penyebara...
# 19     aplikasi teknologi komunikasi wireless zigbee ...
# 20     forensics analysis router computer networks li...
# 21                   manajemen proyeksi sistem informasi
# 22                   manajemen proyeksi sistem informasi
# 23                   tri destanto 175100067p sectionquis
# 24           rancang bangun aplikasi chatting web docker
# 25     multimedia animated corrosion corrosion coatin...
# 26     quality service traffic monitoring system stat...
# 27              analisis topologi area jaringan komputer
# 28              resume pembuatan tugas jaringan komputer
# 29              perkembangan jaringan komputer indonesia
# ...                                                  ...
# 37179  pengaruh pengetahuan keterlibatan pengguna pro...
# 37180  analisa cryptography penghitungan manual metod...
# 37181      steganografi citra terkompresi metode huffman
# 37182             steganografi video metode end file eof
# 37183  kajian kritis penyelenggaraan kegiatan pengemb...
# 37184  penggunaan teknik analisis pengembangan sistem...
# 37185  sistem rekomendasi pengambilan mata kuliah alg...
# 37186  sistem pengontrolan eksekusi pelanggaran lampu...
# 37187  analisis kombinasi steganografi metode gray co...
# 37188  pengaruh lingkungan kerja kepuasan kerja karya...
# 37189  implementasi algoritma luc pengamanan citra di...
# 37190  pengamanan data aplikasi penyimpanan cloud com...
# 37191  analisis perancangan user manager mikrotik rou...
# 37192  analisis pemanfaatan algoritma rsa pengamanan ...
# 37193  membangun firewall sistem operasi freebsd 4 ap...
# 37194  implementasi monitoring autonomous spreading m...
# 37195  tinjauan hukum internasional kasus hacking son...
# 37196  enkripsi dekripsi pesan grup simetri mengamank...
# 37197  perancangan e business trimatra unggul sadaya ...
# 37198  mereduksi serangan denial services terdistribu...
# 37199  bagaimana standar eu nis platform nist ietf me...
# 37200                slims membangun kerjasama komunitas
# 37201                 panduan hacking website kali linux
# 37202  sistem informasi properti web metode object mo...
# 37203  pembuatan situs social network mahasiswa dosen...
# 37204  analisis faktor faktor mempengaruhi kinerja si...
# 37205  analisis kesalahan sintaksis abstract skripsi ...
# 37206    cyberpornography kejahatan pornografi masa kini
# 37207  efek media sosial facebook murid kelas vi enam...
# 37208  analisis kinerja metode metode seleksi algorit...
#
# [37209 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 37209
# [['pendeteksi', 'gangguan', 'jaringan', 'lokal', 'metode', 'certainty', 'factor']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                      0               1                2             3   \
# 0            pendeteksi        gangguan         jaringan         lokal
# 1            eksistensi      penggunaan               wi            fi
# 2              pengaruh        internet        financial     reporting
# 3              security        function         analysis   performance
# 4        implementation             top             down      approach
# 5          optimization        wireless          network   performance
# 6              analysis             qos             vlan      djikstra
# 7                  link     performance      improvement     sananibun
# 8                 legal      protection          efforts        patent
# 9                   use               e         learning            by
# 10           definition          patent           rights      examples
# 11             analysis  implementation           backup          line
# 12       classification      principles            legal         basis
# 13           attendance          system        automatic          door
# 14         registration    requirements      application        rights
# 15        patentability           block            chain    technology
# 16            influence           speed             user      mobility
# 17                    4             ghz  omnidirectional       antenna
# 18          pemanfaatan         telepon           pintar     informasi
# 19             aplikasi       teknologi       komunikasi      wireless
# 20            forensics        analysis           router      computer
# 21            manajemen        proyeksi           sistem     informasi
# 22            manajemen        proyeksi           sistem     informasi
# 23                  tri        destanto       175100067p   sectionquis
# 24              rancang          bangun         aplikasi      chatting
# 25           multimedia        animated        corrosion     corrosion
# 26              quality         service          traffic    monitoring
# 27             analisis        topologi             area      jaringan
# 28               resume       pembuatan            tugas      jaringan
# 29         perkembangan        jaringan         komputer     indonesia
# ...                 ...             ...              ...           ...
# 37179          pengaruh     pengetahuan     keterlibatan      pengguna
# 37180           analisa    cryptography     penghitungan        manual
# 37181      steganografi           citra      terkompresi        metode
# 37182      steganografi           video           metode           end
# 37183            kajian          kritis  penyelenggaraan      kegiatan
# 37184        penggunaan          teknik         analisis  pengembangan
# 37185            sistem     rekomendasi      pengambilan          mata
# 37186            sistem    pengontrolan         eksekusi   pelanggaran
# 37187          analisis       kombinasi     steganografi        metode
# 37188          pengaruh      lingkungan            kerja      kepuasan
# 37189      implementasi       algoritma              luc    pengamanan
# 37190        pengamanan            data         aplikasi   penyimpanan
# 37191          analisis     perancangan             user       manager
# 37192          analisis     pemanfaatan        algoritma           rsa
# 37193         membangun        firewall           sistem       operasi
# 37194      implementasi      monitoring       autonomous     spreading
# 37195          tinjauan           hukum    internasional         kasus
# 37196          enkripsi        dekripsi            pesan          grup
# 37197       perancangan               e         business      trimatra
# 37198         mereduksi        serangan           denial      services
# 37199         bagaimana         standar               eu           nis
# 37200             slims       membangun        kerjasama     komunitas
# 37201           panduan         hacking          website          kali
# 37202            sistem       informasi         properti           web
# 37203         pembuatan           situs           social       network
# 37204          analisis          faktor           faktor  mempengaruhi
# 37205          analisis       kesalahan        sintaksis      abstract
# 37206  cyberpornography       kejahatan       pornografi          masa
# 37207              efek           media           sosial      facebook
# 37208          analisis         kinerja           metode        metode
#
#                        4                   5                   6   \
# 0                  metode           certainty              factor
# 1                  warung                kopi                kota
# 2                 tingkat        pengungkapan           informasi
# 3                    high               speed              router
# 4                  method            redesign                 lan
# 5            hierarchical               token              bucket
# 6                       s           algorithm                open
# 7                     bts                with                link
# 8                 holders           indonesia                None
# 9                teachers            teaching            learning
# 10                   case             studies              iphone
# 11                network              branch              office
# 12           intellectual            property           indonesia
# 13                  locks          laboratory          electrical
# 14                   None                None                None
# 15                 future          innovation                None
# 16                    qos            wireless                 lan
# 17                 design                with          microstrip
# 18             penyebaran              lokasi                guru
# 19                 zigbee              sistem             kontrol
# 20               networks                live           forensics
# 21     manajemen_proyeksi  manajemen_proyeksi  manajemen_proyeksi
# 22     manajemen_proyeksi  manajemen_proyeksi  manajemen_proyeksi
# 23                   None                None                None
# 24                    web              docker      rancang_bangun
# 25                coating              metals              course
# 26                 system              static             routing
# 27               komputer   jaringan_komputer   jaringan_komputer
# 28               komputer   jaringan_komputer   jaringan_komputer
# 29      jaringan_komputer   jaringan_komputer   jaringan_komputer
# ...                   ...                 ...                 ...
# 37179              produk              sistem           informasi
# 37180              metode             matriks                None
# 37181             huffman   citra_terkompresi                None
# 37182                file                 eof            end_file
# 37183        pengembangan             layanan           informasi
# 37184              sistem           informasi                soft
# 37185              kuliah           algoritma            genetika
# 37186               lampu                lalu              lintas
# 37187                gray               codes               pixel
# 37188               kerja            karyawan          direktorat
# 37189               citra             digital             desktop
# 37190               cloud           computing               media
# 37191            mikrotik              router              sistem
# 37192          pengamanan              acakan                biss
# 37193             freebsd                   4            aplikasi
# 37194             malware                 its                 net
# 37195             hacking                sony            pictures
# 37196             simetri         mengamankan           informasi
# 37197              unggul              sadaya              metode
# 37198       terdistribusi               linux             virtual
# 37199            platform                nist                ietf
# 37200                None                None                None
# 37201               linux                None                None
# 37202              metode              object           modelling
# 37203           mahasiswa               dosen               stmik
# 37204             kinerja              sistem           informasi
# 37205             skripsi           mahasiswa              teknik
# 37206                kini                None                None
# 37207               murid               kelas                  vi
# 37208             seleksi           algoritma            genetika
#
#                        7                  8                    9   ...     32  \
# 0          jaringan_lokal   metode_certainty  pendeteksi_gangguan  ...   None
# 1                   banda               aceh                wi_fi  ...   None
# 2                 website          frekuensi          perdagangan  ...   None
# 3              networking               None                 None  ...   None
# 4                 harvani              hotel            palembang  ...   None
# 5                    case       muhammadiyah           university  ...   None
# 6                shortest               path                first  ...   None
# 7                  switch          migration             backbone  ...   None
# 8                    None               None                 None  ...   None
# 9                 process         e_learning           e_learning  ...   None
# 10               products               None                 None  ...   None
# 11                    vpn             speedy             internet  ...   None
# 12                   None               None                 None  ...   None
# 13            engineering         department                   at  ...   None
# 14                   None               None                 None  ...   None
# 15                   None               None                 None  ...   None
# 16                     11                  g                   11  ...   None
# 17           technologies                gsm             internet  ...   None
# 18                sekolah              dasar               negeri  ...   None
# 19             monitoring            ruangan                kelas  ...   None
# 20                 method     live_forensics       live_forensics  ...   None
# 21                   None               None                 None  ...   None
# 22                   None               None                 None  ...   None
# 23                   None               None                 None  ...   None
# 24      aplikasi_chatting     rancang_bangun    aplikasi_chatting  ...   None
# 25                   None               None                 None  ...   None
# 26                   eoip             tunnel                 over  ...   None
# 27      jaringan_komputer               None                 None  ...   None
# 28      jaringan_komputer               None                 None  ...   None
# 29                   None               None                 None  ...   None
# ...                   ...                ...                  ...  ...    ...
# 37179            kualitas             sistem            informasi  ...   None
# 37180                None               None                 None  ...   None
# 37181                None               None                 None  ...   None
# 37182            end_file           end_file                 None  ...   None
# 37183              kepada         masyarakat                  sms  ...   None
# 37184              system        methodology                  ssm  ...   None
# 37185              metode         constraint         satisfaction  ...   None
# 37186               board           funduino                  ldr  ...   None
# 37187               value       differencing        penyembunyian  ...   None
# 37188              sumber               daya              manusia  ...   None
# 37189       citra_digital   pengamanan_citra        citra_digital  ...   None
# 37190             storage          algoritma             genetika  ...   None
# 37191           pembelian             kredit              voucher  ...   None
# 37192       algoritma_rsa      algoritma_rsa        algoritma_rsa  ...   None
# 37193          ipfirewall               ipfw                 None  ...   None
# 37194             dionaea             cuckoo                 None  ...   None
# 37195       entertainment     tinjauan_hukum       tinjauan_hukum  ...   None
# 37196   enkripsi_dekripsi  enkripsi_dekripsi    enkripsi_dekripsi  ...   None
# 37197             quality           function           deployment  ...   None
# 37198              server           honeypot      server_honeypot  ...   None
# 37199             menjadi            dinding           penghambat  ...   None
# 37200                None               None                 None  ...   None
# 37201                None               None                 None  ...   None
# 37202           technique                omt                 None  ...   None
# 37203               sinar          nusantara            surakarta  ...   None
# 37204           akuntansi               bank               negara  ...   None
# 37205         informatika              stmik               amikom  ...   None
# 37206                None               None                 None  ...   None
# 37207                enam                sdn          bontokamase  ...   None
# 37208  algoritma_genetika   analisis_kinerja   algoritma_genetika  ...   None
#
#          33    34    35    36    37    38    39    40    41
# 0      None  None  None  None  None  None  None  None  None
# 1      None  None  None  None  None  None  None  None  None
# 2      None  None  None  None  None  None  None  None  None
# 3      None  None  None  None  None  None  None  None  None
# 4      None  None  None  None  None  None  None  None  None
# 5      None  None  None  None  None  None  None  None  None
# 6      None  None  None  None  None  None  None  None  None
# 7      None  None  None  None  None  None  None  None  None
# 8      None  None  None  None  None  None  None  None  None
# 9      None  None  None  None  None  None  None  None  None
# 10     None  None  None  None  None  None  None  None  None
# 11     None  None  None  None  None  None  None  None  None
# 12     None  None  None  None  None  None  None  None  None
# 13     None  None  None  None  None  None  None  None  None
# 14     None  None  None  None  None  None  None  None  None
# 15     None  None  None  None  None  None  None  None  None
# 16     None  None  None  None  None  None  None  None  None
# 17     None  None  None  None  None  None  None  None  None
# 18     None  None  None  None  None  None  None  None  None
# 19     None  None  None  None  None  None  None  None  None
# 20     None  None  None  None  None  None  None  None  None
# 21     None  None  None  None  None  None  None  None  None
# 22     None  None  None  None  None  None  None  None  None
# 23     None  None  None  None  None  None  None  None  None
# 24     None  None  None  None  None  None  None  None  None
# 25     None  None  None  None  None  None  None  None  None
# 26     None  None  None  None  None  None  None  None  None
# 27     None  None  None  None  None  None  None  None  None
# 28     None  None  None  None  None  None  None  None  None
# 29     None  None  None  None  None  None  None  None  None
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 37179  None  None  None  None  None  None  None  None  None
# 37180  None  None  None  None  None  None  None  None  None
# 37181  None  None  None  None  None  None  None  None  None
# 37182  None  None  None  None  None  None  None  None  None
# 37183  None  None  None  None  None  None  None  None  None
# 37184  None  None  None  None  None  None  None  None  None
# 37185  None  None  None  None  None  None  None  None  None
# 37186  None  None  None  None  None  None  None  None  None
# 37187  None  None  None  None  None  None  None  None  None
# 37188  None  None  None  None  None  None  None  None  None
# 37189  None  None  None  None  None  None  None  None  None
# 37190  None  None  None  None  None  None  None  None  None
# 37191  None  None  None  None  None  None  None  None  None
# 37192  None  None  None  None  None  None  None  None  None
# 37193  None  None  None  None  None  None  None  None  None
# 37194  None  None  None  None  None  None  None  None  None
# 37195  None  None  None  None  None  None  None  None  None
# 37196  None  None  None  None  None  None  None  None  None
# 37197  None  None  None  None  None  None  None  None  None
# 37198  None  None  None  None  None  None  None  None  None
# 37199  None  None  None  None  None  None  None  None  None
# 37200  None  None  None  None  None  None  None  None  None
# 37201  None  None  None  None  None  None  None  None  None
# 37202  None  None  None  None  None  None  None  None  None
# 37203  None  None  None  None  None  None  None  None  None
# 37204  None  None  None  None  None  None  None  None  None
# 37205  None  None  None  None  None  None  None  None  None
# 37206  None  None  None  None  None  None  None  None  None
# 37207  None  None  None  None  None  None  None  None  None
# 37208  None  None  None  None  None  None  None  None  None
#
# [37209 rows x 42 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(28374 unique tokens: ['certainty', 'factor', 'gangguan', 'jaringan', 'jaringan_lokal']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 37209

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))
# Out:
# Num Topics = 2  has Coherence Value of 0.2494291811
# Num Topics = 4  has Coherence Value of 0.3595832496
# Num Topics = 6  has Coherence Value of 0.3742248968
# Num Topics = 8  has Coherence Value of 0.4053329782
# Num Topics = 10  has Coherence Value of 0.4089944474
# Num Topics = 12  has Coherence Value of 0.399623846
# Num Topics = 14  has Coherence Value of 0.4350168647
# Num Topics = 16  has Coherence Value of 0.4725884472
# Num Topics = 18  has Coherence Value of 0.4776285773

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=18)
pprint(model.print_topics())
# Out:
# [(0,
#   '0.008*"persediaan_barang" + 0.008*"backward_chaining" + '
#   '0.007*"rancang_bangun" + 0.006*"deteksi_tepi" + 0.006*"basis_data" + '
#   '0.006*"persediaan" + 0.005*"citra" + 0.005*"analisis_perbandingan" + '
#   '0.005*"aplikasi_panduan" + 0.005*"barang"'),
#  (1,
#   '0.009*"rancang_bangun" + 0.009*"smartphone_android" + 0.008*"k_nearest" + '
#   '0.008*"politeknik_negeri" + 0.007*"metode_promethee" + 0.006*"perpustakaan" '
#   '+ 0.006*"objek_wisata" + 0.006*"studi_kasus" + 0.006*"kesehatan" + '
#   '0.006*"informasi"'),
#  (2,
#   '0.016*"sms_gateway" + 0.014*"e_commerce" + 0.010*"forward_chaining" + '
#   '0.009*"studi_kasus" + 0.008*"rancang_bangun" + 0.008*"php_mysql" + '
#   '0.007*"sms" + 0.007*"terbaik" + 0.006*"gateway" + 0.005*"php"'),
#  (3,
#   '0.015*"jaringan_syaraf" + 0.014*"fuzzy_logic" + 0.014*"case_reasoning" + '
#   '0.010*"rancang_bangun" + 0.009*"information_system" + '
#   '0.008*"penerimaan_siswa" + 0.007*"certainty_factor" + 0.007*"google_maps" + '
#   '0.006*"penerimaan" + 0.006*"syaraf"'),
#  (4,
#   '0.025*"informasi_geografis" + 0.015*"media_pembelajaran" + '
#   '0.010*"pembelajaran" + 0.010*"mata_pelajaran" + 0.010*"siswa_kelas" + '
#   '0.009*"pengembangan_media" + 0.008*"geografis" + 0.008*"informasi" + '
#   '0.008*"pengolahan_citra" + 0.008*"program_studi"'),
#  (5,
#   '0.011*"hasil_belajar" + 0.009*"visual_basic" + 0.007*"rekam_medis" + '
#   '0.006*"studi_kasus" + 0.005*"visual" + 0.005*"kabupaten_kudus" + '
#   '0.004*"segmentasi_citra" + 0.004*"puskesmas" + 0.004*"belajar" + '
#   '0.004*"virtual_reality"'),
#  (6,
#   '0.015*"metode_weighted" + 0.011*"fuzzy_tsukamoto" + '
#   '0.008*"jaringan_internet" + 0.007*"qr_code" + 0.006*"weighted" + '
#   '0.006*"universitas_islam" + 0.005*"product" + 0.005*"penentuan_penerima" + '
#   '0.005*"tata_kelola" + 0.005*"evaluasi_kinerja"'),
#  (7,
#   '0.017*"pendukung_keputusan" + 0.014*"informasi_akuntansi" + '
#   '0.013*"rancang_bangun" + 0.011*"diagnosa_penyakit" + '
#   '0.011*"profile_matching" + 0.010*"sma_negeri" + 0.010*"smp_negeri" + '
#   '0.009*"sekolah_dasar" + 0.009*"informasi_penjualan" + 0.009*"studi_kasus"'),
#  (8,
#   '0.016*"smk_negeri" + 0.012*"tugas_akhir" + 0.010*"operasi_android" + '
#   '0.009*"keamanan_jaringan" + 0.008*"naïve_bayes" + 0.007*"studi_kasus" + '
#   '0.006*"rancang_bangun" + 0.006*"fakultas_sains" + 0.005*"informasi" + '
#   '0.005*"informasi_akademik"'),
#  (9,
#   '0.014*"algoritma_genetika" + 0.014*"logika_fuzzy" + '
#   '0.013*"jaringan_komputer" + 0.013*"game_edukasi" + '
#   '0.010*"penilaian_kinerja" + 0.008*"pengambilan_keputusan" + '
#   '0.008*"data_warehouse" + 0.007*"fuzzy_inference" + 0.007*"studi_kasus" + '
#   '0.006*"sumber_daya"'),
#  (10,
#   '0.025*"metode_simple" + 0.021*"additive_weighting" + '
#   '0.015*"penunjang_keputusan" + 0.014*"simple" + 0.013*"additive" + '
#   '0.013*"weighting" + 0.009*"metode_simple_additive_weighting" + '
#   '0.009*"keputusan" + 0.008*"beasiswa" + 0.008*"jaringan_saraf"'),
#  (11,
#   '0.019*"e_learning" + 0.013*"mata_kuliah" + 0.012*"data_mining" + '
#   '0.010*"teknik_informatika" + 0.007*"learning" + 0.006*"jurusan_teknik" + '
#   '0.006*"studi_kasus" + 0.006*"knowledge_management" + '
#   '0.005*"informasi_pendataan" + 0.005*"e"'),
#  (12,
#   '0.026*"metode_certainty" + 0.020*"pakar_mendiagnosa" + 0.012*"pakar" + '
#   '0.012*"pakar_diagnosis" + 0.010*"penyakit" + 0.010*"learning_vector" + '
#   '0.009*"teorema_bayes" + 0.009*"mendiagnosa" + 0.009*"certainty" + '
#   '0.008*"factor"'),
#  (13,
#   '0.037*"metode_forward" + 0.031*"pakar_diagnosa" + 0.016*"pakar" + '
#   '0.015*"informasi_akademik" + 0.014*"analytical_hierarchy" + '
#   '0.014*"chaining" + 0.014*"metode_dempster" + 0.014*"forward" + '
#   '0.013*"diagnosa" + 0.012*"penyakit"'),
#  (14,
#   '0.045*"pendukung_keputusan" + 0.020*"perangkat_lunak" + 0.014*"pendukung" + '
#   '0.013*"keputusan" + 0.011*"pengolahan_data" + 0.009*"perangkat" + '
#   '0.009*"sekolah_menengah" + 0.009*"lunak" + 0.008*"pemilihan" + '
#   '0.008*"rekayasa_perangkat"'),
#  (15,
#   '0.016*"naive_bayes" + 0.012*"perguruan_tinggi" + '
#   '0.012*"pendukung_keputusan" + 0.009*"fakultas_teknik" + 0.007*"studi_kasus" '
#   '+ 0.007*"sd_negeri" + 0.006*"alat_bantu" + 0.006*"simpan_pinjam" + '
#   '0.006*"tinggi" + 0.006*"naive"'),
#  (16,
#   '0.018*"raspberry_pi" + 0.016*"augmented_reality" + 0.008*"k_means" + '
#   '0.008*"rancang_bangun" + 0.007*"sepeda_motor" + 0.007*"reality" + '
#   '0.007*"augmented" + 0.007*"client_server" + 0.006*"pi" + 0.006*"raspberry"'),
#  (17,
#   '0.014*"pendukung_keputusan" + 0.013*"rumah_sakit" + 0.009*"studi_kasus" + '
#   '0.008*"expert_system" + 0.008*"neural_network" + 0.007*"kota_palembang" + '
#   '0.006*"anak_usia" + 0.006*"principal_component" + 0.006*"fuzzy_sugeno" + '
#   '0.006*"analytic_hierarchy"')]

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=18)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.024*"informasi_akademik" + 0.017*"augmented_reality" + 0.012*"smk_negeri" + 0.011*"sekolah_menengah" + 0.011*"informasi" + 0.010*"studi_kasus" + 0.008*"akademik" + 0.008*"perpustakaan" + 0.006*"jakarta" + 0.006*"sekolah"
# Topic: 1 Word: 0.011*"diagnosa_penyakit" + 0.011*"jaringan_komputer" + 0.009*"teknik_informatika" + 0.008*"expert_system" + 0.008*"data_mining" + 0.007*"visual_basic" + 0.007*"sepeda_motor" + 0.007*"backward_chaining" + 0.007*"data" + 0.005*"kriptografi"
# Topic: 2 Word: 0.032*"metode_forward" + 0.031*"pakar_diagnosa" + 0.013*"diagnosa" + 0.012*"pakar" + 0.011*"forward" + 0.011*"chaining" + 0.010*"fuzzy_tsukamoto" + 0.008*"studi_kasus" + 0.008*"penyakit" + 0.008*"rancang_bangun"
# Topic: 3 Word: 0.015*"metode_weighted" + 0.014*"penunjang_keputusan" + 0.009*"keamanan_jaringan" + 0.009*"citra_digital" + 0.008*"penerimaan_siswa" + 0.008*"kota_palembang" + 0.007*"pakar_diagnosa" + 0.007*"bahasa_pemrograman" + 0.007*"support_vector" + 0.007*"certainty_factor"
# Topic: 4 Word: 0.013*"perguruan_tinggi" + 0.011*"pengembangan_media" + 0.009*"php_mysql" + 0.007*"php" + 0.007*"fuzzy_sugeno" + 0.007*"objek_wisata" + 0.006*"analisis_perbandingan" + 0.005*"mysql" + 0.005*"pengembangan_modul" + 0.005*"studi_kasus"
# Topic: 5 Word: 0.016*"fuzzy_logic" + 0.010*"sma_negeri" + 0.009*"naïve_bayes" + 0.008*"informasi_penjualan" + 0.008*"studi_kasus" + 0.008*"informasi" + 0.006*"penjualan" + 0.006*"pariwisata_kabupaten" + 0.006*"waterfall" + 0.006*"model_waterfall"
# Topic: 6 Word: 0.032*"pendukung_keputusan" + 0.012*"keputusan" + 0.012*"pendukung" + 0.012*"pengolahan_citra" + 0.010*"mata_kuliah" + 0.009*"saw" + 0.009*"topsis" + 0.008*"studi_kasus" + 0.008*"pakar_mendeteksi" + 0.008*"hasil_belajar"
# Topic: 7 Word: 0.024*"pakar_mendiagnosa" + 0.024*"metode_certainty" + 0.013*"pakar" + 0.012*"penyakit" + 0.010*"learning_vector" + 0.010*"mendiagnosa" + 0.009*"metode_dempster" + 0.008*"certainty" + 0.007*"factor" + 0.007*"metode"
# Topic: 8 Word: 0.014*"rumah_sakit" + 0.012*"e_learning" + 0.012*"game_edukasi" + 0.011*"operasi_android" + 0.009*"rekayasa_perangkat" + 0.009*"operasi" + 0.008*"studi_kasus" + 0.008*"kelas_x" + 0.008*"rancang_bangun" + 0.007*"persediaan_barang"
# Topic: 9 Word: 0.043*"rancang_bangun" + 0.014*"sms_gateway" + 0.014*"rancang" + 0.014*"bangun" + 0.013*"e_commerce" + 0.011*"studi_kasus" + 0.009*"smp_negeri" + 0.009*"android" + 0.008*"aplikasi" + 0.007*"smartphone_android"
# Topic: 10 Word: 0.015*"case_reasoning" + 0.010*"k_nearest" + 0.007*"pengenalan_pola" + 0.006*"aplikasi_panduan" + 0.005*"bahasa_inggris" + 0.005*"reasoning" + 0.005*"case" + 0.005*"k" + 0.005*"geographic_information" + 0.005*"rule"
# Topic: 11 Word: 0.027*"pendukung_keputusan" + 0.022*"metode_simple" + 0.019*"additive_weighting" + 0.013*"simple" + 0.011*"additive" + 0.011*"weighting" + 0.010*"pendukung" + 0.010*"keputusan" + 0.010*"studi_kasus" + 0.008*"metode_simple_additive_weighting"
# Topic: 12 Word: 0.022*"pendukung_keputusan" + 0.020*"perangkat_lunak" + 0.013*"analytical_hierarchy" + 0.010*"pengolahan_data" + 0.008*"process" + 0.008*"forward_chaining" + 0.008*"studi_kasus" + 0.008*"ahp" + 0.008*"pendukung" + 0.008*"keputusan"
# Topic: 13 Word: 0.031*"informasi_geografis" + 0.017*"raspberry_pi" + 0.013*"logika_fuzzy" + 0.013*"algoritma_genetika" + 0.012*"tugas_akhir" + 0.011*"profile_matching" + 0.011*"geografis" + 0.009*"pendukung_keputusan" + 0.007*"rancang_bangun" + 0.007*"client_server"
# Topic: 14 Word: 0.017*"naive_bayes" + 0.009*"jaringan_saraf" + 0.008*"qr_code" + 0.007*"pengolahan_citra" + 0.007*"alat_bantu" + 0.007*"deteksi_tepi" + 0.006*"naive" + 0.006*"jaringan_syaraf" + 0.006*"tiruan_backpropagation" + 0.005*"object_oriented"
# Topic: 15 Word: 0.016*"informasi_akuntansi" + 0.013*"pakar_diagnosis" + 0.010*"teorema_bayes" + 0.007*"anak_usia" + 0.006*"akuntansi" + 0.006*"studi_kasus" + 0.006*"palembang" + 0.006*"informasi" + 0.006*"kota_semarang" + 0.005*"tata_kelola"
# Topic: 16 Word: 0.017*"jaringan_syaraf" + 0.009*"neural_network" + 0.008*"beasiswa" + 0.008*"data_warehouse" + 0.008*"program_studi" + 0.006*"syaraf" + 0.006*"tiruan" + 0.006*"simpan_pinjam" + 0.005*"seleksi" + 0.005*"persamaan_linier"
# Topic: 17 Word: 0.016*"media_pembelajaran" + 0.012*"pembelajaran" + 0.012*"mata_pelajaran" + 0.010*"siswa_kelas" + 0.009*"sekolah_dasar" + 0.009*"penilaian_kinerja" + 0.008*"media" + 0.008*"information_system" + 0.007*"kelas" + 0.007*"siswa"

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)
# Out:
#      No_Dokumen  Topik_Dominan  Persentase_Kontribusi  \
# 0             0           13.0                 0.4162
# 1             1           17.0                 0.7292
# 2             2            1.0                 0.7422
# 3             3            7.0                 0.5953
# 4             4            3.0                 0.9325
# 5             5           15.0                 0.5494
# 6             6            2.0                 0.6504
# 7             7           13.0                 0.4340
# 8             8           16.0                 0.5255
# 9             9            6.0                 0.4739
# 10           10           11.0                 0.4731
# 11           11            1.0                 0.7533
# 12           12           16.0                 0.3304
# 13           13           15.0                 0.3198
# 14           14            9.0                 0.2592
# 15           15           12.0                 0.7106
# 16           16            3.0                 0.2421
# 17           17           17.0                 0.8743
# 18           18            5.0                 0.4585
# 19           19            9.0                 0.4717
# 20           20            8.0                 0.5447
# 21           21           12.0                 0.8819
# 22           22           12.0                 0.8819
# 23           23            4.0                 0.8111
# 24           24            9.0                 0.4848
# 25           25            9.0                 0.7352
# 26           26            1.0                 0.8692
# 27           27            1.0                 0.7571
# 28           28            1.0                 0.6965
# 29           29            1.0                 0.7781
# ..          ...            ...                    ...
# 217         217           15.0                 0.8819
# 218         218            1.0                 0.3837
# 219         219            4.0                 0.9503
# 220         220            7.0                 0.4109
# 221         221            6.0                 0.8384
# 222         222            8.0                 0.4446
# 223         223            9.0                 0.5818
# 224         224            3.0                 0.4373
# 225         225           13.0                 0.4370
# 226         226           13.0                 0.5298
# 227         227            4.0                 0.6131
# 228         228           16.0                 0.9274
# 229         229            3.0                 0.4489
# 230         230            6.0                 0.3562
# 231         231           17.0                 0.3873
# 232         232           17.0                 0.4036
# 233         233           13.0                 0.9213
# 234         234           11.0                 0.3522
# 235         235            0.0                 0.4455
# 236         236            4.0                 0.7120
# 237         237            1.0                 0.8788
# 238         238           17.0                 0.9370
# 239         239           12.0                 0.9637
# 240         240           15.0                 0.8578
# 241         241           17.0                 0.6676
# 242         242           16.0                 0.7188
# 243         243            4.0                 0.3975
# 244         244           17.0                 0.3565
# 245         245            3.0                 0.8439
# 246         246            1.0                 0.7670
#
#                                             Kata_Kunci  \
# 0    informasi_geografis, raspberry_pi, logika_fuzz...
# 1    media_pembelajaran, pembelajaran, mata_pelajar...
# 2    diagnosa_penyakit, jaringan_komputer, teknik_i...
# 3    pakar_mendiagnosa, metode_certainty, pakar, pe...
# 4    metode_weighted, penunjang_keputusan, keamanan...
# 5    informasi_akuntansi, pakar_diagnosis, teorema_...
# 6    metode_forward, pakar_diagnosa, diagnosa, paka...
# 7    informasi_geografis, raspberry_pi, logika_fuzz...
# 8    jaringan_syaraf, neural_network, beasiswa, dat...
# 9    pendukung_keputusan, keputusan, pendukung, pen...
# 10   pendukung_keputusan, metode_simple, additive_w...
# 11   diagnosa_penyakit, jaringan_komputer, teknik_i...
# 12   jaringan_syaraf, neural_network, beasiswa, dat...
# 13   informasi_akuntansi, pakar_diagnosis, teorema_...
# 14   rancang_bangun, sms_gateway, rancang, bangun, ...
# 15   pendukung_keputusan, perangkat_lunak, analytic...
# 16   metode_weighted, penunjang_keputusan, keamanan...
# 17   media_pembelajaran, pembelajaran, mata_pelajar...
# 18   fuzzy_logic, sma_negeri, naïve_bayes, informas...
# 19   rancang_bangun, sms_gateway, rancang, bangun, ...
# 20   rumah_sakit, e_learning, game_edukasi, operasi...
# 21   pendukung_keputusan, perangkat_lunak, analytic...
# 22   pendukung_keputusan, perangkat_lunak, analytic...
# 23   perguruan_tinggi, pengembangan_media, php_mysq...
# 24   rancang_bangun, sms_gateway, rancang, bangun, ...
# 25   rancang_bangun, sms_gateway, rancang, bangun, ...
# 26   diagnosa_penyakit, jaringan_komputer, teknik_i...
# 27   diagnosa_penyakit, jaringan_komputer, teknik_i...
# 28   diagnosa_penyakit, jaringan_komputer, teknik_i...
# 29   diagnosa_penyakit, jaringan_komputer, teknik_i...
# ..                                                 ...
# 217  informasi_akuntansi, pakar_diagnosis, teorema_...
# 218  diagnosa_penyakit, jaringan_komputer, teknik_i...
# 219  perguruan_tinggi, pengembangan_media, php_mysq...
# 220  pakar_mendiagnosa, metode_certainty, pakar, pe...
# 221  pendukung_keputusan, keputusan, pendukung, pen...
# 222  rumah_sakit, e_learning, game_edukasi, operasi...
# 223  rancang_bangun, sms_gateway, rancang, bangun, ...
# 224  metode_weighted, penunjang_keputusan, keamanan...
# 225  informasi_geografis, raspberry_pi, logika_fuzz...
# 226  informasi_geografis, raspberry_pi, logika_fuzz...
# 227  perguruan_tinggi, pengembangan_media, php_mysq...
# 228  jaringan_syaraf, neural_network, beasiswa, dat...
# 229  metode_weighted, penunjang_keputusan, keamanan...
# 230  pendukung_keputusan, keputusan, pendukung, pen...
# 231  media_pembelajaran, pembelajaran, mata_pelajar...
# 232  media_pembelajaran, pembelajaran, mata_pelajar...
# 233  informasi_geografis, raspberry_pi, logika_fuzz...
# 234  pendukung_keputusan, metode_simple, additive_w...
# 235  informasi_akademik, augmented_reality, smk_neg...
# 236  perguruan_tinggi, pengembangan_media, php_mysq...
# 237  diagnosa_penyakit, jaringan_komputer, teknik_i...
# 238  media_pembelajaran, pembelajaran, mata_pelajar...
# 239  pendukung_keputusan, perangkat_lunak, analytic...
# 240  informasi_akuntansi, pakar_diagnosis, teorema_...
# 241  media_pembelajaran, pembelajaran, mata_pelajar...
# 242  jaringan_syaraf, neural_network, beasiswa, dat...
# 243  perguruan_tinggi, pengembangan_media, php_mysq...
# 244  media_pembelajaran, pembelajaran, mata_pelajar...
# 245  metode_weighted, penunjang_keputusan, keamanan...
# 246  diagnosa_penyakit, jaringan_komputer, teknik_i...
#
#                                                   Teks
# 0    [pendeteksi, gangguan, jaringan, lokal, metode...
# 1    [eksistensi, penggunaan, wi, fi, warung, kopi,...
# 2    [pengaruh, internet, financial, reporting, tin...
# 3    [security, function, analysis, performance, hi...
# 4    [implementation, top, down, approach, method, ...
# 5    [optimization, wireless, network, performance,...
# 6    [analysis, qos, vlan, djikstra, s, algorithm, ...
# 7    [link, performance, improvement, sananibun, bt...
# 8    [legal, protection, efforts, patent, holders, ...
# 9    [use, e, learning, by, teachers, teaching, lea...
# 10   [definition, patent, rights, examples, case, s...
# 11   [analysis, implementation, backup, line, netwo...
# 12   [classification, principles, legal, basis, int...
# 13   [attendance, system, automatic, door, locks, l...
# 14   [registration, requirements, application, rights]
# 15   [patentability, block, chain, technology, futu...
# 16   [influence, speed, user, mobility, qos, wirele...
# 17   [4, ghz, omnidirectional, antenna, design, wit...
# 18   [pemanfaatan, telepon, pintar, informasi, peny...
# 19   [aplikasi, teknologi, komunikasi, wireless, zi...
# 20   [forensics, analysis, router, computer, networ...
# 21   [manajemen, proyeksi, sistem, informasi, manaj...
# 22   [manajemen, proyeksi, sistem, informasi, manaj...
# 23            [tri, destanto, 175100067p, sectionquis]
# 24   [rancang, bangun, aplikasi, chatting, web, doc...
# 25   [multimedia, animated, corrosion, corrosion, c...
# 26   [quality, service, traffic, monitoring, system...
# 27   [analisis, topologi, area, jaringan, komputer,...
# 28   [resume, pembuatan, tugas, jaringan, komputer,...
# 29   [perkembangan, jaringan, komputer, indonesia, ...
# ..                                                 ...
# 217  [implementasi, captive, portal, pfsense, capti...
# 218  [aspek, hukum, pelayan, publik, online, direkt...
# 219  [steganografi, citra, digital, menyembunyikan,...
# 220  [analisis, faktor, minat, siswa, memilih, juru...
# 221  [managed, service, network, management, system...
# 222  [kebijakan, kriminal, pemerintah, kejahatan, d...
# 223  [pengembangan, aplikasi, e, commerce, pendekat...
# 224  [konsep, pengembangan, sistem, informasi, moni...
# 225  [tugas, akhir, jurnal, tata, kelola, sistem, t...
# 226  [e, commerce, media, promosi, pemasaran, decou...
# 227  [failover, gateway, protokol, virtual, router,...
# 228  [sistem, informasi, administrasi, data, kemaha...
# 229  [analisis, perbandingan, detection, traffic, a...
# 230  [sistem, pendukung, keputusan, pemilihan, pemi...
# 231  [pengaruh, media, packet, tracer, kreativitas,...
# 232  [multimedia, edukasi, interaktif, pelajaran, b...
# 233  [aplikasi, sistem, penyidikan, client, server,...
# 234  [tindak, pidana, dunia, maya, berupa, virus, t...
# 235  [analisis, pengaruh, manfaat, risiko, kepercay...
# 236  [pengaruh, perceived, value, repurchase, inten...
# 237  [cooperative, accounting, computer, applicatio...
# 238  [membangun, rencana, strategis, sistem, inform...
# 239  [perancangan, sistem, pendukung, keputusan, pe...
# 240  [pengamanan, data, aplikasi, sijalu, universit...
# 241  [implementation, pptp, bcp, with, inter, vlan,...
# 242  [analisis, yuridis, penyelesaian, sengketa, cy...
# 243  [smart, campus, model, baru, enterprise, archi...
# 244  [analisis, hubungan, antara, daring, revolusi,...
# 245  [akad, jual, beli, online, perspektif, hukum, ...
# 246  [analisis, akad, undang, undang, nomor, tahun,...
#
# [247 rows x 5 columns]

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics
# Out:
# 9.0     2905
# 12.0    2492
# 6.0     2475
# 17.0    2349
# 1.0     2298
# 2.0     2263
# 11.0    2255
# 7.0     2249
# 8.0     2026
# 0.0     1981
# 3.0     1924
# 13.0    1919
# 16.0    1897
# 10.0    1738
# 15.0    1699
# 4.0     1611
# 14.0    1603
# 5.0     1525
# Name: Topik_Dominan, dtype: int64

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')
# Out:
# Text(0.5,1,'Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.9550
# 1         1.0              0.9695
# 2         2.0              0.9503
# 3         3.0              0.9589
# 4         4.0              0.9695
# 5         5.0              0.9503
# 6         6.0              0.9571
# 7         7.0              0.9571
# 8         8.0              0.9550
# 9         9.0              0.9528
# 10       10.0              0.9550
# 11       11.0              0.9650
# 12       12.0              0.9650
# 13       13.0              0.9444
# 14       14.0              0.9663
# 15       15.0              0.9589
# 16       16.0              0.9622
# 17       17.0              0.9650
#
#                                                                                                Keywords  \
# 0   informasi_akademik, augmented_reality, smk_negeri, sekolah_menengah, informasi, studi_kasus, aka...
# 1   diagnosa_penyakit, jaringan_komputer, teknik_informatika, expert_system, data_mining, visual_bas...
# 2   metode_forward, pakar_diagnosa, diagnosa, pakar, forward, chaining, fuzzy_tsukamoto, studi_kasus...
# 3   metode_weighted, penunjang_keputusan, keamanan_jaringan, citra_digital, penerimaan_siswa, kota_p...
# 4   perguruan_tinggi, pengembangan_media, php_mysql, php, fuzzy_sugeno, objek_wisata, analisis_perba...
# 5   fuzzy_logic, sma_negeri, naïve_bayes, informasi_penjualan, studi_kasus, informasi, penjualan, pa...
# 6   pendukung_keputusan, keputusan, pendukung, pengolahan_citra, mata_kuliah, saw, topsis, studi_kas...
# 7   pakar_mendiagnosa, metode_certainty, pakar, penyakit, learning_vector, mendiagnosa, metode_demps...
# 8   rumah_sakit, e_learning, game_edukasi, operasi_android, rekayasa_perangkat, operasi, studi_kasus...
# 9   rancang_bangun, sms_gateway, rancang, bangun, e_commerce, studi_kasus, smp_negeri, android, apli...
# 10  case_reasoning, k_nearest, pengenalan_pola, aplikasi_panduan, bahasa_inggris, reasoning, case, k...
# 11  pendukung_keputusan, metode_simple, additive_weighting, simple, additive, weighting, pendukung, ...
# 12  pendukung_keputusan, perangkat_lunak, analytical_hierarchy, pengolahan_data, process, forward_ch...
# 13  informasi_geografis, raspberry_pi, logika_fuzzy, algoritma_genetika, tugas_akhir, profile_matchi...
# 14  naive_bayes, jaringan_saraf, qr_code, pengolahan_citra, alat_bantu, deteksi_tepi, naive, jaringa...
# 15  informasi_akuntansi, pakar_diagnosis, teorema_bayes, anak_usia, akuntansi, studi_kasus, palemban...
# 16  jaringan_syaraf, neural_network, beasiswa, data_warehouse, program_studi, syaraf, tiruan, simpan...
# 17  media_pembelajaran, pembelajaran, mata_pelajaran, siswa_kelas, sekolah_dasar, penilaian_kinerja,...
#
#                                                                                     Representative Text
# 0   [desain, sistem, kamus, istilah, komputer, android, studi, kasus, sma, muhammadiyah, kartasura, ...
# 1   [pengaruh, kompetensi, sumber, daya, manusia, pemanfaatan, teknologi, informasi, sistem, pengend...
# 2   [perancangan, aplikasi, sistem, pakar, diagnosa, penyakit, ginekologi, metode, forward, chaining...
# 3   [sistem, pakar, diagnosa, awal, gangguan, attention, deficit, hyperactivity, disorder, anak, met...
# 4   [perancangan, implementasi, virtual, private, network, vpn, protokol, sstp, secure, socket, tunn...
# 5   [pelaksanaan, izin, usaha, mikro, kecil, kecamatan, rumbai, pesisir, kota, pekanbaru, izin_usaha...
# 6   [evaluasi, sistem, otomasi, perpustakaan, senayan, library, management, system, slims, perpustak...
# 7   [sistem, pakar, mendiagnosa, hama, penyakit, tanaman, kopi, arabika, metode, certainty, factor, ...
# 8   [penilaian, penerimaan, teknologi, e, learning, pemrograman, gamification, metode, technology, a...
# 9   [implementasi, bauran, pemasaran, melalui, kegiatan, sales, e, commerce, ota, online, travel, ag...
# 10  [pengenalan, bunga, anggrek, gray, level, co, occurrence, algoritma, k, nearest, neighbours, mob...
# 11  [sistem, pendukung, keputusan, pemilihan, program, studi, fakultas, teknik, universitas, nusanta...
# 12  [sistem, pendukung, keputusan, pemilihan, mahasiswa, berprestasi, metode, moora, studi, kasus, f...
# 13  [sistem, informasi, pencarian, judul, skripsi, tugas, akhir, stmik, tidore, mandiri, pencarian_j...
# 14  [identifikasi, kualitas, mutu, kopi, kadar, air, biji, kopi, pengolahan, citra, digital, metode,...
# 15  [perbandingan, metode, ahp, ahp, topsis, penentuan, kelayakan, pengisian, bibit, ayam, broiler, ...
# 16  [sistem, keamanan, server, honeypot, intrusion, detection, system, ids, studi, kasus, perusahaan...
# 17  [pemanfaatan, media, pembelajaran, teknologi, informasi, prestasi, belajar, siswa, bidang, studi...

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-range4.html')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 12     0.029587 -0.171011       1        1  6.460726
# 1     -0.009588  0.032019       2        1  6.137423
# 17     0.131319  0.119513       3        1  6.086735
# 6      0.017937 -0.121428       4        1  5.883035
# 2     -0.037429  0.036313       5        1  5.771029
# 11    -0.005244 -0.203035       6        1  5.730803
# 9      0.128525  0.072654       7        1  5.715988
# 3     -0.134982  0.027364       8        1  5.667372
# 7     -0.177513  0.081484       9        1  5.647096
# 16    -0.046204 -0.014783      10        1  5.500605
# 8      0.096601  0.083645      11        1  5.474418
# 13     0.046949 -0.078688      12        1  5.365919
# 15    -0.007369 -0.004962      13        1  5.346850
# 0      0.101883  0.063846      14        1  5.197943
# 10    -0.113923  0.045694      15        1  5.143899
# 4      0.024726  0.000057      16        1  5.050187
# 14    -0.115623  0.041103      17        1  4.929067
# 5      0.070348 -0.009785      18        1  4.890901, topic_info=      Category        Freq                  Term       Total  loglift  logprob
# term
# 750    Default  691.000000   pendukung_keputusan  691.000000  30.0000  30.0000
# 4273   Default  231.000000        metode_forward  231.000000  29.0000  29.0000
# 4193   Default  239.000000        pakar_diagnosa  239.000000  28.0000  28.0000
# 207    Default  566.000000        rancang_bangun  566.000000  27.0000  27.0000
# 855    Default  241.000000   informasi_geografis  241.000000  26.0000  26.0000
# 4240   Default  147.000000     pakar_mendiagnosa  147.000000  25.0000  25.0000
# 7      Default  181.000000      metode_certainty  181.000000  24.0000  24.0000
# 1893   Default  136.000000         metode_simple  136.000000  23.0000  23.0000
# 3110   Default  139.000000       perangkat_lunak  139.000000  22.0000  22.0000
# 1518   Default  136.000000    informasi_akademik  136.000000  21.0000  21.0000
# 5051   Default  116.000000    additive_weighting  116.000000  20.0000  20.0000
# 522    Default  153.000000       jaringan_syaraf  153.000000  19.0000  19.0000
# 631    Default   99.000000          raspberry_pi   99.000000  18.0000  18.0000
# 265    Default  111.000000    media_pembelajaran  111.000000  17.0000  17.0000
# 1215   Default   92.000000           naive_bayes   92.000000  16.0000  16.0000
# 262    Default   92.000000     augmented_reality   92.000000  15.0000  15.0000
# 2530   Default  101.000000   informasi_akuntansi  101.000000  14.0000  14.0000
# 6261   Default   91.000000       metode_weighted   91.000000  13.0000  13.0000
# 6868   Default   87.000000           sms_gateway   87.000000  12.0000  12.0000
# 4358   Default   83.000000        case_reasoning   83.000000  11.0000  11.0000
# 1269   Default   89.000000  analytical_hierarchy   89.000000  10.0000  10.0000
# 3810   Default   81.000000           fuzzy_logic   81.000000   9.0000   9.0000
# 2671   Default   86.000000   penunjang_keputusan   86.000000   8.0000   8.0000
# 898    Default  227.000000                 pakar  227.000000   7.0000   7.0000
# 1014   Default   82.000000           rumah_sakit   82.000000   6.0000   6.0000
# 749    Default  262.000000             pendukung  262.000000   5.0000   5.0000
# 748    Default  268.000000             keputusan  268.000000   4.0000   4.0000
# 3975   Default  141.000000      pengolahan_citra  141.000000   3.0000   3.0000
# 844    Default   78.000000            e_commerce   78.000000   2.0000   2.0000
# 4191   Default  119.000000              diagnosa  119.000000   1.0000   1.0000
# ...        ...         ...                   ...         ...      ...      ...
# 4691   Topic18   16.676058     algoritma_apriori   17.428150   2.9737  -5.7393
# 4238   Topic18   16.860498                 naïve   17.627211   2.9733  -5.7283
# 13788  Topic18   17.687162       self_organizing   18.503151   2.9727  -5.6805
# 1373   Topic18   14.216253                alumni   14.964675   2.9665  -5.8989
# 3504   Topic18   13.863840        manajemen_aset   14.636088   2.9636  -5.9240
# 8540   Topic18   13.322227      pengelolaan_dana   14.070685   2.9631  -5.9639
# 7226   Topic18   13.019857                    ta   13.768485   2.9619  -5.9868
# 2759   Topic18   13.331732                cahaya   14.102980   2.9616  -5.9632
# 472    Topic18   12.841090          obyek_wisata   13.589512   2.9611  -6.0006
# 1030   Topic18   12.663674                     m   13.412097   2.9604  -6.0146
# 2152   Topic18   12.346673             reservasi   13.096320   2.9588  -6.0399
# 1223   Topic18   12.735899             peminatan   13.527316   2.9575  -6.0089
# 8241   Topic18   11.743250      kabupaten_sleman   12.496016   2.9557  -6.0900
# 7777   Topic18   17.840286      pemberian_kredit   19.032221   2.9531  -5.6718
# 7516   Topic18   15.199555             pendataan   16.314646   2.9470  -5.8320
# 2834   Topic18   53.800350            sma_negeri   64.930786   2.8298  -4.5680
# 1750   Topic18   43.815769   informasi_penjualan   61.884308   2.6725  -4.7733
# 6959   Topic18   17.519823                apotek   20.939507   2.8395  -5.6900
# 746    Topic18   24.299488       fuzzy_inference   54.288868   2.2139  -5.3628
# 801    Topic18   19.313059            pariwisata   34.035866   2.4512  -5.5925
# 1330   Topic18   30.935677             penjualan  105.142899   1.7944  -5.1214
# 375    Topic18   22.332277                   sma   60.575104   2.0199  -5.4473
# 23     Topic18   39.886005             informasi  394.019409   0.7274  -4.8673
# 378    Topic18   41.421101           studi_kasus  593.244690   0.3560  -4.8295
# 208    Topic18   28.351353                   web  279.808746   0.7284  -5.2086
# 745    Topic18   22.251808                 fuzzy  127.189903   1.2745  -5.4509
# 187    Topic18   24.967276                sistem  445.988037   0.1351  -5.3357
# 750    Topic18   25.103739   pendukung_keputusan  691.167603  -0.2976  -5.3303
# 720    Topic18   20.846333               android  281.402710   0.4152  -5.5161
# 272    Topic18   19.650707           perancangan  269.430450   0.3996  -5.5752
#
# [899 rows x 6 columns], token_table=       Topic      Freq                Term
# term
# 5369       2  0.967824                  3d
# 7005       7  0.944490   absensi_mahasiswa
# 3706       3  0.955431      adaptive_neuro
# 4128       6  0.993279            additive
# 5051       6  0.994351  additive_weighting
# 1103       2  0.062530        administrasi
# 1103      10  0.521087        administrasi
# 1103      14  0.396026        administrasi
# 2723       7  0.971965         adobe_flash
# 1138       1  0.892081               agama
# 1138       4  0.089208               agama
# 2167       4  0.930380         agama_islam
# 1266       1  0.803894                 ahp
# 1266       2  0.014616                 ahp
# 1266      13  0.160779                 ahp
# 5098      13  0.937117          ahp_topsis
# 12172      2  0.950070           air_minum
# 1385       3  0.071348            akademik
# 1385       4  0.014270            akademik
# 1385       5  0.028539            akademik
# 1385       6  0.014270            akademik
# 1385       7  0.099887            akademik
# 1385       9  0.014270            akademik
# 1385      10  0.028539            akademik
# 1385      13  0.028539            akademik
# 1385      14  0.613594            akademik
# 1385      18  0.071348            akademik
# 1064      12  0.967896               akhir
# 13100     17  0.928458         aksara_jawa
# 1255       2  0.102351           akuntansi
# ...      ...       ...                 ...
# 208        8  0.032165                 web
# 208        9  0.053608                 web
# 208       10  0.025017                 web
# 208       11  0.053608                 web
# 208       12  0.064330                 web
# 208       13  0.053608                 web
# 208       14  0.110790                 web
# 208       15  0.010722                 web
# 208       16  0.067904                 web
# 208       17  0.010722                 web
# 208       18  0.100068                 web
# 1023      16  0.985094         web_service
# 5464       2  0.050419            weighted
# 5464       8  0.882324            weighted
# 5464      16  0.050419            weighted
# 3342       4  0.043204           weighting
# 3342       6  0.936094           weighting
# 3343       4  0.939161       weighting_saw
# 2660       4  0.853450             windows
# 2660       7  0.037107             windows
# 2660      18  0.111320             windows
# 2024      17  0.957787     wireless_sensor
# 606        5  0.053657                   x
# 606        8  0.134142                   x
# 606       11  0.590224                   x
# 606       14  0.080485                   x
# 606       16  0.080485                   x
# 606       17  0.026828                   x
# 3718       8  0.976612               x_ray
# 2431       5  0.945517                 xyz
#
# [1818 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[13, 2, 18, 7, 3, 12, 10, 4, 8, 17, 9, 14, 16, 1, 11, 5, 15, 6])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model-range4.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

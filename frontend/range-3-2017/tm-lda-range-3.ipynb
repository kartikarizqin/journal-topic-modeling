# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned-range3.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                     text
# 0      pendeteksi gangguan jaringan lokal metode cert...
# 1      eksistensi penggunaan wi fi warung kopi kota b...
# 2      pengaruh internet financial reporting tingkat ...
# 3      security function analysis performance high sp...
# 4      implementation top down approach method redesi...
# 5      optimization wireless network performance hier...
# 6      analysis qos vlan djikstra s algorithm open sh...
# 7      link performance improvement sananibun bts wit...
# 8      legal protection efforts patent holders indonesia
# 9      use e learning by teachers teaching learning p...
# 10     definition patent rights examples case studies...
# 11     analysis implementation backup line network br...
# 12     classification principles legal basis intellec...
# 13     attendance system automatic door locks laborat...
# 14          registration requirements application rights
# 15     patentability block chain technology future in...
# 16     influence speed user mobility qos wireless lan...
# 17     4 ghz omnidirectional antenna design with micr...
# 18     pemanfaatan telepon pintar informasi penyebara...
# 19     aplikasi teknologi komunikasi wireless zigbee ...
# 20     forensics analysis router computer networks li...
# 21                   manajemen proyeksi sistem informasi
# 22                   manajemen proyeksi sistem informasi
# 23                   tri destanto 175100067p sectionquis
# 24           rancang bangun aplikasi chatting web docker
# 25     multimedia animated corrosion corrosion coatin...
# 26     quality service traffic monitoring system stat...
# 27              analisis topologi area jaringan komputer
# 28              resume pembuatan tugas jaringan komputer
# 29              perkembangan jaringan komputer indonesia
# ...                                                  ...
# 27485  pengaruh lingkungan kerja pemberian insentif k...
# 27486  upaya perlindungan hukum konsumen transaksi e ...
# 27487  implementasi one time password mobile token al...
# 27488   pengembangan web online shop butik azzalea store
# 27489  analisis laporan keuangan menilai kinerja mana...
# 27490          laporan pengabdian masyarakat ganjil 2018
# 27491  analisa manajemen bandwidth mkrotik departemen...
# 27492  implementasi hybrid cryptosystem algoritma aff...
# 27493      rancang bangun kendali off lampu raspberry pi
# 27494  tinjauan steganography layanan voip voice over...
# 27495  budaya cari untung pemicu terjadinya fraud seb...
# 27496  sistem pengujian kadar logam berat krom vi air...
# 27497  pengujian kepuasan sistem informasi end user c...
# 27498  peran e satisfaction e trust pengembangan e lo...
# 27499  implementasi kriptografi hybrid algoritma one ...
# 27500  kajian mengenai kepuasan nasabah bank syariah ...
# 27501             tingkat kecanduan internet remaja awal
# 27502  analisis wacana cyberwar artikel situs kompasiana
# 27503  kebijakan integral hukum pidana techno prevent...
# 27504             mata kuliah sistem informasi kesehatan
# 27505  pengaruh kapasitas sumber daya manusia pemanfa...
# 27506  perlindungan hukum nasabah bankpengguna intern...
# 27507  sanksi pidanan tindak pidana judi bola online ...
# 27508  dashboard monitoring system web pemantau layan...
# 27509  hubungan self efficacy perilaku penemuan infor...
# 27510  naskah akademik rancangan pengembangan kelemba...
# 27511  pengaruh internet mahasiswa studi tim sepak bo...
# 27512  analisa strategi implementasi green computing ...
# 27513  peran pemerintah daerah menjamin ketertiban um...
# 27514  ternyata mendidik anak cara rasulullah mudah e...
#
# [27515 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 27515
# [['pendeteksi', 'gangguan', 'jaringan', 'lokal', 'metode', 'certainty', 'factor']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                    0               1                2             3   \
# 0          pendeteksi        gangguan         jaringan         lokal
# 1          eksistensi      penggunaan               wi            fi
# 2            pengaruh        internet        financial     reporting
# 3            security        function         analysis   performance
# 4      implementation             top             down      approach
# 5        optimization        wireless          network   performance
# 6            analysis             qos             vlan      djikstra
# 7                link     performance      improvement     sananibun
# 8               legal      protection          efforts        patent
# 9                 use               e         learning            by
# 10         definition          patent           rights      examples
# 11           analysis  implementation           backup          line
# 12     classification      principles            legal         basis
# 13         attendance          system        automatic          door
# 14       registration    requirements      application        rights
# 15      patentability           block            chain    technology
# 16          influence           speed             user      mobility
# 17                  4             ghz  omnidirectional       antenna
# 18        pemanfaatan         telepon           pintar     informasi
# 19           aplikasi       teknologi       komunikasi      wireless
# 20          forensics        analysis           router      computer
# 21          manajemen        proyeksi           sistem     informasi
# 22          manajemen        proyeksi           sistem     informasi
# 23                tri        destanto       175100067p   sectionquis
# 24            rancang          bangun         aplikasi      chatting
# 25         multimedia        animated        corrosion     corrosion
# 26            quality         service          traffic    monitoring
# 27           analisis        topologi             area      jaringan
# 28             resume       pembuatan            tugas      jaringan
# 29       perkembangan        jaringan         komputer     indonesia
# ...               ...             ...              ...           ...
# 27485        pengaruh      lingkungan            kerja     pemberian
# 27486           upaya    perlindungan            hukum      konsumen
# 27487    implementasi             one             time      password
# 27488    pengembangan             web           online          shop
# 27489        analisis         laporan         keuangan       menilai
# 27490         laporan      pengabdian       masyarakat        ganjil
# 27491         analisa       manajemen        bandwidth       mkrotik
# 27492    implementasi          hybrid     cryptosystem     algoritma
# 27493         rancang          bangun          kendali           off
# 27494        tinjauan   steganography          layanan          voip
# 27495          budaya            cari           untung        pemicu
# 27496          sistem       pengujian            kadar         logam
# 27497       pengujian        kepuasan           sistem     informasi
# 27498           peran               e     satisfaction             e
# 27499    implementasi     kriptografi           hybrid     algoritma
# 27500          kajian        mengenai         kepuasan       nasabah
# 27501         tingkat       kecanduan         internet        remaja
# 27502        analisis          wacana         cyberwar       artikel
# 27503       kebijakan        integral            hukum        pidana
# 27504            mata          kuliah           sistem     informasi
# 27505        pengaruh       kapasitas           sumber          daya
# 27506    perlindungan           hukum          nasabah  bankpengguna
# 27507          sanksi         pidanan           tindak        pidana
# 27508       dashboard      monitoring           system           web
# 27509        hubungan            self         efficacy      perilaku
# 27510          naskah        akademik        rancangan  pengembangan
# 27511        pengaruh        internet        mahasiswa         studi
# 27512         analisa        strategi     implementasi         green
# 27513           peran      pemerintah           daerah      menjamin
# 27514        ternyata        mendidik             anak          cara
#
#                        4                         5                      6   \
# 0                  metode                 certainty                 factor
# 1                  warung                      kopi                   kota
# 2                 tingkat              pengungkapan              informasi
# 3                    high                     speed                 router
# 4                  method                  redesign                    lan
# 5            hierarchical                     token                 bucket
# 6                       s                 algorithm                   open
# 7                     bts                      with                   link
# 8                 holders                 indonesia                   None
# 9                teachers                  teaching               learning
# 10                   case                   studies                 iphone
# 11                network                    branch                 office
# 12           intellectual                  property              indonesia
# 13                  locks                laboratory             electrical
# 14                   None                      None                   None
# 15                 future                innovation                   None
# 16                    qos                  wireless                    lan
# 17                 design                      with             microstrip
# 18             penyebaran                    lokasi                   guru
# 19                 zigbee                    sistem                kontrol
# 20               networks                      live              forensics
# 21     manajemen_proyeksi        manajemen_proyeksi     manajemen_proyeksi
# 22     manajemen_proyeksi        manajemen_proyeksi     manajemen_proyeksi
# 23                   None                      None                   None
# 24                    web                    docker         rancang_bangun
# 25                coating                    metals                 course
# 26                 system                    static                routing
# 27               komputer         jaringan_komputer      jaringan_komputer
# 28               komputer         jaringan_komputer      jaringan_komputer
# 29      jaringan_komputer         jaringan_komputer      jaringan_komputer
# ...                   ...                       ...                    ...
# 27485            insentif                  kepuasan                  kerja
# 27486           transaksi                         e               commerce
# 27487              mobile                     token              algoritma
# 27488               butik                   azzalea                  store
# 27489             kinerja                 manajemen         telekomunikasi
# 27490                2018     pengabdian_masyarakat  pengabdian_masyarakat
# 27491         departement              radiotherapy                  rumah
# 27492              affine                    cipher              algoritma
# 27493               lampu                 raspberry                     pi
# 27494               voice                      over               internet
# 27495          terjadinya                     fraud                 sebuah
# 27496               berat                      krom                     vi
# 27497                 end                      user              computing
# 27498               trust              pengembangan                      e
# 27499                 one                      time                    pad
# 27500                bank                   syariah                   kota
# 27501                awal                      None                   None
# 27502               situs                kompasiana                   None
# 27503              techno                prevention                  upaya
# 27504           kesehatan               mata_kuliah            mata_kuliah
# 27505             manusia               pemanfaatan              teknologi
# 27506            internet  bankingterhadapkejahatan                    ite
# 27507                judi                      bola                 online
# 27508            pemantau                   layanan                litebig
# 27509            penemuan                 informasi                  studi
# 27510         kelembagaan               kementerian             komunikasi
# 27511                 tim                     sepak                   bola
# 27512           computing                 perguruan                 tinggi
# 27513          ketertiban                      umum           perlindungan
# 27514          rasulullah                     mudah                efektif
#
#                           7                       8                       9   \
# 0             jaringan_lokal        metode_certainty          jaringan_lokal
# 1                      banda                    aceh                   wi_fi
# 2                    website               frekuensi             perdagangan
# 3                 networking                    None                    None
# 4                    harvani                   hotel               palembang
# 5                       case            muhammadiyah              university
# 6                   shortest                    path                   first
# 7                     switch               migration                backbone
# 8                       None                    None                    None
# 9                    process              e_learning       teaching_learning
# 10                  products                    None                    None
# 11                       vpn                  speedy                internet
# 12                      None                    None                    None
# 13               engineering              department                      at
# 14                      None                    None                    None
# 15                      None                    None                    None
# 16                        11                       g                      11
# 17              technologies                     gsm                internet
# 18                   sekolah                   dasar                  negeri
# 19                monitoring                 ruangan                   kelas
# 20                    method          live_forensics          live_forensics
# 21                      None                    None                    None
# 22                      None                    None                    None
# 23                      None                    None                    None
# 24         aplikasi_chatting          rancang_bangun       aplikasi_chatting
# 25                      None                    None                    None
# 26                      eoip                  tunnel                    over
# 27         jaringan_komputer                    None                    None
# 28         jaringan_komputer                    None                    None
# 29                      None                    None                    None
# ...                      ...                     ...                     ...
# 27485                perawat                   rumah                   sakit
# 27486              mendukung             pertumbuhan                 ekonomi
# 27487                 secure                    hash               algorithm
# 27488            online_shop             online_shop             online_shop
# 27489              indonesia                     tbk        laporan_keuangan
# 27490  pengabdian_masyarakat                    None                    None
# 27491                  sakit     manajemen_bandwidth             rumah_sakit
# 27492                    luc              pengamanan                    file
# 27493         rancang_bangun            raspberry_pi          rancang_bangun
# 27494               protocol              voip_voice           over_internet
# 27495                  studi               etnografi                    None
# 27496                    air                  sensor                  cahaya
# 27497           satisfaction                   studi                   kasus
# 27498                loyalty               pembelian                  online
# 27499                    otp               algoritma                  micali
# 27500               makassar            nasabah_bank           kota_makassar
# 27501                   None                    None                    None
# 27502                   None                    None                    None
# 27503             pencegahan               kejahatan           cyberbullying
# 27504            mata_kuliah                    None                    None
# 27505              informasi            pengendalian                  intern
# 27506     perlindungan_hukum      perlindungan_hukum      perlindungan_hukum
# 27507                 tindak                  pidana                   cyber
# 27508                instant               messenger    dashboard_monitoring
# 27509            eksplanatif                 tentang                hubungan
# 27510            informatika  komunikasi_informatika  komunikasi_informatika
# 27511                    mon                   malem              sepak_bola
# 27512       perguruan_tinggi        perguruan_tinggi        perguruan_tinggi
# 27513           pengembangan               investasi                   studi
# 27514                   None                    None                    None
#
#        ...                   30                               31    32    33  \
# 0      ...                 None                             None  None  None
# 1      ...                 None                             None  None  None
# 2      ...                 None                             None  None  None
# 3      ...                 None                             None  None  None
# 4      ...                 None                             None  None  None
# 5      ...                 None                             None  None  None
# 6      ...                 None                             None  None  None
# 7      ...                 None                             None  None  None
# 8      ...                 None                             None  None  None
# 9      ...                 None                             None  None  None
# 10     ...                 None                             None  None  None
# 11     ...                 None                             None  None  None
# 12     ...                 None                             None  None  None
# 13     ...                 None                             None  None  None
# 14     ...                 None                             None  None  None
# 15     ...                 None                             None  None  None
# 16     ...                 None                             None  None  None
# 17     ...                 None                             None  None  None
# 18     ...                 None                             None  None  None
# 19     ...                 None                             None  None  None
# 20     ...                 None                             None  None  None
# 21     ...                 None                             None  None  None
# 22     ...                 None                             None  None  None
# 23     ...                 None                             None  None  None
# 24     ...                 None                             None  None  None
# 25     ...                 None                             None  None  None
# 26     ...                 None                             None  None  None
# 27     ...                 None                             None  None  None
# 28     ...                 None                             None  None  None
# 29     ...                 None                             None  None  None
# ...    ...                  ...                              ...   ...   ...
# 27485  ...                 None                             None  None  None
# 27486  ...                 None                             None  None  None
# 27487  ...                 None                             None  None  None
# 27488  ...                 None                             None  None  None
# 27489  ...                 None                             None  None  None
# 27490  ...                 None                             None  None  None
# 27491  ...                 None                             None  None  None
# 27492  ...                 None                             None  None  None
# 27493  ...                 None                             None  None  None
# 27494  ...                 None                             None  None  None
# 27495  ...                 None                             None  None  None
# 27496  ...                 None                             None  None  None
# 27497  ...   informasi_akademik  uin_syarif_hidayatullah_jakarta  None  None
# 27498  ...                 None                             None  None  None
# 27499  ...                 None                             None  None  None
# 27500  ...                 None                             None  None  None
# 27501  ...                 None                             None  None  None
# 27502  ...                 None                             None  None  None
# 27503  ...                 None                             None  None  None
# 27504  ...                 None                             None  None  None
# 27505  ...                 None                             None  None  None
# 27506  ...                 None                             None  None  None
# 27507  ...                 None                             None  None  None
# 27508  ...                 None                             None  None  None
# 27509  ...                 None                             None  None  None
# 27510  ...                 None                             None  None  None
# 27511  ...                 None                             None  None  None
# 27512  ...                 None                             None  None  None
# 27513  ...                 None                             None  None  None
# 27514  ...                 None                             None  None  None
#
#          34    35    36    37    38    39
# 0      None  None  None  None  None  None
# 1      None  None  None  None  None  None
# 2      None  None  None  None  None  None
# 3      None  None  None  None  None  None
# 4      None  None  None  None  None  None
# 5      None  None  None  None  None  None
# 6      None  None  None  None  None  None
# 7      None  None  None  None  None  None
# 8      None  None  None  None  None  None
# 9      None  None  None  None  None  None
# 10     None  None  None  None  None  None
# 11     None  None  None  None  None  None
# 12     None  None  None  None  None  None
# 13     None  None  None  None  None  None
# 14     None  None  None  None  None  None
# 15     None  None  None  None  None  None
# 16     None  None  None  None  None  None
# 17     None  None  None  None  None  None
# 18     None  None  None  None  None  None
# 19     None  None  None  None  None  None
# 20     None  None  None  None  None  None
# 21     None  None  None  None  None  None
# 22     None  None  None  None  None  None
# 23     None  None  None  None  None  None
# 24     None  None  None  None  None  None
# 25     None  None  None  None  None  None
# 26     None  None  None  None  None  None
# 27     None  None  None  None  None  None
# 28     None  None  None  None  None  None
# 29     None  None  None  None  None  None
# ...     ...   ...   ...   ...   ...   ...
# 27485  None  None  None  None  None  None
# 27486  None  None  None  None  None  None
# 27487  None  None  None  None  None  None
# 27488  None  None  None  None  None  None
# 27489  None  None  None  None  None  None
# 27490  None  None  None  None  None  None
# 27491  None  None  None  None  None  None
# 27492  None  None  None  None  None  None
# 27493  None  None  None  None  None  None
# 27494  None  None  None  None  None  None
# 27495  None  None  None  None  None  None
# 27496  None  None  None  None  None  None
# 27497  None  None  None  None  None  None
# 27498  None  None  None  None  None  None
# 27499  None  None  None  None  None  None
# 27500  None  None  None  None  None  None
# 27501  None  None  None  None  None  None
# 27502  None  None  None  None  None  None
# 27503  None  None  None  None  None  None
# 27504  None  None  None  None  None  None
# 27505  None  None  None  None  None  None
# 27506  None  None  None  None  None  None
# 27507  None  None  None  None  None  None
# 27508  None  None  None  None  None  None
# 27509  None  None  None  None  None  None
# 27510  None  None  None  None  None  None
# 27511  None  None  None  None  None  None
# 27512  None  None  None  None  None  None
# 27513  None  None  None  None  None  None
# 27514  None  None  None  None  None  None
#
# [27515 rows x 40 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(23897 unique tokens: ['certainty', 'factor', 'gangguan', 'jaringan', 'jaringan_lokal']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 27515

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))
# Out:
# Num Topics = 2  has Coherence Value of 0.2454965953
# Num Topics = 4  has Coherence Value of 0.3177359595
# Num Topics = 6  has Coherence Value of 0.3828337194
# Num Topics = 8  has Coherence Value of 0.4189457424
# Num Topics = 10  has Coherence Value of 0.4266258449
# Num Topics = 12  has Coherence Value of 0.4743320975
# Num Topics = 14  has Coherence Value of 0.4630544754
# Num Topics = 16  has Coherence Value of 0.4987779732
# Num Topics = 18  has Coherence Value of 0.4947762254

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=16)
pprint(model.print_topics())
# Out:
# [(0,
#   '0.017*"informasi_akademik" + 0.013*"studi_kasus" + 0.013*"smk_negeri" + '
#   '0.009*"informasi" + 0.008*"sekolah_menengah" + 0.007*"negeri" + '
#   '0.007*"sma_negeri" + 0.007*"sekolah" + 0.007*"jurusan_teknik" + '
#   '0.007*"keamanan_jaringan"'),
#  (1,
#   '0.019*"e_commerce" + 0.014*"pengolahan_data" + 0.007*"support_vector" + '
#   '0.007*"commerce" + 0.006*"algoritma_genetika" + 0.006*"segmentasi_citra" + '
#   '0.005*"e" + 0.005*"provinsi_jawa" + 0.005*"jaringan_komputer" + '
#   '0.004*"data"'),
#  (2,
#   '0.024*"metode_certainty" + 0.010*"sistem_pakar" + 0.010*"pakar" + '
#   '0.009*"penyakit" + 0.008*"pakar_diagnosis" + 0.008*"sepeda_motor" + '
#   '0.008*"certainty" + 0.008*"factor" + 0.008*"penyakit_tanaman" + '
#   '0.008*"naïve_bayes"'),
#  (3,
#   '0.019*"media_pembelajaran" + 0.017*"augmented_reality" + '
#   '0.013*"pengembangan_media" + 0.013*"siswa_kelas" + 0.011*"php_mysql" + '
#   '0.010*"pembelajaran" + 0.008*"media" + 0.007*"terbaik" + 0.007*"reality" + '
#   '0.006*"augmented"'),
#  (4,
#   '0.014*"informasi_akuntansi" + 0.011*"expert_system" + '
#   '0.010*"penerimaan_siswa" + 0.007*"informasi" + 0.007*"studi_kasus" + '
#   '0.006*"akuntansi" + 0.005*"framework_codeigniter" + '
#   '0.005*"smartphone_android" + 0.005*"karyawan" + 0.005*"sistem"'),
#  (5,
#   '0.032*"rancang_bangun" + 0.011*"e_learning" + 0.011*"metode_weighted" + '
#   '0.011*"rancang" + 0.011*"bangun" + 0.007*"rekayasa_perangkat" + '
#   '0.006*"game_edukasi" + 0.006*"studi_kasus" + 0.005*"administrasi" + '
#   '0.005*"pendukung_keputusan"'),
#  (6,
#   '0.051*"pendukung_keputusan" + 0.026*"informasi_penjualan" + '
#   '0.019*"keputusan" + 0.019*"pendukung" + 0.010*"saw" + 0.009*"studi_kasus" + '
#   '0.009*"pemilihan" + 0.009*"program_studi" + 0.008*"ahp" + 0.008*"sistem"'),
#  (7,
#   '0.023*"perangkat_lunak" + 0.011*"sms_gateway" + 0.008*"k_means" + '
#   '0.008*"anak_usia" + 0.008*"perangkat" + 0.008*"lunak" + 0.008*"process" + '
#   '0.005*"basis_data" + 0.005*"sms" + 0.005*"simpan_pinjam"'),
#  (8,
#   '0.015*"perguruan_tinggi" + 0.014*"mata_kuliah" + 0.010*"data_mining" + '
#   '0.010*"teorema_bayes" + 0.009*"penilaian_kinerja" + 0.007*"jaringan_saraf" '
#   '+ 0.006*"fakultas_ilmu" + 0.006*"penilaian" + 0.006*"visual_basic" + '
#   '0.005*"tinggi"'),
#  (9,
#   '0.022*"metode_simple" + 0.019*"additive_weighting" + 0.011*"additive" + '
#   '0.011*"simple" + 0.010*"weighting" + '
#   '0.009*"metode_simple_additive_weighting" + 0.008*"rekam_medis" + '
#   '0.007*"informasi_kepegawaian" + 0.007*"backward_chaining" + '
#   '0.007*"studi_kasus"'),
#  (10,
#   '0.017*"pendukung_keputusan" + 0.016*"metode_topsis" + 0.013*"rumah_sakit" + '
#   '0.011*"studi_kasus" + 0.008*"sumber_daya" + 0.007*"topsis" + '
#   '0.007*"persediaan_barang" + 0.007*"informasi" + 0.006*"keputusan" + '
#   '0.006*"pendukung"'),
#  (11,
#   '0.019*"pengolahan_citra" + 0.012*"case_reasoning" + 0.010*"mata_pelajaran" '
#   '+ 0.010*"learning_vector" + 0.006*"citra" + 0.006*"pengolahan" + '
#   '0.006*"multimedia_interaktif" + 0.005*"kelas_x" + '
#   '0.004*"kendaraan_bermotor" + 0.004*"bahan_baku"'),
#  (12,
#   '0.011*"citra_digital" + 0.010*"forward_chaining" + '
#   '0.008*"universitas_muhammadiyah" + 0.007*"metode_profile" + '
#   '0.007*"deteksi_tepi" + 0.007*"client_server" + 0.006*"virtual_reality" + '
#   '0.005*"pengolahan_nilai" + 0.004*"studi_kasus" + 0.004*"obat"'),
#  (13,
#   '0.035*"metode_forward" + 0.019*"pakar" + 0.019*"sistem_pakar" + '
#   '0.017*"pakar_diagnosa" + 0.014*"penyakit" + 0.013*"forward" + '
#   '0.012*"chaining" + 0.012*"diagnosa_penyakit" + 0.011*"diagnosa" + '
#   '0.011*"metode_dempster"'),
#  (14,
#   '0.017*"informasi_geografis" + 0.011*"fuzzy_logic" + 0.010*"rancang_bangun" '
#   '+ 0.010*"operasi_android" + 0.007*"smp_negeri" + 0.007*"informasi" + '
#   '0.007*"informasi_pemesanan" + 0.006*"sekolah_dasar" + 0.006*"geografis" + '
#   '0.005*"menerapkan_metode"'),
#  (15,
#   '0.015*"raspberry_pi" + 0.014*"jaringan_syaraf" + 0.010*"neural_network" + '
#   '0.006*"tiruan" + 0.005*"backpropagation" + 0.005*"artificial_neural" + '
#   '0.005*"raspberry" + 0.005*"syaraf" + 0.005*"pi" + 0.005*"algoritma_k"')]

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=16)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.029*"pendukung_keputusan" + 0.013*"metode_weighted" + 0.011*"pendukung" + 0.009*"keputusan" + 0.008*"studi_kasus" + 0.008*"sma_negeri" + 0.007*"saw" + 0.007*"program_studi" + 0.007*"algoritma_genetika" + 0.006*"neural_network"
# Topic: 1 Word: 0.010*"learning_vector" + 0.007*"support_vector" + 0.007*"jarak_jauh" + 0.006*"location_service" + 0.006*"object_oriented" + 0.006*"visual_basic" + 0.006*"vector" + 0.005*"penginderaan_jauh" + 0.005*"demam_berdarah" + 0.005*"operasi_windows"
# Topic: 2 Word: 0.025*"metode_simple" + 0.022*"additive_weighting" + 0.015*"mata_kuliah" + 0.013*"simple" + 0.013*"additive" + 0.012*"weighting" + 0.010*"metode_simple_additive_weighting" + 0.009*"game_edukasi" + 0.006*"metodologi_berorientasi" + 0.006*"game"
# Topic: 3 Word: 0.027*"metode_forward" + 0.021*"pakar" + 0.021*"sistem_pakar" + 0.020*"metode_certainty" + 0.017*"penyakit" + 0.017*"pakar_diagnosa" + 0.013*"diagnosa" + 0.012*"diagnosa_penyakit" + 0.011*"pakar_mendiagnosa" + 0.010*"forward"
# Topic: 4 Word: 0.015*"rancang_bangun" + 0.011*"certainty_factor" + 0.010*"operasi_android" + 0.007*"administrasi" + 0.006*"deteksi_tepi" + 0.006*"framework_codeigniter" + 0.006*"aplikasi" + 0.005*"android" + 0.005*"bangun" + 0.005*"pengenalan_wajah"
# Topic: 5 Word: 0.013*"jaringan_komputer" + 0.011*"pakar_diagnosis" + 0.009*"diagnosis_penyakit" + 0.008*"informasi_pemesanan" + 0.006*"artificial_neural" + 0.006*"client_server" + 0.005*"jaringan" + 0.004*"provinsi_jawa" + 0.004*"komputer" + 0.004*"rancang_bangun"
# Topic: 6 Word: 0.015*"informasi_akuntansi" + 0.012*"metode_waterfall" + 0.011*"sms_gateway" + 0.009*"informasi" + 0.009*"forward_chaining" + 0.008*"studi_kasus" + 0.007*"informasi_kepegawaian" + 0.006*"akuntansi" + 0.006*"waterfall" + 0.006*"multimedia_interaktif"
# Topic: 7 Word: 0.020*"metode_topsis" + 0.015*"mata_pelajaran" + 0.010*"topsis" + 0.007*"penunjang_keputusan" + 0.007*"terbaik" + 0.006*"information_system" + 0.005*"pelajaran" + 0.005*"kelas_x" + 0.005*"tempat" + 0.005*"ahp_topsis"
# Topic: 8 Word: 0.016*"perangkat_lunak" + 0.015*"informasi_akademik" + 0.011*"pendukung_keputusan" + 0.011*"pengolahan_citra" + 0.009*"naive_bayes" + 0.009*"studi_kasus" + 0.008*"rancang_bangun" + 0.007*"penilaian_kinerja" + 0.007*"persediaan_barang" + 0.006*"perangkat"
# Topic: 9 Word: 0.016*"e_commerce" + 0.010*"rekam_medis" + 0.007*"pendukung_keputusan" + 0.006*"studi_kasus" + 0.006*"commerce" + 0.006*"basis_data" + 0.005*"informasi" + 0.005*"e" + 0.005*"perancangan" + 0.005*"inventory"
# Topic: 10 Word: 0.015*"perguruan_tinggi" + 0.008*"anak_usia" + 0.006*"citra_landsat" + 0.005*"kesehatan" + 0.005*"perguruan" + 0.005*"tinggi" + 0.005*"siswa_berprestasi" + 0.005*"buku" + 0.004*"studi_kasus" + 0.004*"fuzzy_mamdani"
# Topic: 11 Word: 0.014*"raspberry_pi" + 0.013*"rumah_sakit" + 0.011*"fuzzy_logic" + 0.010*"logika_fuzzy" + 0.009*"k_nearest" + 0.008*"data_mining" + 0.008*"citra_digital" + 0.006*"algoritma_k" + 0.006*"k" + 0.005*"deteksi_dini"
# Topic: 12 Word: 0.030*"informasi_penjualan" + 0.011*"pendukung_keputusan" + 0.011*"pengolahan_data" + 0.010*"penjualan" + 0.009*"penerimaan_siswa" + 0.009*"php_mysql" + 0.009*"studi_kasus" + 0.008*"pengambilan_keputusan" + 0.007*"informasi" + 0.006*"sistem"
# Topic: 13 Word: 0.017*"pendukung_keputusan" + 0.011*"rancang_bangun" + 0.010*"sepeda_motor" + 0.008*"sumber_daya" + 0.008*"keamanan_jaringan" + 0.008*"metode_analytical" + 0.008*"arduino_uno" + 0.008*"k_means" + 0.007*"hierarchy_process" + 0.007*"process"
# Topic: 14 Word: 0.015*"informasi_geografis" + 0.014*"media_pembelajaran" + 0.011*"augmented_reality" + 0.011*"rancang_bangun" + 0.010*"metode_dempster" + 0.008*"pembelajaran" + 0.007*"studi_kasus" + 0.007*"rekayasa_perangkat" + 0.007*"e_learning" + 0.007*"informasi"
# Topic: 15 Word: 0.016*"smk_negeri" + 0.011*"siswa_kelas" + 0.011*"expert_system" + 0.010*"hasil_belajar" + 0.009*"studi_kasus" + 0.007*"mobile_learning" + 0.006*"metode_profile" + 0.006*"smk" + 0.005*"rancang_bangun" + 0.005*"matlab"

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)
# Out:
#      No_Dokumen  Topik_Dominan  Persentase_Kontribusi  \
# 0             0            3.0                 0.4946
# 1             1           12.0                 0.4704
# 2             2           14.0                 0.4011
# 3             3            5.0                 0.4077
# 4             4            6.0                 0.9148
# 5             5            5.0                 0.5522
# 6             6            6.0                 0.7299
# 7             7           15.0                 0.3156
# 8             8            0.0                 0.6520
# 9             9           14.0                 0.8651
# 10           10            1.0                 0.6187
# 11           11            5.0                 0.4919
# 12           12           13.0                 0.4643
# 13           13           13.0                 0.3843
# 14           14            0.0                 0.4097
# 15           15           13.0                 0.8661
# 16           16            1.0                 0.4976
# 17           17            2.0                 0.8113
# 18           18            8.0                 0.5185
# 19           19           15.0                 0.3527
# 20           20            2.0                 0.6246
# 21           21            9.0                 0.8828
# 22           22            9.0                 0.8828
# 23           23           13.0                 0.8125
# 24           24           12.0                 0.9279
# 25           25            1.0                 0.7525
# 26           26            5.0                 0.9375
# 27           27            5.0                 0.8958
# 28           28            5.0                 0.6688
# 29           29            5.0                 0.7318
# ..          ...            ...                    ...
# 217         217           13.0                 0.8828
# 218         218            8.0                 0.2945
# 219         219            7.0                 0.7820
# 220         220           12.0                 0.4533
# 221         221           10.0                 0.3511
# 222         222            7.0                 0.4653
# 223         223           12.0                 0.5651
# 224         224           14.0                 0.9062
# 225         225            8.0                 0.4427
# 226         226           14.0                 0.6406
# 227         227           15.0                 0.6101
# 228         228            4.0                 0.8018
# 229         229            1.0                 0.4880
# 230         230            0.0                 0.9531
# 231         231           15.0                 0.3182
# 232         232            2.0                 0.6107
# 233         233            5.0                 0.9219
# 234         234            3.0                 0.3814
# 235         235            9.0                 0.4473
# 236         236            1.0                 0.6012
# 237         237            5.0                 0.7661
# 238         238            4.0                 0.7505
# 239         239           13.0                 0.9639
# 240         240            5.0                 0.9375
# 241         241           15.0                 0.7572
# 242         242            9.0                 0.6387
# 243         243            7.0                 0.4576
# 244         244            7.0                 0.4598
# 245         245            3.0                 0.4402
# 246         246           10.0                 0.6389
#
#                                             Kata_Kunci  \
# 0    metode_forward, pakar, sistem_pakar, metode_ce...
# 1    informasi_penjualan, pendukung_keputusan, peng...
# 2    informasi_geografis, media_pembelajaran, augme...
# 3    jaringan_komputer, pakar_diagnosis, diagnosis_...
# 4    informasi_akuntansi, metode_waterfall, sms_gat...
# 5    jaringan_komputer, pakar_diagnosis, diagnosis_...
# 6    informasi_akuntansi, metode_waterfall, sms_gat...
# 7    smk_negeri, siswa_kelas, expert_system, hasil_...
# 8    pendukung_keputusan, metode_weighted, pendukun...
# 9    informasi_geografis, media_pembelajaran, augme...
# 10   learning_vector, support_vector, jarak_jauh, l...
# 11   jaringan_komputer, pakar_diagnosis, diagnosis_...
# 12   pendukung_keputusan, rancang_bangun, sepeda_mo...
# 13   pendukung_keputusan, rancang_bangun, sepeda_mo...
# 14   pendukung_keputusan, metode_weighted, pendukun...
# 15   pendukung_keputusan, rancang_bangun, sepeda_mo...
# 16   learning_vector, support_vector, jarak_jauh, l...
# 17   metode_simple, additive_weighting, mata_kuliah...
# 18   perangkat_lunak, informasi_akademik, pendukung...
# 19   smk_negeri, siswa_kelas, expert_system, hasil_...
# 20   metode_simple, additive_weighting, mata_kuliah...
# 21   e_commerce, rekam_medis, pendukung_keputusan, ...
# 22   e_commerce, rekam_medis, pendukung_keputusan, ...
# 23   pendukung_keputusan, rancang_bangun, sepeda_mo...
# 24   informasi_penjualan, pendukung_keputusan, peng...
# 25   learning_vector, support_vector, jarak_jauh, l...
# 26   jaringan_komputer, pakar_diagnosis, diagnosis_...
# 27   jaringan_komputer, pakar_diagnosis, diagnosis_...
# 28   jaringan_komputer, pakar_diagnosis, diagnosis_...
# 29   jaringan_komputer, pakar_diagnosis, diagnosis_...
# ..                                                 ...
# 217  pendukung_keputusan, rancang_bangun, sepeda_mo...
# 218  perangkat_lunak, informasi_akademik, pendukung...
# 219  metode_topsis, mata_pelajaran, topsis, penunja...
# 220  informasi_penjualan, pendukung_keputusan, peng...
# 221  perguruan_tinggi, anak_usia, citra_landsat, ke...
# 222  metode_topsis, mata_pelajaran, topsis, penunja...
# 223  informasi_penjualan, pendukung_keputusan, peng...
# 224  informasi_geografis, media_pembelajaran, augme...
# 225  perangkat_lunak, informasi_akademik, pendukung...
# 226  informasi_geografis, media_pembelajaran, augme...
# 227  smk_negeri, siswa_kelas, expert_system, hasil_...
# 228  rancang_bangun, certainty_factor, operasi_andr...
# 229  learning_vector, support_vector, jarak_jauh, l...
# 230  pendukung_keputusan, metode_weighted, pendukun...
# 231  smk_negeri, siswa_kelas, expert_system, hasil_...
# 232  metode_simple, additive_weighting, mata_kuliah...
# 233  jaringan_komputer, pakar_diagnosis, diagnosis_...
# 234  metode_forward, pakar, sistem_pakar, metode_ce...
# 235  e_commerce, rekam_medis, pendukung_keputusan, ...
# 236  learning_vector, support_vector, jarak_jauh, l...
# 237  jaringan_komputer, pakar_diagnosis, diagnosis_...
# 238  rancang_bangun, certainty_factor, operasi_andr...
# 239  pendukung_keputusan, rancang_bangun, sepeda_mo...
# 240  jaringan_komputer, pakar_diagnosis, diagnosis_...
# 241  smk_negeri, siswa_kelas, expert_system, hasil_...
# 242  e_commerce, rekam_medis, pendukung_keputusan, ...
# 243  metode_topsis, mata_pelajaran, topsis, penunja...
# 244  metode_topsis, mata_pelajaran, topsis, penunja...
# 245  metode_forward, pakar, sistem_pakar, metode_ce...
# 246  perguruan_tinggi, anak_usia, citra_landsat, ke...
#
#                                                   Teks
# 0    [pendeteksi, gangguan, jaringan, lokal, metode...
# 1    [eksistensi, penggunaan, wi, fi, warung, kopi,...
# 2    [pengaruh, internet, financial, reporting, tin...
# 3    [security, function, analysis, performance, hi...
# 4    [implementation, top, down, approach, method, ...
# 5    [optimization, wireless, network, performance,...
# 6    [analysis, qos, vlan, djikstra, s, algorithm, ...
# 7    [link, performance, improvement, sananibun, bt...
# 8    [legal, protection, efforts, patent, holders, ...
# 9    [use, e, learning, by, teachers, teaching, lea...
# 10   [definition, patent, rights, examples, case, s...
# 11   [analysis, implementation, backup, line, netwo...
# 12   [classification, principles, legal, basis, int...
# 13   [attendance, system, automatic, door, locks, l...
# 14   [registration, requirements, application, rights]
# 15   [patentability, block, chain, technology, futu...
# 16   [influence, speed, user, mobility, qos, wirele...
# 17   [4, ghz, omnidirectional, antenna, design, wit...
# 18   [pemanfaatan, telepon, pintar, informasi, peny...
# 19   [aplikasi, teknologi, komunikasi, wireless, zi...
# 20   [forensics, analysis, router, computer, networ...
# 21   [manajemen, proyeksi, sistem, informasi, manaj...
# 22   [manajemen, proyeksi, sistem, informasi, manaj...
# 23            [tri, destanto, 175100067p, sectionquis]
# 24   [rancang, bangun, aplikasi, chatting, web, doc...
# 25   [multimedia, animated, corrosion, corrosion, c...
# 26   [quality, service, traffic, monitoring, system...
# 27   [analisis, topologi, area, jaringan, komputer,...
# 28   [resume, pembuatan, tugas, jaringan, komputer,...
# 29   [perkembangan, jaringan, komputer, indonesia, ...
# ..                                                 ...
# 217  [implementasi, captive, portal, pfsense, capti...
# 218  [aspek, hukum, pelayan, publik, online, direkt...
# 219  [steganografi, citra, digital, menyembunyikan,...
# 220  [analisis, faktor, minat, siswa, memilih, juru...
# 221  [managed, service, network, management, system...
# 222  [kebijakan, kriminal, pemerintah, kejahatan, d...
# 223  [pengembangan, aplikasi, e, commerce, pendekat...
# 224  [konsep, pengembangan, sistem, informasi, moni...
# 225  [tugas, akhir, jurnal, tata, kelola, sistem, t...
# 226  [e, commerce, media, promosi, pemasaran, decou...
# 227  [failover, gateway, protokol, virtual, router,...
# 228  [sistem, informasi, administrasi, data, kemaha...
# 229  [analisis, perbandingan, detection, traffic, a...
# 230  [sistem, pendukung, keputusan, pemilihan, pemi...
# 231  [pengaruh, media, packet, tracer, kreativitas,...
# 232  [multimedia, edukasi, interaktif, pelajaran, b...
# 233  [aplikasi, sistem, penyidikan, client, server,...
# 234  [tindak, pidana, dunia, maya, berupa, virus, t...
# 235  [analisis, pengaruh, manfaat, risiko, kepercay...
# 236  [pengaruh, perceived, value, repurchase, inten...
# 237  [cooperative, accounting, computer, applicatio...
# 238  [membangun, rencana, strategis, sistem, inform...
# 239  [perancangan, sistem, pendukung, keputusan, pe...
# 240  [pengamanan, data, aplikasi, sijalu, universit...
# 241  [implementation, pptp, bcp, with, inter, vlan,...
# 242  [analisis, yuridis, penyelesaian, sengketa, cy...
# 243  [smart, campus, model, baru, enterprise, archi...
# 244  [analisis, hubungan, antara, daring, revolusi,...
# 245  [akad, jual, beli, online, perspektif, hukum, ...
# 246  [analisis, akad, undang, undang, nomor, tahun,...
#
# [247 rows x 5 columns]

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics
# Out:
# 3.0     3172
# 14.0    2320
# 0.0     2226
# 8.0     1977
# 11.0    1935
# 12.0    1856
# 13.0    1720
# 15.0    1637
# 4.0     1429
# 1.0     1412
# 6.0     1396
# 5.0     1378
# 9.0     1376
# 10.0    1272
# 7.0     1221
# 2.0     1188
# Name: Topik_Dominan, dtype: int64

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')
# Out:
# Text(0.5,1,'Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.9625
# 1         1.0              0.9698
# 2         2.0              0.9507
# 3         3.0              0.9609
# 4         4.0              0.9574
# 5         5.0              0.9592
# 6         6.0              0.9639
# 7         7.0              0.9592
# 8         8.0              0.9554
# 9         9.0              0.9609
# 10       10.0              0.9507
# 11       11.0              0.9609
# 12       12.0              0.9625
# 13       13.0              0.9639
# 14       14.0              0.9639
# 15       15.0              0.9698
#
#                                                                                                Keywords  \
# 0   pendukung_keputusan, metode_weighted, pendukung, keputusan, studi_kasus, sma_negeri, saw, progra...
# 1   learning_vector, support_vector, jarak_jauh, location_service, object_oriented, visual_basic, ve...
# 2   metode_simple, additive_weighting, mata_kuliah, simple, additive, weighting, metode_simple_addit...
# 3   metode_forward, pakar, sistem_pakar, metode_certainty, penyakit, pakar_diagnosa, diagnosa, diagn...
# 4   rancang_bangun, certainty_factor, operasi_android, administrasi, deteksi_tepi, framework_codeign...
# 5   jaringan_komputer, pakar_diagnosis, diagnosis_penyakit, informasi_pemesanan, artificial_neural, ...
# 6   informasi_akuntansi, metode_waterfall, sms_gateway, informasi, forward_chaining, studi_kasus, in...
# 7   metode_topsis, mata_pelajaran, topsis, penunjang_keputusan, terbaik, information_system, pelajar...
# 8   perangkat_lunak, informasi_akademik, pendukung_keputusan, pengolahan_citra, naive_bayes, studi_k...
# 9   e_commerce, rekam_medis, pendukung_keputusan, studi_kasus, commerce, basis_data, informasi, e, p...
# 10  perguruan_tinggi, anak_usia, citra_landsat, kesehatan, perguruan, tinggi, siswa_berprestasi, buk...
# 11  raspberry_pi, rumah_sakit, fuzzy_logic, logika_fuzzy, k_nearest, data_mining, citra_digital, alg...
# 12  informasi_penjualan, pendukung_keputusan, pengolahan_data, penjualan, penerimaan_siswa, php_mysq...
# 13  pendukung_keputusan, rancang_bangun, sepeda_motor, sumber_daya, keamanan_jaringan, metode_analyt...
# 14  informasi_geografis, media_pembelajaran, augmented_reality, rancang_bangun, metode_dempster, pem...
# 15  smk_negeri, siswa_kelas, expert_system, hasil_belajar, studi_kasus, mobile_learning, metode_prof...
#
#                                                                                     Representative Text
# 0   [rancang, bangun, sistem, informasi, inventarisasi, laporan, tugas, akhir, mahasiswa, program, s...
# 1   [klasifikasi, pola, sidik, bibir, jenis, kelamin, manusia, metode, gray, level, co, occurrence, ...
# 2   [sistem, informasi, tunggakan, premi, nasabah, pemrograman, visual, delphi, asuransi, jiwa, bery...
# 3   [deteksi, usia, citra, panoramik, pulpa, gigi, molar, pertama, mandibula, discrete, wavelet, tra...
# 4   [rancang, bangun, sistem, pengenalan, citra, tingkat, kematangan, buah, pepaya, california, warn...
# 5   [rancang, bangun, keamanan, data, jaringan, komputer, metode, ipsec, vpn, studi, kasus, agrabudi...
# 6   [rancang, bangun, sistem, informasi, kepegawaian, simpeg, sdlc, metode, waterfall, studi, kasus,...
# 7   [metode, technique, others, preference, by, similary, ideal, solution, topsis, pemilihan, lokasi...
# 8   [desain, sistem, kamus, istilah, komputer, android, studi, kasus, sma, muhammadiyah, kartasura, ...
# 9   [implementasi, konsep, business, customer, teknologi, e, commerce, web, studi, kasus, toko, sepa...
# 10  [analisis, kebijakan, pendidikan, anak, usia, dini, era, revolusi, industri, 0, anak_usia, era_r...
# 11  [operasi, morfologi, matematika, citra, digital, ekstraksi, area, plat, nomor, kendaraan, bermot...
# 12  [sistem, keamanan, server, honeypot, intrusion, detection, system, ids, studi, kasus, perusahaan...
# 13  [perancangan, sistem, pendukung, keputusan, pemilihan, dosen, pembimbing, skripsi, minat, mahasi...
# 14  [pembangunan, media, pembelajaran, interaktif, mata, pelajaran, bahasa, inggris, kelas, vii, kas...
# 15  [perancangan, implementasi, virtual, private, network, vpn, protokol, sstp, secure, socket, tunn...

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-range3.html')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 3     -0.230562 -0.203869       1        1  8.725219
# 14     0.108760 -0.015505       2        1  7.304197
# 8      0.045497 -0.096395       3        1  6.782347
# 11    -0.131353  0.097687       4        1  6.781981
# 12     0.032892 -0.083806       5        1  6.611269
# 0      0.083982 -0.092871       6        1  6.591941
# 15     0.085835 -0.039902       7        1  6.119252
# 13     0.015322 -0.005599       8        1  6.106954
# 1     -0.090851  0.128334       9        1  5.864684
# 10     0.023546  0.009901      10        1  5.803957
# 4     -0.055806  0.065845      11        1  5.724933
# 5     -0.004113  0.058214      12        1  5.696629
# 7      0.022406  0.046787      13        1  5.658555
# 9      0.049449 -0.002807      14        1  5.526490
# 6      0.072290  0.040699      15        1  5.415445
# 2     -0.027291  0.093289      16        1  5.286147, topic_info=      Category        Freq                     Term       Total  loglift  \
# term
# 4190   Default  190.000000           metode_forward  190.000000  30.0000
# 1722   Default  160.000000      informasi_penjualan  160.000000  29.0000
# 738    Default  475.000000      pendukung_keputusan  475.000000  28.0000
# 7      Default  136.000000         metode_certainty  136.000000  27.0000
# 1862   Default  112.000000            metode_simple  112.000000  26.0000
# 4109   Default  116.000000           pakar_diagnosa  116.000000  25.0000
# 884    Default  174.000000             sistem_pakar  174.000000  24.0000
# 883    Default  175.000000                    pakar  175.000000  23.0000
# 4950   Default   90.000000       additive_weighting   90.000000  22.0000
# 7018   Default   94.000000            metode_topsis   94.000000  21.0000
# 3040   Default  111.000000          perangkat_lunak  111.000000  20.0000
# 2748   Default  143.000000                 penyakit  143.000000  19.0000
# 613    Default   77.000000               smk_negeri   77.000000  18.0000
# 4107   Default   86.000000        diagnosa_penyakit   86.000000  17.0000
# 4106   Default   88.000000                 diagnosa   88.000000  16.0000
# 623    Default   81.000000             raspberry_pi   81.000000  15.0000
# 1360   Default   72.000000         perguruan_tinggi   72.000000  14.0000
# 263    Default   86.000000       media_pembelajaran   86.000000  13.0000
# 1493   Default  103.000000       informasi_akademik  103.000000  12.0000
# 831    Default   81.000000               e_commerce   81.000000  11.0000
# 391    Default   66.000000              mata_kuliah   66.000000  10.0000
# 611    Default   67.000000           mata_pelajaran   67.000000   9.0000
# 997    Default   76.000000              rumah_sakit   76.000000   8.0000
# 2475   Default   68.000000      informasi_akuntansi   68.000000   7.0000
# 842    Default  138.000000      informasi_geografis  138.000000   6.0000
# 6107   Default   68.000000          metode_weighted   68.000000   5.0000
# 4158   Default   77.000000        pakar_mendiagnosa   77.000000   4.0000
# 260    Default   66.000000        augmented_reality   66.000000   3.0000
# 2742   Default   73.000000                  forward   73.000000   2.0000
# 225    Default   69.000000        jaringan_komputer   69.000000   1.0000
# ...        ...         ...                      ...         ...      ...
# 10294  Topic16   11.568426         development_life   12.340891   2.8754
# 5430   Topic16   10.652995       euclidean_distance   11.376523   2.8744
# 4697   Topic16   10.384941   pakar_mengidentifikasi   11.112840   2.8723
# 556    Topic16   16.349161               metodologi   17.497822   2.8722
# 5064   Topic16   10.284000                air_tawar   11.007528   2.8721
# 7842   Topic16   11.654263               saw_simple   12.481171   2.8715
# 6268   Topic16   10.168380                  numerik   10.891912   2.8713
# 747    Topic16    9.762336         blended_learning   10.485864   2.8686
# 10544  Topic16    9.504210           cross_platform   10.227737   2.8667
# 2015   Topic16    9.962347           suhu_permukaan   10.751657   2.8638
# 16112  Topic16   12.314309         kenaikan_pangkat   13.290786   2.8638
# 8201   Topic16    9.120939            motor_induksi    9.844950   2.8637
# 8035   Topic16    9.084386            self_efficacy    9.807983   2.8634
# 1232   Topic16    9.157966                 variabel    9.893818   2.8628
# 280    Topic16    8.961804                pontianak    9.685334   2.8624
# 1862   Topic16  103.148514            metode_simple  112.170845   2.8562
# 9812   Topic16   26.101500  metodologi_berorientasi   28.284691   2.8598
# 724    Topic16   54.692600                   simple   59.842319   2.8501
# 9610   Topic16   23.027981         platform_android   25.326941   2.8449
# 7917   Topic16   23.310196          simple_additive   25.765446   2.8399
# 629    Topic16   23.680965                siswa_smk   30.031395   2.7025
# 4681   Topic16   11.102783                   status   12.291272   2.8384
# 389    Topic16   20.091978                   kuliah   28.875248   2.5774
# 2916   Topic16   14.021509                 platform   17.687529   2.7078
# 498    Topic16   23.953695                     game   45.950882   2.2886
# 548    Topic16   13.617182                pengujian   17.942429   2.6642
# 348    Topic16   18.113661                     mata   56.264030   1.8067
# 205    Topic16   22.503592           rancang_bangun  415.673065   0.0239
# 6      Topic16   15.868834                   metode  256.878448   0.1558
# 373    Topic16   11.919969              studi_kasus  410.788635  -0.5998
#
#        logprob
# term
# 4190   30.0000
# 1722   29.0000
# 738    28.0000
# 7      27.0000
# 1862   26.0000
# 4109   25.0000
# 884    24.0000
# 883    23.0000
# 4950   22.0000
# 7018   21.0000
# 3040   20.0000
# 2748   19.0000
# 613    18.0000
# 4107   17.0000
# 4106   16.0000
# 623    15.0000
# 1360   14.0000
# 263    13.0000
# 1493   12.0000
# 831    11.0000
# 391    10.0000
# 611     9.0000
# 997     8.0000
# 2475    7.0000
# 842     6.0000
# 6107    5.0000
# 4158    4.0000
# 260     3.0000
# 2742    2.0000
# 225     1.0000
# ...        ...
# 10294  -5.8875
# 5430   -5.9699
# 4697   -5.9954
# 556    -5.5416
# 5064   -6.0052
# 7842   -5.8801
# 6268   -6.0165
# 747    -6.0572
# 10544  -6.0840
# 2015   -6.0369
# 16112  -5.8250
# 8201   -6.1252
# 8035   -6.1292
# 1232   -6.1211
# 280    -6.1428
# 1862   -3.6996
# 9812   -5.0738
# 724    -4.3340
# 9610   -5.1990
# 7917   -5.1869
# 629    -5.1711
# 4681   -5.9286
# 389    -5.3354
# 2916   -5.6952
# 498    -5.1596
# 548    -5.7244
# 348    -5.4391
# 205    -5.2221
# 6      -5.5714
# 373    -5.8575
#
# [824 rows x 6 columns], token_table=       Topic      Freq                       Term
# term
# 1977       9  0.925647               access_point
# 4043       1  0.018133                   additive
# 4043      16  0.961051                   additive
# 4950      16  0.989703         additive_weighting
# 1083       6  0.140895               administrasi
# 1083      11  0.774922               administrasi
# 1083      12  0.046965               administrasi
# 10482     11  0.887760  administrasi_kependudukan
# 2661       1  0.937057                adobe_flash
# 14966     14  0.920492             adventure_game
# 1245       3  0.106107                        ahp
# 1245       8  0.657861                        ahp
# 1245      13  0.212213                        ahp
# 4995      13  0.978948                 ahp_topsis
# 5064      16  0.908469                  air_tawar
# 1362       1  0.019182                   akademik
# 1362       2  0.076728                   akademik
# 1362       3  0.575459                   akademik
# 1362       7  0.115092                   akademik
# 1362      10  0.038364                   akademik
# 1362      12  0.057546                   akademik
# 1362      15  0.095910                   akademik
# 12630     12  0.892735                aksara_jawa
# 1234       2  0.031271                  akuntansi
# 1234       4  0.031271                  akuntansi
# 1234      13  0.093812                  akuntansi
# 1234      14  0.031271                  akuntansi
# 1234      15  0.813039                  akuntansi
# 4083       2  0.921671                     al_qur
# 3763       2  0.898854                 alat_bantu
# ...      ...       ...                        ...
# 206        5  0.130272                        web
# 206        6  0.049414                        web
# 206        7  0.053906                        web
# 206        8  0.049414                        web
# 206        9  0.017969                        web
# 206       10  0.035937                        web
# 206       11  0.040429                        web
# 206       12  0.040429                        web
# 206       13  0.040429                        web
# 206       14  0.067382                        web
# 206       15  0.067382                        web
# 206       16  0.008984                        web
# 1006       3  0.922042                web_service
# 8210      12  0.930436             weight_product
# 5346       6  0.949532                   weighted
# 5346       8  0.031651                   weighted
# 3267       1  0.019148                  weighting
# 3267      16  0.976571                  weighting
# 1990       9  0.907970            wireless_sensor
# 600        1  0.041691                          x
# 600        4  0.250143                          x
# 600        8  0.041691                          x
# 600       13  0.583667                          x
# 600       14  0.041691                          x
# 600       15  0.041691                          x
# 2380       2  0.951770                        xyz
# 2160       2  0.356991                 yogyakarta
# 2160       3  0.148746                 yogyakarta
# 2160      11  0.446239                 yogyakarta
# 2160      16  0.029749                 yogyakarta
#
# [1670 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 15, 9, 12, 13, 1, 16, 14, 2, 11, 5, 6, 8, 10, 7, 3])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model-range3.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

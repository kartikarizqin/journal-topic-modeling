# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned2011.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                    text
# 0     optimalisasi keamanan jaringan pemfilteran apl...
# 1     sistem informasi web jurusan sistem informasi ...
# 2     teknologi bluetooth aplikasinya jaringan komputer
# 3               teori modul praktikum jaringan komputer
# 4           membangun jaringan komputer server internet
# 5     simulasi pemanfaatan dynamic routing protocol ...
# 6     analisis perancangan jaringan komputer studi k...
# 7     pengembangan desain pembelajaran mobile learni...
# 8         kitab suci jaringan komputer koneksi internet
# 9     perancangan implementasi video demand jaringan...
# 10    jaringan komputer radio itb telah tersambung j...
# 11       simulasi model jaringan mobile ad hoc manet ns
# 12    implementasi load balance jaringan multihoming...
# 13                   real time system jaringan komputer
# 14    analisa implementasi sistem keamanan jaringan ...
# 15            manajemen jaringan wireless server radius
# 16    implementasi rule expert systems mendeteksi ke...
# 17    komunikasi data jaringan komputer network deve...
# 18    rancang bangun vlan segmentasi jaringan cyber ...
# 19    konsep membangun internet gratis masyarakat me...
# 20    pemanfaatan jejaring sosial facebook media bis...
# 21              pengembangan jaringan komputer rip ospf
# 22    implementasi intrusion detection system ids sn...
# 23    membangun jaringan wireless lan kantor kelurah...
# 24    membangun jaringan hotspot wi fi rt rw net kel...
# 25          perbandingan tipe mac jaringan vsat mesh ns
# 26                  pemanfaatan e commerce dunia bisnis
# 27    analisis deteksi penyusupan jaringan komputer ...
# 28    analisis pengaruh iklan kepercayaan merek citr...
# 29    studi kelayakan sarana prasarana laboratorium ...
# ...                                                 ...
# 6042  kantor sewa surakarta pendekatan arsitektur hijau
# 6043  analisa perancangan sistem informasi akademik ...
# 6044  citra rumah zakat indonesia cabang yogyakarta ...
# 6045  rancang bangun sistem informasi spasial webgis...
# 6046                aplikasi manajemen database sekolah
# 6047  strategi kelangsungan usaha industri rotan str...
# 6048  sistem informasi katalog buku web studi kasus ...
# 6049  penyusunan model penetapan luas lahan optimum ...
# 6050  implementasi metode pembelajaran inquiry terbi...
# 6051  rancang bangun sistem informasi penunjang kepu...
# 6052  kualitas pelayanan perusahaan daerah air minum...
# 6053  pengembangan sistem informasi pemetaan sekolah...
# 6054  implementasi sistem penjualan online e commerc...
# 6055  pengembangan aplikasi penjadwalan kegiatan alg...
# 6056  sistem konsultasi online agribisnis cabai caps...
# 6057  pengembangan web potal universitas jquery stmi...
# 6058  pemanfaatan laboratorium komputer peningkatan ...
# 6059  analisis efisiensi tempat pelelangan ikan tpi ...
# 6060  aplikasi e commerce aromatherapy content manag...
# 6061  desain interior solo multimedia school pendeka...
# 6062  perancangan tongkat tuna netra teknologi senso...
# 6063  pengaruh kecerdasan emosional eq motivasi bela...
# 6064  komunikasi strategis pemilihan umum kepala dae...
# 6065  pengembangan media online oleh institusi media...
# 6066  penyelesaian analitik model totally asymmetric...
# 6067                demokrasi politik lokal kota santri
# 6068  penelusuran potensi daerah pembinaan olahraga ...
# 6069  pusat perfilman nasional bandung pendekatan de...
# 6070  pengaruh pemanfaatan teknologi informatika kin...
# 6071  pengaruh model pembelajaran proyek pendekatan ...
#
# [6072 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 6072
# [['optimalisasi', 'keamanan', 'jaringan', 'pemfilteran', 'aplikasi', 'mikrotik']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# [['optimalisasi', 'keamanan', 'jaringan', 'pemfilteran', 'aplikasi', 'mikrotik', 'keamanan_jaringan', 'keamanan_jaringan', 'keamanan_jaringan'], ['sistem', 'informasi', 'web', 'jurusan', 'sistem', 'informasi', 'fakultas', 'ilmu', 'komputer', 'universitas', 'sriwijaya', 'fakultas_ilmu', 'sistem_informasi', 'sistem_informasi', 'fakultas_ilmu', 'fakultas_ilmu'], ['teknologi', 'bluetooth', 'aplikasinya', 'jaringan', 'komputer', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['teori', 'modul', 'praktikum', 'jaringan', 'komputer', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['membangun', 'jaringan', 'komputer', 'server', 'internet', 'jaringan_komputer', 'membangun_jaringan', 'jaringan_komputer'], ['simulasi', 'pemanfaatan', 'dynamic', 'routing', 'protocol', 'ospf', 'router', 'jaringan', 'komputer', 'unpar', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['analisis', 'perancangan', 'jaringan', 'komputer', 'studi', 'kasus', 'inna', 'garuda', 'yogyakarta', 'jaringan_komputer', 'studi_kasus', 'analisis_perancangan', 'jaringan_komputer', 'studi_kasus', 'jaringan_komputer', 'studi_kasus'], ['pengembangan', 'desain', 'pembelajaran', 'mobile', 'learning', 'management', 'system', 'materi', 'pengenalan', 'komponen', 'jaringan', 'management_system', 'mobile_learning', 'management_system', 'management_system'], ['kitab', 'suci', 'jaringan', 'komputer', 'koneksi', 'internet', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['perancangan', 'implementasi', 'video', 'demand', 'jaringan', 'lokal', 'jaringan_lokal', 'jaringan_lokal', 'jaringan_lokal'], ['jaringan', 'komputer', 'radio', 'itb', 'telah', 'tersambung', 'jaringan', 'internasional', 'internet', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['simulasi', 'model', 'jaringan', 'mobile', 'ad', 'hoc', 'manet', 'ns', 'ad_hoc', 'ad_hoc'], ['implementasi', 'load', 'balance', 'jaringan', 'multihoming', 'router', 'metode', 'round', 'robin'], ['real', 'time', 'system', 'jaringan', 'komputer', 'real_time', 'jaringan_komputer', 'real_time', 'jaringan_komputer', 'real_time', 'jaringan_komputer'], ['analisa', 'implementasi', 'sistem', 'keamanan', 'jaringan', 'komputer', 'iptables', 'firewall', 'metode', 'port', 'knocking', 'keamanan_jaringan', 'keamanan_jaringan', 'keamanan_jaringan'], ['manajemen', 'jaringan', 'wireless', 'server', 'radius'], ['implementasi', 'rule', 'expert', 'systems', 'mendeteksi', 'kerusakan', 'sistem', 'jaringan', 'komputer', 'metode', 'backward', 'chaining', 'mendeteksi_kerusakan', 'jaringan_komputer', 'metode_backward', 'mendeteksi_kerusakan', 'jaringan_komputer', 'metode_backward', 'mendeteksi_kerusakan', 'jaringan_komputer', 'metode_backward'], ['komunikasi', 'data', 'jaringan', 'komputer', 'network', 'development', 'life', 'cycle', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['rancang', 'bangun', 'vlan', 'segmentasi', 'jaringan', 'cyber', 'campus', 'laboratory', 'universitas', 'stikubank', 'rancang_bangun', 'rancang_bangun', 'rancang_bangun'], ['konsep', 'membangun', 'internet', 'gratis', 'masyarakat', 'memanfaatkan', 'bandwidth', 'tidur', 'korporasi'], ['pemanfaatan', 'jejaring', 'sosial', 'facebook', 'media', 'bisnis', 'online', 'studi', 'kasus', 'batik', 'solo', 'jejaring_sosial', 'studi_kasus', 'jejaring_sosial', 'studi_kasus', 'jejaring_sosial', 'studi_kasus'], ['pengembangan', 'jaringan', 'komputer', 'rip', 'ospf', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['implementasi', 'intrusion', 'detection', 'system', 'ids', 'snort', 'jaringan', 'wireless', 'studi', 'kasus', 'smk', 'triguna', 'ciputat', 'intrusion_detection', 'studi_kasus', 'intrusion_detection', 'studi_kasus', 'intrusion_detection', 'studi_kasus'], ['membangun', 'jaringan', 'wireless', 'lan', 'kantor', 'kelurahan', 'bintaro', 'membangun_jaringan'], ['membangun', 'jaringan', 'hotspot', 'wi', 'fi', 'rt', 'rw', 'net', 'kelurahan', 'belimbing', 'kecamatan', 'murung', 'pudak', 'kabupaten', ' ...

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                 0             1             2             3             4   \
# 0     optimalisasi      keamanan      jaringan   pemfilteran      aplikasi
# 1           sistem     informasi           web       jurusan        sistem
# 2        teknologi     bluetooth   aplikasinya      jaringan      komputer
# 3            teori         modul     praktikum      jaringan      komputer
# 4        membangun      jaringan      komputer        server      internet
# 5         simulasi   pemanfaatan       dynamic       routing      protocol
# 6         analisis   perancangan      jaringan      komputer         studi
# 7     pengembangan        desain  pembelajaran        mobile      learning
# 8            kitab          suci      jaringan      komputer       koneksi
# 9      perancangan  implementasi         video        demand      jaringan
# 10        jaringan      komputer         radio           itb         telah
# 11        simulasi         model      jaringan        mobile            ad
# 12    implementasi          load       balance      jaringan   multihoming
# 13            real          time        system      jaringan      komputer
# 14         analisa  implementasi        sistem      keamanan      jaringan
# 15       manajemen      jaringan      wireless        server        radius
# 16    implementasi          rule        expert       systems    mendeteksi
# 17      komunikasi          data      jaringan      komputer       network
# 18         rancang        bangun          vlan    segmentasi      jaringan
# 19          konsep     membangun      internet        gratis    masyarakat
# 20     pemanfaatan      jejaring        sosial      facebook         media
# 21    pengembangan      jaringan      komputer           rip          ospf
# 22    implementasi     intrusion     detection        system           ids
# 23       membangun      jaringan      wireless           lan        kantor
# 24       membangun      jaringan       hotspot            wi            fi
# 25    perbandingan          tipe           mac      jaringan          vsat
# 26     pemanfaatan             e      commerce         dunia        bisnis
# 27        analisis       deteksi    penyusupan      jaringan      komputer
# 28        analisis      pengaruh         iklan   kepercayaan         merek
# 29           studi     kelayakan        sarana     prasarana  laboratorium
# ...            ...           ...           ...           ...           ...
# 6042        kantor          sewa     surakarta    pendekatan    arsitektur
# 6043       analisa   perancangan        sistem     informasi      akademik
# 6044         citra         rumah         zakat     indonesia        cabang
# 6045       rancang        bangun        sistem     informasi       spasial
# 6046      aplikasi     manajemen      database       sekolah          None
# 6047      strategi  kelangsungan         usaha      industri         rotan
# 6048        sistem     informasi       katalog          buku           web
# 6049    penyusunan         model     penetapan          luas         lahan
# 6050  implementasi        metode  pembelajaran       inquiry    terbimbing
# 6051       rancang        bangun        sistem     informasi     penunjang
# 6052      kualitas     pelayanan    perusahaan        daerah           air
# 6053  pengembangan        sistem     informasi      pemetaan       sekolah
# 6054  implementasi        sistem     penjualan        online             e
# 6055  pengembangan      aplikasi   penjadwalan      kegiatan     algoritma
# 6056        sistem    konsultasi        online    agribisnis         cabai
# 6057  pengembangan           web         potal   universitas        jquery
# 6058   pemanfaatan  laboratorium      komputer   peningkatan   ketrampilan
# 6059      analisis     efisiensi        tempat    pelelangan          ikan
# 6060      aplikasi             e      commerce  aromatherapy       content
# 6061        desain      interior          solo    multimedia        school
# 6062   perancangan       tongkat          tuna         netra     teknologi
# 6063      pengaruh    kecerdasan     emosional            eq      motivasi
# 6064    komunikasi     strategis     pemilihan          umum        kepala
# 6065  pengembangan         media        online          oleh     institusi
# 6066  penyelesaian      analitik         model       totally    asymmetric
# 6067     demokrasi       politik         lokal          kota        santri
# 6068   penelusuran       potensi        daerah     pembinaan      olahraga
# 6069         pusat     perfilman      nasional       bandung    pendekatan
# 6070      pengaruh   pemanfaatan     teknologi   informatika       kinerja
# 6071      pengaruh         model  pembelajaran        proyek    pendekatan
#
#                      5                   6                   7   \
# 0              mikrotik   keamanan_jaringan   keamanan_jaringan
# 1             informasi            fakultas                ilmu
# 2     jaringan_komputer   jaringan_komputer   jaringan_komputer
# 3     jaringan_komputer   jaringan_komputer   jaringan_komputer
# 4     jaringan_komputer  membangun_jaringan   jaringan_komputer
# 5                  ospf              router            jaringan
# 6                 kasus                inna              garuda
# 7            management              system              materi
# 8              internet   jaringan_komputer   jaringan_komputer
# 9                 lokal      jaringan_lokal      jaringan_lokal
# 10           tersambung            jaringan       internasional
# 11                  hoc               manet                  ns
# 12               router              metode               round
# 13            real_time   jaringan_komputer           real_time
# 14             komputer            iptables            firewall
# 15                 None                None                None
# 16            kerusakan              sistem            jaringan
# 17          development                life               cycle
# 18                cyber              campus          laboratory
# 19         memanfaatkan           bandwidth               tidur
# 20               bisnis              online               studi
# 21    jaringan_komputer   jaringan_komputer   jaringan_komputer
# 22                snort            jaringan            wireless
# 23            kelurahan             bintaro  membangun_jaringan
# 24                   rt                  rw                 net
# 25                 mesh                  ns                None
# 26           e_commerce          e_commerce          e_commerce
# 27                snort               studi               kasus
# 28                citra               merek               minat
# 29             komputer             jurusan              teknik
# ...                 ...                 ...                 ...
# 6042              hijau                None                None
# 6043            sekolah                 web              metode
# 6044         yogyakarta          masyarakat                None
# 6045             webgis             sebaran          pencemaran
# 6046               None                None                None
# 6047           strategi        kelangsungan               usaha
# 6048              studi               kasus             jurusan
# 6049            optimum               usaha                tani
# 6050            inquiry               bebas       termodifikasi
# 6051          keputusan          penerimaan             nasabah
# 6052              minum                pdam               tirta
# 6053           menengah                atas              negeri
# 6054           commerce               usaha             rumahan
# 6055           genetika               studi               kasus
# 6056           capsicum              annuum                   l
# 6057              stmik               islam       internasional
# 6058         penggunaan           teknologi           informasi
# 6059                tpi               kelas                   i
# 6060         management              system               studi
# 6061         pendekatan              konsep              modern
# 6062             sensor          ultrasonik            membantu
# 6063            belajar          matematika               siswa
# 6064             daerah               studi               kasus
# 6065              media               studi               kasus
# 6066          exclusion             process               tasep
# 6067               None                None                None
# 6068               usia                dini           kecamatan
# 6069             desain       fleksibilitas             akustik
# 6070            pegawai        administrasi            madrasah
# 6071            jelajah                alam             sekitar
#
#                      8                  9   ...     25    26    27    28  \
# 0     keamanan_jaringan               None  ...   None  None  None  None
# 1              komputer        universitas  ...   None  None  None  None
# 2                  None               None  ...   None  None  None  None
# 3                  None               None  ...   None  None  None  None
# 4                  None               None  ...   None  None  None  None
# 5              komputer              unpar  ...   None  None  None  None
# 6            yogyakarta  jaringan_komputer  ...   None  None  None  None
# 7            pengenalan           komponen  ...   None  None  None  None
# 8     jaringan_komputer               None  ...   None  None  None  None
# 9        jaringan_lokal               None  ...   None  None  None  None
# 10             internet  jaringan_komputer  ...   None  None  None  None
# 11               ad_hoc             ad_hoc  ...   None  None  None  None
# 12                robin               None  ...   None  None  None  None
# 13    jaringan_komputer          real_time  ...   None  None  None  None
# 14               metode               port  ...   None  None  None  None
# 15                 None               None  ...   None  None  None  None
# 16             komputer             metode  ...   None  None  None  None
# 17    jaringan_komputer  jaringan_komputer  ...   None  None  None  None
# 18          universitas          stikubank  ...   None  None  None  None
# 19            korporasi               None  ...   None  None  None  None
# 20                kasus              batik  ...   None  None  None  None
# 21                 None               None  ...   None  None  None  None
# 22                studi              kasus  ...   None  None  None  None
# 23                 None               None  ...   None  None  None  None
# 24            kelurahan          belimbing  ...   None  None  None  None
# 25                 None               None  ...   None  None  None  None
# 26                 None               None  ...   None  None  None  None
# 27                dinas         pariwisata  ...   None  None  None  None
# 28                 beli           konsumen  ...   None  None  None  None
# 29               gambar           bangunan  ...   None  None  None  None
# ...                 ...                ...  ...    ...   ...   ...   ...
# 6042               None               None  ...   None  None  None  None
# 6043         structured           analysis  ...   None  None  None  None
# 6044               None               None  ...   None  None  None  None
# 6045              udara             primer  ...   None  None  None  None
# 6046               None               None  ...   None  None  None  None
# 6047           industri          kerajinan  ...   None  None  None  None
# 6048             teknik           industri  ...   None  None  None  None
# 6049               padi              sawah  ...   None  None  None  None
# 6050           prestasi            belajar  ...   None  None  None  None
# 6051         pembiayaan          murabahah  ...   None  None  None  None
# 6052               lawu          kabupaten  ...   None  None  None  None
# 6053               sman              dinas  ...   None  None  None  None
# 6054              griya               unik  ...   None  None  None  None
# 6055              humas         departemen  ...   None  None  None  None
# 6056             mobile               None  ...   None  None  None  None
# 6057            jakarta               None  ...   None  None  None  None
# 6058         komunikasi            peserta  ...   None  None  None  None
# 6059                 ii                iii  ...   None  None  None  None
# 6060              kasus               viko  ...   None  None  None  None
# 6061                 hi               tech  ...   None  None  None  None
# 6062        kewaspadaan          mobilitas  ...   None  None  None  None
# 6063              kelas                vii  ...   None  None  None  None
# 6064           kampanye           pasangan  ...   None  None  None  None
# 6065           mengenai             faktor  ...   None  None  None  None
# 6066               satu             kekisi  ...   None  None  None  None
# 6067               None               None  ...   None  None  None  None
# 6068          baturetno          kabupaten  ...   None  None  None  None
# 6069              ruang              ruang  ...   None  None  None  None
# 6070          indragiri              hilir  ...   None  None  None  None
# 6071          kemampuan           berpikir  ...   None  None  None  None
#
#         29    30    31    32    33    34
# 0     None  None  None  None  None  None
# 1     None  None  None  None  None  None
# 2     None  None  None  None  None  None
# 3     None  None  None  None  None  None
# 4     None  None  None  None  None  None
# 5     None  None  None  None  None  None
# 6     None  None  None  None  None  None
# 7     None  None  None  None  None  None
# 8     None  None  None  None  None  None
# 9     None  None  None  None  None  None
# 10    None  None  None  None  None  None
# 11    None  None  None  None  None  None
# 12    None  None  None  None  None  None
# 13    None  None  None  None  None  None
# 14    None  None  None  None  None  None
# 15    None  None  None  None  None  None
# 16    None  None  None  None  None  None
# 17    None  None  None  None  None  None
# 18    None  None  None  None  None  None
# 19    None  None  None  None  None  None
# 20    None  None  None  None  None  None
# 21    None  None  None  None  None  None
# 22    None  None  None  None  None  None
# 23    None  None  None  None  None  None
# 24    None  None  None  None  None  None
# 25    None  None  None  None  None  None
# 26    None  None  None  None  None  None
# 27    None  None  None  None  None  None
# 28    None  None  None  None  None  None
# 29    None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...
# 6042  None  None  None  None  None  None
# 6043  None  None  None  None  None  None
# 6044  None  None  None  None  None  None
# 6045  None  None  None  None  None  None
# 6046  None  None  None  None  None  None
# 6047  None  None  None  None  None  None
# 6048  None  None  None  None  None  None
# 6049  None  None  None  None  None  None
# 6050  None  None  None  None  None  None
# 6051  None  None  None  None  None  None
# 6052  None  None  None  None  None  None
# 6053  None  None  None  None  None  None
# 6054  None  None  None  None  None  None
# 6055  None  None  None  None  None  None
# 6056  None  None  None  None  None  None
# 6057  None  None  None  None  None  None
# 6058  None  None  None  None  None  None
# 6059  None  None  None  None  None  None
# 6060  None  None  None  None  None  None
# 6061  None  None  None  None  None  None
# 6062  None  None  None  None  None  None
# 6063  None  None  None  None  None  None
# 6064  None  None  None  None  None  None
# 6065  None  None  None  None  None  None
# 6066  None  None  None  None  None  None
# 6067  None  None  None  None  None  None
# 6068  None  None  None  None  None  None
# 6069  None  None  None  None  None  None
# 6070  None  None  None  None  None  None
# 6071  None  None  None  None  None  None
#
# [6072 rows x 35 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(8861 unique tokens: ['aplikasi', 'jaringan', 'keamanan', 'keamanan_jaringan', 'mikrotik']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 6072

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=16)
pprint(model.print_topics())

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=16)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-2011.html')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model2011.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned-range9.xlsx') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                     text
# 0      pendeteksi gangguan jaringan lokal metode cert...
# 1      eksistensi penggunaan wi fi warung kopi kota b...
# 2      pengaruh internet financial reporting tingkat ...
# 3      security function analysis performance high sp...
# 4      implementation top down approach method redesi...
# 5      optimization wireless network performance hier...
# 6      analysis qos vlan djikstra s algorithm open sh...
# 7      link performance improvement sananibun bts wit...
# 8      legal protection efforts patent holders indonesia
# 9      use e learning by teachers teaching learning p...
# 10     definition patent rights examples case studies...
# 11     analysis implementation backup line network br...
# 12     classification principles legal basis intellec...
# 13     attendance system automatic door locks laborat...
# 14          registration requirements application rights
# 15     patentability block chain technology future in...
# 16     influence speed user mobility qos wireless lan...
# 17     4 ghz omnidirectional antenna design with micr...
# 18     pemanfaatan telepon pintar informasi penyebara...
# 19     aplikasi teknologi komunikasi wireless zigbee ...
# 20     forensics analysis router computer networks li...
# 21                   manajemen proyeksi sistem informasi
# 22                   manajemen proyeksi sistem informasi
# 23                   tri destanto 175100067p sectionquis
# 24           rancang bangun aplikasi chatting web docker
# 25     multimedia animated corrosion corrosion coatin...
# 26     quality service traffic monitoring system stat...
# 27              analisis topologi area jaringan komputer
# 28              resume pembuatan tugas jaringan komputer
# 29              perkembangan jaringan komputer indonesia
# ...                                                  ...
# 79574  fuzzy logic diagnosis tata laksana penyakit de...
# 79575  pengaruh model problem learning pbl hasil bela...
# 79576  pengaruh pertisipasi anggaran kinerja manajeri...
# 79577  adopsi e commerce pendekatan technology accept...
# 79578  advertising board djarum super analisis deskri...
# 79579  eksplorasi metode bar chart cpm pdm pert line ...
# 79580  sistem pendukung keputusan pemilihan supplier ...
# 79581  analisa perancangan e marketing studi kasus ba...
# 79582  analisa perancangan sistem informasi pengelola...
# 79583  e learning penunjang pembelajaran konvensional...
# 79584  sistem informasi monitoring korosi pipa minyak...
# 79585  pengaruh faktor demografi personality stres ke...
# 79586  pembuatan aplikasi digital library studi kasus...
# 79587               sistem informasi manajemen buku ajar
# 79588  pengaruh partisipasi penganggaran kinerja apar...
# 79589  efektivitas pembelajaran kontekstual kemampuan...
# 79590  analisis efisiensi koperasi pegawai negeri rep...
# 79591  pemberdayaan sekolah menengah kejuruan smk mel...
# 79592  pelaksanaan kurikulum tingkat satuan pendidika...
# 79593  revitalisasi benteng vastenburg surakarta pusa...
# 79594  identifikasi bakat siswa sekolah dasar negeri ...
# 79595  analisisi model simple criteria optimal portof...
# 79596  pembuatan aplikasi penyebaran informasi short ...
# 79597  pembelajaran fisika masalah melalui metode pro...
# 79598  pengaruh service quality satisfaction expertis...
# 79599  pengaruh total quality management kinerja mana...
# 79600  lokalitas televisi lokal menonton orang ngapak...
# 79601  pembelajaran fisika metode demonstrasi melalui...
# 79602  analisis efisiensi bank bumn bank swasta setel...
# 79603  puppet show inovasi metode pengajaran bahasa i...
#
# [79604 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 79604
# [['pendeteksi', 'gangguan', 'jaringan', 'lokal', 'metode', 'certainty', 'factor']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                    0               1                2             3   \
# 0          pendeteksi        gangguan         jaringan         lokal
# 1          eksistensi      penggunaan               wi            fi
# 2            pengaruh        internet        financial     reporting
# 3            security        function         analysis   performance
# 4      implementation             top             down      approach
# 5        optimization        wireless          network   performance
# 6            analysis             qos             vlan      djikstra
# 7                link     performance      improvement     sananibun
# 8               legal      protection          efforts        patent
# 9                 use               e         learning            by
# 10         definition          patent           rights      examples
# 11           analysis  implementation           backup          line
# 12     classification      principles            legal         basis
# 13         attendance          system        automatic          door
# 14       registration    requirements      application        rights
# 15      patentability           block            chain    technology
# 16          influence           speed             user      mobility
# 17                  4             ghz  omnidirectional       antenna
# 18        pemanfaatan         telepon           pintar     informasi
# 19           aplikasi       teknologi       komunikasi      wireless
# 20          forensics        analysis           router      computer
# 21          manajemen        proyeksi           sistem     informasi
# 22          manajemen        proyeksi           sistem     informasi
# 23                tri        destanto       175100067p   sectionquis
# 24            rancang          bangun         aplikasi      chatting
# 25         multimedia        animated        corrosion     corrosion
# 26            quality         service          traffic    monitoring
# 27           analisis        topologi             area      jaringan
# 28             resume       pembuatan            tugas      jaringan
# 29       perkembangan        jaringan         komputer     indonesia
# ...               ...             ...              ...           ...
# 79574           fuzzy           logic        diagnosis          tata
# 79575        pengaruh           model          problem      learning
# 79576        pengaruh     pertisipasi         anggaran       kinerja
# 79577          adopsi               e         commerce    pendekatan
# 79578     advertising           board           djarum         super
# 79579      eksplorasi          metode              bar         chart
# 79580          sistem       pendukung        keputusan     pemilihan
# 79581         analisa     perancangan                e     marketing
# 79582         analisa     perancangan           sistem     informasi
# 79583               e        learning        penunjang  pembelajaran
# 79584          sistem       informasi       monitoring        korosi
# 79585        pengaruh          faktor        demografi   personality
# 79586       pembuatan        aplikasi          digital       library
# 79587          sistem       informasi        manajemen          buku
# 79588        pengaruh     partisipasi     penganggaran       kinerja
# 79589     efektivitas    pembelajaran      kontekstual     kemampuan
# 79590        analisis       efisiensi         koperasi       pegawai
# 79591    pemberdayaan         sekolah         menengah      kejuruan
# 79592     pelaksanaan       kurikulum          tingkat        satuan
# 79593    revitalisasi         benteng       vastenburg     surakarta
# 79594    identifikasi           bakat            siswa       sekolah
# 79595       analisisi           model           simple      criteria
# 79596       pembuatan        aplikasi       penyebaran     informasi
# 79597    pembelajaran          fisika          masalah       melalui
# 79598        pengaruh         service          quality  satisfaction
# 79599        pengaruh           total          quality    management
# 79600       lokalitas        televisi            lokal      menonton
# 79601    pembelajaran          fisika           metode   demonstrasi
# 79602        analisis       efisiensi             bank          bumn
# 79603          puppet            show          inovasi        metode
#
#                        4                    5                    6   \
# 0                  metode            certainty               factor
# 1                  warung                 kopi                 kota
# 2                 tingkat         pengungkapan            informasi
# 3                    high                speed               router
# 4                  method             redesign                  lan
# 5            hierarchical                token               bucket
# 6                       s            algorithm                 open
# 7                     bts                 with                 link
# 8                 holders            indonesia                 None
# 9                teachers             teaching             learning
# 10                   case              studies               iphone
# 11                network               branch               office
# 12           intellectual             property            indonesia
# 13                  locks           laboratory           electrical
# 14                   None                 None                 None
# 15                 future           innovation                 None
# 16                    qos             wireless                  lan
# 17                 design                 with           microstrip
# 18             penyebaran               lokasi                 guru
# 19                 zigbee               sistem              kontrol
# 20               networks                 live            forensics
# 21     manajemen_proyeksi                 None                 None
# 22     manajemen_proyeksi                 None                 None
# 23                   None                 None                 None
# 24                    web               docker       rancang_bangun
# 25                coating               metals               course
# 26                 system               static              routing
# 27               komputer    jaringan_komputer    jaringan_komputer
# 28               komputer    jaringan_komputer    jaringan_komputer
# 29      jaringan_komputer    jaringan_komputer    jaringan_komputer
# ...                   ...                  ...                  ...
# 79574             laksana             penyakit                demam
# 79575                 pbl                hasil              belajar
# 79576          manajerial                 gaya         kepemimpinan
# 79577          technology           acceptance                model
# 79578            analisis           deskriptif           kualitatif
# 79579                 cpm                  pdm                 pert
# 79580            supplier                 obat               metode
# 79581               studi                kasus                bajaj
# 79582         pengelolaan                biaya               proyek
# 79583        konvensional                pokok              bahasan
# 79584                pipa               minyak                  web
# 79585               stres                kerja           penggunaan
# 79586               studi                kasus         perpustakaan
# 79587                ajar            buku_ajar  informasi_manajemen
# 79588              aparat            integrasi             variabel
# 79589       menyelesaikan                 soal              aljabar
# 79590              negeri             republik            indonesia
# 79591                 smk              melalui                  smm
# 79592          pendidikan             prestasi              belajar
# 79593               pusat                 seni               museum
# 79594               dasar               negeri                   se
# 79595             optimal  portofolioselection                scops
# 79596               short              message              service
# 79597              metode               proyek            pemberian
# 79598           expertise             costumer              loyalty
# 79599             kinerja           manajerial              empiris
# 79600               orang               ngapak                jogja
# 79601             melalui           pendekatan              quantum
# 79602                bank               swasta              setelah
# 79603          pengajaran               bahasa              inggris
#
#                       7                 8                    9   ...   \
# 0         jaringan_lokal  metode_certainty  pendeteksi_gangguan  ...
# 1                  banda              aceh                wi_fi  ...
# 2                website         frekuensi          perdagangan  ...
# 3             networking              None                 None  ...
# 4                harvani             hotel            palembang  ...
# 5                   case      muhammadiyah           university  ...
# 6               shortest              path                first  ...
# 7                 switch         migration             backbone  ...
# 8                   None              None                 None  ...
# 9                process        e_learning    teaching_learning  ...
# 10              products              None                 None  ...
# 11                   vpn            speedy             internet  ...
# 12                  None              None                 None  ...
# 13           engineering        department                   at  ...
# 14                  None              None                 None  ...
# 15                  None              None                 None  ...
# 16                    11                 g                   11  ...
# 17          technologies               gsm             internet  ...
# 18               sekolah             dasar               negeri  ...
# 19            monitoring           ruangan                kelas  ...
# 20                method    live_forensics       live_forensics  ...
# 21                  None              None                 None  ...
# 22                  None              None                 None  ...
# 23                  None              None                 None  ...
# 24     aplikasi_chatting    rancang_bangun    aplikasi_chatting  ...
# 25                  None              None                 None  ...
# 26                  eoip            tunnel                 over  ...
# 27     jaringan_komputer              None                 None  ...
# 28     jaringan_komputer              None                 None  ...
# 29                  None              None                 None  ...
# ...                  ...               ...                  ...  ...
# 79574           berdarah            dengue                demam  ...
# 79575              kimia             siswa               konsep  ...
# 79576              iklim        organisasi             variabel  ...
# 79577                tam               ukm                studi  ...
# 79578                 tv             value          advertising  ...
# 79579               line           balance                 time  ...
# 79580            electre       elimination                   et  ...
# 79581            persada         nusantara          e_marketing  ...
# 79582         konstruksi            metode                 cost  ...
# 79583            listrik           dinamis                kelas  ...
# 79584              studi             kasus              stasiun  ...
# 79585             sistem         informasi             komputer  ...
# 79586              sains         teknologi          universitas  ...
# 79587          buku_ajar         buku_ajar                 None  ...
# 79588        intervening          variabel           moderating  ...
# 79589               soal            cerita             ditinjau  ...
# 79590          kabupaten            klaten     koperasi_pegawai  ...
# 79591                iso  sekolah_menengah         kejuruan_smk  ...
# 79592              siswa               smk               negeri  ...
# 79593               seni       kontemporer                 None  ...
# 79594          kecamatan          ngemplak             boyolali  ...
# 79595        pembentukan        portofolio              optimal  ...
# 79596                sms        lingkungan              program  ...
# 79597              tugas          ditinjau                 gaya  ...
# 79598              studi           peserta                didik  ...
# 79599            manajer        perhotelan          dipekanbaru  ...
# 79600                 tv              None                 None  ...
# 79601        ketrampilan            proses             ditinjau  ...
# 79602             merger          tinjauan                 bank  ...
# 79603              upaya         kemampuan            berbicara  ...
#
#                          31    32    33    34    35    36    37    38    39  \
# 0                      None  None  None  None  None  None  None  None  None
# 1                      None  None  None  None  None  None  None  None  None
# 2                      None  None  None  None  None  None  None  None  None
# 3                      None  None  None  None  None  None  None  None  None
# 4                      None  None  None  None  None  None  None  None  None
# 5                      None  None  None  None  None  None  None  None  None
# 6                      None  None  None  None  None  None  None  None  None
# 7                      None  None  None  None  None  None  None  None  None
# 8                      None  None  None  None  None  None  None  None  None
# 9                      None  None  None  None  None  None  None  None  None
# 10                     None  None  None  None  None  None  None  None  None
# 11                     None  None  None  None  None  None  None  None  None
# 12                     None  None  None  None  None  None  None  None  None
# 13                     None  None  None  None  None  None  None  None  None
# 14                     None  None  None  None  None  None  None  None  None
# 15                     None  None  None  None  None  None  None  None  None
# 16                     None  None  None  None  None  None  None  None  None
# 17                     None  None  None  None  None  None  None  None  None
# 18                     None  None  None  None  None  None  None  None  None
# 19                     None  None  None  None  None  None  None  None  None
# 20                     None  None  None  None  None  None  None  None  None
# 21                     None  None  None  None  None  None  None  None  None
# 22                     None  None  None  None  None  None  None  None  None
# 23                     None  None  None  None  None  None  None  None  None
# 24                     None  None  None  None  None  None  None  None  None
# 25                     None  None  None  None  None  None  None  None  None
# 26                     None  None  None  None  None  None  None  None  None
# 27                     None  None  None  None  None  None  None  None  None
# 28                     None  None  None  None  None  None  None  None  None
# 29                     None  None  None  None  None  None  None  None  None
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 79574                  None  None  None  None  None  None  None  None  None
# 79575                  None  None  None  None  None  None  None  None  None
# 79576                  None  None  None  None  None  None  None  None  None
# 79577                  None  None  None  None  None  None  None  None  None
# 79578                  None  None  None  None  None  None  None  None  None
# 79579                  None  None  None  None  None  None  None  None  None
# 79580                  None  None  None  None  None  None  None  None  None
# 79581                  None  None  None  None  None  None  None  None  None
# 79582                  None  None  None  None  None  None  None  None  None
# 79583                  None  None  None  None  None  None  None  None  None
# 79584                  None  None  None  None  None  None  None  None  None
# 79585                  None  None  None  None  None  None  None  None  None
# 79586  hidayatullah_jakarta  None  None  None  None  None  None  None  None
# 79587                  None  None  None  None  None  None  None  None  None
# 79588                  None  None  None  None  None  None  None  None  None
# 79589                  None  None  None  None  None  None  None  None  None
# 79590                  None  None  None  None  None  None  None  None  None
# 79591                  None  None  None  None  None  None  None  None  None
# 79592                  None  None  None  None  None  None  None  None  None
# 79593                  None  None  None  None  None  None  None  None  None
# 79594                  None  None  None  None  None  None  None  None  None
# 79595                  None  None  None  None  None  None  None  None  None
# 79596                  None  None  None  None  None  None  None  None  None
# 79597                  None  None  None  None  None  None  None  None  None
# 79598                  None  None  None  None  None  None  None  None  None
# 79599                  None  None  None  None  None  None  None  None  None
# 79600                  None  None  None  None  None  None  None  None  None
# 79601                  None  None  None  None  None  None  None  None  None
# 79602                  None  None  None  None  None  None  None  None  None
# 79603                  None  None  None  None  None  None  None  None  None
#
#          40
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
# ...     ...
# 79574  None
# 79575  None
# 79576  None
# 79577  None
# 79578  None
# 79579  None
# 79580  None
# 79581  None
# 79582  None
# 79583  None
# 79584  None
# 79585  None
# 79586  None
# 79587  None
# 79588  None
# 79589  None
# 79590  None
# 79591  None
# 79592  None
# 79593  None
# 79594  None
# 79595  None
# 79596  None
# 79597  None
# 79598  None
# 79599  None
# 79600  None
# 79601  None
# 79602  None
# 79603  None
#
# [79604 rows x 41 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(44498 unique tokens: ['certainty', 'factor', 'gangguan', 'jaringan', 'jaringan_lokal']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 79604

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))
# Out:
# Num Topics = 2  has Coherence Value of 0.2329707823
# Num Topics = 4  has Coherence Value of 0.28871885
# Num Topics = 6  has Coherence Value of 0.3035428558
# Num Topics = 8  has Coherence Value of 0.379694521
# Num Topics = 10  has Coherence Value of 0.3532032544
# Num Topics = 12  has Coherence Value of 0.3918635496
# Num Topics = 14  has Coherence Value of 0.425887536
# Num Topics = 16  has Coherence Value of 0.4453338428
# Num Topics = 18  has Coherence Value of 0.4505668673

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=18)
pprint(model.print_topics())
# Out:
# [(0,
#   '0.013*"logika_fuzzy" + 0.013*"smp_negeri" + 0.007*"process" + '
#   '0.007*"learning_vector" + 0.007*"operasi_linux" + 0.007*"buku" + '
#   '0.006*"fakultas_sains" + 0.005*"hidayatullah_jakarta" + '
#   '0.005*"intrusion_detection" + 0.005*"logika"'),
#  (1,
#   '0.013*"sekolah_menengah" + 0.010*"hasil_belajar" + 0.008*"belajar" + '
#   '0.008*"pembelajaran" + 0.008*"matematika_siswa" + 0.007*"prestasi_belajar" '
#   '+ 0.007*"penyakit_tanaman" + 0.007*"media_pembelajaran" + 0.007*"kelas" + '
#   '0.006*"pakar_mendeteksi"'),
#  (2,
#   '0.015*"lkp" + 0.011*"algoritma_genetika" + 0.009*"tugas_akhir" + '
#   '0.009*"sepeda_motor" + 0.008*"jurusan_teknik" + 0.008*"local_area" + '
#   '0.007*"information_system" + 0.007*"pembuatan_website" + '
#   '0.005*"perkuliahan" + 0.005*"system"'),
#  (3,
#   '0.012*"jaringan_saraf" + 0.012*"faktor_faktor" + 0.012*"faktor" + '
#   '0.010*"diagnosa_penyakit" + 0.009*"metode_promethee" + 0.008*"xyz" + '
#   '0.006*"kelas_vii" + 0.006*"jaringan_lan" + 0.005*"studi_empiris" + '
#   '0.005*"mobile_phone"'),
#  (4,
#   '0.020*"pakar_mendiagnosa" + 0.007*"windows" + 0.006*"kurikulum_program" + '
#   '0.006*"pakar" + 0.006*"operasi_windows" + 0.006*"penyakit" + '
#   '0.006*"pakar_mendiagnosis" + 0.006*"kereta_api" + 0.005*"mendiagnosa" + '
#   '0.005*"berorientasi"'),
#  (5,
#   '0.009*"kota_semarang" + 0.009*"pemanfaatan_teknologi" + '
#   '0.008*"e_government" + 0.007*"kesehatan" + 0.006*"informasi" + '
#   '0.006*"analisis_perbandingan" + 0.006*"lokasi" + 0.005*"penentuan_lokasi" + '
#   '0.005*"proyek" + 0.005*"studi_kasus"'),
#  (6,
#   '0.026*"jaringan_syaraf" + 0.009*"syaraf" + 0.009*"bahasa_pemrograman" + '
#   '0.009*"tiruan" + 0.008*"berorientasi_objek" + 0.008*"pengenalan_pola" + '
#   '0.008*"pakar_diagnosis" + 0.008*"data_mining" + 0.008*"jaringan" + '
#   '0.007*"alat_bantu"'),
#  (7,
#   '0.016*"lkp_rancang" + 0.009*"fuzzy_logic" + 0.009*"visual_basic" + '
#   '0.007*"desain_implementasi" + 0.007*"pln_persero" + 0.007*"expert_system" + '
#   '0.006*"pc_router" + 0.006*"informasi_eksekutif" + 0.006*"pengendalian" + '
#   '0.006*"penunjang_keputusan"'),
#  (8,
#   '0.029*"informasi_geografis" + 0.012*"siswa_kelas" + 0.010*"geografis" + '
#   '0.009*"penginderaan_jauh" + 0.007*"open_source" + 0.007*"informasi" + '
#   '0.006*"knowledge_management" + 0.006*"pengembangan_media" + '
#   '0.006*"rancang_bangun" + 0.006*"studi_kasus"'),
#  (9,
#   '0.025*"e_commerce" + 0.012*"studi_kasus" + 0.011*"penilaian_kinerja" + '
#   '0.010*"rancang_bangun" + 0.010*"surabaya" + 0.010*"smk_negeri" + '
#   '0.009*"java" + 0.008*"informasi" + 0.008*"commerce" + 0.008*"e"'),
#  (10,
#   '0.019*"jaringan_komputer" + 0.018*"e_learning" + 0.015*"sma_negeri" + '
#   '0.011*"pengolahan_citra" + 0.010*"operasi_android" + '
#   '0.008*"pembelajaran_kooperatif" + 0.008*"pengolahan_data" + '
#   '0.008*"komputer" + 0.007*"operasi" + 0.007*"studi_kasus"'),
#  (11,
#   '0.032*"perangkat_lunak" + 0.031*"informasi_akuntansi" + 0.013*"akuntansi" + '
#   '0.012*"php_mysql" + 0.010*"informasi" + 0.010*"lunak" + 0.010*"perangkat" + '
#   '0.007*"rancang_bangun" + 0.007*"php" + 0.007*"studi_kasus"'),
#  (12,
#   '0.028*"sms_gateway" + 0.021*"pakar_diagnosa" + 0.018*"pakar" + '
#   '0.017*"metode_forward" + 0.014*"pengambilan_keputusan" + 0.013*"sms" + '
#   '0.013*"penyakit" + 0.013*"metode_certainty" + 0.010*"diagnosa" + '
#   '0.008*"rancang_bangun"'),
#  (13,
#   '0.021*"rumah_sakit" + 0.011*"sumber_daya" + 0.009*"rancang_bangun" + '
#   '0.009*"persediaan_barang" + 0.008*"pengenalan_wajah" + 0.008*"persediaan" + '
#   '0.008*"sakit" + 0.008*"pembelian_penjualan" + 0.007*"rumah" + '
#   '0.006*"informasi"'),
#  (14,
#   '0.024*"rekayasa_perangkat" + 0.010*"rekayasa" + 0.007*"perangkat" + '
#   '0.007*"lunak" + 0.006*"artificial_neural" + 0.006*"pembelajaran_matematika" '
#   '+ 0.005*"pegawai" + 0.005*"framework_codeigniter" + 0.005*"studi_kasus" + '
#   '0.005*"sig"'),
#  (15,
#   '0.019*"perguruan_tinggi" + 0.014*"client_server" + '
#   '0.008*"customer_relationship" + 0.007*"rancang_bangun" + '
#   '0.007*"studi_kasus" + 0.007*"augmented_reality" + 0.007*"perguruan" + '
#   '0.007*"jawa_timur" + 0.007*"tinggi" + 0.007*"pokok_bahasan"'),
#  (16,
#   '0.012*"program_studi" + 0.012*"rancang_bangun" + 0.010*"studi_kasus" + '
#   '0.008*"akademik" + 0.008*"teknik_informatika" + 0.008*"neural_network" + '
#   '0.007*"informasi" + 0.007*"sekolah_dasar" + 0.007*"informasi_akademik" + '
#   '0.007*"penerimaan_siswa"'),
#  (17,
#   '0.068*"pendukung_keputusan" + 0.025*"pendukung" + 0.025*"keputusan" + '
#   '0.012*"studi_kasus" + 0.011*"basis_data" + 0.010*"pemilihan" + '
#   '0.009*"metode" + 0.009*"ahp" + 0.008*"metode_simple" + 0.007*"sistem"')]

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=18)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.013*"lkp" + 0.012*"smk_negeri" + 0.012*"sumber_daya" + 0.012*"penilaian_kinerja" + 0.010*"operasi_android" + 0.010*"rancang_bangun" + 0.009*"studi_kasus" + 0.009*"fuzzy_logic" + 0.008*"prestasi_belajar" + 0.008*"tugas_akhir"
# Topic: 1 Word: 0.012*"basis_data" + 0.009*"studi_kasus" + 0.008*"rancang_bangun" + 0.008*"pengenalan_wajah" + 0.007*"management_system" + 0.007*"informasi" + 0.007*"xyz" + 0.006*"informasi_eksekutif" + 0.006*"gateway" + 0.005*"kelas_vii"
# Topic: 2 Word: 0.022*"jaringan_komputer" + 0.018*"pengolahan_citra" + 0.009*"bahasa_pemrograman" + 0.008*"diagnosa_penyakit" + 0.008*"mata_pelajaran" + 0.007*"additive_weighting" + 0.007*"metode_simple" + 0.007*"komputer" + 0.006*"pengembangan_media" + 0.006*"real_time"
# Topic: 3 Word: 0.018*"e_learning" + 0.016*"rumah_sakit" + 0.015*"sma_negeri" + 0.012*"pembelajaran" + 0.011*"siswa_kelas" + 0.011*"hasil_belajar" + 0.009*"smp_negeri" + 0.009*"pembelajaran_kooperatif" + 0.008*"media_pembelajaran" + 0.008*"belajar"
# Topic: 4 Word: 0.010*"visual_basic" + 0.010*"neural_network" + 0.010*"matematika_siswa" + 0.009*"logika_fuzzy" + 0.009*"decision_support" + 0.009*"penyakit_tanaman" + 0.008*"pln_persero" + 0.008*"pakar_mendeteksi" + 0.007*"learning_vector" + 0.007*"visual"
# Topic: 5 Word: 0.012*"faktor" + 0.012*"informasi_akuntansi" + 0.011*"faktor_faktor" + 0.008*"stikom_surabaya" + 0.007*"information_system" + 0.007*"pc_router" + 0.007*"informasi" + 0.006*"studi_kasus" + 0.006*"rekam_medis" + 0.006*"fakultas_sains"
# Topic: 6 Word: 0.017*"studi_kasus" + 0.014*"informasi" + 0.013*"rancang_bangun" + 0.010*"akademik" + 0.009*"psi_rancang" + 0.009*"informasi_akademik" + 0.008*"berorientasi_objek" + 0.008*"persediaan_barang" + 0.008*"data_mining" + 0.008*"sistem"
# Topic: 7 Word: 0.024*"sms_gateway" + 0.012*"sms" + 0.011*"surabaya" + 0.008*"informasi" + 0.007*"informasi_manajemen" + 0.007*"alat_bantu" + 0.007*"local_area" + 0.007*"rancang_bangun" + 0.006*"studi_kasus" + 0.006*"pokok_bahasan"
# Topic: 8 Word: 0.008*"pemanfaatan_teknologi" + 0.008*"keamanan_jaringan" + 0.008*"kesehatan" + 0.006*"sekolah_tinggi" + 0.006*"pakar_mengidentifikasi" + 0.006*"certainty_factor" + 0.006*"penentuan_lokasi" + 0.006*"penyakit_kulit" + 0.005*"palembang" + 0.005*"enterprise_architecture"
# Topic: 9 Word: 0.011*"pengolahan_data" + 0.011*"penginderaan_jauh" + 0.007*"file" + 0.006*"platform_android" + 0.006*"citra_digital" + 0.006*"pendukung_keputusan" + 0.006*"load_balancing" + 0.005*"studi_kasus" + 0.005*"metode_profile" + 0.005*"laporan_keuangan"
# Topic: 10 Word: 0.023*"e_commerce" + 0.021*"informasi_akuntansi" + 0.012*"php_mysql" + 0.011*"penjualan" + 0.010*"informasi" + 0.009*"rancang_bangun" + 0.009*"akuntansi" + 0.008*"commerce" + 0.007*"e" + 0.007*"studi_kasus"
# Topic: 11 Word: 0.052*"pendukung_keputusan" + 0.020*"keputusan" + 0.019*"pendukung" + 0.015*"studi_kasus" + 0.012*"program_studi" + 0.010*"pengambilan_keputusan" + 0.009*"pemilihan" + 0.009*"rancang_bangun" + 0.008*"pakar_diagnosis" + 0.008*"sistem"
# Topic: 12 Word: 0.035*"informasi_geografis" + 0.034*"perangkat_lunak" + 0.012*"client_server" + 0.012*"geografis" + 0.011*"lunak" + 0.011*"perangkat" + 0.009*"informasi" + 0.007*"yogyakarta" + 0.006*"jurusan_teknik" + 0.006*"informasi_geografi"
# Topic: 13 Word: 0.020*"pakar_diagnosa" + 0.020*"pakar" + 0.018*"perguruan_tinggi" + 0.017*"pakar_mendiagnosa" + 0.016*"metode_forward" + 0.015*"penyakit" + 0.011*"metode_certainty" + 0.009*"diagnosa" + 0.008*"mendiagnosa" + 0.007*"e_government"
# Topic: 14 Word: 0.016*"lkp_rancang" + 0.009*"algoritma_genetika" + 0.008*"customer_relationship" + 0.007*"expert_system" + 0.007*"system" + 0.005*"pengendalian_intern" + 0.005*"usaha_kecil" + 0.005*"power_system" + 0.005*"segmentasi_citra" + 0.005*"studi_kasus"
# Topic: 15 Word: 0.026*"jaringan_syaraf" + 0.011*"tiruan" + 0.011*"jaringan_saraf" + 0.010*"jaringan" + 0.010*"syaraf" + 0.009*"pengenalan_pola" + 0.007*"j2me" + 0.007*"jawa_timur" + 0.006*"analisis_perbandingan" + 0.006*"pembelajaran_bahasa"
# Topic: 16 Word: 0.025*"rekayasa_perangkat" + 0.016*"sekolah_menengah" + 0.010*"sekolah" + 0.010*"rekayasa" + 0.010*"sekolah_dasar" + 0.009*"kota_semarang" + 0.009*"metode_promethee" + 0.007*"perangkat" + 0.006*"lunak" + 0.006*"jaringan_lan"
# Topic: 17 Word: 0.010*"penerimaan" + 0.009*"penerimaan_siswa" + 0.009*"desain_implementasi" + 0.008*"data_warehouse" + 0.006*"backward_chaining" + 0.006*"beasiswa" + 0.005*"seleksi_penerimaan" + 0.005*"apotek" + 0.005*"desain" + 0.005*"forward_chaining"

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)
# Out:
#      No_Dokumen  Topik_Dominan  Persentase_Kontribusi  \
# 0             0            8.0                 0.5389
# 1             1           15.0                 0.7449
# 2             2            3.0                 0.6690
# 3             3            8.0                 0.5444
# 4             4           17.0                 0.6318
# 5             5            1.0                 0.6394
# 6             6           14.0                 0.9444
# 7             7           15.0                 0.3610
# 8             8            6.0                 0.3142
# 9             9            3.0                 0.4805
# 10           10           14.0                 0.7932
# 11           11           14.0                 0.4913
# 12           12            0.0                 0.3480
# 13           13            9.0                 0.3125
# 14           14            5.0                 0.2900
# 15           15            5.0                 0.7019
# 16           16            1.0                 0.6392
# 17           17           15.0                 0.5338
# 18           18            8.0                 0.2917
# 19           19            3.0                 0.9370
# 20           20            2.0                 0.5986
# 21           21            6.0                 0.5992
# 22           22            6.0                 0.5993
# 23           23            9.0                 0.8111
# 24           24            3.0                 0.5979
# 25           25           11.0                 0.8819
# 26           26           14.0                 0.8638
# 27           27            2.0                 0.7574
# 28           28            2.0                 0.6239
# 29           29            2.0                 0.7282
# ..          ...            ...                    ...
# 217         217           15.0                 0.8819
# 218         218            7.0                 0.4152
# 219         219           17.0                 0.9503
# 220         220            6.0                 0.8084
# 221         221            1.0                 0.5150
# 222         222           16.0                 0.4101
# 223         223           10.0                 0.5664
# 224         224            3.0                 0.3810
# 225         225            6.0                 0.4333
# 226         226           10.0                 0.5288
# 227         227            6.0                 0.3211
# 228         228            6.0                 0.9274
# 229         229            4.0                 0.4557
# 230         230           11.0                 0.9528
# 231         231            2.0                 0.3585
# 232         232           16.0                 0.7296
# 233         233           12.0                 0.5231
# 234         234            8.0                 0.3910
# 235         235           10.0                 0.5763
# 236         236           14.0                 0.8979
# 237         237            8.0                 0.8054
# 238         238            3.0                 0.9325
# 239         239           11.0                 0.3671
# 240         240           10.0                 0.8203
# 241         241            2.0                 0.6795
# 242         242           10.0                 0.6891
# 243         243            8.0                 0.4041
# 244         244            8.0                 0.3688
# 245         245           10.0                 0.3968
# 246         246            7.0                 0.5005
#
#                                             Kata_Kunci  \
# 0    pemanfaatan_teknologi, keamanan_jaringan, kese...
# 1    jaringan_syaraf, tiruan, jaringan_saraf, jarin...
# 2    e_learning, rumah_sakit, sma_negeri, pembelaja...
# 3    pemanfaatan_teknologi, keamanan_jaringan, kese...
# 4    penerimaan, penerimaan_siswa, desain_implement...
# 5    basis_data, studi_kasus, rancang_bangun, penge...
# 6    lkp_rancang, algoritma_genetika, customer_rela...
# 7    jaringan_syaraf, tiruan, jaringan_saraf, jarin...
# 8    studi_kasus, informasi, rancang_bangun, akadem...
# 9    e_learning, rumah_sakit, sma_negeri, pembelaja...
# 10   lkp_rancang, algoritma_genetika, customer_rela...
# 11   lkp_rancang, algoritma_genetika, customer_rela...
# 12   lkp, smk_negeri, sumber_daya, penilaian_kinerj...
# 13   pengolahan_data, penginderaan_jauh, file, plat...
# 14   faktor, informasi_akuntansi, faktor_faktor, st...
# 15   faktor, informasi_akuntansi, faktor_faktor, st...
# 16   basis_data, studi_kasus, rancang_bangun, penge...
# 17   jaringan_syaraf, tiruan, jaringan_saraf, jarin...
# 18   pemanfaatan_teknologi, keamanan_jaringan, kese...
# 19   e_learning, rumah_sakit, sma_negeri, pembelaja...
# 20   jaringan_komputer, pengolahan_citra, bahasa_pe...
# 21   studi_kasus, informasi, rancang_bangun, akadem...
# 22   studi_kasus, informasi, rancang_bangun, akadem...
# 23   pengolahan_data, penginderaan_jauh, file, plat...
# 24   e_learning, rumah_sakit, sma_negeri, pembelaja...
# 25   pendukung_keputusan, keputusan, pendukung, stu...
# 26   lkp_rancang, algoritma_genetika, customer_rela...
# 27   jaringan_komputer, pengolahan_citra, bahasa_pe...
# 28   jaringan_komputer, pengolahan_citra, bahasa_pe...
# 29   jaringan_komputer, pengolahan_citra, bahasa_pe...
# ..                                                 ...
# 217  jaringan_syaraf, tiruan, jaringan_saraf, jarin...
# 218  sms_gateway, sms, surabaya, informasi, informa...
# 219  penerimaan, penerimaan_siswa, desain_implement...
# 220  studi_kasus, informasi, rancang_bangun, akadem...
# 221  basis_data, studi_kasus, rancang_bangun, penge...
# 222  rekayasa_perangkat, sekolah_menengah, sekolah,...
# 223  e_commerce, informasi_akuntansi, php_mysql, pe...
# 224  e_learning, rumah_sakit, sma_negeri, pembelaja...
# 225  studi_kasus, informasi, rancang_bangun, akadem...
# 226  e_commerce, informasi_akuntansi, php_mysql, pe...
# 227  studi_kasus, informasi, rancang_bangun, akadem...
# 228  studi_kasus, informasi, rancang_bangun, akadem...
# 229  visual_basic, neural_network, matematika_siswa...
# 230  pendukung_keputusan, keputusan, pendukung, stu...
# 231  jaringan_komputer, pengolahan_citra, bahasa_pe...
# 232  rekayasa_perangkat, sekolah_menengah, sekolah,...
# 233  informasi_geografis, perangkat_lunak, client_s...
# 234  pemanfaatan_teknologi, keamanan_jaringan, kese...
# 235  e_commerce, informasi_akuntansi, php_mysql, pe...
# 236  lkp_rancang, algoritma_genetika, customer_rela...
# 237  pemanfaatan_teknologi, keamanan_jaringan, kese...
# 238  e_learning, rumah_sakit, sma_negeri, pembelaja...
# 239  pendukung_keputusan, keputusan, pendukung, stu...
# 240  e_commerce, informasi_akuntansi, php_mysql, pe...
# 241  jaringan_komputer, pengolahan_citra, bahasa_pe...
# 242  e_commerce, informasi_akuntansi, php_mysql, pe...
# 243  pemanfaatan_teknologi, keamanan_jaringan, kese...
# 244  pemanfaatan_teknologi, keamanan_jaringan, kese...
# 245  e_commerce, informasi_akuntansi, php_mysql, pe...
# 246  sms_gateway, sms, surabaya, informasi, informa...
#
#                                                   Teks
# 0    [pendeteksi, gangguan, jaringan, lokal, metode...
# 1    [eksistensi, penggunaan, wi, fi, warung, kopi,...
# 2    [pengaruh, internet, financial, reporting, tin...
# 3    [security, function, analysis, performance, hi...
# 4    [implementation, top, down, approach, method, ...
# 5    [optimization, wireless, network, performance,...
# 6    [analysis, qos, vlan, djikstra, s, algorithm, ...
# 7    [link, performance, improvement, sananibun, bt...
# 8    [legal, protection, efforts, patent, holders, ...
# 9    [use, e, learning, by, teachers, teaching, lea...
# 10   [definition, patent, rights, examples, case, s...
# 11   [analysis, implementation, backup, line, netwo...
# 12   [classification, principles, legal, basis, int...
# 13   [attendance, system, automatic, door, locks, l...
# 14   [registration, requirements, application, rights]
# 15   [patentability, block, chain, technology, futu...
# 16   [influence, speed, user, mobility, qos, wirele...
# 17   [4, ghz, omnidirectional, antenna, design, wit...
# 18   [pemanfaatan, telepon, pintar, informasi, peny...
# 19   [aplikasi, teknologi, komunikasi, wireless, zi...
# 20   [forensics, analysis, router, computer, networ...
# 21   [manajemen, proyeksi, sistem, informasi, manaj...
# 22   [manajemen, proyeksi, sistem, informasi, manaj...
# 23            [tri, destanto, 175100067p, sectionquis]
# 24   [rancang, bangun, aplikasi, chatting, web, doc...
# 25   [multimedia, animated, corrosion, corrosion, c...
# 26   [quality, service, traffic, monitoring, system...
# 27   [analisis, topologi, area, jaringan, komputer,...
# 28   [resume, pembuatan, tugas, jaringan, komputer,...
# 29   [perkembangan, jaringan, komputer, indonesia, ...
# ..                                                 ...
# 217  [implementasi, captive, portal, pfsense, capti...
# 218  [aspek, hukum, pelayan, publik, online, direkt...
# 219  [steganografi, citra, digital, menyembunyikan,...
# 220  [analisis, faktor, minat, siswa, memilih, juru...
# 221  [managed, service, network, management, system...
# 222  [kebijakan, kriminal, pemerintah, kejahatan, d...
# 223  [pengembangan, aplikasi, e, commerce, pendekat...
# 224  [konsep, pengembangan, sistem, informasi, moni...
# 225  [tugas, akhir, jurnal, tata, kelola, sistem, t...
# 226  [e, commerce, media, promosi, pemasaran, decou...
# 227  [failover, gateway, protokol, virtual, router,...
# 228  [sistem, informasi, administrasi, data, kemaha...
# 229  [analisis, perbandingan, detection, traffic, a...
# 230  [sistem, pendukung, keputusan, pemilihan, pemi...
# 231  [pengaruh, media, packet, tracer, kreativitas,...
# 232  [multimedia, edukasi, interaktif, pelajaran, b...
# 233  [aplikasi, sistem, penyidikan, client, server,...
# 234  [tindak, pidana, dunia, maya, berupa, virus, t...
# 235  [analisis, pengaruh, manfaat, risiko, kepercay...
# 236  [pengaruh, perceived, value, repurchase, inten...
# 237  [cooperative, accounting, computer, applicatio...
# 238  [membangun, rencana, strategis, sistem, inform...
# 239  [perancangan, sistem, pendukung, keputusan, pe...
# 240  [pengamanan, data, aplikasi, sijalu, universit...
# 241  [implementation, pptp, bcp, with, inter, vlan,...
# 242  [analisis, yuridis, penyelesaian, sengketa, cy...
# 243  [smart, campus, model, baru, enterprise, archi...
# 244  [analisis, hubungan, antara, daring, revolusi,...
# 245  [akad, jual, beli, online, perspektif, hukum, ...
# 246  [analisis, akad, undang, undang, nomor, tahun,...
#
# [247 rows x 5 columns]

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xlsx', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics
# Out:
# 11.0    8377
# 13.0    6405
# 6.0     5745
# 10.0    5384
# 3.0     5194
# 12.0    5073
# 15.0    4414
# 0.0     4187
# 2.0     4084
# 14.0    4068
# 7.0     3772
# 4.0     3752
# 9.0     3664
# 1.0     3518
# 16.0    3164
# 8.0     3028
# 5.0     2983
# 17.0    2792
# Name: Topik_Dominan, dtype: int64

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')
# Out:
# Text(0.5,1,'Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.9589
# 1         1.0              0.9528
# 2         2.0              0.9410
# 3         3.0              0.9622
# 4         4.0              0.9622
# 5         5.0              0.9663
# 6         6.0              0.9550
# 7         7.0              0.9650
# 8         8.0              0.9503
# 9         9.0              0.9571
# 10       10.0              0.9571
# 11       11.0              0.9637
# 12       12.0              0.9637
# 13       13.0              0.9606
# 14       14.0              0.9550
# 15       15.0              0.9475
# 16       16.0              0.9444
# 17       17.0              0.9589
#
#                                                                                                Keywords  \
# 0   lkp, smk_negeri, sumber_daya, penilaian_kinerja, operasi_android, rancang_bangun, studi_kasus, f...
# 1   basis_data, studi_kasus, rancang_bangun, pengenalan_wajah, management_system, informasi, xyz, in...
# 2   jaringan_komputer, pengolahan_citra, bahasa_pemrograman, diagnosa_penyakit, mata_pelajaran, addi...
# 3   e_learning, rumah_sakit, sma_negeri, pembelajaran, siswa_kelas, hasil_belajar, smp_negeri, pembe...
# 4   visual_basic, neural_network, matematika_siswa, logika_fuzzy, decision_support, penyakit_tanaman...
# 5   faktor, informasi_akuntansi, faktor_faktor, stikom_surabaya, information_system, pc_router, info...
# 6   studi_kasus, informasi, rancang_bangun, akademik, psi_rancang, informasi_akademik, berorientasi_...
# 7   sms_gateway, sms, surabaya, informasi, informasi_manajemen, alat_bantu, local_area, rancang_bang...
# 8   pemanfaatan_teknologi, keamanan_jaringan, kesehatan, sekolah_tinggi, pakar_mengidentifikasi, cer...
# 9   pengolahan_data, penginderaan_jauh, file, platform_android, citra_digital, pendukung_keputusan, ...
# 10  e_commerce, informasi_akuntansi, php_mysql, penjualan, informasi, rancang_bangun, akuntansi, com...
# 11  pendukung_keputusan, keputusan, pendukung, studi_kasus, program_studi, pengambilan_keputusan, pe...
# 12  informasi_geografis, perangkat_lunak, client_server, geografis, lunak, perangkat, informasi, yog...
# 13  pakar_diagnosa, pakar, perguruan_tinggi, pakar_mendiagnosa, metode_forward, penyakit, metode_cer...
# 14  lkp_rancang, algoritma_genetika, customer_relationship, expert_system, system, pengendalian_inte...
# 15  jaringan_syaraf, tiruan, jaringan_saraf, jaringan, syaraf, pengenalan_pola, j2me, jawa_timur, an...
# 16  rekayasa_perangkat, sekolah_menengah, sekolah, rekayasa, sekolah_dasar, kota_semarang, metode_pr...
# 17  penerimaan, penerimaan_siswa, desain_implementasi, data_warehouse, backward_chaining, beasiswa, ...
#
#                                                                                     Representative Text
# 0   [sistem, keamanan, server, honeypot, intrusion, detection, system, ids, studi, kasus, perusahaan...
# 1   [sistem, informasi, maintenance, work, order, web, studi, kasus, departemen, building, elangperd...
# 2   [pengembangan, media, pembelajaran, visualisasi, instalasi, konfigurasi, sistem, operasi, jaring...
# 3   [pengembangan, model, pembelajaran, hybrid, e, learning, tutor, sebaya, media, blog, materi, mat...
# 4   [analisis, sinyal, ekg, aritmia, deteksi, risiko, jantung, koroner, adaptive, neuro, fuzzy, infe...
# 5   [pengaruh, teknologi, informasi, pengendalian, internal, kualitas, sistem, informasi, akuntansi,...
# 6   [analisis, audit, sistem, informasi, bagian, kurikulum, sma, al, hidayah, way, seputih, lampung,...
# 7   [analisis, kualitas, pelayanan, publik, kantor, pelayanan, terpadu, satu, pintu, kecamatan, joha...
# 8   [analisis, keamanan, jaringan, virtual, private, network, vpn, sistem, online, microbanking, kea...
# 9   [metode, regresi, linier, berganda, estimasi, biaya, pencetakan, spanduk, studi, kasus, hansindo...
# 10  [aplikasi, website, content, commerce, content, management, system, cms, prestashop, studi, kasu...
# 11  [sistem, pendukung, keputusan, pemilihan, siswa, berprestasi, jemaat, moria, samarinda, seberang...
# 12  [metode, technique, others, preference, by, similary, ideal, solution, topsis, pemilihan, lokasi...
# 13  [aplikasi, sistem, pakar, diagnosa, kerusakan, sepeda, motor, honda, metode, certainty, factor, ...
# 14  [rancang, bangun, customer, relationship, management, crm, metode, framework, dynamic, crm, tote...
# 15  [jaringan, saraf, tiruan, backpropagation, aplikasi, pengenalan, tanda, tangan, jaringan_saraf, ...
# 16  [memicu, kemampuan, berpikir, matematis, siswa, pembelajaran, matematika, kemampuan_berpikir, ma...
# 17  [aplikasi, steganografi, menyembunyikan, teks, citra, digital, metode, least, significant, bit, ...

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-2010.html')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 11    -0.077895  0.173826       1        1  6.969282
# 13     0.071219  0.210847       2        1  6.518561
# 3     -0.057050 -0.189845       3        1  6.091135
# 10    -0.113529  0.014913       4        1  5.831002
# 2      0.044445 -0.097037       5        1  5.732702
# 14     0.115504 -0.062214       6        1  5.690137
# 12    -0.081056 -0.010539       7        1  5.682946
# 0     -0.080447  0.021469       8        1  5.589558
# 6     -0.138827  0.003309       9        1  5.534678
# 15     0.134671 -0.079136      10        1  5.502738
# 4      0.194338 -0.002653      11        1  5.495455
# 9      0.045494  0.096098      12        1  5.441385
# 7     -0.105885 -0.048284      13        1  5.336482
# 1     -0.082596 -0.019907      14        1  5.201366
# 8      0.057445  0.016058      15        1  5.013439
# 16    -0.001736 -0.014033      16        1  4.806677
# 5     -0.039127 -0.018132      17        1  4.804641
# 17     0.115032  0.005261      18        1  4.757808, topic_info=      Category         Freq                   Term        Total  loglift  \
# term
# 772    Default  1089.000000    pendukung_keputusan  1089.000000  30.0000
# 3242   Default   431.000000        perangkat_lunak   431.000000  29.0000
# 881    Default   493.000000    informasi_geografis   493.000000  28.0000
# 539    Default   410.000000        jaringan_syaraf   410.000000  27.0000
# 2639   Default   395.000000    informasi_akuntansi   395.000000  26.0000
# 870    Default   300.000000             e_commerce   300.000000  25.0000
# 7262   Default   291.000000            sms_gateway   291.000000  24.0000
# 7861   Default   270.000000     rekayasa_perangkat   270.000000  23.0000
# 4408   Default   293.000000         pakar_diagnosa   293.000000  22.0000
# 234    Default   329.000000      jaringan_komputer   329.000000  21.0000
# 1427   Default   271.000000       perguruan_tinggi   271.000000  20.0000
# 95     Default   252.000000             e_learning   252.000000  19.0000
# 4458   Default   262.000000      pakar_mendiagnosa   262.000000  18.0000
# 4491   Default   238.000000         metode_forward   238.000000  17.0000
# 771    Default   417.000000              pendukung   417.000000  16.0000
# 770    Default   429.000000              keputusan   429.000000  15.0000
# 1048   Default   218.000000            rumah_sakit   218.000000  14.0000
# 4173   Default   269.000000       pengolahan_citra   269.000000  13.0000
# 20708  Default   201.000000            lkp_rancang   201.000000  12.0000
# 2952   Default   204.000000             sma_negeri   204.000000  11.0000
# 929    Default   424.000000                  pakar   424.000000  10.0000
# 293    Default   190.000000       sekolah_menengah   190.000000   9.0000
# 938    Default   181.000000          program_studi   181.000000   8.0000
# 3239   Default   210.000000                  lunak   210.000000   7.0000
# 834    Default   162.000000                    lkp   162.000000   6.0000
# 2929   Default   307.000000               penyakit   307.000000   5.0000
# 1159   Default   159.000000          client_server   159.000000   4.0000
# 319    Default   245.000000              perangkat   245.000000   3.0000
# 901    Default   189.000000               surabaya   189.000000   2.0000
# 639    Default   151.000000             smk_negeri   151.000000   1.0000
# ...        ...          ...                    ...          ...      ...
# 7473   Topic18    35.320629              warehouse    36.124203   3.0229
# 1764   Topic18    35.149567      enkripsi_dekripsi    35.952114   3.0228
# 3972   Topic18    36.109959              k_nearest    36.934464   3.0228
# 39071  Topic18    45.697269           biaya_proyek    46.761898   3.0224
# 1718   Topic18    32.898827                  audio    33.727249   3.0205
# 5150   Topic18    31.407009                optimal    32.209438   3.0202
# 1196   Topic18    30.981133      least_significant    31.784725   3.0198
# 2285   Topic18    30.532839                  sehat    31.335251   3.0194
# 7894   Topic18    30.515760               smk_pgri    31.325434   3.0192
# 4440   Topic18    29.903164                   kata    30.705574   3.0189
# 10764  Topic18    28.151794           fuzzy_tahani    28.954269   3.0173
# 11353  Topic18    28.125698           tiga_dimensi    28.928112   3.0173
# 1021   Topic18    28.080328               services    28.882740   3.0172
# 14046  Topic18    27.434555  pakar_troubleshooting    28.236971   3.0166
# 11280  Topic18    27.228701  algoritma_kriptografi    28.031116   3.0163
# 11203  Topic18    26.785563               konversi    27.588877   3.0158
# 7371   Topic18    52.676987                 apotek    55.194969   2.9987
# 3843   Topic18   104.983429             penerimaan   133.430984   2.8056
# 945    Topic18    46.940708                  situs    60.495907   2.7917
# 3791   Topic18    33.184799                   kayu    40.360958   2.8496
# 4100   Topic18    32.793701                dimensi    39.896069   2.8493
# 1343   Topic18    48.829960                   baru   103.026505   2.2987
# 320    Topic18    51.180687                 desain   131.976379   2.0981
# 495    Topic18    34.097935                   teks    45.033852   2.7672
# 282    Topic18    42.649124              algoritma   214.353088   1.4308
# 970    Topic18    41.688095                  citra   257.361938   1.2251
# 162    Topic18    34.653385                 design    73.991463   2.2868
# 323    Topic18    39.342663           implementasi   367.458679   0.8111
# 402    Topic18    35.958782                   data   318.626770   0.8637
# 186    Topic18    34.595291               aplikasi   714.884155   0.0170
#
#        logprob
# term
# 772    30.0000
# 3242   29.0000
# 881    28.0000
# 539    27.0000
# 2639   26.0000
# 870    25.0000
# 7262   24.0000
# 7861   23.0000
# 4408   22.0000
# 234    21.0000
# 1427   20.0000
# 95     19.0000
# 4458   18.0000
# 4491   17.0000
# 771    16.0000
# 770    15.0000
# 1048   14.0000
# 4173   13.0000
# 20708  12.0000
# 2952   11.0000
# 929    10.0000
# 293     9.0000
# 938     8.0000
# 3239    7.0000
# 834     6.0000
# 2929    5.0000
# 1159    4.0000
# 319     3.0000
# 901     2.0000
# 639     1.0000
# ...        ...
# 7473   -5.7083
# 1764   -5.7131
# 3972   -5.6862
# 39071  -5.4507
# 1718   -5.7793
# 5150   -5.8257
# 1196   -5.8394
# 2285   -5.8539
# 7894   -5.8545
# 4440   -5.8748
# 10764  -5.9351
# 11353  -5.9360
# 1021   -5.9377
# 14046  -5.9609
# 11280  -5.9685
# 11203  -5.9849
# 7371   -5.3086
# 3843   -4.6189
# 945    -5.4238
# 3791   -5.7706
# 4100   -5.7825
# 1343   -5.3844
# 320    -5.3374
# 495    -5.7435
# 282    -5.5197
# 970    -5.5425
# 162    -5.7273
# 323    -5.6004
# 402    -5.6904
# 186    -5.7290
#
# [898 rows x 6 columns], token_table=       Topic      Freq                      Term
# term
# 1783       4  0.084515                         0
# 1783       5  0.012074                         0
# 1783       6  0.012074                         0
# 1783       7  0.036221                         0
# 1783       9  0.036221                         0
# 1783      11  0.627825                         0
# 1783      15  0.193177                         0
# 1690       4  0.039130                         a
# 1690       5  0.088044                         a
# 1690       6  0.361957                         a
# 1690      11  0.215218                         a
# 1690      12  0.107609                         a
# 1690      15  0.068478                         a
# 1690      16  0.068478                         a
# 1690      17  0.039130                         a
# 911        2  0.144567                   absensi
# 911        5  0.024095                   absensi
# 911       13  0.819213                   absensi
# 2096      14  0.975678              access_point
# 20645     16  0.981755          activity_costing
# 3891      11  0.961790            adaptive_neuro
# 4340       1  0.110197                  additive
# 4340       5  0.881580                  additive
# 5309       5  0.986794        additive_weighting
# 1142       4  0.096844              administrasi
# 1142       8  0.106529              administrasi
# 1142       9  0.561696              administrasi
# 1142      12  0.067791              administrasi
# 1142      13  0.164635              administrasi
# 22105      9  0.987994  administrasi_kepegawaian
# ...      ...       ...                       ...
# 215        6  0.014834                       web
# 215        7  0.070873                       web
# 215        8  0.044502                       web
# 215        9  0.128560                       web
# 215       10  0.016482                       web
# 215       11  0.009889                       web
# 215       12  0.047798                       web
# 215       13  0.090651                       web
# 215       14  0.064280                       web
# 215       15  0.039557                       web
# 215       16  0.034612                       web
# 215       17  0.029668                       web
# 215       18  0.023075                       web
# 1057       1  0.984867               web_service
# 10955     16  0.977467              web_services
# 5830       2  0.992555                    webcam
# 3503       5  0.973329                 weighting
# 14485      7  0.984747            windows_server
# 160       17  0.960246              wireless_lan
# 86         6  0.733897                      with
# 86         8  0.043170                      with
# 86         9  0.043170                      with
# 86        10  0.107926                      with
# 86        18  0.064756                      with
# 17098     11  0.974947                       xml
# 2536      14  0.989074                       xyz
# 2302       2  0.060156                yogyakarta
# 2302       7  0.608246                yogyakarta
# 2302       8  0.167101                yogyakarta
# 2302      17  0.160417                yogyakarta
#
# [2049 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[12, 14, 4, 11, 3, 15, 13, 1, 7, 16, 5, 10, 8, 2, 9, 17, 6, 18])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model2010.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

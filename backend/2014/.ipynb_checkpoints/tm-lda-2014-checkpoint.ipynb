# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned2014.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                    text
# 0                              buku jaringan komputer i
# 1     perancangan implementasi user interface web mo...
# 2     analisis optimalisasi jaringan teknik load bal...
# 3     perancangan analisis perbandingan implementasi...
# 4     analisis keamanan jaringan wireless lan wlan p...
# 5                           trik jaringan komputer wifi
# 6     pengembangan lab komputer sederhana jaringan m...
# 7     analisa perancangan server voip voice internet...
# 8                          cara mudah jaringan wireless
# 9     rancang bangun cloud computing laboratorium ko...
# 10    analisis pemasaran bisnis online e commerce ja...
# 11    analisis quality service qos jaringan internet...
# 12    analisis kualitas layanan video live streaming...
# 13    perancangan jaringan sensor nirkabel jsn meman...
# 14    analisis kinerja routing dinamis teknik rip ro...
# 15    perancangan vlan jaringan komputer rumah sakit...
# 16    analisis kinerja routing dinamis teknik ospf o...
# 17    optimalisasi jaringan wireless router mikrotik...
# 18    perancangan arsitektur sistem e academic konse...
# 19    redesain jaringan komputer sma katolik rex mun...
# 20    perancangan infrastruktur jaringan komputer ko...
# 21    perancangan sistem pencegahan flooding data ja...
# 22    implementasi teknologi voip e jabber memanfaat...
# 23    rancang bangun jaringan komputer kabel listrik...
# 24    analisis pemrosesan paralel kompresi video jar...
# 25    analisis keamanan jaringan single sign sso lig...
# 26    kecepatan transfer multi protocol label switch...
# 27    analisis perbandingan kinerja jaringan vpn mik...
# 28    aplikasi monitoring jaringan web simple networ...
# 29    ilmiah unikom kajian virtual private network v...
# ...                                                 ...
# 8095  evaluasi sistem informasi akuntansi kemitraan ...
# 8096  otentikasi user algoritma aes private cloud st...
# 8097  deteksi pencegahan buffer overflow efm web ser...
# 8098  perancangan sistem berorientasi objek aplikasi...
# 8099  implementasi algoritma tea enkripsi dekripsi b...
# 8100  analisis evaluasi vulnerabelity content manage...
# 8101  perlindungan hukum korban pencurian informasi ...
# 8102  aspek infcirc revisi pengoperasian reaktor pen...
# 8103                pemaknaan warung kopi pangku gresik
# 8104  kebijakan antisipatif hukum pidana penanggulan...
# 8105                  hacker perspektif hukum indonesia
# 8106  analisa implementasi voip sip jaringan wireles...
# 8107  interactive hotspot billing system metode prot...
# 8108  prestasi belajar media pembelajaran interaktif...
# 8109   aspek hukum perlindungan data pribadi dunia maya
# 8110  internet marketing kepuasan pelanggan studi de...
# 8111  sistem pemantau aktivitas pengguna jaringan cl...
# 8112                   sistem enkripsi e mail algoritma
# 8113  pendidikan tentang pencegahan kekerasan peremp...
# 8114                       pengamanan pc segala ancaman
# 8115  kajian yuridis pemakaian rekam medis elektroni...
# 8116               konferensi nasional sistem informasi
# 8117  analisis deskriptif kualitatif kajian implemen...
# 8118          makna iklan visual museum sangiran sragen
# 8119                     pengantar open source aplikasi
# 8120  faktor faktor mempengaruhi kualitas laporan ke...
# 8121  ketik konfrensi nasional pengembangan teknolog...
# 8122  perlindungan hukum konsumen transaksi e commer...
# 8123  sistem informasi perpustakaan web balai pengka...
# 8124  metode klasifikasi spasial pendukung informasi...
#
# [8125 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 8125
# [['buku', 'jaringan', 'komputer', 'i']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# [['buku', 'jaringan', 'komputer', 'i', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['perancangan', 'implementasi', 'user', 'interface', 'web', 'monitoring', 'suhu', 'kelembaban', 'asap', 'ruangan', 'berbeda', 'memanfaatkan', 'user_interface', 'monitoring_suhu', 'user_interface', 'monitoring_suhu', 'user_interface', 'monitoring_suhu'], ['analisis', 'optimalisasi', 'jaringan', 'teknik', 'load', 'balancing', 'studi', 'kasus', 'jaringan', 'uad', 'kampus', 'load_balancing', 'studi_kasus', 'load_balancing', 'studi_kasus', 'load_balancing', 'studi_kasus'], ['perancangan', 'analisis', 'perbandingan', 'implementasi', 'ospf', 'jaringan', 'ipv4', 'ipv6', 'analisis_perbandingan', 'analisis_perbandingan', 'analisis_perbandingan'], ['analisis', 'keamanan', 'jaringan', 'wireless', 'lan', 'wlan', 'pln', 'persero', 'wilayah', 'p2b', 'area', 'sorong', 'keamanan_jaringan', 'wireless_lan', 'pln_persero', 'keamanan_jaringan', 'pln_persero', 'keamanan_jaringan', 'wireless_lan', 'pln_persero'], ['trik', 'jaringan', 'komputer', 'wifi', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['pengembangan', 'lab', 'komputer', 'sederhana', 'jaringan', 'multipoint', 'switch', 'sarana', 'penunjang', 'proses', 'pembelajaran'], ['analisa', 'perancangan', 'server', 'voip', 'voice', 'internet', 'protocol', 'opensource', 'asterisk', 'vpn', 'virtual', 'private', 'network', 'pengaman', 'jaringan', 'antar', 'client', 'analisa_perancangan', 'internet_protocol', 'virtual_private', 'analisa_perancangan', 'internet_protocol', 'virtual_private', 'analisa_perancangan', 'internet_protocol', 'virtual_private'], ['cara', 'mudah', 'jaringan', 'wireless', 'jaringan_wireless', 'jaringan_wireless', 'jaringan_wireless'], ['rancang', 'bangun', 'cloud', 'computing', 'laboratorium', 'komputer', 'teknik', 'elektro', 'universitas', 'bangka', 'belitung', 'rancang_bangun', 'cloud_computing', 'teknik_elektro', 'rancang_bangun', 'cloud_computing', 'laboratorium_komputer', 'teknik_elektro', 'rancang_bangun', 'cloud_computing', 'teknik_elektro'], ['analisis', 'pemasaran', 'bisnis', 'online', 'e', 'commerce', 'jaringan', 'sosial', 'internet', 'e_commerce', 'e_commerce', 'e_commerce'], ['analisis', 'quality', 'service', 'qos', 'jaringan', 'internet', 'smk', 'telkom', 'medan', 'quality_service', 'quality_service', 'quality_service'], ['analisis', 'kualitas', 'layanan', 'video', 'live', 'streaming', 'jaringan', 'lokal', 'universitas', 'telkom', 'jaringan_lokal', 'universitas_telkom'], ['perancangan', 'jaringan', 'sensor', 'nirkabel', 'jsn', 'memantau', 'suhu', 'kelembaban', 'nrf24l01'], ['analisis', 'kinerja', 'routing', 'dinamis', 'teknik', 'rip', 'routing', 'information', 'protocol', 'topologi', 'ring', 'jaringan', 'lan', 'local', 'area', 'network', 'jaringan_lan', 'local_area', 'jaringan_lan', 'local_area', 'jaringan_lan', 'local_area'], ['perancangan', 'vlan', 'jaringan', 'komputer', 'rumah', 'sakit', 'bethesda', 'yogyakarta', 'jaringan_komputer', 'rumah_sakit', 'jaringan_komputer', 'rumah_sakit', 'jaringan_komputer', 'rumah_sakit'], ['analisis', 'kinerja', 'routing', 'dinamis', 'teknik', 'ospf', 'open', 'shortest', 'path', 'first', 'topologi', 'mesh', 'jaringan', 'local', 'area', 'network', 'lan', 'cisco', 'packet', 'local_area', 'network_lan', 'local_area', 'network_lan', 'local_area_network_lan'], ['optimalisasi', 'jaringan', 'wireless', 'router', 'mikrotik', 'studi', 'kasus', 'kampus', 'bsi', 'tangerang', 'jaringan_wireless', 'studi_kasus', 'jaringan_wireless', 'studi_kasus', 'jaringan_wireless', 'studi_kasus'], ['perancangan', 'arsitektur', 'sistem', 'e', 'academic', 'konsep', 'kampus', 'digital', 'unified', 'software', 'development', 'process', 'usdp', 'perancangan_arsitektur'], ['redesain', 'jaringan', 'komputer', 'sma', 'katolik', 'rex', 'mundi', 'manado', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['perancangan', 'infrastruktur', 'jaringan', 'komputer', 'konsep', 'membangun', 'serang', 'menuju', 'smart', 'city', 'jaringan_komput ...

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                 0              1              2              3   \
# 0             buku       jaringan       komputer              i
# 1      perancangan   implementasi           user      interface
# 2         analisis   optimalisasi       jaringan         teknik
# 3      perancangan       analisis   perbandingan   implementasi
# 4         analisis       keamanan       jaringan       wireless
# 5             trik       jaringan       komputer           wifi
# 6     pengembangan            lab       komputer      sederhana
# 7          analisa    perancangan         server           voip
# 8             cara          mudah       jaringan       wireless
# 9          rancang         bangun          cloud      computing
# 10        analisis      pemasaran         bisnis         online
# 11        analisis        quality        service            qos
# 12        analisis       kualitas        layanan          video
# 13     perancangan       jaringan         sensor       nirkabel
# 14        analisis        kinerja        routing        dinamis
# 15     perancangan           vlan       jaringan       komputer
# 16        analisis        kinerja        routing        dinamis
# 17    optimalisasi       jaringan       wireless         router
# 18     perancangan     arsitektur         sistem              e
# 19        redesain       jaringan       komputer            sma
# 20     perancangan  infrastruktur       jaringan       komputer
# 21     perancangan         sistem     pencegahan       flooding
# 22    implementasi      teknologi           voip              e
# 23         rancang         bangun       jaringan       komputer
# 24        analisis     pemrosesan        paralel       kompresi
# 25        analisis       keamanan       jaringan         single
# 26       kecepatan       transfer          multi       protocol
# 27        analisis   perbandingan        kinerja       jaringan
# 28        aplikasi     monitoring       jaringan            web
# 29          ilmiah         unikom         kajian        virtual
# ...            ...            ...            ...            ...
# 8095      evaluasi         sistem      informasi      akuntansi
# 8096    otentikasi           user      algoritma            aes
# 8097       deteksi     pencegahan         buffer       overflow
# 8098   perancangan         sistem   berorientasi          objek
# 8099  implementasi      algoritma            tea       enkripsi
# 8100      analisis       evaluasi  vulnerabelity        content
# 8101  perlindungan          hukum         korban      pencurian
# 8102         aspek        infcirc         revisi  pengoperasian
# 8103     pemaknaan         warung           kopi         pangku
# 8104     kebijakan    antisipatif          hukum         pidana
# 8105        hacker     perspektif          hukum      indonesia
# 8106       analisa   implementasi           voip            sip
# 8107   interactive        hotspot        billing         system
# 8108      prestasi        belajar          media   pembelajaran
# 8109         aspek          hukum   perlindungan           data
# 8110      internet      marketing       kepuasan      pelanggan
# 8111        sistem       pemantau      aktivitas       pengguna
# 8112        sistem       enkripsi              e           mail
# 8113    pendidikan        tentang     pencegahan      kekerasan
# 8114    pengamanan             pc         segala        ancaman
# 8115        kajian        yuridis      pemakaian          rekam
# 8116    konferensi       nasional         sistem      informasi
# 8117      analisis     deskriptif     kualitatif         kajian
# 8118         makna          iklan         visual         museum
# 8119     pengantar           open         source       aplikasi
# 8120        faktor         faktor   mempengaruhi       kualitas
# 8121         ketik      konfrensi       nasional   pengembangan
# 8122  perlindungan          hukum       konsumen      transaksi
# 8123        sistem      informasi   perpustakaan            web
# 8124        metode    klasifikasi        spasial      pendukung
#
#                        4                  5                    6   \
# 0       jaringan_komputer  jaringan_komputer    jaringan_komputer
# 1                     web         monitoring                 suhu
# 2                    load          balancing                studi
# 3                    ospf           jaringan                 ipv4
# 4                     lan               wlan                  pln
# 5       jaringan_komputer  jaringan_komputer    jaringan_komputer
# 6                jaringan         multipoint               switch
# 7                   voice           internet             protocol
# 8       jaringan_wireless  jaringan_wireless    jaringan_wireless
# 9            laboratorium           komputer               teknik
# 10                      e           commerce             jaringan
# 11               jaringan           internet                  smk
# 12                   live          streaming             jaringan
# 13                    jsn           memantau                 suhu
# 14                 teknik                rip              routing
# 15                  rumah              sakit             bethesda
# 16                 teknik               ospf                 open
# 17               mikrotik              studi                kasus
# 18               academic             konsep               kampus
# 19                katolik                rex                mundi
# 20                 konsep          membangun               serang
# 21                   data           jaringan             komputer
# 22                 jabber       memanfaatkan        infrastruktur
# 23                  kabel            listrik                media
# 24                  video           jaringan             komputer
# 25                   sign                sso          lightweight
# 26                  label          switching                 mpls
# 27                    vpn           mikrotik             protokol
# 28                 simple            network           management
# 29                private            network                  vpn
# ...                   ...                ...                  ...
# 8095            kemitraan         peternakan                 inti
# 8096              private              cloud              storage
# 8097                  efm                web               server
# 8098             aplikasi                web              service
# 8099             dekripsi             bahasa          pemrograman
# 8100           management             system                 mybb
# 8101            informasi            pribadi              melalui
# 8102              reaktor         penelitian                 None
# 8103               gresik               None                 None
# 8104       penanggulangan     cyberterrorism                 None
# 8105                 None               None                 None
# 8106             jaringan           wireless                  lan
# 8107               metode         protoyping                  web
# 8108           interaktif          kurikulum                  smk
# 8109              pribadi              dunia                 maya
# 8110                studi         deskriptif           kualitatif
# 8111             jaringan             client               server
# 8112            algoritma             e_mail               e_mail
# 8113            perempuan            dimensi            kejahatan
# 8114                 None               None                 None
# 8115                medis         elektronik                rumah
# 8116  konferensi_nasional   sistem_informasi  konferensi_nasional
# 8117         implementasi           tutorial               online
# 8118             sangiran             sragen                 None
# 8119          open_source        open_source          open_source
# 8120              laporan           keuangan           pemerintah
# 8121            teknologi          informasi           komunikasi
# 8122                    e           commerce               tinjau
# 8123                balai         pengkajian            teknologi
# 8124            informasi        pengkelasan                 data
#
#                      7                      8                       9   ...   \
# 0                  None                   None                    None  ...
# 1            kelembaban                   asap                 ruangan  ...
# 2                 kasus               jaringan                     uad  ...
# 3                  ipv6  analisis_perbandingan   analisis_perbandingan  ...
# 4               persero                wilayah                     p2b  ...
# 5                  None                   None                    None  ...
# 6                sarana              penunjang                  proses  ...
# 7            opensource               asterisk                     vpn  ...
# 8                  None                   None                    None  ...
# 9               elektro            universitas                  bangka  ...
# 10               sosial               internet              e_commerce  ...
# 11               telkom                  medan         quality_service  ...
# 12                lokal            universitas                  telkom  ...
# 13           kelembaban               nrf24l01                    None  ...
# 14          information               protocol                topologi  ...
# 15           yogyakarta      jaringan_komputer             rumah_sakit  ...
# 16             shortest                   path                   first  ...
# 17               kampus                    bsi               tangerang  ...
# 18              digital                unified                software  ...
# 19               manado      jaringan_komputer       jaringan_komputer  ...
# 20               menuju                  smart                    city  ...
# 21        flooding_data      jaringan_komputer       jaringan_komputer  ...
# 22             jaringan               komputer                    wifi  ...
# 23            transmisi             komunikasi                    data  ...
# 24                 ipv6      jaringan_komputer       jaringan_komputer  ...
# 25            directory                 access                protocol  ...
# 26              virtual                private                 network  ...
# 27                 pptp                   l2tp                   media  ...
# 28             protocol                   None                    None  ...
# 29               sistem             pengamanan                    data  ...
# ...                 ...                    ...                     ...  ...
# 8095             rakyat                    pir               framework  ...
# 8096      algoritma_aes          cloud_storage           cloud_storage  ...
# 8097              snort                   None                    None  ...
# 8098  interoperabilitas                   data                  sistem  ...
# 8099             visual                  basic  implementasi_algoritma  ...
# 8100              phpbb     content_management      content_management  ...
# 8101              dunia                  cyber                ditinjau  ...
# 8102               None                   None                    None  ...
# 8103               None                   None                    None  ...
# 8104               None                   None                    None  ...
# 8105               None                   None                    None  ...
# 8106          kemampuan                   auto          authentication  ...
# 8107                sms                gateway                   studi  ...
# 8108              studi                  kasus                    mata  ...
# 8109         dunia_maya             dunia_maya                    None  ...
# 8110           kepuasan              pelanggan              berbelanja  ...
# 8111      client_server          client_server           client_server  ...
# 8112             e_mail                   None                    None  ...
# 8113              siber                   None                    None  ...
# 8114               None                   None                    None  ...
# 8115              sakit            rekam_medis             rumah_sakit  ...
# 8116               None                   None                    None  ...
# 8117          mahasiswa                 pendas                   upbjj  ...
# 8118               None                   None                    None  ...
# 8119               None                   None                    None  ...
# 8120             daerah            mendapatkan                   opini  ...
# 8121          prosiding    teknologi_informasi     teknologi_informasi  ...
# 8122              hukum              perikatan      perlindungan_hukum  ...
# 8123          pertanian                   jawa                   timur  ...
# 8124          indikator                 banjir                    None  ...
#
#                28                 29    30    31    32    33    34    35  \
# 0            None               None  None  None  None  None  None  None
# 1            None               None  None  None  None  None  None  None
# 2            None               None  None  None  None  None  None  None
# 3            None               None  None  None  None  None  None  None
# 4            None               None  None  None  None  None  None  None
# 5            None               None  None  None  None  None  None  None
# 6            None               None  None  None  None  None  None  None
# 7            None               None  None  None  None  None  None  None
# 8            None               None  None  None  None  None  None  None
# 9            None               None  None  None  None  None  None  None
# 10           None               None  None  None  None  None  None  None
# 11           None               None  None  None  None  None  None  None
# 12           None               None  None  None  None  None  None  None
# 13           None               None  None  None  None  None  None  None
# 14           None               None  None  None  None  None  None  None
# 15           None               None  None  None  None  None  None  None
# 16           None               None  None  None  None  None  None  None
# 17           None               None  None  None  None  None  None  None
# 18           None               None  None  None  None  None  None  None
# 19           None               None  None  None  None  None  None  None
# 20           None               None  None  None  None  None  None  None
# 21           None               None  None  None  None  None  None  None
# 22           None               None  None  None  None  None  None  None
# 23           None               None  None  None  None  None  None  None
# 24           None               None  None  None  None  None  None  None
# 25           None               None  None  None  None  None  None  None
# 26           None               None  None  None  None  None  None  None
# 27           None               None  None  None  None  None  None  None
# 28           None               None  None  None  None  None  None  None
# 29    studi_kasus  jaringan_komputer  None  None  None  None  None  None
# ...           ...                ...   ...   ...   ...   ...   ...   ...
# 8095         None               None  None  None  None  None  None  None
# 8096         None               None  None  None  None  None  None  None
# 8097         None               None  None  None  None  None  None  None
# 8098         None               None  None  None  None  None  None  None
# 8099         None               None  None  None  None  None  None  None
# 8100         None               None  None  None  None  None  None  None
# 8101         None               None  None  None  None  None  None  None
# 8102         None               None  None  None  None  None  None  None
# 8103         None               None  None  None  None  None  None  None
# 8104         None               None  None  None  None  None  None  None
# 8105         None               None  None  None  None  None  None  None
# 8106         None               None  None  None  None  None  None  None
# 8107         None               None  None  None  None  None  None  None
# 8108         None               None  None  None  None  None  None  None
# 8109         None               None  None  None  None  None  None  None
# 8110         None               None  None  None  None  None  None  None
# 8111         None               None  None  None  None  None  None  None
# 8112         None               None  None  None  None  None  None  None
# 8113         None               None  None  None  None  None  None  None
# 8114         None               None  None  None  None  None  None  None
# 8115         None               None  None  None  None  None  None  None
# 8116         None               None  None  None  None  None  None  None
# 8117         None               None  None  None  None  None  None  None
# 8118         None               None  None  None  None  None  None  None
# 8119         None               None  None  None  None  None  None  None
# 8120         None               None  None  None  None  None  None  None
# 8121         None               None  None  None  None  None  None  None
# 8122         None               None  None  None  None  None  None  None
# 8123         None               None  None  None  None  None  None  None
# 8124         None               None  None  None  None  None  None  None
#
#         36    37
# 0     None  None
# 1     None  None
# 2     None  None
# 3     None  None
# 4     None  None
# 5     None  None
# 6     None  None
# 7     None  None
# 8     None  None
# 9     None  None
# 10    None  None
# 11    None  None
# 12    None  None
# 13    None  None
# 14    None  None
# 15    None  None
# 16    None  None
# 17    None  None
# 18    None  None
# 19    None  None
# 20    None  None
# 21    None  None
# 22    None  None
# 23    None  None
# 24    None  None
# 25    None  None
# 26    None  None
# 27    None  None
# 28    None  None
# 29    None  None
# ...    ...   ...
# 8095  None  None
# 8096  None  None
# 8097  None  None
# 8098  None  None
# 8099  None  None
# 8100  None  None
# 8101  None  None
# 8102  None  None
# 8103  None  None
# 8104  None  None
# 8105  None  None
# 8106  None  None
# 8107  None  None
# 8108  None  None
# 8109  None  None
# 8110  None  None
# 8111  None  None
# 8112  None  None
# 8113  None  None
# 8114  None  None
# 8115  None  None
# 8116  None  None
# 8117  None  None
# 8118  None  None
# 8119  None  None
# 8120  None  None
# 8121  None  None
# 8122  None  None
# 8123  None  None
# 8124  None  None
#
# [8125 rows x 38 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(11167 unique tokens: ['buku', 'i', 'jaringan', 'jaringan_komputer', 'komputer']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 8125

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=12)
pprint(model.print_topics())

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=12)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-2014.html')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model2014.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

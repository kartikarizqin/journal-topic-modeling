# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned-range2.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                     text
# 0      pendeteksi gangguan jaringan lokal metode cert...
# 1      eksistensi penggunaan wi fi warung kopi kota b...
# 2      pengaruh internet financial reporting tingkat ...
# 3      security function analysis performance high sp...
# 4      implementation top down approach method redesi...
# 5      optimization wireless network performance hier...
# 6      analysis qos vlan djikstra s algorithm open sh...
# 7      link performance improvement sananibun bts wit...
# 8      legal protection efforts patent holders indonesia
# 9      use e learning by teachers teaching learning p...
# 10     definition patent rights examples case studies...
# 11     analysis implementation backup line network br...
# 12     classification principles legal basis intellec...
# 13     attendance system automatic door locks laborat...
# 14          registration requirements application rights
# 15     patentability block chain technology future in...
# 16     influence speed user mobility qos wireless lan...
# 17     4 ghz omnidirectional antenna design with micr...
# 18     pemanfaatan telepon pintar informasi penyebara...
# 19     aplikasi teknologi komunikasi wireless zigbee ...
# 20     forensics analysis router computer networks li...
# 21                   manajemen proyeksi sistem informasi
# 22                   manajemen proyeksi sistem informasi
# 23                   tri destanto 175100067p sectionquis
# 24           rancang bangun aplikasi chatting web docker
# 25     multimedia animated corrosion corrosion coatin...
# 26     quality service traffic monitoring system stat...
# 27              analisis topologi area jaringan komputer
# 28              resume pembuatan tugas jaringan komputer
# 29              perkembangan jaringan komputer indonesia
# ...                                                  ...
# 17221  pengembangan pipeline identifikasi single nucl...
# 17222  perlindungan hukum pembeli barang situs mall o...
# 17223  melindungi informasi pribadi pengemudi uber po...
# 17224  analisis pengaruh lingkungan kerja insentif ki...
# 17225  eksistensi e signature perdagangan internasion...
# 17226  analisis faktor faktor penggunaan e commerce u...
# 17227  fenomena cyber pedofilia media facebook ditinj...
# 17228  analisis praktik sistem informasi akuntansi le...
# 17229    pengembangan bahan ajar spreadsheet audiovisual
# 17230                      diktat pengantar ilmu kompuer
# 17231  hybryd crystosystem algoritma variably modifie...
# 17232  analisis steganografi video kombinasi algoritm...
# 17233  standar akuntansi akrual kualitas laporan keua...
# 17234  analisis semiotika film dokumenter citizenfour...
# 17235         penetration testing domain uii ac id owasp
# 17236  design robot otomatis penyiram tanaman berbasi...
# 17237  tinjauan hukum internasional atas perbuatan ha...
# 17238  rancang bangun sistem informasi surat tugas an...
# 17239  tinjauan yuridis tanggungjawab bank hilangnya ...
# 17240                      langkah basmi virus berbahaya
# 17241  pengamanan file audio citra algoritma rithmeti...
# 17242  kesedaran amalan keselamatan siber kalangan pe...
# 17243  pengembangan adaptive content e learning ontol...
# 17244  praktek jual beli online sistem dropship persp...
# 17245  pengaruh standar akuntansi pemerintahan kompet...
# 17246  evaluasi sistem pengendalian internal perusaha...
# 17247          forensic imaging application raspberry pi
# 17248  pengaruh kompetensi sumber daya manusia pemanf...
# 17249  pengujian alur proses bisnis state transition ...
# 17250  deteksi pemalsuan data digital citra copy move...
#
# [17251 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 17251
# [['pendeteksi', 'gangguan', 'jaringan', 'lokal', 'metode', 'certainty', 'factor']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                    0               1                2             3   \
# 0          pendeteksi        gangguan         jaringan         lokal
# 1          eksistensi      penggunaan               wi            fi
# 2            pengaruh        internet        financial     reporting
# 3            security        function         analysis   performance
# 4      implementation             top             down      approach
# 5        optimization        wireless          network   performance
# 6            analysis             qos             vlan      djikstra
# 7                link     performance      improvement     sananibun
# 8               legal      protection          efforts        patent
# 9                 use               e         learning            by
# 10         definition          patent           rights      examples
# 11           analysis  implementation           backup          line
# 12     classification      principles            legal         basis
# 13         attendance          system        automatic          door
# 14       registration    requirements      application        rights
# 15      patentability           block            chain    technology
# 16          influence           speed             user      mobility
# 17                  4             ghz  omnidirectional       antenna
# 18        pemanfaatan         telepon           pintar     informasi
# 19           aplikasi       teknologi       komunikasi      wireless
# 20          forensics        analysis           router      computer
# 21          manajemen        proyeksi           sistem     informasi
# 22          manajemen        proyeksi           sistem     informasi
# 23                tri        destanto       175100067p   sectionquis
# 24            rancang          bangun         aplikasi      chatting
# 25         multimedia        animated        corrosion     corrosion
# 26            quality         service          traffic    monitoring
# 27           analisis        topologi             area      jaringan
# 28             resume       pembuatan            tugas      jaringan
# 29       perkembangan        jaringan         komputer     indonesia
# ...               ...             ...              ...           ...
# 17221    pengembangan        pipeline     identifikasi        single
# 17222    perlindungan           hukum          pembeli        barang
# 17223      melindungi       informasi          pribadi     pengemudi
# 17224        analisis        pengaruh       lingkungan         kerja
# 17225      eksistensi               e        signature   perdagangan
# 17226        analisis          faktor           faktor    penggunaan
# 17227        fenomena           cyber        pedofilia         media
# 17228        analisis         praktik           sistem     informasi
# 17229    pengembangan           bahan             ajar   spreadsheet
# 17230          diktat       pengantar             ilmu       kompuer
# 17231          hybryd    crystosystem        algoritma      variably
# 17232        analisis    steganografi            video     kombinasi
# 17233         standar       akuntansi           akrual      kualitas
# 17234        analisis       semiotika             film    dokumenter
# 17235     penetration         testing           domain           uii
# 17236          design           robot         otomatis      penyiram
# 17237        tinjauan           hukum    internasional          atas
# 17238         rancang          bangun           sistem     informasi
# 17239        tinjauan         yuridis    tanggungjawab          bank
# 17240         langkah           basmi            virus     berbahaya
# 17241      pengamanan            file            audio         citra
# 17242       kesedaran          amalan      keselamatan         siber
# 17243    pengembangan        adaptive          content             e
# 17244         praktek            jual             beli        online
# 17245        pengaruh         standar        akuntansi  pemerintahan
# 17246        evaluasi          sistem     pengendalian      internal
# 17247        forensic         imaging      application     raspberry
# 17248        pengaruh      kompetensi           sumber          daya
# 17249       pengujian            alur           proses        bisnis
# 17250         deteksi       pemalsuan             data       digital
#
#                        4                   5                   6   \
# 0                  metode           certainty              factor
# 1                  warung                kopi                kota
# 2                 tingkat        pengungkapan           informasi
# 3                    high               speed              router
# 4                  method            redesign                 lan
# 5            hierarchical               token              bucket
# 6                       s           algorithm                open
# 7                     bts                with                link
# 8                 holders           indonesia                None
# 9                teachers            teaching            learning
# 10                   case             studies              iphone
# 11                network              branch              office
# 12           intellectual            property           indonesia
# 13                  locks          laboratory          electrical
# 14                   None                None                None
# 15                 future          innovation                None
# 16                    qos            wireless                 lan
# 17                 design                with          microstrip
# 18             penyebaran              lokasi                guru
# 19                 zigbee              sistem             kontrol
# 20               networks                live           forensics
# 21     manajemen_proyeksi    sistem_informasi  manajemen_proyeksi
# 22     manajemen_proyeksi    sistem_informasi  manajemen_proyeksi
# 23                   None                None                None
# 24                    web              docker      rancang_bangun
# 25                coating              metals              course
# 26                 system              static             routing
# 27               komputer   jaringan_komputer   jaringan_komputer
# 28               komputer   jaringan_komputer   jaringan_komputer
# 29      jaringan_komputer   jaringan_komputer   jaringan_komputer
# ...                   ...                 ...                 ...
# 17221          nucleotide        polymorphism          konstruksi
# 17222               situs                mall              online
# 17223                uber             potensi      penyalahgunaan
# 17224            insentif             kinerja            karyawan
# 17225       internasional            konvensi       internasional
# 17226                   e            commerce               usaha
# 17227            facebook            ditinjau               hukum
# 17228           akuntansi             lembaga            keuangan
# 17229         audiovisual  pengembangan_bahan  pengembangan_bahan
# 17230                None                None                None
# 17231            modified         permutation         composition
# 17232           algoritma            discrete     cosinetransform
# 17233             laporan            keuangan          pengadilan
# 17234         citizenfour               karya               laura
# 17235                  ac                  id               owasp
# 17236             tanaman         berbasiskan          artificial
# 17237           perbuatan             hacking            cracking
# 17238               surat               tugas            analisis
# 17239           hilangnya            sejumlah                dana
# 17240                None                None                None
# 17241           algoritma           rithmetic              coding
# 17242            kalangan            pengguna            internet
# 17243            learning            ontology            semantik
# 17244              sistem            dropship          perspektif
# 17245          kompetensi              sumber                daya
# 17246          perusahaan              daerah                 air
# 17247                  pi        raspberry_pi        raspberry_pi
# 17248             manusia         pemanfaatan           teknologi
# 17249               state          transition             diagram
# 17250               citra                copy                move
#
#                         7                   8                    9   ...   \
# 0           jaringan_lokal    metode_certainty  pendeteksi_gangguan  ...
# 1                    banda                aceh                wi_fi  ...
# 2                  website           frekuensi          perdagangan  ...
# 3               networking                None                 None  ...
# 4                  harvani               hotel            palembang  ...
# 5                     case        muhammadiyah           university  ...
# 6                 shortest                path                first  ...
# 7                   switch           migration             backbone  ...
# 8                     None                None                 None  ...
# 9                  process          e_learning           e_learning  ...
# 10                products                None                 None  ...
# 11                     vpn              speedy             internet  ...
# 12                    None                None                 None  ...
# 13             engineering          department                   at  ...
# 14                    None                None                 None  ...
# 15                    None                None                 None  ...
# 16                      11                   g                   11  ...
# 17            technologies                 gsm             internet  ...
# 18                 sekolah               dasar               negeri  ...
# 19              monitoring             ruangan                kelas  ...
# 20                  method                None                 None  ...
# 21        sistem_informasi  manajemen_proyeksi     sistem_informasi  ...
# 22        sistem_informasi  manajemen_proyeksi     sistem_informasi  ...
# 23                    None                None                 None  ...
# 24       aplikasi_chatting      rancang_bangun    aplikasi_chatting  ...
# 25                    None                None                 None  ...
# 26                    eoip              tunnel                 over  ...
# 27       jaringan_komputer                None                 None  ...
# 28       jaringan_komputer                None                 None  ...
# 29                    None                None                 None  ...
# ...                    ...                 ...                  ...  ...
# 17221                pohon         filogenetik                 None  ...
# 17222   perlindungan_hukum  perlindungan_hukum   perlindungan_hukum  ...
# 17223                 oleh            karyawan            eksekutif  ...
# 17224                 bank             mestika                  tbk  ...
# 17225                hukum            nasional                 None  ...
# 17226                mikro               kecil             menengah  ...
# 17227              positif               hukum                islam  ...
# 17228                mikro             syariah              melalui  ...
# 17229   pengembangan_bahan                None                 None  ...
# 17230                 None                None                 None  ...
# 17231                 vmpc           algoritma              elgamal  ...
# 17232                  dct                  2d             discrete  ...
# 17233                agama               batam    standar_akuntansi  ...
# 17234              poitras                None                 None  ...
# 17235  penetration_testing               ac_id                ac_id  ...
# 17236               neural             network    artificial_neural  ...
# 17237               bentuk           kejahatan           cybercrime  ...
# 17238           penerimaan              sistem               metode  ...
# 17239             tabungan             nasabah              melalui  ...
# 17240                 None                None                 None  ...
# 17241               triple                data           encryption  ...
# 17242             malaysia                None                 None  ...
# 17243                  web          e_learning           e_learning  ...
# 17244                hukum               islam           kuhperdata  ...
# 17245              manusia         pemanfaatan            teknologi  ...
# 17246                minum                pdam                 kota  ...
# 17247         raspberry_pi                None                 None  ...
# 17248            informasi              sistem         pengendalian  ...
# 17249                studi               kasus               sistem  ...
# 17250            perpaduan              teknik             discrete  ...
#
#                         29                                    30    31    32  \
# 0                     None                                  None  None  None
# 1                     None                                  None  None  None
# 2                     None                                  None  None  None
# 3                     None                                  None  None  None
# 4                     None                                  None  None  None
# 5                     None                                  None  None  None
# 6                     None                                  None  None  None
# 7                     None                                  None  None  None
# 8                     None                                  None  None  None
# 9                     None                                  None  None  None
# 10                    None                                  None  None  None
# 11                    None                                  None  None  None
# 12                    None                                  None  None  None
# 13                    None                                  None  None  None
# 14                    None                                  None  None  None
# 15                    None                                  None  None  None
# 16                    None                                  None  None  None
# 17                    None                                  None  None  None
# 18                    None                                  None  None  None
# 19                    None                                  None  None  None
# 20                    None                                  None  None  None
# 21                    None                                  None  None  None
# 22                    None                                  None  None  None
# 23                    None                                  None  None  None
# 24                    None                                  None  None  None
# 25                    None                                  None  None  None
# 26                    None                                  None  None  None
# 27                    None                                  None  None  None
# 28                    None                                  None  None  None
# 29                    None                                  None  None  None
# ...                    ...                                   ...   ...   ...
# 17221                 None                                  None  None  None
# 17222                 None                                  None  None  None
# 17223                 None                                  None  None  None
# 17224                 None                                  None  None  None
# 17225                 None                                  None  None  None
# 17226                 None                                  None  None  None
# 17227                 None                                  None  None  None
# 17228                 None                                  None  None  None
# 17229                 None                                  None  None  None
# 17230                 None                                  None  None  None
# 17231                 None                                  None  None  None
# 17232                 None                                  None  None  None
# 17233                 None                                  None  None  None
# 17234                 None                                  None  None  None
# 17235                 None                                  None  None  None
# 17236                 None                                  None  None  None
# 17237                 None                                  None  None  None
# 17238                 None                                  None  None  None
# 17239                 None                                  None  None  None
# 17240                 None                                  None  None  None
# 17241                 None                                  None  None  None
# 17242                 None                                  None  None  None
# 17243                 None                                  None  None  None
# 17244                 None                                  None  None  None
# 17245                 None                                  None  None  None
# 17246                 None                                  None  None  None
# 17247                 None                                  None  None  None
# 17248  pengendalian_intern  kualitas_laporan_keuangan_pemerintah  None  None
# 17249                 None                                  None  None  None
# 17250                 None                                  None  None  None
#
#          33    34    35    36    37    38
# 0      None  None  None  None  None  None
# 1      None  None  None  None  None  None
# 2      None  None  None  None  None  None
# 3      None  None  None  None  None  None
# 4      None  None  None  None  None  None
# 5      None  None  None  None  None  None
# 6      None  None  None  None  None  None
# 7      None  None  None  None  None  None
# 8      None  None  None  None  None  None
# 9      None  None  None  None  None  None
# 10     None  None  None  None  None  None
# 11     None  None  None  None  None  None
# 12     None  None  None  None  None  None
# 13     None  None  None  None  None  None
# 14     None  None  None  None  None  None
# 15     None  None  None  None  None  None
# 16     None  None  None  None  None  None
# 17     None  None  None  None  None  None
# 18     None  None  None  None  None  None
# 19     None  None  None  None  None  None
# 20     None  None  None  None  None  None
# 21     None  None  None  None  None  None
# 22     None  None  None  None  None  None
# 23     None  None  None  None  None  None
# 24     None  None  None  None  None  None
# 25     None  None  None  None  None  None
# 26     None  None  None  None  None  None
# 27     None  None  None  None  None  None
# 28     None  None  None  None  None  None
# 29     None  None  None  None  None  None
# ...     ...   ...   ...   ...   ...   ...
# 17221  None  None  None  None  None  None
# 17222  None  None  None  None  None  None
# 17223  None  None  None  None  None  None
# 17224  None  None  None  None  None  None
# 17225  None  None  None  None  None  None
# 17226  None  None  None  None  None  None
# 17227  None  None  None  None  None  None
# 17228  None  None  None  None  None  None
# 17229  None  None  None  None  None  None
# 17230  None  None  None  None  None  None
# 17231  None  None  None  None  None  None
# 17232  None  None  None  None  None  None
# 17233  None  None  None  None  None  None
# 17234  None  None  None  None  None  None
# 17235  None  None  None  None  None  None
# 17236  None  None  None  None  None  None
# 17237  None  None  None  None  None  None
# 17238  None  None  None  None  None  None
# 17239  None  None  None  None  None  None
# 17240  None  None  None  None  None  None
# 17241  None  None  None  None  None  None
# 17242  None  None  None  None  None  None
# 17243  None  None  None  None  None  None
# 17244  None  None  None  None  None  None
# 17245  None  None  None  None  None  None
# 17246  None  None  None  None  None  None
# 17247  None  None  None  None  None  None
# 17248  None  None  None  None  None  None
# 17249  None  None  None  None  None  None
# 17250  None  None  None  None  None  None
#
# [17251 rows x 39 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(18305 unique tokens: ['certainty', 'factor', 'gangguan', 'jaringan', 'jaringan_lokal']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 17251

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))
# Out:
# Num Topics = 2  has Coherence Value of 0.2369825182
# Num Topics = 4  has Coherence Value of 0.3613191821
# Num Topics = 6  has Coherence Value of 0.440897708
# Num Topics = 8  has Coherence Value of 0.4328239948
# Num Topics = 10  has Coherence Value of 0.451720986
# Num Topics = 12  has Coherence Value of 0.4862225438
# Num Topics = 14  has Coherence Value of 0.5183195359
# Num Topics = 16  has Coherence Value of 0.4852706631
# Num Topics = 18  has Coherence Value of 0.5019647373

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=14)
pprint(model.print_topics())
# Out:
# [(0,
#   '0.033*"sistem_informasi" + 0.012*"informasi" + 0.008*"expert_system" + '
#   '0.007*"metodologi_berorientasi" + 0.007*"studi_kasus" + '
#   '0.007*"teknologi_informasi" + 0.006*"sistem" + 0.005*"akademik" + '
#   '0.005*"process" + 0.005*"bandar_lampung"'),
#  (1,
#   '0.013*"rancang_bangun" + 0.010*"sistem_informasi" + 0.008*"sms_gateway" + '
#   '0.008*"k_nearest" + 0.008*"web_service" + 0.007*"k_means" + '
#   '0.007*"studi_kasus" + 0.005*"fakultas_teknik" + 0.005*"arduino_uno" + '
#   '0.005*"penjualan_barang"'),
#  (2,
#   '0.009*"mata_kuliah" + 0.008*"metode_weighted" + 0.008*"pengolahan_citra" + '
#   '0.008*"tugas_akhir" + 0.006*"kriptografi" + 0.006*"learning_vector" + '
#   '0.005*"algoritma" + 0.005*"algoritma_k" + 0.005*"support_vector" + '
#   '0.005*"pengamanan_pesan"'),
#  (3,
#   '0.009*"jaringan_syaraf" + 0.009*"forward_chaining" + 0.008*"sepeda_motor" + '
#   '0.007*"rekayasa_perangkat" + 0.006*"citra_digital" + '
#   '0.006*"kinerja_karyawan" + 0.006*"sistem_informasi" + '
#   '0.006*"kota_palembang" + 0.005*"diagnosis_penyakit" + '
#   '0.005*"pengenalan_wajah"'),
#  (4,
#   '0.017*"rancang_bangun" + 0.017*"sistem_informasi" + 0.008*"sumber_daya" + '
#   '0.007*"sma_negeri" + 0.007*"universitas_negeri" + 0.007*"studi_kasus" + '
#   '0.006*"bangun" + 0.006*"rancang" + 0.006*"informasi" + '
#   '0.005*"penilaian_kinerja"'),
#  (5,
#   '0.017*"diagnosa_penyakit" + 0.016*"sistem_pakar" + 0.015*"e_commerce" + '
#   '0.012*"rancang_bangun" + 0.011*"analisa_perancangan" + '
#   '0.010*"sistem_informasi" + 0.007*"diagnosa" + 0.007*"pakar" + '
#   '0.007*"penyakit" + 0.007*"sistem_pakar_diagnosa_penyakit"'),
#  (6,
#   '0.013*"augmented_reality" + 0.009*"sistem_informasi" + '
#   '0.009*"perguruan_tinggi" + 0.007*"rekam_medis" + 0.006*"fuzzy_tsukamoto" + '
#   '0.005*"case_reasoning" + 0.005*"pemanfaatan_teknologi" + 0.004*"persamaan" '
#   '+ 0.004*"deteksi_dini" + 0.004*"augmented"'),
#  (7,
#   '0.022*"metode_forward" + 0.016*"sistem_pendukung" + '
#   '0.014*"keputusan_pemilihan" + 0.011*"sistem_pakar" + '
#   '0.009*"sistem_informasi" + 0.008*"rancang_bangun" + 0.008*"studi_kasus" + '
#   '0.008*"chaining" + 0.007*"pendukung" + 0.007*"forward"'),
#  (8,
#   '0.016*"sistem_informasi" + 0.010*"pengolahan_data" + 0.008*"rumah_sakit" + '
#   '0.008*"rawat_jalan" + 0.007*"studi_kasus" + 0.007*"sistem_pendukung" + '
#   '0.007*"smp_negeri" + 0.006*"metode_topsis" + 0.006*"informasi" + '
#   '0.005*"penunjang_keputusan"'),
#  (9,
#   '0.014*"metode_certainty" + 0.009*"perangkat_lunak" + '
#   '0.007*"sistem_informasi" + 0.007*"sistem_pakar" + 0.006*"terbaik" + '
#   '0.006*"mobile_learning" + 0.006*"unified_modeling" + 0.006*"rancang_bangun" '
#   '+ 0.006*"simpan_pinjam" + 0.005*"sistem_monitoring"'),
#  (10,
#   '0.015*"object_oriented" + 0.012*"raspberry_pi" + 0.010*"naive_bayes" + '
#   '0.008*"sistem_informasi" + 0.006*"object" + 0.006*"internet_things" + '
#   '0.005*"multimedia_interaktif" + 0.005*"penyakit_tanaman" + '
#   '0.005*"jaringan_komputer" + 0.005*"naïve_bayes"'),
#  (11,
#   '0.014*"sistem_pendukung" + 0.012*"pengembangan_media" + '
#   '0.012*"metode_simple" + 0.010*"additive_weighting" + 0.008*"data_mining" + '
#   '0.008*"matriks" + 0.007*"pengadaan_barang" + 0.007*"simple" + '
#   '0.007*"additive" + 0.006*"e_learning"'),
#  (12,
#   '0.013*"sistem_pendukung" + 0.012*"mata_pelajaran" + 0.010*"berorientasi" + '
#   '0.007*"logika_fuzzy" + 0.007*"keputusan_penerimaan" + 0.007*"fuzzy_logic" + '
#   '0.007*"menerapkan_metode" + 0.007*"hasil_belajar" + '
#   '0.007*"keputusan_penentuan" + 0.006*"kelas_x"'),
#  (13,
#   '0.011*"sistem_informasi" + 0.010*"metode_dempster" + 0.009*"sekolah_dasar" '
#   '+ 0.008*"sistem_pakar" + 0.007*"pengambilan_keputusan" + '
#   '0.007*"backward_chaining" + 0.007*"mendiagnosa_penyakit" + '
#   '0.006*"rancang_bangun" + 0.005*"aplikasi_kamus" + 0.005*"vigenere_cipher"')]

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=14)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.012*"perangkat_lunak" + 0.011*"mata_pelajaran" + 0.010*"pengembangan_media" + 0.008*"smk_negeri" + 0.008*"pengadaan_barang" + 0.007*"hasil_belajar" + 0.007*"perangkat" + 0.006*"analisa_perancangan" + 0.006*"rekayasa_perangkat" + 0.006*"pembelajaran"
# Topic: 1 Word: 0.030*"sistem_informasi" + 0.017*"rancang_bangun" + 0.014*"studi_kasus" + 0.010*"informasi" + 0.009*"program_studi" + 0.006*"studi" + 0.006*"information_system" + 0.006*"sistem" + 0.006*"penjualan_pembelian" + 0.006*"web"
# Topic: 2 Word: 0.018*"sistem_informasi" + 0.010*"naive_bayes" + 0.007*"smp_negeri" + 0.006*"informasi" + 0.006*"sistem" + 0.006*"unified_modeling" + 0.005*"penerimaan_siswa" + 0.005*"case_reasoning" + 0.005*"diagnosa_kerusakan" + 0.005*"arduino_uno"
# Topic: 3 Word: 0.014*"metode_simple" + 0.013*"sistem_pendukung" + 0.011*"additive_weighting" + 0.008*"simple" + 0.008*"additive" + 0.007*"weighting" + 0.005*"jaya" + 0.005*"pendukung" + 0.005*"metode_simple_additive_weighting" + 0.005*"keputusan"
# Topic: 4 Word: 0.029*"sistem_informasi" + 0.017*"metodologi_berorientasi" + 0.011*"augmented_reality" + 0.009*"informasi" + 0.008*"rancang_bangun" + 0.008*"mata_kuliah" + 0.008*"e_commerce" + 0.007*"studi_kasus" + 0.007*"matriks" + 0.007*"metodologi"
# Topic: 5 Word: 0.028*"sistem_pakar" + 0.026*"metode_forward" + 0.017*"diagnosa_penyakit" + 0.011*"pakar" + 0.010*"chaining" + 0.009*"forward" + 0.009*"diagnosa" + 0.008*"penyakit" + 0.007*"sistem_pakar_diagnosa_penyakit" + 0.006*"metode"
# Topic: 6 Word: 0.009*"media_pembelajaran" + 0.008*"e_learning" + 0.008*"multimedia_interaktif" + 0.006*"platform_android" + 0.006*"multimedia" + 0.005*"rawat" + 0.005*"convolutional_neural" + 0.004*"jalan" + 0.004*"learning" + 0.004*"pengendali"
# Topic: 7 Word: 0.012*"raspberry_pi" + 0.010*"metode_topsis" + 0.010*"sistem_pendukung" + 0.009*"perguruan_tinggi" + 0.008*"rancang_bangun" + 0.007*"fuzzy_logic" + 0.006*"logika_fuzzy" + 0.006*"terbaik" + 0.006*"internet_things" + 0.005*"support_vector"
# Topic: 8 Word: 0.019*"metode_certainty" + 0.015*"sistem_pakar" + 0.008*"mendiagnosa_penyakit" + 0.008*"sistem_informasi" + 0.007*"sepeda_motor" + 0.007*"factor" + 0.007*"certainty" + 0.007*"sma_negeri" + 0.006*"pakar" + 0.006*"penyakit_tanaman"
# Topic: 9 Word: 0.017*"sistem_informasi" + 0.014*"rancang_bangun" + 0.009*"rumah_sakit" + 0.009*"pengolahan_data" + 0.009*"metode_waterfall" + 0.009*"studi_kasus" + 0.008*"rawat_jalan" + 0.008*"sms_gateway" + 0.007*"rekam_medis" + 0.006*"teorema_bayes"
# Topic: 10 Word: 0.020*"sistem_pendukung" + 0.016*"keputusan_pemilihan" + 0.010*"studi_kasus" + 0.010*"keputusan" + 0.009*"pendukung" + 0.008*"sistem_pendukung_keputusan_pemilihan" + 0.008*"menerapkan_metode" + 0.008*"pemilihan" + 0.007*"sekolah_dasar" + 0.007*"metode_weighted"
# Topic: 11 Word: 0.010*"metode_dempster" + 0.010*"expert_system" + 0.009*"sistem_informasi" + 0.008*"process" + 0.007*"sekolah_menengah" + 0.007*"location_service" + 0.006*"sistem_pendukung" + 0.006*"bandar_lampung" + 0.005*"sistem_pakar" + 0.005*"persediaan_barang"
# Topic: 12 Word: 0.016*"object_oriented" + 0.010*"berorientasi" + 0.008*"forward_chaining" + 0.008*"citra_digital" + 0.007*"object" + 0.005*"file" + 0.005*"matlab" + 0.005*"provinsi_riau" + 0.005*"sistem_informasi" + 0.005*"oriented"
# Topic: 13 Word: 0.008*"k_nearest" + 0.007*"keputusan_penerimaan" + 0.007*"k_means" + 0.006*"metode_profile" + 0.006*"sistem_informasi" + 0.006*"kriptografi" + 0.005*"sistem_pendukung" + 0.005*"penjualan_barang" + 0.005*"studi_kasus" + 0.004*"k"

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)
# Out:
#      No_Dokumen  Topik_Dominan  Persentase_Kontribusi  \
# 0             0            3.0                 0.4883
# 1             1           12.0                 0.8361
# 2             2            4.0                 0.6642
# 3             3           13.0                 0.7813
# 4             4            4.0                 0.5349
# 5             5            8.0                 0.7316
# 6             6            5.0                 0.3185
# 7             7           13.0                 0.5063
# 8             8            7.0                 0.8673
# 9             9            6.0                 0.9226
# 10           10            3.0                 0.4487
# 11           11           13.0                 0.3051
# 12           12            7.0                 0.5395
# 13           13           12.0                 0.3464
# 14           14           11.0                 0.3663
# 15           15            7.0                 0.5041
# 16           16            3.0                 0.6050
# 17           17           13.0                 0.4896
# 18           18           10.0                 0.8438
# 19           19            7.0                 0.5034
# 20           20           12.0                 0.6058
# 21           21           11.0                 0.5539
# 22           22           11.0                 0.5540
# 23           23           12.0                 0.8143
# 24           24            5.0                 0.9286
# 25           25            8.0                 0.7620
# 26           26            0.0                 0.8033
# 27           27            3.0                 0.7683
# 28           28            5.0                 0.4593
# 29           29            5.0                 0.8839
# ..          ...            ...                    ...
# 217         217           11.0                 0.8673
# 218         218            4.0                 0.5468
# 219         219            6.0                 0.9484
# 220         220            0.0                 0.6776
# 221         221           10.0                 0.7412
# 222         222            2.0                 0.5213
# 223         223           13.0                 0.6824
# 224         224            4.0                 0.5876
# 225         225            4.0                 0.4696
# 226         226            1.0                 0.4594
# 227         227            9.0                 0.7385
# 228         228            4.0                 0.6475
# 229         229            7.0                 0.4587
# 230         230           10.0                 0.5479
# 231         231            0.0                 0.6695
# 232         232            6.0                 0.5072
# 233         233            1.0                 0.5324
# 234         234            9.0                 0.6968
# 235         235           10.0                 0.4618
# 236         236            3.0                 0.5207
# 237         237            1.0                 0.8689
# 238         238           10.0                 0.5247
# 239         239           10.0                 0.9668
# 240         240           13.0                 0.8585
# 241         241           10.0                 0.6504
# 242         242            7.0                 0.5476
# 243         243            5.0                 0.4059
# 244         244            0.0                 0.5016
# 245         245            4.0                 0.4768
# 246         246            9.0                 0.8397
#
#                                             Kata_Kunci  \
# 0    metode_simple, sistem_pendukung, additive_weig...
# 1    object_oriented, berorientasi, forward_chainin...
# 2    sistem_informasi, metodologi_berorientasi, aug...
# 3    k_nearest, keputusan_penerimaan, k_means, meto...
# 4    sistem_informasi, metodologi_berorientasi, aug...
# 5    metode_certainty, sistem_pakar, mendiagnosa_pe...
# 6    sistem_pakar, metode_forward, diagnosa_penyaki...
# 7    k_nearest, keputusan_penerimaan, k_means, meto...
# 8    raspberry_pi, metode_topsis, sistem_pendukung,...
# 9    media_pembelajaran, e_learning, multimedia_int...
# 10   metode_simple, sistem_pendukung, additive_weig...
# 11   k_nearest, keputusan_penerimaan, k_means, meto...
# 12   raspberry_pi, metode_topsis, sistem_pendukung,...
# 13   object_oriented, berorientasi, forward_chainin...
# 14   metode_dempster, expert_system, sistem_informa...
# 15   raspberry_pi, metode_topsis, sistem_pendukung,...
# 16   metode_simple, sistem_pendukung, additive_weig...
# 17   k_nearest, keputusan_penerimaan, k_means, meto...
# 18   sistem_pendukung, keputusan_pemilihan, studi_k...
# 19   raspberry_pi, metode_topsis, sistem_pendukung,...
# 20   object_oriented, berorientasi, forward_chainin...
# 21   metode_dempster, expert_system, sistem_informa...
# 22   metode_dempster, expert_system, sistem_informa...
# 23   object_oriented, berorientasi, forward_chainin...
# 24   sistem_pakar, metode_forward, diagnosa_penyaki...
# 25   metode_certainty, sistem_pakar, mendiagnosa_pe...
# 26   perangkat_lunak, mata_pelajaran, pengembangan_...
# 27   metode_simple, sistem_pendukung, additive_weig...
# 28   sistem_pakar, metode_forward, diagnosa_penyaki...
# 29   sistem_pakar, metode_forward, diagnosa_penyaki...
# ..                                                 ...
# 217  metode_dempster, expert_system, sistem_informa...
# 218  sistem_informasi, metodologi_berorientasi, aug...
# 219  media_pembelajaran, e_learning, multimedia_int...
# 220  perangkat_lunak, mata_pelajaran, pengembangan_...
# 221  sistem_pendukung, keputusan_pemilihan, studi_k...
# 222  sistem_informasi, naive_bayes, smp_negeri, inf...
# 223  k_nearest, keputusan_penerimaan, k_means, meto...
# 224  sistem_informasi, metodologi_berorientasi, aug...
# 225  sistem_informasi, metodologi_berorientasi, aug...
# 226  sistem_informasi, rancang_bangun, studi_kasus,...
# 227  sistem_informasi, rancang_bangun, rumah_sakit,...
# 228  sistem_informasi, metodologi_berorientasi, aug...
# 229  raspberry_pi, metode_topsis, sistem_pendukung,...
# 230  sistem_pendukung, keputusan_pemilihan, studi_k...
# 231  perangkat_lunak, mata_pelajaran, pengembangan_...
# 232  media_pembelajaran, e_learning, multimedia_int...
# 233  sistem_informasi, rancang_bangun, studi_kasus,...
# 234  sistem_informasi, rancang_bangun, rumah_sakit,...
# 235  sistem_pendukung, keputusan_pemilihan, studi_k...
# 236  metode_simple, sistem_pendukung, additive_weig...
# 237  sistem_informasi, rancang_bangun, studi_kasus,...
# 238  sistem_pendukung, keputusan_pemilihan, studi_k...
# 239  sistem_pendukung, keputusan_pemilihan, studi_k...
# 240  k_nearest, keputusan_penerimaan, k_means, meto...
# 241  sistem_pendukung, keputusan_pemilihan, studi_k...
# 242  raspberry_pi, metode_topsis, sistem_pendukung,...
# 243  sistem_pakar, metode_forward, diagnosa_penyaki...
# 244  perangkat_lunak, mata_pelajaran, pengembangan_...
# 245  sistem_informasi, metodologi_berorientasi, aug...
# 246  sistem_informasi, rancang_bangun, rumah_sakit,...
#
#                                                   Teks
# 0    [pendeteksi, gangguan, jaringan, lokal, metode...
# 1    [eksistensi, penggunaan, wi, fi, warung, kopi,...
# 2    [pengaruh, internet, financial, reporting, tin...
# 3    [security, function, analysis, performance, hi...
# 4    [implementation, top, down, approach, method, ...
# 5    [optimization, wireless, network, performance,...
# 6    [analysis, qos, vlan, djikstra, s, algorithm, ...
# 7    [link, performance, improvement, sananibun, bt...
# 8    [legal, protection, efforts, patent, holders, ...
# 9    [use, e, learning, by, teachers, teaching, lea...
# 10   [definition, patent, rights, examples, case, s...
# 11   [analysis, implementation, backup, line, netwo...
# 12   [classification, principles, legal, basis, int...
# 13   [attendance, system, automatic, door, locks, l...
# 14   [registration, requirements, application, rights]
# 15   [patentability, block, chain, technology, futu...
# 16   [influence, speed, user, mobility, qos, wirele...
# 17   [4, ghz, omnidirectional, antenna, design, wit...
# 18   [pemanfaatan, telepon, pintar, informasi, peny...
# 19   [aplikasi, teknologi, komunikasi, wireless, zi...
# 20   [forensics, analysis, router, computer, networ...
# 21   [manajemen, proyeksi, sistem, informasi, manaj...
# 22   [manajemen, proyeksi, sistem, informasi, manaj...
# 23            [tri, destanto, 175100067p, sectionquis]
# 24   [rancang, bangun, aplikasi, chatting, web, doc...
# 25   [multimedia, animated, corrosion, corrosion, c...
# 26   [quality, service, traffic, monitoring, system...
# 27   [analisis, topologi, area, jaringan, komputer,...
# 28   [resume, pembuatan, tugas, jaringan, komputer,...
# 29   [perkembangan, jaringan, komputer, indonesia, ...
# ..                                                 ...
# 217  [implementasi, captive, portal, pfsense, capti...
# 218  [aspek, hukum, pelayan, publik, online, direkt...
# 219  [steganografi, citra, digital, menyembunyikan,...
# 220  [analisis, faktor, minat, siswa, memilih, juru...
# 221  [managed, service, network, management, system...
# 222  [kebijakan, kriminal, pemerintah, kejahatan, d...
# 223  [pengembangan, aplikasi, e, commerce, pendekat...
# 224  [konsep, pengembangan, sistem, informasi, moni...
# 225  [tugas, akhir, jurnal, tata, kelola, sistem, t...
# 226  [e, commerce, media, promosi, pemasaran, decou...
# 227  [failover, gateway, protokol, virtual, router,...
# 228  [sistem, informasi, administrasi, data, kemaha...
# 229  [analisis, perbandingan, detection, traffic, a...
# 230  [sistem, pendukung, keputusan, pemilihan, pemi...
# 231  [pengaruh, media, packet, tracer, kreativitas,...
# 232  [multimedia, edukasi, interaktif, pelajaran, b...
# 233  [aplikasi, sistem, penyidikan, client, server,...
# 234  [tindak, pidana, dunia, maya, berupa, virus, t...
# 235  [analisis, pengaruh, manfaat, risiko, kepercay...
# 236  [pengaruh, perceived, value, repurchase, inten...
# 237  [cooperative, accounting, computer, applicatio...
# 238  [membangun, rencana, strategis, sistem, inform...
# 239  [perancangan, sistem, pendukung, keputusan, pe...
# 240  [pengamanan, data, aplikasi, sijalu, universit...
# 241  [implementation, pptp, bcp, with, inter, vlan,...
# 242  [analisis, yuridis, penyelesaian, sengketa, cy...
# 243  [smart, campus, model, baru, enterprise, archi...
# 244  [analisis, hubungan, antara, daring, revolusi,...
# 245  [akad, jual, beli, online, perspektif, hukum, ...
# 246  [analisis, akad, undang, undang, nomor, tahun,...
#
# [247 rows x 5 columns]

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics
# Out:
# 1.0     1979
# 5.0     1669
# 4.0     1520
# 10.0    1513
# 8.0     1216
# 7.0     1215
# 3.0     1205
# 0.0     1184
# 9.0     1146
# 2.0     1094
# 13.0    1061
# 12.0     911
# 11.0     802
# 6.0      736
# Name: Topik_Dominan, dtype: int64

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')
# Out:
# Text(0.5,1,'Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.9735
# 1         1.0              0.9668
# 2         2.0              0.9643
# 3         3.0              0.9656
# 4         4.0              0.9613
# 5         5.0              0.9613
# 6         6.0              0.9558
# 7         7.0              0.9668
# 8         8.0              0.9656
# 9         9.0              0.9690
# 10       10.0              0.9668
# 11       11.0              0.9381
# 12       12.0              0.9596
# 13       13.0              0.9596
#
#                                                                                                Keywords  \
# 0   perangkat_lunak, mata_pelajaran, pengembangan_media, smk_negeri, pengadaan_barang, hasil_belajar...
# 1   sistem_informasi, rancang_bangun, studi_kasus, informasi, program_studi, studi, information_syst...
# 2   sistem_informasi, naive_bayes, smp_negeri, informasi, sistem, unified_modeling, penerimaan_siswa...
# 3   metode_simple, sistem_pendukung, additive_weighting, simple, additive, weighting, jaya, pendukun...
# 4   sistem_informasi, metodologi_berorientasi, augmented_reality, informasi, rancang_bangun, mata_ku...
# 5   sistem_pakar, metode_forward, diagnosa_penyakit, pakar, chaining, forward, diagnosa, penyakit, s...
# 6   media_pembelajaran, e_learning, multimedia_interaktif, platform_android, multimedia, rawat, conv...
# 7   raspberry_pi, metode_topsis, sistem_pendukung, perguruan_tinggi, rancang_bangun, fuzzy_logic, lo...
# 8   metode_certainty, sistem_pakar, mendiagnosa_penyakit, sistem_informasi, sepeda_motor, factor, ce...
# 9   sistem_informasi, rancang_bangun, rumah_sakit, pengolahan_data, metode_waterfall, studi_kasus, r...
# 10  sistem_pendukung, keputusan_pemilihan, studi_kasus, keputusan, pendukung, sistem_pendukung_keput...
# 11  metode_dempster, expert_system, sistem_informasi, process, sekolah_menengah, location_service, s...
# 12  object_oriented, berorientasi, forward_chaining, citra_digital, object, file, matlab, provinsi_r...
# 13  k_nearest, keputusan_penerimaan, k_means, metode_profile, sistem_informasi, kriptografi, sistem_...
#
#                                                                                     Representative Text
# 0   [pengembangan, media, pembelajaran, video, tutorial, mata, pelajaran, dasar, desain, grafis, kel...
# 1   [rancang, bangun, sistem, informasi, penjualan, pembelian, client, server, studi, kasus, toko, u...
# 2   [model, inovasi, pemerintah, daerah, bidang, pelayanan, perizinan, mewujudkan, smart, city, stud...
# 3   [prototipe, penilaian, kinerja, tenaga, ahli, inacon, luhur, pertiwi, pendekatan, adaptive, neur...
# 4   [implementasi, konsep, business, customer, teknologi, e, commerce, web, studi, kasus, toko, sepa...
# 5   [rancang, bangun, aplikasi, sistem, pakar, diagnosa, penyakit, anemia, metode, forward, chaining...
# 6   [steganografi, citra, metode, least, significant, bit, lsb, linear, congruential, generator, lcg...
# 7   [inisiasi, natural, language, processing, nlp, klasifikasi, jenis, wisata, kuliner, program, cha...
# 8   [analisis, load, balancing, jaringan, software, defined, network, sdn, algoritma, jaringan, syar...
# 9   [rancang, bangun, sistem, informasi, rumah, sakit, web, studi, kasus, rumah, sakit, az, zahra, u...
# 10  [perancangan, sistem, pendukung, keputusan, pemilihan, dosen, pembimbing, skripsi, minat, mahasi...
# 11  [sistem, informasi, persediaan, barang, toko, mainan, nanda, toys, bekasi, sistem_informasi, per...
# 12  [analisis, plasmodium, malaria, sel, darah, merah, eritrosit, melalui, segmentasi, warna, deteks...
# 13  [analisis, metode, additive, ratio, assessment, aras, pemberian, insentif, sales, penjualan, gun...

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-range2.html')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 1      0.122259 -0.060755       1        1  8.073014
# 10    -0.056064 -0.143814       2        1  7.973396
# 5     -0.095102  0.149556       3        1  7.905050
# 4      0.171995  0.017841       4        1  7.505055
# 7     -0.042273 -0.088365       5        1  7.493623
# 3     -0.129208 -0.065310       6        1  7.456208
# 8      0.000133  0.111455       7        1  7.413787
# 13    -0.017263 -0.023533       8        1  7.166375
# 2      0.034449 -0.073586       9        1  7.053042
# 0      0.081853  0.055031      10        1  6.986468
# 9      0.088485  0.013389      11        1  6.872033
# 12    -0.072321  0.052499      12        1  6.629054
# 11    -0.057190 -0.008054      13        1  6.043212
# 6     -0.029752  0.063647      14        1  5.429684, topic_info=     Category        Freq                     Term       Total  loglift  \
# term
# 4046  Default  107.000000           metode_forward  107.000000  30.0000
# 856   Default  215.000000             sistem_pakar  215.000000  29.0000
# 193   Default  507.000000         sistem_informasi  507.000000  28.0000
# 7     Default   74.000000         metode_certainty   74.000000  27.0000
# 715   Default  232.000000         sistem_pendukung  232.000000  26.0000
# 9262  Default   68.000000  metodologi_berorientasi   68.000000  25.0000
# 3968  Default   69.000000        diagnosa_penyakit   69.000000  24.0000
# 1660  Default   55.000000          object_oriented   55.000000  23.0000
# 1153  Default   90.000000      keputusan_pemilihan   90.000000  22.0000
# 1793  Default   59.000000            metode_simple   59.000000  21.0000
# 605   Default   48.000000             raspberry_pi   48.000000  20.0000
# 255   Default   43.000000        augmented_reality   43.000000  19.0000
# 4762  Default   43.000000       additive_weighting   43.000000  18.0000
# 2939  Default   44.000000          perangkat_lunak   44.000000  17.0000
# 594   Default   41.000000           mata_pelajaran   41.000000  16.0000
# 203   Default  259.000000           rancang_bangun  259.000000  15.0000
# 855   Default   86.000000                    pakar   86.000000  14.0000
# 258   Default   55.000000       media_pembelajaran   55.000000  13.0000
# 1147  Default   36.000000              naive_bayes   36.000000  12.0000
# 3966  Default   46.000000                 chaining   46.000000  11.0000
# 2223  Default   33.000000             berorientasi   33.000000  10.0000
# 6693  Default   48.000000            metode_topsis   48.000000   9.0000
# 2653  Default   42.000000                  forward   42.000000   8.0000
# 422   Default   46.000000       pengembangan_media   46.000000   7.0000
# 961   Default   32.000000              rumah_sakit   32.000000   6.0000
# 1309  Default   34.000000         perguruan_tinggi   34.000000   5.0000
# 4904  Default   29.000000            expert_system   29.000000   4.0000
# 4404  Default   30.000000          metode_dempster   30.000000   3.0000
# 651   Default   36.000000          pengolahan_data   36.000000   2.0000
# 3967  Default   46.000000                 diagnosa   46.000000   1.0000
# ...       ...         ...                      ...         ...      ...
# 1100  Topic14    6.213049       steganografi_citra    6.934083   2.8035
# 5717  Topic14    5.819756      linear_congruential    6.500034   2.8027
# 5206  Topic14    5.889059                     lalu    6.586000   2.8014
# 1903  Topic14    6.850083          framework_cobit    7.663150   2.8011
# 3853  Topic14    5.697453                     sari    6.377744   2.8005
# 1836  Topic14    5.469370                pengajuan    6.149658   2.7961
# 3496  Topic14    6.243534                   rakyat    7.053441   2.7913
# 5166  Topic14    5.217743       perbaikan_kualitas    5.914631   2.7879
# 8148  Topic14    5.057833             menu_makanan    5.738871   2.7870
# 4589  Topic14    5.933923                paru_paru    6.737878   2.7862
# 6789  Topic14    7.421709          pembelian_bahan    8.429658   2.7859
# 5207  Topic14    7.022620                   lintas    8.031834   2.7790
# 2261  Topic14    6.389892     transaksi_elektronik    7.316092   2.7779
# 1099  Topic14    9.921538             steganografi   11.779836   2.7416
# 9061  Topic14   11.409229               pengendali   14.593727   2.6671
# 210   Topic14   15.474035               multimedia   22.881285   2.5221
# 90    Topic14   22.232304               e_learning   37.046326   2.4027
# 3960  Topic14    9.061091                permainan   11.765126   2.6521
# 46    Topic14    9.390389           implementation   12.401531   2.6352
# 3736  Topic14   11.851294                    jalan   17.431992   2.5274
# 258   Topic14   24.549063       media_pembelajaran   55.371681   2.0999
# 9116  Topic14    8.774318             game_edukasi   11.757324   2.6206
# 419   Topic14   10.718696               interaktif   16.189108   2.5009
# 490   Topic14   10.384398                     game   18.852575   2.3169
# 3626  Topic14   11.138669                   linear   25.805902   2.0731
# 91    Topic14   11.497116                 learning   39.969727   1.6673
# 259   Topic14   11.030375             pembelajaran   59.814995   1.2227
# 335   Topic14    7.673164                 serangan   13.039713   2.3830
# 688   Topic14    9.528331                  android  128.897552   0.3085
# 176   Topic14    9.598601                 aplikasi  161.754059   0.0888
#
#       logprob
# term
# 4046  30.0000
# 856   29.0000
# 193   28.0000
# 7     27.0000
# 715   26.0000
# 9262  25.0000
# 3968  24.0000
# 1660  23.0000
# 1153  22.0000
# 1793  21.0000
# 605   20.0000
# 255   19.0000
# 4762  18.0000
# 2939  17.0000
# 594   16.0000
# 203   15.0000
# 855   14.0000
# 258   13.0000
# 1147  12.0000
# 3966  11.0000
# 2223  10.0000
# 6693   9.0000
# 2653   8.0000
# 422    7.0000
# 961    6.0000
# 1309   5.0000
# 4904   4.0000
# 4404   3.0000
# 651    2.0000
# 3967   1.0000
# ...       ...
# 1100  -6.0824
# 5717  -6.1477
# 5206  -6.1359
# 1903  -5.9847
# 3853  -6.1690
# 1836  -6.2098
# 3496  -6.0775
# 5166  -6.2569
# 8148  -6.2881
# 4589  -6.1283
# 6789  -5.9046
# 5207  -5.9599
# 2261  -6.0543
# 1099  -5.6143
# 9061  -5.4746
# 210   -5.1698
# 90    -4.8075
# 3960  -5.7050
# 46    -5.6693
# 3736  -5.4366
# 258   -4.7083
# 9116  -5.7372
# 419   -5.5370
# 490   -5.5687
# 3626  -5.4986
# 91    -5.4669
# 259   -5.5084
# 335   -5.8713
# 688   -5.6547
# 176   -5.6474
#
# [733 rows x 6 columns], token_table=       Topic      Freq                 Term
# term
# 3904       6  0.946478             additive
# 3904       8  0.032637             additive
# 4762       6  0.960064   additive_weighting
# 4762      12  0.022859   additive_weighting
# 1043       4  0.513836         administrasi
# 1043       5  0.274046         administrasi
# 1043       6  0.068512         administrasi
# 1043       8  0.137023         administrasi
# 9536      14  0.920589  advanced_encryption
# 1196       1  0.034569                  ahp
# 1196       2  0.691387                  ahp
# 1196       3  0.034569                  ahp
# 1196       5  0.034569                  ahp
# 1196       9  0.207416                  ahp
# 4803       9  0.909993           ahp_topsis
# 1187       1  0.678342            akuntansi
# 1187       4  0.193812            akuntansi
# 1187       7  0.096906            akuntansi
# 1187       8  0.048453            akuntansi
# 1187      12  0.048453            akuntansi
# 3638      12  0.882203           alat_bantu
# 13458     13  0.889235           alat_berat
# 6024      11  0.933587           alat_musik
# 2623       7  0.917144      alat_pendeteksi
# 9934       1  0.968577           alat_tulis
# 6282      11  0.968858            alat_ukur
# 266        2  0.067542            algoritma
# 266        3  0.189118            algoritma
# 266        5  0.040525            algoritma
# 266        6  0.108068            algoritma
# ...      ...       ...                  ...
# 3643       9  0.956611      virtual_reality
# 3125       4  0.931909         visual_basic
# 463       11  0.940993            waterfall
# 204        1  0.166157                  web
# 204        2  0.057794                  web
# 204        3  0.072242                  web
# 204        4  0.130036                  web
# 204        5  0.050570                  web
# 204        6  0.021673                  web
# 204        7  0.093915                  web
# 204        8  0.043345                  web
# 204        9  0.108363                  web
# 204       10  0.057794                  web
# 204       11  0.108363                  web
# 204       12  0.014448                  web
# 204       13  0.050570                  web
# 204       14  0.021673                  web
# 2114       4  0.964153              web_php
# 969        2  0.991111          web_service
# 7118       4  0.958036    wedding_organizer
# 7813       5  0.900293       weight_product
# 5127       2  0.972230             weighted
# 7627       2  0.911087     weighted_product
# 3161       5  0.037413            weighting
# 3161       6  0.935313            weighting
# 4216       5  0.886755       wisata_kuliner
# 7086      11  0.971234           work_order
# 2299      11  0.950659                  xyz
# 2082       3  0.084453           yogyakarta
# 2082      12  0.844531           yogyakarta
#
# [1379 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 11, 6, 5, 8, 4, 9, 14, 3, 1, 10, 13, 12, 7])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model-range2.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned2010.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                    text
# 0       cara mudah membangun jaringan komputer internet
# 1                              jaringan komputer tcp ip
# 2     parallel programming teknik aplikasi jaringan ...
# 3                      tip jitu optimasi jaringan wi fi
# 4     pengembangan media pembelajaran teknologi info...
# 5     autentikasi kendali akses audit sistem keamana...
# 6                          cisco ccna jaringan komputer
# 7     koneksi jaringan antar sekolah teknologi wireless
# 8     analisis tingkat penggunaan internet dikalanga...
# 9     implementasi intrusion detection system ids sn...
# 10    rancang bangun analisa qos audio video streami...
# 11          analisa qos jaringan mpls ipv6 routing ospf
# 12    monitoring sistem kerja pengembangan jaringan ...
# 13    langsung praktik mengelola jaringan lebih efek...
# 14    studi implementasi voip sip jaringan kampus un...
# 15      cara mudah membangun jaringan komputer internet
# 16                  desain standar perpustakaan digital
# 17                   panduan praktis menguasai komputer
# 18    merakit sendiri komputer tahan banting modal j...
# 19    analisis perancangan sistem komputerisasi jari...
# 20    optimasi routing pengaturan route advertisemen...
# 21    perancangan sistem keamanan jaringan komputer ...
# 22                      sistem jaringan komputer pemula
# 23         bahasa pemrograman python platform gnu linux
# 24                   optimasi bandwith traffic shapping
# 25    rancang bangun sistem pencegahan data flooding...
# 26      cara mudah membangun jaringan komputer internet
# 27    cara jitu pengelolaan jaringan windows remote ...
# 28     membangun software monitoring jaringan sms alert
# 29    implementasi sistem autentikasi jaringan hotsp...
# ...                                                 ...
# 4881  fuzzy logic diagnosis tata laksana penyakit de...
# 4882  pengaruh model problem learning pbl hasil bela...
# 4883  pengaruh pertisipasi anggaran kinerja manajeri...
# 4884  adopsi e commerce pendekatan technology accept...
# 4885  advertising board djarum super analisis deskri...
# 4886  eksplorasi metode bar chart cpm pdm pert line ...
# 4887  sistem pendukung keputusan pemilihan supplier ...
# 4888  analisa perancangan e marketing studi kasus ba...
# 4889  analisa perancangan sistem informasi pengelola...
# 4890  e learning penunjang pembelajaran konvensional...
# 4891  sistem informasi monitoring korosi pipa minyak...
# 4892  pengaruh faktor demografi personality stres ke...
# 4893  pembuatan aplikasi digital library studi kasus...
# 4894               sistem informasi manajemen buku ajar
# 4895  pengaruh partisipasi penganggaran kinerja apar...
# 4896  efektivitas pembelajaran kontekstual kemampuan...
# 4897  analisis efisiensi koperasi pegawai negeri rep...
# 4898  pemberdayaan sekolah menengah kejuruan smk mel...
# 4899  pelaksanaan kurikulum tingkat satuan pendidika...
# 4900  revitalisasi benteng vastenburg surakarta pusa...
# 4901  identifikasi bakat siswa sekolah dasar negeri ...
# 4902  analisisi model simple criteria optimal portof...
# 4903  pembuatan aplikasi penyebaran informasi short ...
# 4904  pembelajaran fisika masalah melalui metode pro...
# 4905  pengaruh service quality satisfaction expertis...
# 4906  pengaruh total quality management kinerja mana...
# 4907  lokalitas televisi lokal menonton orang ngapak...
# 4908  pembelajaran fisika metode demonstrasi melalui...
# 4909  analisis efisiensi bank bumn bank swasta setel...
# 4910  puppet show inovasi metode pengajaran bahasa i...
#
# [4911 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 4911
# [['cara', 'mudah', 'membangun', 'jaringan', 'komputer', 'internet']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# [['cara', 'mudah', 'membangun', 'jaringan', 'komputer', 'internet', 'cara_mudah', 'membangun_jaringan', 'cara_mudah', 'membangun_jaringan', 'cara_mudah', 'membangun_jaringan'], ['jaringan', 'komputer', 'tcp', 'ip', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['parallel', 'programming', 'teknik', 'aplikasi', 'jaringan', 'workstation', 'komputer', 'paralel'], ['tip', 'jitu', 'optimasi', 'jaringan', 'wi', 'fi'], ['pengembangan', 'media', 'pembelajaran', 'teknologi', 'informasi', 'media_pembelajaran', 'teknologi_informasi', 'media_pembelajaran', 'teknologi_informasi', 'media_pembelajaran', 'teknologi_informasi'], ['autentikasi', 'kendali', 'akses', 'audit', 'sistem', 'keamanan', 'jaringan', 'komputer', 'jaringan_komputer', 'sistem_keamanan', 'jaringan_komputer', 'jaringan_komputer'], ['cisco', 'ccna', 'jaringan', 'komputer', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['koneksi', 'jaringan', 'antar', 'sekolah', 'teknologi', 'wireless'], ['analisis', 'tingkat', 'penggunaan', 'internet', 'dikalangan', 'mahasiswa', 'hubungannya', 'peningkatan', 'nilai', 'akademik', 'studi', 'kasus', 'mahasiswa', 'kota', 'penggunaan_internet', 'studi_kasus', 'penggunaan_internet', 'studi_kasus', 'penggunaan_internet', 'studi_kasus'], ['implementasi', 'intrusion', 'detection', 'system', 'ids', 'snort', 'laboratorium', 'jaringan', 'komputer', 'lepkom', 'universitas', 'gunadarma', 'implementasi_intrusion', 'detection_system', 'jaringan_komputer', 'implementasi_intrusion', 'detection_system', 'jaringan_komputer', 'implementasi_intrusion', 'detection_system', 'jaringan_komputer'], ['rancang', 'bangun', 'analisa', 'qos', 'audio', 'video', 'streaming', 'jaringan', 'mpls', 'vpn', 'rancang_bangun', 'rancang_bangun', 'rancang_bangun'], ['analisa', 'qos', 'jaringan', 'mpls', 'ipv6', 'routing', 'ospf'], ['monitoring', 'sistem', 'kerja', 'pengembangan', 'jaringan', 'komputer', 'networking', 'rumah', 'sakit', 'dr', 'moewardi', 'residen', 'bedah', 'simulasi', 'dude', 'jaringan_komputer', 'rumah_sakit', 'jaringan_komputer', 'rumah_sakit', 'jaringan_komputer', 'rumah_sakit'], ['langsung', 'praktik', 'mengelola', 'jaringan', 'lebih', 'efektif', 'efisien', 'linux', 'fedora', 'windows', 'xp', 'windows_xp', 'windows_xp', 'windows_xp'], ['studi', 'implementasi', 'voip', 'sip', 'jaringan', 'kampus', 'universitas', 'sam', 'ratulangi'], ['cara', 'mudah', 'membangun', 'jaringan', 'komputer', 'internet', 'cara_mudah', 'membangun_jaringan', 'cara_mudah', 'membangun_jaringan', 'cara_mudah', 'membangun_jaringan'], ['desain', 'standar', 'perpustakaan', 'digital', 'perpustakaan_digital', 'perpustakaan_digital', 'perpustakaan_digital'], ['panduan', 'praktis', 'menguasai', 'komputer'], ['merakit', 'sendiri', 'komputer', 'tahan', 'banting', 'modal', 'jutaan'], ['analisis', 'perancangan', 'sistem', 'komputerisasi', 'jaringan', 'komunikasi', 'data', 'radio', 'karysma', 'fm', 'boyolali', 'analisis_perancangan', 'analisis_perancangan', 'komunikasi_data', 'analisis_perancangan'], ['optimasi', 'routing', 'pengaturan', 'route', 'advertisement', 'jaringan', 'mobile', 'ipv6'], ['perancangan', 'sistem', 'keamanan', 'jaringan', 'komputer', 'snort', 'intrussion', 'detection', 'system', 'ip', 'tables', 'firewall', 'jaringan_komputer', 'detection_system', 'sistem_keamanan', 'jaringan_komputer', 'detection_system', 'jaringan_komputer', 'detection_system'], ['sistem', 'jaringan', 'komputer', 'pemula', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['bahasa', 'pemrograman', 'python', 'platform', 'gnu', 'linux', 'bahasa_pemrograman', 'gnu_linux', 'bahasa_pemrograman', 'gnu_linux', 'bahasa_pemrograman', 'gnu_linux'], ['optimasi', 'bandwith', 'traffic', 'shapping'], ['rancang', 'bangun', 'sistem', 'pencegahan', 'data', 'flooding', 'jaringan', 'komputer', 'rancang_bangun', 'jaringan_komputer', 'rancang_bangun', 'jaringan_komputer', 'rancang_bangun', 'jaringan_komputer'], ['cara', 'mudah', 'membangun', 'jaringan', 'komputer', 'internet', 'cara_mudah', ...

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                 0             1             2              3   \
# 0             cara         mudah     membangun       jaringan
# 1         jaringan      komputer           tcp             ip
# 2         parallel   programming        teknik       aplikasi
# 3              tip          jitu      optimasi       jaringan
# 4     pengembangan         media  pembelajaran      teknologi
# 5      autentikasi       kendali         akses          audit
# 6            cisco          ccna      jaringan       komputer
# 7          koneksi      jaringan         antar        sekolah
# 8         analisis       tingkat    penggunaan       internet
# 9     implementasi     intrusion     detection         system
# 10         rancang        bangun       analisa            qos
# 11         analisa           qos      jaringan           mpls
# 12      monitoring        sistem         kerja   pengembangan
# 13        langsung       praktik     mengelola       jaringan
# 14           studi  implementasi          voip            sip
# 15            cara         mudah     membangun       jaringan
# 16          desain       standar  perpustakaan        digital
# 17         panduan       praktis     menguasai       komputer
# 18         merakit       sendiri      komputer          tahan
# 19        analisis   perancangan        sistem  komputerisasi
# 20        optimasi       routing    pengaturan          route
# 21     perancangan        sistem      keamanan       jaringan
# 22          sistem      jaringan      komputer         pemula
# 23          bahasa   pemrograman        python       platform
# 24        optimasi      bandwith       traffic       shapping
# 25         rancang        bangun        sistem     pencegahan
# 26            cara         mudah     membangun       jaringan
# 27            cara          jitu   pengelolaan       jaringan
# 28       membangun      software    monitoring       jaringan
# 29    implementasi        sistem   autentikasi       jaringan
# ...            ...           ...           ...            ...
# 4881         fuzzy         logic     diagnosis           tata
# 4882      pengaruh         model       problem       learning
# 4883      pengaruh   pertisipasi      anggaran        kinerja
# 4884        adopsi             e      commerce     pendekatan
# 4885   advertising         board        djarum          super
# 4886    eksplorasi        metode           bar          chart
# 4887        sistem     pendukung     keputusan      pemilihan
# 4888       analisa   perancangan             e      marketing
# 4889       analisa   perancangan        sistem      informasi
# 4890             e      learning     penunjang   pembelajaran
# 4891        sistem     informasi    monitoring         korosi
# 4892      pengaruh        faktor     demografi    personality
# 4893     pembuatan      aplikasi       digital        library
# 4894        sistem     informasi     manajemen           buku
# 4895      pengaruh   partisipasi  penganggaran        kinerja
# 4896   efektivitas  pembelajaran   kontekstual      kemampuan
# 4897      analisis     efisiensi      koperasi        pegawai
# 4898  pemberdayaan       sekolah      menengah       kejuruan
# 4899   pelaksanaan     kurikulum       tingkat         satuan
# 4900  revitalisasi       benteng    vastenburg      surakarta
# 4901  identifikasi         bakat         siswa        sekolah
# 4902     analisisi         model        simple       criteria
# 4903     pembuatan      aplikasi    penyebaran      informasi
# 4904  pembelajaran        fisika       masalah        melalui
# 4905      pengaruh       service       quality   satisfaction
# 4906      pengaruh         total       quality     management
# 4907     lokalitas      televisi         lokal       menonton
# 4908  pembelajaran        fisika        metode    demonstrasi
# 4909      analisis     efisiensi          bank           bumn
# 4910        puppet          show       inovasi         metode
#
#                         4                     5                     6   \
# 0                 komputer              internet            cara_mudah
# 1        jaringan_komputer     jaringan_komputer     jaringan_komputer
# 2                 jaringan           workstation              komputer
# 3                       wi                    fi                  None
# 4                informasi    media_pembelajaran   teknologi_informasi
# 5                   sistem              keamanan              jaringan
# 6        jaringan_komputer     jaringan_komputer     jaringan_komputer
# 7                teknologi              wireless                  None
# 8               dikalangan             mahasiswa           hubungannya
# 9                      ids                 snort          laboratorium
# 10                   audio                 video             streaming
# 11                    ipv6               routing                  ospf
# 12                jaringan              komputer            networking
# 13                   lebih               efektif               efisien
# 14                jaringan                kampus           universitas
# 15                komputer              internet            cara_mudah
# 16    perpustakaan_digital  perpustakaan_digital  perpustakaan_digital
# 17                    None                  None                  None
# 18                 banting                 modal                jutaan
# 19                jaringan            komunikasi                  data
# 20           advertisement              jaringan                mobile
# 21                komputer                 snort            intrussion
# 22       jaringan_komputer     jaringan_komputer     jaringan_komputer
# 23                     gnu                 linux    bahasa_pemrograman
# 24                    None                  None                  None
# 25                    data              flooding              jaringan
# 26                komputer              internet            cara_mudah
# 27                 windows                remote               desktop
# 28                     sms                 alert                  None
# 29                 hotspot           universitas               udayana
# ...                    ...                   ...                   ...
# 4881               laksana              penyakit                 demam
# 4882                   pbl                 hasil               belajar
# 4883            manajerial                  gaya          kepemimpinan
# 4884            technology            acceptance                 model
# 4885              analisis            deskriptif            kualitatif
# 4886                   cpm                   pdm                  pert
# 4887              supplier                  obat                metode
# 4888                 studi                 kasus                 bajaj
# 4889           pengelolaan                 biaya                proyek
# 4890          konvensional                 pokok               bahasan
# 4891                  pipa                minyak                   web
# 4892                 stres                 kerja            penggunaan
# 4893                 studi                 kasus          perpustakaan
# 4894                  ajar      sistem_informasi      sistem_informasi
# 4895                aparat             integrasi              variabel
# 4896         menyelesaikan                  soal               aljabar
# 4897                negeri              republik             indonesia
# 4898                   smk               melalui                   smm
# 4899            pendidikan              prestasi               belajar
# 4900                 pusat                  seni                museum
# 4901                 dasar                negeri                    se
# 4902               optimal   portofolioselection                 scops
# 4903                 short               message               service
# 4904                metode                proyek             pemberian
# 4905             expertise              costumer               loyalty
# 4906               kinerja            manajerial               empiris
# 4907                 orang                ngapak                 jogja
# 4908               melalui            pendekatan               quantum
# 4909                  bank                swasta               setelah
# 4910            pengajaran                bahasa               inggris
#
#                       7                    8                    9   ...   \
# 0     membangun_jaringan           cara_mudah   membangun_jaringan  ...
# 1                   None                 None                 None  ...
# 2                paralel                 None                 None  ...
# 3                   None                 None                 None  ...
# 4     media_pembelajaran  teknologi_informasi   media_pembelajaran  ...
# 5               komputer    jaringan_komputer      sistem_keamanan  ...
# 6                   None                 None                 None  ...
# 7                   None                 None                 None  ...
# 8            peningkatan                nilai             akademik  ...
# 9               jaringan             komputer               lepkom  ...
# 10              jaringan                 mpls                  vpn  ...
# 11                  None                 None                 None  ...
# 12                 rumah                sakit                   dr  ...
# 13                 linux               fedora              windows  ...
# 14                   sam            ratulangi                 None  ...
# 15    membangun_jaringan           cara_mudah   membangun_jaringan  ...
# 16                  None                 None                 None  ...
# 17                  None                 None                 None  ...
# 18                  None                 None                 None  ...
# 19                 radio              karysma                   fm  ...
# 20                  ipv6                 None                 None  ...
# 21             detection               system                   ip  ...
# 22                  None                 None                 None  ...
# 23             gnu_linux   bahasa_pemrograman            gnu_linux  ...
# 24                  None                 None                 None  ...
# 25              komputer       rancang_bangun    jaringan_komputer  ...
# 26    membangun_jaringan           cara_mudah   membangun_jaringan  ...
# 27        administration                 None                 None  ...
# 28                  None                 None                 None  ...
# 29                  open               source           freeradius  ...
# ...                  ...                  ...                  ...  ...
# 4881            berdarah               dengue                demam  ...
# 4882               kimia                siswa               konsep  ...
# 4883               iklim           organisasi             variabel  ...
# 4884                 tam                  ukm                studi  ...
# 4885                  tv                value          advertising  ...
# 4886                line              balance                 time  ...
# 4887             electre          elimination                   et  ...
# 4888             persada            nusantara  analisa_perancangan  ...
# 4889          konstruksi               metode                 cost  ...
# 4890             listrik              dinamis                kelas  ...
# 4891               studi                kasus              stasiun  ...
# 4892              sistem            informasi             komputer  ...
# 4893               sains            teknologi          universitas  ...
# 4894    sistem_informasi                 None                 None  ...
# 4895         intervening             variabel           moderating  ...
# 4896                soal               cerita             ditinjau  ...
# 4897           kabupaten               klaten                 None  ...
# 4898                 iso     sekolah_menengah     sekolah_menengah  ...
# 4899               siswa                  smk               negeri  ...
# 4900                seni          kontemporer                 None  ...
# 4901           kecamatan             ngemplak             boyolali  ...
# 4902         pembentukan           portofolio              optimal  ...
# 4903                 sms           lingkungan              program  ...
# 4904               tugas             ditinjau                 gaya  ...
# 4905               studi              peserta                didik  ...
# 4906             manajer           perhotelan          dipekanbaru  ...
# 4907                  tv                 None                 None  ...
# 4908         ketrampilan               proses             ditinjau  ...
# 4909              merger             tinjauan                 bank  ...
# 4910               upaya            kemampuan            berbicara  ...
#
#                  26               27           28               29  \
# 0              None             None         None             None
# 1              None             None         None             None
# 2              None             None         None             None
# 3              None             None         None             None
# 4              None             None         None             None
# 5              None             None         None             None
# 6              None             None         None             None
# 7              None             None         None             None
# 8              None             None         None             None
# 9              None             None         None             None
# 10             None             None         None             None
# 11             None             None         None             None
# 12             None             None         None             None
# 13             None             None         None             None
# 14             None             None         None             None
# 15             None             None         None             None
# 16             None             None         None             None
# 17             None             None         None             None
# 18             None             None         None             None
# 19             None             None         None             None
# 20             None             None         None             None
# 21             None             None         None             None
# 22             None             None         None             None
# 23             None             None         None             None
# 24             None             None         None             None
# 25             None             None         None             None
# 26             None             None         None             None
# 27             None             None         None             None
# 28             None             None         None             None
# 29             None             None         None             None
# ...             ...              ...          ...              ...
# 4881           None             None         None             None
# 4882           None             None         None             None
# 4883           None             None         None             None
# 4884           None             None         None             None
# 4885           None             None         None             None
# 4886           None             None         None             None
# 4887           None             None         None             None
# 4888           None             None         None             None
# 4889           None             None         None             None
# 4890           None             None         None             None
# 4891           None             None         None             None
# 4892           None             None         None             None
# 4893  negeri_syarif  digital_library  studi_kasus  sains_teknologi
# 4894           None             None         None             None
# 4895           None             None         None             None
# 4896           None             None         None             None
# 4897           None             None         None             None
# 4898           None             None         None             None
# 4899           None             None         None             None
# 4900           None             None         None             None
# 4901           None             None         None             None
# 4902           None             None         None             None
# 4903           None             None         None             None
# 4904           None             None         None             None
# 4905           None             None         None             None
# 4906           None             None         None             None
# 4907           None             None         None             None
# 4908           None             None         None             None
# 4909           None             None         None             None
# 4910           None             None         None             None
#
#                                    30                    31    32    33    34  \
# 0                                None                  None  None  None  None
# 1                                None                  None  None  None  None
# 2                                None                  None  None  None  None
# 3                                None                  None  None  None  None
# 4                                None                  None  None  None  None
# 5                                None                  None  None  None  None
# 6                                None                  None  None  None  None
# 7                                None                  None  None  None  None
# 8                                None                  None  None  None  None
# 9                                None                  None  None  None  None
# 10                               None                  None  None  None  None
# 11                               None                  None  None  None  None
# 12                               None                  None  None  None  None
# 13                               None                  None  None  None  None
# 14                               None                  None  None  None  None
# 15                               None                  None  None  None  None
# 16                               None                  None  None  None  None
# 17                               None                  None  None  None  None
# 18                               None                  None  None  None  None
# 19                               None                  None  None  None  None
# 20                               None                  None  None  None  None
# 21                               None                  None  None  None  None
# 22                               None                  None  None  None  None
# 23                               None                  None  None  None  None
# 24                               None                  None  None  None  None
# 25                               None                  None  None  None  None
# 26                               None                  None  None  None  None
# 27                               None                  None  None  None  None
# 28                               None                  None  None  None  None
# 29                               None                  None  None  None  None
# ...                               ...                   ...   ...   ...   ...
# 4881                             None                  None  None  None  None
# 4882                             None                  None  None  None  None
# 4883                             None                  None  None  None  None
# 4884                             None                  None  None  None  None
# 4885                             None                  None  None  None  None
# 4886                             None                  None  None  None  None
# 4887                             None                  None  None  None  None
# 4888                             None                  None  None  None  None
# 4889                             None                  None  None  None  None
# 4890                             None                  None  None  None  None
# 4891                             None                  None  None  None  None
# 4892                             None                  None  None  None  None
# 4893  universitas_islam_negeri_syarif  hidayatullah_jakarta  None  None  None
# 4894                             None                  None  None  None  None
# 4895                             None                  None  None  None  None
# 4896                             None                  None  None  None  None
# 4897                             None                  None  None  None  None
# 4898                             None                  None  None  None  None
# 4899                             None                  None  None  None  None
# 4900                             None                  None  None  None  None
# 4901                             None                  None  None  None  None
# 4902                             None                  None  None  None  None
# 4903                             None                  None  None  None  None
# 4904                             None                  None  None  None  None
# 4905                             None                  None  None  None  None
# 4906                             None                  None  None  None  None
# 4907                             None                  None  None  None  None
# 4908                             None                  None  None  None  None
# 4909                             None                  None  None  None  None
# 4910                             None                  None  None  None  None
#
#         35
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# ...    ...
# 4881  None
# 4882  None
# 4883  None
# 4884  None
# 4885  None
# 4886  None
# 4887  None
# 4888  None
# 4889  None
# 4890  None
# 4891  None
# 4892  None
# 4893  None
# 4894  None
# 4895  None
# 4896  None
# 4897  None
# 4898  None
# 4899  None
# 4900  None
# 4901  None
# 4902  None
# 4903  None
# 4904  None
# 4905  None
# 4906  None
# 4907  None
# 4908  None
# 4909  None
# 4910  None
#
# [4911 rows x 36 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(7977 unique tokens: ['cara', 'cara_mudah', 'internet', 'jaringan', 'komputer']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 4911

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))
# Out:
# Num Topics = 2  has Coherence Value of 0.38045848
# Num Topics = 4  has Coherence Value of 0.4021779938
# Num Topics = 6  has Coherence Value of 0.4453480274
# Num Topics = 8  has Coherence Value of 0.494962478
# Num Topics = 10  has Coherence Value of 0.5227859604
# Num Topics = 12  has Coherence Value of 0.5100114031
# Num Topics = 14  has Coherence Value of 0.5205330873
# Num Topics = 16  has Coherence Value of 0.5592981226
# Num Topics = 18  has Coherence Value of 0.5331236419

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=16)
pprint(model.print_topics())
# Out:
# [(0,
#   '0.010*"sistem_informasi" + 0.010*"matematika" + 0.009*"prestasi_belajar" + '
#   '0.009*"pembuatan_cd" + 0.009*"load_balancing" + 0.007*"kelas_vii" + '
#   '0.007*"interaktif" + 0.007*"studi_kasus" + 0.007*"implementasi_algoritma" + '
#   '0.007*"pembelajaran_matematika"'),
#  (1,
#   '0.008*"motivasi_belajar" + 0.007*"pengolahan_data" + 0.005*"xml" + '
#   '0.005*"browser" + 0.004*"penerima_beasiswa" + 0.004*"bilangan" + '
#   '0.004*"sarana" + 0.004*"sistem_pendukung" + 0.004*"sistem_pakar" + '
#   '0.004*"dokumen"'),
#  (2,
#   '0.011*"flash" + 0.010*"keputusan_pemilihan" + 0.010*"sistem_pendukung" + '
#   '0.009*"perguruan_tinggi" + 0.007*"problem_learning" + 0.006*"linier" + '
#   '0.006*"seleksi_penerimaan" + 0.006*"sistem_informasi" + '
#   '0.005*"pengiriman_barang" + 0.005*"pemilihan"'),
#  (3,
#   '0.012*"sistem_informasi" + 0.009*"rancang_bangun" + 0.008*"studi_kasus" + '
#   '0.007*"smart" + 0.006*"pembuatan_website" + 0.005*"pengendalian_persediaan" '
#   '+ 0.005*"teknik_informatika" + 0.005*"informasi" + '
#   '0.005*"kurikulum_program" + 0.005*"analisis_faktor"'),
#  (4,
#   '0.009*"bahan_ajar" + 0.008*"universitas_islam" + 0.008*"sistem_pendukung" + '
#   '0.007*"teknologi_informasi" + 0.007*"fakultas_sains" + '
#   '0.007*"implementasi_ip" + 0.006*"sistem_informasi" + 0.005*"negeri_syarif" '
#   '+ 0.005*"s" + 0.005*"smp_n"'),
#  (5,
#   '0.021*"siswa_kelas" + 0.013*"hasil_belajar" + 0.010*"kelas" + 0.010*"siswa" '
#   '+ 0.010*"sma_negeri" + 0.009*"pembelajaran" + 0.009*"model_pembelajaran" + '
#   '0.008*"pokok_bahasan" + 0.008*"pembelajaran_kooperatif" + 0.007*"belajar"'),
#  (6,
#   '0.008*"open_source" + 0.007*"php_mysql" + 0.006*"penilaian_kinerja" + '
#   '0.005*"rancang_bangun" + 0.005*"pengamanan_data" + 0.005*"sistem_informasi" '
#   '+ 0.004*"mendiagnosa_penyakit" + 0.004*"balanced_scorecard" + '
#   '0.004*"jaringan_lan" + 0.004*"studi_kasus"'),
#  (7,
#   '0.007*"studi_kasus" + 0.007*"analisa_perancangan" + 0.007*"e_government" + '
#   '0.005*"sistem_informasi" + 0.005*"data_mining" + 0.005*"aplikasi_pemantau" '
#   '+ 0.004*"pelayanan_puskesmas" + 0.004*"rancang_bangun" + 0.004*"data" + '
#   '0.004*"grid"'),
#  (8,
#   '0.019*"sistem_informasi" + 0.007*"studi_kasus" + 0.007*"rancang_bangun" + '
#   '0.007*"internet_protocol" + 0.006*"informasi" + 0.006*"basis_data" + '
#   '0.006*"sistem_pendukung" + 0.006*"sistem" + 0.005*"metode_analytical" + '
#   '0.005*"metode_ahp"'),
#  (9,
#   '0.010*"sistem_informasi" + 0.006*"diagnosa_penyakit" + '
#   '0.006*"sistem_pendukung" + 0.006*"keputusan_penentuan" + 0.006*"toko_buku" '
#   '+ 0.006*"real_time" + 0.006*"studi_kasus" + 0.005*"penentuan" + '
#   '0.005*"persamaan" + 0.004*"buku"'),
#  (10,
#   '0.015*"sms_gateway" + 0.009*"e_commerce" + 0.009*"sistem_informasi" + '
#   '0.009*"sistem_pakar" + 0.006*"sms" + 0.006*"aplikasi" + '
#   '0.005*"perangkat_lunak" + 0.005*"gateway" + 0.005*"masalah" + '
#   '0.005*"penerimaan_siswa"'),
#  (11,
#   '0.014*"sistem_informasi" + 0.011*"media_pembelajaran" + '
#   '0.007*"customer_relationship" + 0.007*"studi_kasus" + '
#   '0.005*"bahasa_inggris" + 0.005*"informasi" + 0.005*"power_system" + '
#   '0.005*"kinerja_manajerial" + 0.005*"sistem_pakar" + 0.004*"sistem"'),
#  (12,
#   '0.011*"sistem_informasi" + 0.010*"rancang_bangun" + 0.007*"aplikasi" + '
#   '0.007*"client_server" + 0.007*"rumah_sakit" + 0.007*"server" + 0.007*"java" '
#   '+ 0.006*"matriks" + 0.006*"bahasa_indonesia" + 0.006*"membangun"'),
#  (13,
#   '0.009*"sistem_informasi" + 0.008*"sekolah_dasar" + '
#   '0.007*"perancangan_implementasi" + 0.007*"proxy_server" + '
#   '0.006*"perangkat_lunak" + 0.006*"cd" + 0.005*"implementasi" + '
#   '0.005*"produksi_minyak" + 0.005*"laboratorium_komputer" + '
#   '0.005*"pemberian"'),
#  (14,
#   '0.014*"sistem_informasi" + 0.008*"studi_kasus" + '
#   '0.007*"analisis_perancangan" + 0.006*"sql_server" + 0.006*"web_service" + '
#   '0.005*"informasi" + 0.005*"manajemen" + 0.005*"modul" + 0.004*"sistem" + '
#   '0.004*"sistem_pakar"'),
#  (15,
#   '0.014*"sekolah_menengah" + 0.010*"hasil_belajar" + '
#   '0.007*"membangun_jaringan" + 0.006*"bahasa_pemrograman" + '
#   '0.005*"cara_mudah" + 0.005*"menengah" + 0.005*"gnu_linux" + '
#   '0.005*"rekayasa_perangkat" + 0.005*"sistem_pakar" + 0.004*"voip"')]

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=16)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.010*"diagnosa_penyakit" + 0.009*"tugas_akhir" + 0.009*"program_studi" + 0.009*"sistem_informasi" + 0.008*"game" + 0.007*"sistem_pakar" + 0.006*"membangun" + 0.005*"kinerja_manajerial" + 0.005*"diagnosa" + 0.005*"sejati"
# Topic: 1 Word: 0.019*"sistem_informasi" + 0.014*"perangkat_lunak" + 0.010*"sms_gateway" + 0.008*"analisis_perancangan" + 0.007*"prestasi_belajar" + 0.006*"informasi" + 0.006*"rancang_bangun" + 0.006*"local_area" + 0.006*"penerimaan_siswa" + 0.006*"perancangan"
# Topic: 2 Word: 0.010*"pembuatan_cd" + 0.009*"pembuatan_website" + 0.007*"cd" + 0.006*"kinerja_karyawan" + 0.006*"mata_kuliah" + 0.005*"interaktif" + 0.005*"lalu_lintas" + 0.005*"sistem_informasi" + 0.005*"publik" + 0.005*"port"
# Topic: 3 Word: 0.015*"sistem_informasi" + 0.011*"studi_kasus" + 0.008*"internet_protocol" + 0.008*"rancang_bangun" + 0.006*"informasi" + 0.004*"sistem" + 0.004*"content_management" + 0.004*"adisucipto_yogyakarta" + 0.004*"pekanbaru" + 0.004*"industri"
# Topic: 4 Word: 0.013*"flash" + 0.011*"analisis_perancangan" + 0.008*"smart" + 0.005*"sistem_informasi" + 0.005*"studi_kasus" + 0.005*"smart_card" + 0.004*"analisis" + 0.004*"algoritma_blowfish" + 0.004*"development" + 0.004*"distro"
# Topic: 5 Word: 0.014*"rancang_bangun" + 0.013*"sistem_pakar" + 0.008*"load_balancing" + 0.006*"proxy_server" + 0.006*"sistem_pendukung" + 0.005*"anak" + 0.005*"server" + 0.005*"sistem_informasi" + 0.005*"rancang" + 0.005*"pakar"
# Topic: 6 Word: 0.010*"rekayasa_perangkat" + 0.010*"studi_kasus" + 0.008*"sistem_informasi" + 0.008*"implementasi_algoritma" + 0.007*"sistem_pendukung" + 0.006*"kota_surakarta" + 0.006*"metode_analytical" + 0.006*"keputusan_penentuan" + 0.006*"metode_ahp" + 0.005*"micro_edition"
# Topic: 7 Word: 0.012*"siswa_kelas" + 0.008*"linier" + 0.007*"sistem_informasi" + 0.007*"motivasi_belajar" + 0.006*"analisis_faktor" + 0.006*"faktor" + 0.005*"pembelajaran_kooperatif" + 0.005*"pengamanan_data" + 0.005*"team_assisted" + 0.005*"x_sma"
# Topic: 8 Word: 0.009*"sistem_informasi" + 0.008*"keputusan_pemilihan" + 0.007*"sistem_pendukung" + 0.006*"perguruan_tinggi" + 0.006*"siswa_kelas" + 0.006*"real_time" + 0.004*"delphi_0" + 0.004*"tenaga_kerja" + 0.004*"komputer" + 0.004*"sistem_pendukung_keputusan_pemilihan"
# Topic: 9 Word: 0.016*"e_commerce" + 0.007*"bahan_ajar" + 0.007*"analisa_perancangan" + 0.007*"basis_data" + 0.007*"online" + 0.006*"toko_buku" + 0.005*"commerce" + 0.005*"aplikasi" + 0.004*"e" + 0.004*"personal"
# Topic: 10 Word: 0.012*"rumah_sakit" + 0.011*"sistem_pendukung" + 0.007*"sistem_informasi" + 0.007*"radio" + 0.007*"fuzzy_logic" + 0.006*"bahasa_indonesia" + 0.004*"support_system" + 0.004*"grid" + 0.004*"kredit" + 0.004*"dinas_pendidikan"
# Topic: 11 Word: 0.012*"studi_kasus" + 0.012*"rancang_bangun" + 0.009*"sistem_informasi" + 0.007*"jaringan_komputer" + 0.007*"matriks" + 0.007*"smp_negeri" + 0.006*"sistem_pendukung" + 0.006*"open_source" + 0.006*"universitas_islam" + 0.005*"administrasi"
# Topic: 12 Word: 0.008*"matematika" + 0.007*"kelas_vii" + 0.007*"model_pembelajaran" + 0.007*"perangkat_lunak" + 0.006*"power_system" + 0.006*"motivasi_hasil" + 0.006*"data_warehouse" + 0.006*"pembelajaran_matematika" + 0.005*"sistem_informasi" + 0.005*"kelas"
# Topic: 13 Word: 0.012*"hasil_belajar" + 0.012*"media_pembelajaran" + 0.010*"pokok_bahasan" + 0.009*"sekolah_dasar" + 0.009*"siswa_kelas" + 0.009*"pembelajaran" + 0.008*"sistem_informasi" + 0.008*"dasar" + 0.007*"belajar_siswa" + 0.007*"belajar"
# Topic: 14 Word: 0.019*"sistem_informasi" + 0.010*"studi_kasus" + 0.010*"sms_gateway" + 0.009*"teknologi_informasi" + 0.007*"informasi" + 0.006*"customer_relationship" + 0.006*"alat_bantu" + 0.005*"puskesmas" + 0.005*"sistem" + 0.005*"dinas"
# Topic: 15 Word: 0.014*"sma_negeri" + 0.010*"pc_router" + 0.009*"sekolah_menengah" + 0.008*"sistem_informasi" + 0.008*"short_message" + 0.008*"php_mysql" + 0.008*"e_learning" + 0.006*"sistem_pakar" + 0.006*"studi_kasus" + 0.006*"hasil_belajar"

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)
# Out:
#      No_Dokumen  Topik_Dominan  Persentase_Kontribusi  \
# 0             0           14.0                 0.9279
# 1             1           11.0                 0.5849
# 2             2           11.0                 0.6691
# 3             3           12.0                 0.4101
# 4             4           13.0                 0.7435
# 5             5           11.0                 0.3980
# 6             6           11.0                 0.8828
# 7             7           10.0                 0.4470
# 8             8           11.0                 0.4919
# 9             9           11.0                 0.9033
# 10           10           15.0                 0.3155
# 11           11           15.0                 0.8828
# 12           12           11.0                 0.5829
# 13           13           11.0                 0.4575
# 14           14            9.0                 0.2778
# 15           15           14.0                 0.9279
# 16           16           15.0                 0.6397
# 17           17           14.0                 0.8125
# 18           18           10.0                 0.8828
# 19           19           11.0                 0.5301
# 20           20            3.0                 0.6709
# 21           21           11.0                 0.5814
# 22           22           11.0                 0.7283
# 23           23            0.0                 0.9279
# 24           24           15.0                 0.8125
# 25           25           11.0                 0.9375
# 26           26           14.0                 0.9279
# 27           27            2.0                 0.5211
# 28           28            0.0                 0.8661
# 29           29           11.0                 0.9330
# ..          ...            ...                    ...
# 217         217            3.0                 0.8661
# 218         218            0.0                 0.5633
# 219         219            9.0                 0.5028
# 220         220           10.0                 0.8125
# 221         221           10.0                 0.5639
# 222         222            5.0                 0.5900
# 223         223           14.0                 0.5343
# 224         224            7.0                 0.4799
# 225         225            2.0                 0.8437
# 226         226            6.0                 0.6323
# 227         227            5.0                 0.7242
# 228         228            7.0                 0.5588
# 229         229           11.0                 0.7659
# 230         230           14.0                 0.5342
# 231         231           11.0                 0.6440
# 232         232            9.0                 0.9062
# 233         233           10.0                 0.5174
# 234         234           15.0                 0.9592
# 235         235           15.0                 0.8821
# 236         236           15.0                 0.9479
# 237         237            1.0                 0.4405
# 238         238           12.0                 0.5934
# 239         239            7.0                 0.8958
# 240         240            9.0                 0.5310
# 241         241            1.0                 0.4973
# 242         242            3.0                 0.4796
# 243         243           14.0                 0.7477
# 244         244           12.0                 0.7146
# 245         245            1.0                 0.6778
# 246         246           14.0                 0.3592
#
#                                             Kata_Kunci  \
# 0    sistem_informasi, studi_kasus, sms_gateway, te...
# 1    studi_kasus, rancang_bangun, sistem_informasi,...
# 2    studi_kasus, rancang_bangun, sistem_informasi,...
# 3    matematika, kelas_vii, model_pembelajaran, per...
# 4    hasil_belajar, media_pembelajaran, pokok_bahas...
# 5    studi_kasus, rancang_bangun, sistem_informasi,...
# 6    studi_kasus, rancang_bangun, sistem_informasi,...
# 7    rumah_sakit, sistem_pendukung, sistem_informas...
# 8    studi_kasus, rancang_bangun, sistem_informasi,...
# 9    studi_kasus, rancang_bangun, sistem_informasi,...
# 10   sma_negeri, pc_router, sekolah_menengah, siste...
# 11   sma_negeri, pc_router, sekolah_menengah, siste...
# 12   studi_kasus, rancang_bangun, sistem_informasi,...
# 13   studi_kasus, rancang_bangun, sistem_informasi,...
# 14   e_commerce, bahan_ajar, analisa_perancangan, b...
# 15   sistem_informasi, studi_kasus, sms_gateway, te...
# 16   sma_negeri, pc_router, sekolah_menengah, siste...
# 17   sistem_informasi, studi_kasus, sms_gateway, te...
# 18   rumah_sakit, sistem_pendukung, sistem_informas...
# 19   studi_kasus, rancang_bangun, sistem_informasi,...
# 20   sistem_informasi, studi_kasus, internet_protoc...
# 21   studi_kasus, rancang_bangun, sistem_informasi,...
# 22   studi_kasus, rancang_bangun, sistem_informasi,...
# 23   diagnosa_penyakit, tugas_akhir, program_studi,...
# 24   sma_negeri, pc_router, sekolah_menengah, siste...
# 25   studi_kasus, rancang_bangun, sistem_informasi,...
# 26   sistem_informasi, studi_kasus, sms_gateway, te...
# 27   pembuatan_cd, pembuatan_website, cd, kinerja_k...
# 28   diagnosa_penyakit, tugas_akhir, program_studi,...
# 29   studi_kasus, rancang_bangun, sistem_informasi,...
# ..                                                 ...
# 217  sistem_informasi, studi_kasus, internet_protoc...
# 218  diagnosa_penyakit, tugas_akhir, program_studi,...
# 219  e_commerce, bahan_ajar, analisa_perancangan, b...
# 220  rumah_sakit, sistem_pendukung, sistem_informas...
# 221  rumah_sakit, sistem_pendukung, sistem_informas...
# 222  rancang_bangun, sistem_pakar, load_balancing, ...
# 223  sistem_informasi, studi_kasus, sms_gateway, te...
# 224  siswa_kelas, linier, sistem_informasi, motivas...
# 225  pembuatan_cd, pembuatan_website, cd, kinerja_k...
# 226  rekayasa_perangkat, studi_kasus, sistem_inform...
# 227  rancang_bangun, sistem_pakar, load_balancing, ...
# 228  siswa_kelas, linier, sistem_informasi, motivas...
# 229  studi_kasus, rancang_bangun, sistem_informasi,...
# 230  sistem_informasi, studi_kasus, sms_gateway, te...
# 231  studi_kasus, rancang_bangun, sistem_informasi,...
# 232  e_commerce, bahan_ajar, analisa_perancangan, b...
# 233  rumah_sakit, sistem_pendukung, sistem_informas...
# 234  sma_negeri, pc_router, sekolah_menengah, siste...
# 235  sma_negeri, pc_router, sekolah_menengah, siste...
# 236  sma_negeri, pc_router, sekolah_menengah, siste...
# 237  sistem_informasi, perangkat_lunak, sms_gateway...
# 238  matematika, kelas_vii, model_pembelajaran, per...
# 239  siswa_kelas, linier, sistem_informasi, motivas...
# 240  e_commerce, bahan_ajar, analisa_perancangan, b...
# 241  sistem_informasi, perangkat_lunak, sms_gateway...
# 242  sistem_informasi, studi_kasus, internet_protoc...
# 243  sistem_informasi, studi_kasus, sms_gateway, te...
# 244  matematika, kelas_vii, model_pembelajaran, per...
# 245  sistem_informasi, perangkat_lunak, sms_gateway...
# 246  sistem_informasi, studi_kasus, sms_gateway, te...
#
#                                                   Teks
# 0    [cara, mudah, membangun, jaringan, komputer, i...
# 1    [jaringan, komputer, tcp, ip, jaringan_kompute...
# 2    [parallel, programming, teknik, aplikasi, jari...
# 3              [tip, jitu, optimasi, jaringan, wi, fi]
# 4    [pengembangan, media, pembelajaran, teknologi,...
# 5    [autentikasi, kendali, akses, audit, sistem, k...
# 6    [cisco, ccna, jaringan, komputer, jaringan_kom...
# 7    [koneksi, jaringan, antar, sekolah, teknologi,...
# 8    [analisis, tingkat, penggunaan, internet, dika...
# 9    [implementasi, intrusion, detection, system, i...
# 10   [rancang, bangun, analisa, qos, audio, video, ...
# 11   [analisa, qos, jaringan, mpls, ipv6, routing, ...
# 12   [monitoring, sistem, kerja, pengembangan, jari...
# 13   [langsung, praktik, mengelola, jaringan, lebih...
# 14   [studi, implementasi, voip, sip, jaringan, kam...
# 15   [cara, mudah, membangun, jaringan, komputer, i...
# 16   [desain, standar, perpustakaan, digital, perpu...
# 17             [panduan, praktis, menguasai, komputer]
# 18   [merakit, sendiri, komputer, tahan, banting, m...
# 19   [analisis, perancangan, sistem, komputerisasi,...
# 20   [optimasi, routing, pengaturan, route, adverti...
# 21   [perancangan, sistem, keamanan, jaringan, komp...
# 22   [sistem, jaringan, komputer, pemula, jaringan_...
# 23   [bahasa, pemrograman, python, platform, gnu, l...
# 24             [optimasi, bandwith, traffic, shapping]
# 25   [rancang, bangun, sistem, pencegahan, data, fl...
# 26   [cara, mudah, membangun, jaringan, komputer, i...
# 27   [cara, jitu, pengelolaan, jaringan, windows, r...
# 28   [membangun, software, monitoring, jaringan, sm...
# 29   [implementasi, sistem, autentikasi, jaringan, ...
# ..                                                 ...
# 217  [manajemen, backup, data, otomatis, jaringan, ...
# 218  [analisis, kinerja, level, komponen, protokol,...
# 219  [modul, ajar, komunikasi, data, antar, kompute...
# 220                   [berbagi, data, antar, jaringan]
# 221  [algoritma, routing, lingkungan, jaringan, gri...
# 222  [sistem, pakar, solusi, penyelesaian, masalah,...
# 223  [jurusan, teknik, informatika, sekolah, tinggi...
# 224  [membangun, jaringan, lan, file, sharing, prin...
# 225            [koneksi, jaringan, nat, publik, lokal]
# 226  [membangun, firewall, jaringan, windows, serve...
# 227  [implementasi, konfigurasi, jaringan, lokal, f...
# 228  [pembuatan, perangkat, lunak, sistem, telemetr...
# 229  [algoritma, paralel, odd, even, transposition,...
# 230  [jurusan, teknik, informatika, sekolah, tinggi...
# 231  [rancang, bangun, aplikasi, netcare, manager, ...
# 232  [implementasi, sentral, komunikasi, telepon, i...
# 233  [virtual, private, network, protokol, ipsec, f...
# 234  [membangun, jaringan, internet, pc, router, vy...
# 235  [mengembangkan, jaringan, mendukung, aplikasi,...
# 236  [pemanfaatan, komputer, pentium, ii, pc, route...
# 237  [perencanaan, jaringan, akses, mobile, wimax, ...
# 238  [prototipe, ruting, dinamik, protokol, ibgp, a...
# 239  [analisis, jaringan, wireless, universitas, ga...
# 240  [analisis, perancangan, jaringan, ip, telephon...
# 241  [optimalisasi, bandwidth, jaringan, internet, ...
# 242  [perancangan, jaringan, komunikasi, voip, voiv...
# 243  [membangun, jaringan, client, server, microsof...
# 244  [kajian, pengembangan, jaringan, komunikasi, d...
# 245  [membangun, jaringan, local, area, network, la...
# 246  [perancangan, sistem, aplikasi, komputer, alat...
#
# [247 rows x 5 columns]

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics
# Out:
# 11.0    484
# 1.0     475
# 14.0    451
# 5.0     424
# 15.0    357
# 6.0     317
# 3.0     289
# 8.0     285
# 13.0    265
# 10.0    258
# 9.0     248
# 12.0    247
# 0.0     214
# 4.0     204
# 2.0     198
# 7.0     195
# Name: Topik_Dominan, dtype: int64

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')
# Out:
# Text(0.5,1,'Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.9574
# 1         1.0              0.9716
# 2         2.0              0.9414
# 3         3.0              0.9625
# 4         4.0              0.9747
# 5         5.0              0.9677
# 6         6.0              0.9653
# 7         7.0              0.9531
# 8         8.0              0.9592
# 9         9.0              0.9653
# 10       10.0              0.9531
# 11       11.0              0.9653
# 12       12.0              0.9625
# 13       13.0              0.9531
# 14       14.0              0.9625
# 15       15.0              0.9625
#
#                                                                                                Keywords  \
# 0   diagnosa_penyakit, tugas_akhir, program_studi, sistem_informasi, game, sistem_pakar, membangun, ...
# 1   sistem_informasi, perangkat_lunak, sms_gateway, analisis_perancangan, prestasi_belajar, informas...
# 2   pembuatan_cd, pembuatan_website, cd, kinerja_karyawan, mata_kuliah, interaktif, lalu_lintas, sis...
# 3   sistem_informasi, studi_kasus, internet_protocol, rancang_bangun, informasi, sistem, content_man...
# 4   flash, analisis_perancangan, smart, sistem_informasi, studi_kasus, smart_card, analisis, algorit...
# 5   rancang_bangun, sistem_pakar, load_balancing, proxy_server, sistem_pendukung, anak, server, sist...
# 6   rekayasa_perangkat, studi_kasus, sistem_informasi, implementasi_algoritma, sistem_pendukung, kot...
# 7   siswa_kelas, linier, sistem_informasi, motivasi_belajar, analisis_faktor, faktor, pembelajaran_k...
# 8   sistem_informasi, keputusan_pemilihan, sistem_pendukung, perguruan_tinggi, siswa_kelas, real_tim...
# 9   e_commerce, bahan_ajar, analisa_perancangan, basis_data, online, toko_buku, commerce, aplikasi, ...
# 10  rumah_sakit, sistem_pendukung, sistem_informasi, radio, fuzzy_logic, bahasa_indonesia, support_s...
# 11  studi_kasus, rancang_bangun, sistem_informasi, jaringan_komputer, matriks, smp_negeri, sistem_pe...
# 12  matematika, kelas_vii, model_pembelajaran, perangkat_lunak, power_system, motivasi_hasil, data_w...
# 13  hasil_belajar, media_pembelajaran, pokok_bahasan, sekolah_dasar, siswa_kelas, pembelajaran, sist...
# 14  sistem_informasi, studi_kasus, sms_gateway, teknologi_informasi, informasi, customer_relationshi...
# 15  sma_negeri, pc_router, sekolah_menengah, sistem_informasi, short_message, php_mysql, e_learning,...
#
#                                                                                     Representative Text
# 0   [sistem, informasi, pengelolaan, data, skripsi, program, studi, sistem, informasi, universitas, ...
# 1   [perangkat, lunak, bantu, pengolahan, data, penjualan, barang, client, server, integrasi, barcod...
# 2   [mobilitas, tinggi, pengguna, internet, pengguna, hotspot, menjadi, tuntutan, walaupun, umum, te...
# 3   [implementasi, frame, relay, voice, over, frame, relay, vofr, perangkat, frad, act, sdm, citra, ...
# 4   [aplikasi, smart, card, electronic, medical, record, emr, smart, card, application, electronic, ...
# 5   [aplikasi, ujian, madrasah, lokal, area, network, lan, studi, kasus, mata, pelajaran, tik, madra...
# 6   [rekayasa, perangkat, lunak, pengambilan, keputusan, penerimaan, dosen, yayasan, pendidikan, dip...
# 7   [sistem, informasi, manajemen, sumber, daya, manusia, institut, sains, teknologi, jayapura, sist...
# 8   [membangun, firewall, jaringan, komputer, windows, server, smk, negeri, watulimo, kabupaten, tre...
# 9   [aplikasi, data, mining, menampilkan, informasi, tingkat, kelulusan, mahasiswa, studi, kasus, fa...
# 10  [fuzzy, logic, diagnosis, tata, laksana, penyakit, demam, berdarah, dengue, demam, tifoid, fuzzy...
# 11  [rancang, bangun, sistem, pendukung, keputusan, pemilihan, karyawan, teladan, metode, fuzzy, ahp...
# 12  [model, pembelajaran, kooperatif, teams, games, tournament, tgt, motivasi, prestasi, belajar, ma...
# 13  [analisis, sistem, informasi, manajemen, kepegawaian, simpeg, badan, kepegawaian, daerah, bkd, k...
# 14  [alternatif, alternatif, langkah, dinas, kesehatan, keterlibatan, pegawai, puskesmas, aplikasi, ...
# 15  [easy, intrusion, detction, system, easyids, pemberi, peringatan, dini, kepada, administrator, s...

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-2010.html')
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 11    -0.055147 -0.055853       1        1  8.442469
# 5     -0.046867 -0.045307       2        1  7.586251
# 1      0.012560 -0.121938       3        1  7.532159
# 15     0.065790 -0.089550       4        1  7.229875
# 14    -0.062683 -0.042936       5        1  7.018791
# 6     -0.055000  0.023675       6        1  6.572150
# 8     -0.010843  0.059296       7        1  6.271698
# 13     0.112043  0.006474       8        1  5.996114
# 12     0.124658  0.029285       9        1  5.918041
# 3     -0.038239 -0.005930      10        1  5.829681
# 10    -0.041476  0.058329      11        1  5.678172
# 0     -0.034503 -0.003017      12        1  5.430015
# 9      0.016189  0.048140      13        1  5.295683
# 4     -0.030311  0.018701      14        1  5.159542
# 7      0.072846  0.024282      15        1  5.092744
# 2     -0.029017  0.096349      16        1  4.946614, topic_info=     Category       Freq                     Term       Total  loglift  \
# term
# 2043  Default  23.000000              siswa_kelas   23.000000  30.0000
# 509   Default  24.000000              sms_gateway   24.000000  29.0000
# 788   Default  18.000000               sma_negeri   18.000000  28.0000
# 520   Default  20.000000               e_commerce   20.000000  27.0000
# 761   Default  28.000000          perangkat_lunak   28.000000  26.0000
# 429   Default  23.000000            hasil_belajar   23.000000  25.0000
# 183   Default  44.000000         sistem_pendukung   44.000000  24.0000
# 428   Default  10.000000                    flash   10.000000  23.0000
# 74    Default  58.000000           rancang_bangun   58.000000  22.0000
# 24    Default  11.000000       media_pembelajaran   11.000000  21.0000
# 90    Default  19.000000              rumah_sakit   19.000000  20.0000
# 2464  Default  12.000000       rekayasa_perangkat   12.000000  19.0000
# 123   Default  28.000000     analisis_perancangan   28.000000  18.0000
# 562   Default  13.000000                pc_router   13.000000  17.0000
# 2747  Default   9.000000            pokok_bahasan    9.000000  16.0000
# 336   Default  43.000000             sistem_pakar   43.000000  15.0000
# 765   Default  11.000000       model_pembelajaran   11.000000  14.0000
# 859   Default  12.000000         sekolah_menengah   12.000000  13.0000
# 3043  Default   8.000000        diagnosa_penyakit    8.000000  12.0000
# 6410  Default   8.000000             pembuatan_cd    8.000000  11.0000
# 2976  Default  11.000000      keputusan_pemilihan   11.000000  10.0000
# 640   Default   8.000000            sekolah_dasar    8.000000   9.0000
# 744   Default   8.000000            short_message    8.000000   8.0000
# 687   Default   8.000000              tugas_akhir    8.000000   7.0000
# 204   Default   9.000000           load_balancing    9.000000   6.0000
# 315   Default   7.000000        internet_protocol    7.000000   5.0000
# 54    Default  74.000000              studi_kasus   74.000000   4.0000
# 3039  Default   8.000000                  matriks    8.000000   3.0000
# 1298  Default   9.000000            program_studi    9.000000   2.0000
# 327   Default   9.000000   implementasi_algoritma    9.000000   1.0000
# ...       ...        ...                      ...         ...      ...
# 154   Topic16   1.730228                  desktop    2.330494   2.7086
# 2541  Topic16   2.157383    technology_acceptance    2.918224   2.7044
# 883   Topic16   3.240230                   publik    4.417443   2.6966
# 1611  Topic16   1.809469                   lintas    2.501161   2.6827
# 1609  Topic16   1.809469                     lalu    2.501161   2.6827
# 5303  Topic16   1.546608                peradilan    2.162422   2.6713
# 4722  Topic16   1.463511                     high    2.063830   2.6627
# 4858  Topic16   1.409881                    batam    2.010152   2.6518
# 3761  Topic16   1.407072    mendiagnosis_penyakit    2.007338   2.6512
# 271   Topic16   2.001047             wireless_lan    2.878164   2.6430
# 7055  Topic16   1.671629                   kernel    2.406863   2.6419
# 6652  Topic16   1.361012                statement    1.961278   2.6411
# 6651  Topic16   1.361012               blackberry    1.961278   2.6411
# 1409  Topic16   1.311924                     worm    1.912193   2.6297
# 3014  Topic16   1.297857               governance    1.898123   2.6263
# 4246  Topic16   1.451545                 operator    2.125871   2.6249
# 933   Topic16   2.795248                    smp_n    4.137178   2.6144
# 1805  Topic16   2.506000               siswa_baru    4.332617   2.4590
# 2338  Topic16   3.627477               interaktif    9.175319   2.0785
# 4989  Topic16   2.627924  pengendalian_persediaan    5.719244   2.2288
# 1408  Topic16   2.668677             visual_basic    5.880527   2.2164
# 5263  Topic16   1.878282          pinjaman_kredit    3.471012   2.3924
# 236   Topic16   1.611270        management_system    2.621996   2.5196
# 1330  Topic16   1.969326                  menjadi    4.962401   2.0823
# 279   Topic16   2.814636                pembuatan   20.562706   1.0178
# 191   Topic16   3.571640         sistem_informasi  131.486359  -0.5994
# 637   Topic16   1.881785                framework    5.937799   1.8573
# 183   Topic16   2.225300         sistem_pendukung   44.992470  -0.0001
# 66    Topic16   1.990958                   system   22.007387   0.6037
# 34    Topic16   1.852541                   sistem   50.114223  -0.2913
#
#       logprob
# term
# 2043  30.0000
# 509   29.0000
# 788   28.0000
# 520   27.0000
# 761   26.0000
# 429   25.0000
# 183   24.0000
# 428   23.0000
# 74    22.0000
# 24    21.0000
# 90    20.0000
# 2464  19.0000
# 123   18.0000
# 562   17.0000
# 2747  16.0000
# 336   15.0000
# 765   14.0000
# 859   13.0000
# 3043  12.0000
# 6410  11.0000
# 2976  10.0000
# 640    9.0000
# 744    8.0000
# 687    7.0000
# 204    6.0000
# 315    5.0000
# 54     4.0000
# 3039   3.0000
# 1298   2.0000
# 327    1.0000
# ...       ...
# 154   -6.0048
# 2541  -5.7842
# 883   -5.3775
# 1611  -5.9601
# 1609  -5.9601
# 5303  -6.1170
# 4722  -6.1723
# 4858  -6.2096
# 3761  -6.2116
# 271   -5.8594
# 7055  -6.0393
# 6652  -6.2449
# 6651  -6.2449
# 1409  -6.2816
# 3014  -6.2924
# 4246  -6.1805
# 933   -5.5252
# 1805  -5.6344
# 2338  -5.2646
# 4989  -5.5869
# 1408  -5.5715
# 5263  -5.9227
# 236   -6.0761
# 1330  -5.8754
# 279   -5.5183
# 191   -5.2801
# 637   -5.9209
# 183   -5.7532
# 66    -5.8645
# 34    -5.9365
#
# [874 rows x 6 columns], token_table=      Topic      Freq                   Term
# term
# 4286     15  0.802809                     3d
# 1099      6  0.826144                      5
# 701       1  0.105849                      a
# 701       2  0.105849                      a
# 701       4  0.105849                      a
# 701       5  0.105849                      a
# 701       8  0.105849                      a
# 701      11  0.105849                      a
# 701      13  0.211697                      a
# 1254     11  0.832217                     ad
# 1483     11  0.705793               adaptive
# 1693     10  0.875962             adisucipto
# 1694     10  0.763496  adisucipto_yogyakarta
# 667       1  0.555182           administrasi
# 667       2  0.092530           administrasi
# 667       4  0.092530           administrasi
# 667       6  0.092530           administrasi
# 667      11  0.092530           administrasi
# 667      12  0.092530           administrasi
# 7156      8  0.482151                  adobe
# 1661     14  0.915166            advertising
# 2560      5  0.736991                    aes
# 7071     12  0.773691           agribusiness
# 1025      3  0.525820                   ajar
# 1025     13  0.350547                   ajar
# 683      12  0.555051                  akhir
# 2132     16  0.949645              aktivitas
# 3181      4  0.667740               akuisisi
# 4635      2  0.851231    akuntansi_penjualan
# 348       2  0.672745                     al
# ...     ...       ...                    ...
# 1742      3  0.762140                warning
# 193       1  0.112863                    web
# 193       2  0.084647                    web
# 193       3  0.084647                    web
# 193       4  0.084647                    web
# 193       5  0.112863                    web
# 193       6  0.056432                    web
# 193       7  0.056432                    web
# 193       8  0.056432                    web
# 193       9  0.056432                    web
# 193      10  0.056432                    web
# 193      11  0.056432                    web
# 193      12  0.056432                    web
# 193      13  0.056432                    web
# 193      14  0.028216                    web
# 193      15  0.028216                    web
# 193      16  0.028216                    web
# 314       8  0.876942            web_service
# 6908     11  0.780238                   wind
# 212       5  0.441699         windows_server
# 212       7  0.220849         windows_server
# 212      11  0.220849         windows_server
# 102      11  0.691888             windows_xp
# 271      16  0.694887           wireless_lan
# 1409     16  0.522960                   worm
# 6760     15  0.692275                  x_sma
# 2045      1  0.259530                     xi
# 2045      8  0.778591                     xi
# 1435     12  0.764861                    xml
# 3604     15  0.540032                 yadika
#
# [1590 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[12, 6, 2, 16, 15, 7, 9, 14, 13, 4, 11, 1, 10, 5, 8, 3])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model2010.pkl'
pickle.dump(model, open(filename, 'wb'))
model.save('lda.model')

# %%
from helper import *
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
fo = pd.ExcelFile('cleaned2019.xls') 
# clean-data.xlsx
df = pd.read_excel(fo, 'Sheet1')
print(df)
# Out:
#                                                    text
# 0     pendeteksi gangguan jaringan lokal metode cert...
# 1     eksistensi penggunaan wi fi warung kopi kota b...
# 2     pengaruh internet financial reporting tingkat ...
# 3     security function analysis performance high sp...
# 4     implementation top down approach method redesi...
# 5     optimization wireless network performance hier...
# 6     analysis qos vlan djikstra s algorithm open sh...
# 7     link performance improvement sananibun bts wit...
# 8     legal protection efforts patent holders indonesia
# 9     use e learning by teachers teaching learning p...
# 10    definition patent rights examples case studies...
# 11    analysis implementation backup line network br...
# 12    classification principles legal basis intellec...
# 13    attendance system automatic door locks laborat...
# 14         registration requirements application rights
# 15    patentability block chain technology future in...
# 16    influence speed user mobility qos wireless lan...
# 17    4 ghz omnidirectional antenna design with micr...
# 18    pemanfaatan telepon pintar informasi penyebara...
# 19    aplikasi teknologi komunikasi wireless zigbee ...
# 20    forensics analysis router computer networks li...
# 21                  manajemen proyeksi sistem informasi
# 22                  manajemen proyeksi sistem informasi
# 23                  tri destanto 175100067p sectionquis
# 24          rancang bangun aplikasi chatting web docker
# 25    multimedia animated corrosion corrosion coatin...
# 26    quality service traffic monitoring system stat...
# 27             analisis topologi area jaringan komputer
# 28             resume pembuatan tugas jaringan komputer
# 29             perkembangan jaringan komputer indonesia
# ...                                                 ...
# 6902  perbandingan performa algoritma hill cipher rs...
# 6903  model kano dimensi serqvqual upaya peningkatan...
# 6904  sistem pendukung keputusan pemilihan smartphon...
# 6905  implementasi algoritma transposisi cipher sist...
# 6906  tindak pidana dunia maya berupa virus trojan h...
# 6907  expert system technology implementation k mean...
# 6908  rancang bangun aplikasi pendaftaran yudisium w...
# 6909  pengaruh pembelajaran e learning hasil belajar...
# 6910  implementasi steganografi audio file wav metod...
# 6911  algoritma kriptografi advanced encryption stan...
# 6912  game online teka teki silang software hot pota...
# 6913  eksplorasi abac xacml design access control re...
# 6914  analysis siem implementation open source siem ...
# 6915  alat patroli lingkungan perkantoran radio freq...
# 6916  steganografi digital image metode least signif...
# 6917  sistem monitoring pengaman motor remote cerdas...
# 6918                 analisa sistem reservasi tiket xyz
# 6919  operasi siber ofensif iran amerika serikat isr...
# 6920  sistem pendukung keputusan metode simple addit...
# 6921    matematika diskrit penerapannya dunia informasi
# 6922  pengaruh teknologi informasi kompetensi kompen...
# 6923    college academic freedom digital disruption era
# 6924  tanggung jawab penyediaan layanan atas kerahas...
# 6925  visualisasi operasi aritmatika pengolahan citr...
# 6926  penegakan hukum pencurian data pribadi penggun...
# 6927  studi perbandingan digital forensic tools android
# 6928  perlindungan hukum anak korban kejahatan seksu...
# 6929  analisis pengaruh kualitas layanan kepuasan ke...
# 6930  pengaruhpemanfaatanteknologiinformasidan kompe...
# 6931  penyelesaian sengketa e commerce melalui badan...
#
# [6932 rows x 1 columns]

# %%
#drop empty line
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

text = df['text']
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list[:1])
# Out:
# 6932
# [['pendeteksi', 'gangguan', 'jaringan', 'lokal', 'metode', 'certainty', 'factor']]

# %%
#Create Biagram & Trigram Models 
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 5 means only that appear 5 times or more.
bigram = Phrases(text_list, min_count=5)
trigram = Phrases(bigram[text_list], min_count=5)

for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
            
print(text_list)
# Out:
# [['pendeteksi', 'gangguan', 'jaringan', 'lokal', 'metode', 'certainty', 'factor', 'jaringan_lokal', 'metode_certainty', 'jaringan_lokal', 'jaringan_lokal', 'metode_certainty'], ['eksistensi', 'penggunaan', 'wi', 'fi', 'warung', 'kopi', 'kota', 'banda', 'aceh', 'banda_aceh', 'banda_aceh', 'banda_aceh'], ['pengaruh', 'internet', 'financial', 'reporting', 'tingkat', 'pengungkapan', 'informasi', 'website', 'frekuensi', 'perdagangan', 'saham', 'perusahaan', 'pertambangan'], ['security', 'function', 'analysis', 'performance', 'high', 'speed', 'router', 'networking'], ['implementation', 'top', 'down', 'approach', 'method', 'redesign', 'lan', 'harvani', 'hotel', 'palembang'], ['optimization', 'wireless', 'network', 'performance', 'hierarchical', 'token', 'bucket', 'case', 'muhammadiyah', 'university', 'palembang'], ['analysis', 'qos', 'vlan', 'djikstra', 's', 'algorithm', 'open', 'shortest', 'path', 'first', 'ospf'], ['link', 'performance', 'improvement', 'sananibun', 'bts', 'with', 'link', 'switch', 'migration', 'backbone', 'network', 'indosat', 'ooredoo'], ['legal', 'protection', 'efforts', 'patent', 'holders', 'indonesia'], ['use', 'e', 'learning', 'by', 'teachers', 'teaching', 'learning', 'process', 'e_learning', 'e_learning', 'e_learning'], ['definition', 'patent', 'rights', 'examples', 'case', 'studies', 'iphone', 'products'], ['analysis', 'implementation', 'backup', 'line', 'network', 'branch', 'office', 'vpn', 'speedy', 'internet', 'broadband'], ['classification', 'principles', 'legal', 'basis', 'intellectual', 'property', 'indonesia'], ['attendance', 'system', 'automatic', 'door', 'locks', 'laboratory', 'electrical', 'engineering', 'department', 'at', 'unikom', 'with', 'ink', 'spray', 'radio', 'frequency', 'identification', 'radio_frequency', 'radio_frequency', 'radio_frequency'], ['registration', 'requirements', 'application', 'rights'], ['patentability', 'block', 'chain', 'technology', 'future', 'innovation'], ['influence', 'speed', 'user', 'mobility', 'qos', 'wireless', 'lan', '11', 'g', '11', 'n', '4', 'ghz', 'riverbed', 'modeler'], ['4', 'ghz', 'omnidirectional', 'antenna', 'design', 'with', 'microstrip', 'technologies', 'gsm', 'internet', 'protocol', 'repeater'], ['pemanfaatan', 'telepon', 'pintar', 'informasi', 'penyebaran', 'lokasi', 'guru', 'sekolah', 'dasar', 'negeri', 'bersertifikasi', 'provinsi', 'lampung', 'jalur', 'sekolah_dasar', 'sekolah_dasar', 'sekolah_dasar'], ['aplikasi', 'teknologi', 'komunikasi', 'wireless', 'zigbee', 'sistem', 'kontrol', 'monitoring', 'ruangan', 'kelas', 'sistem_kontrol'], ['forensics', 'analysis', 'router', 'computer', 'networks', 'live', 'forensics', 'method'], ['manajemen', 'proyeksi', 'sistem', 'informasi', 'manajemen_proyeksi', 'sistem_informasi', 'sistem_informasi', 'manajemen_proyeksi', 'sistem_informasi'], ['manajemen', 'proyeksi', 'sistem', 'informasi', 'manajemen_proyeksi', 'sistem_informasi', 'sistem_informasi', 'manajemen_proyeksi', 'sistem_informasi'], ['tri', 'destanto', '175100067p', 'sectionquis'], ['rancang', 'bangun', 'aplikasi', 'chatting', 'web', 'docker', 'rancang_bangun', 'rancang_bangun', 'rancang_bangun'], ['multimedia', 'animated', 'corrosion', 'corrosion', 'coating', 'metals', 'course'], ['quality', 'service', 'traffic', 'monitoring', 'system', 'static', 'routing', 'eoip', 'tunnel', 'over', 'ipsec', 'quality_service', 'quality_service', 'quality_service'], ['analisis', 'topologi', 'area', 'jaringan', 'komputer', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['resume', 'pembuatan', 'tugas', 'jaringan', 'komputer', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['perkembangan', 'jaringan', 'komputer', 'indonesia', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['fitri', 'hidayahtullah', 'jenis', 'jaringan', 'komputer', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['pengantar', 'topik', 'jaringan', 'komputer', 'jaringan_komputer', 'jaringan_komputer', 'jaringan_komputer'], ['jaringan', 'kompute ...

# %%
phrasedf = pd.DataFrame(text_list)
print(phrasedf)
# Out:
#                                             0               1   \
# 0                                   pendeteksi        gangguan
# 1                                   eksistensi      penggunaan
# 2                                     pengaruh        internet
# 3                                     security        function
# 4                               implementation             top
# 5                                 optimization        wireless
# 6                                     analysis             qos
# 7                                         link     performance
# 8                                        legal      protection
# 9                                          use               e
# 10                                  definition          patent
# 11                                    analysis  implementation
# 12                              classification      principles
# 13                                  attendance          system
# 14                                registration    requirements
# 15                               patentability           block
# 16                                   influence           speed
# 17                                           4             ghz
# 18                                 pemanfaatan         telepon
# 19                                    aplikasi       teknologi
# 20                                   forensics        analysis
# 21                                   manajemen        proyeksi
# 22                                   manajemen        proyeksi
# 23                                         tri        destanto
# 24                                     rancang          bangun
# 25                                  multimedia        animated
# 26                                     quality         service
# 27                                    analisis        topologi
# 28                                      resume       pembuatan
# 29                                perkembangan        jaringan
# ...                                        ...             ...
# 6902                              perbandingan        performa
# 6903                                     model            kano
# 6904                                    sistem       pendukung
# 6905                              implementasi       algoritma
# 6906                                    tindak          pidana
# 6907                                    expert          system
# 6908                                   rancang          bangun
# 6909                                  pengaruh    pembelajaran
# 6910                              implementasi    steganografi
# 6911                                 algoritma     kriptografi
# 6912                                      game          online
# 6913                                eksplorasi            abac
# 6914                                  analysis            siem
# 6915                                      alat         patroli
# 6916                              steganografi         digital
# 6917                                    sistem      monitoring
# 6918                                   analisa          sistem
# 6919                                   operasi           siber
# 6920                                    sistem       pendukung
# 6921                                matematika         diskrit
# 6922                                  pengaruh       teknologi
# 6923                                   college        academic
# 6924                                  tanggung           jawab
# 6925                               visualisasi         operasi
# 6926                                 penegakan           hukum
# 6927                                     studi    perbandingan
# 6928                              perlindungan           hukum
# 6929                                  analisis        pengaruh
# 6930  pengaruhpemanfaatanteknologiinformasidan      kompetensi
# 6931                              penyelesaian        sengketa
#
#                    2               3                   4                  5   \
# 0            jaringan           lokal              metode          certainty
# 1                  wi              fi              warung               kopi
# 2           financial       reporting             tingkat       pengungkapan
# 3            analysis     performance                high              speed
# 4                down        approach              method           redesign
# 5             network     performance        hierarchical              token
# 6                vlan        djikstra                   s          algorithm
# 7         improvement       sananibun                 bts               with
# 8             efforts          patent             holders          indonesia
# 9            learning              by            teachers           teaching
# 10             rights        examples                case            studies
# 11             backup            line             network             branch
# 12              legal           basis        intellectual           property
# 13          automatic            door               locks         laboratory
# 14        application          rights                None               None
# 15              chain      technology              future         innovation
# 16               user        mobility                 qos           wireless
# 17    omnidirectional         antenna              design               with
# 18             pintar       informasi          penyebaran             lokasi
# 19         komunikasi        wireless              zigbee             sistem
# 20             router        computer            networks               live
# 21             sistem       informasi  manajemen_proyeksi   sistem_informasi
# 22             sistem       informasi  manajemen_proyeksi   sistem_informasi
# 23         175100067p     sectionquis                None               None
# 24           aplikasi        chatting                 web             docker
# 25          corrosion       corrosion             coating             metals
# 26            traffic      monitoring              system             static
# 27               area        jaringan            komputer  jaringan_komputer
# 28              tugas        jaringan            komputer  jaringan_komputer
# 29           komputer       indonesia   jaringan_komputer  jaringan_komputer
# ...               ...             ...                 ...                ...
# 6902        algoritma            hill              cipher                rsa
# 6903          dimensi       serqvqual               upaya        peningkatan
# 6904        keputusan       pemilihan          smartphone            android
# 6905      transposisi          cipher              sistem         pengamanan
# 6906            dunia            maya              berupa              virus
# 6907       technology  implementation                   k              means
# 6908         aplikasi     pendaftaran            yudisium            website
# 6909                e        learning               hasil            belajar
# 6910            audio            file                 wav             metode
# 6911         advanced      encryption            standard                aes
# 6912             teka            teki              silang           software
# 6913            xacml          design              access            control
# 6914   implementation            open              source               siem
# 6915       lingkungan     perkantoran               radio          frequency
# 6916            image          metode               least        significant
# 6917         pengaman           motor              remote             cerdas
# 6918        reservasi           tiket                 xyz               None
# 6919          ofensif            iran             amerika            serikat
# 6920        keputusan          metode              simple            additve
# 6921     penerapannya           dunia           informasi               None
# 6922        informasi      kompetensi          kompensasi            kinerja
# 6923          freedom         digital          disruption                era
# 6924       penyediaan         layanan                atas        kerahasiaan
# 6925       aritmatika      pengolahan               citra            digital
# 6926        pencurian            data             pribadi           pengguna
# 6927          digital        forensic               tools            android
# 6928             anak          korban           kejahatan            seksual
# 6929         kualitas         layanan            kepuasan        kepercayaan
# 6930              sdm        kualitas             laporan           keuangan
# 6931                e        commerce             melalui              badan
#
#                      6                   7                 8   \
# 0                factor      jaringan_lokal  metode_certainty
# 1                  kota               banda              aceh
# 2             informasi             website         frekuensi
# 3                router          networking              None
# 4                   lan             harvani             hotel
# 5                bucket                case      muhammadiyah
# 6                  open            shortest              path
# 7                  link              switch         migration
# 8                  None                None              None
# 9              learning             process        e_learning
# 10               iphone            products              None
# 11               office                 vpn            speedy
# 12            indonesia                None              None
# 13           electrical         engineering        department
# 14                 None                None              None
# 15                 None                None              None
# 16                  lan                  11                 g
# 17           microstrip        technologies               gsm
# 18                 guru             sekolah             dasar
# 19              kontrol          monitoring           ruangan
# 20            forensics              method              None
# 21     sistem_informasi  manajemen_proyeksi  sistem_informasi
# 22     sistem_informasi  manajemen_proyeksi  sistem_informasi
# 23                 None                None              None
# 24       rancang_bangun      rancang_bangun    rancang_bangun
# 25               course                None              None
# 26              routing                eoip            tunnel
# 27    jaringan_komputer   jaringan_komputer              None
# 28    jaringan_komputer   jaringan_komputer              None
# 29    jaringan_komputer                None              None
# ...                 ...                 ...               ...
# 6902             proses            enkripsi          dekripsi
# 6903           kualitas             layanan               web
# 6904             metode               fuzzy         tsukamoto
# 6905               data            jaringan               lan
# 6906             trojan               horse            undang
# 6907         clustering           algorithm          patients
# 6908        universitas               islam         majapahit
# 6909          mahasiswa                pgsd              mata
# 6910          redundant             pattern          encoding
# 6911             sistem           manajemen             arsip
# 6912                hot            potatoes         mendukung
# 6913           resource             digital              None
# 6914              tools                case             wazuh
# 6915     identification                rfid   radio_frequency
# 6916                bit           insertion      metode_least
# 6917            android                 gps            google
# 6918               None                None              None
# 6919             israel                arab             saudi
# 6920          weighting                 saw          prediksi
# 6921               None                None              None
# 6922        pengelolaan            keuangan             badan
# 6923               None                None              None
# 6924               data             pribadi          pengguna
# 6925   pengolahan_citra    pengolahan_citra  pengolahan_citra
# 6926           provider                None              None
# 6927               None                None              None
# 6928        denganmodus               media            sosial
# 6929          passanger              garuda         indonesia
# 6930             sistem        pengendalian            intern
# 6931       penyelesaian            sengketa          konsumen
#
#                           9   ...     27    28    29    30    31    32    33  \
# 0             jaringan_lokal  ...   None  None  None  None  None  None  None
# 1                 banda_aceh  ...   None  None  None  None  None  None  None
# 2                perdagangan  ...   None  None  None  None  None  None  None
# 3                       None  ...   None  None  None  None  None  None  None
# 4                  palembang  ...   None  None  None  None  None  None  None
# 5                 university  ...   None  None  None  None  None  None  None
# 6                      first  ...   None  None  None  None  None  None  None
# 7                   backbone  ...   None  None  None  None  None  None  None
# 8                       None  ...   None  None  None  None  None  None  None
# 9                 e_learning  ...   None  None  None  None  None  None  None
# 10                      None  ...   None  None  None  None  None  None  None
# 11                  internet  ...   None  None  None  None  None  None  None
# 12                      None  ...   None  None  None  None  None  None  None
# 13                        at  ...   None  None  None  None  None  None  None
# 14                      None  ...   None  None  None  None  None  None  None
# 15                      None  ...   None  None  None  None  None  None  None
# 16                        11  ...   None  None  None  None  None  None  None
# 17                  internet  ...   None  None  None  None  None  None  None
# 18                    negeri  ...   None  None  None  None  None  None  None
# 19                     kelas  ...   None  None  None  None  None  None  None
# 20                      None  ...   None  None  None  None  None  None  None
# 21                      None  ...   None  None  None  None  None  None  None
# 22                      None  ...   None  None  None  None  None  None  None
# 23                      None  ...   None  None  None  None  None  None  None
# 24                      None  ...   None  None  None  None  None  None  None
# 25                      None  ...   None  None  None  None  None  None  None
# 26                      over  ...   None  None  None  None  None  None  None
# 27                      None  ...   None  None  None  None  None  None  None
# 28                      None  ...   None  None  None  None  None  None  None
# 29                      None  ...   None  None  None  None  None  None  None
# ...                      ...  ...    ...   ...   ...   ...   ...   ...   ...
# 6902                    text  ...   None  None  None  None  None  None  None
# 6903                 sekolah  ...   None  None  None  None  None  None  None
# 6904        sistem_pendukung  ...   None  None  None  None  None  None  None
# 6905  implementasi_algoritma  ...   None  None  None  None  None  None  None
# 6906                  undang  ...   None  None  None  None  None  None  None
# 6907                    with  ...   None  None  None  None  None  None  None
# 6908          rancang_bangun  ...   None  None  None  None  None  None  None
# 6909                  kuliah  ...   None  None  None  None  None  None  None
# 6910                     rpe  ...   None  None  None  None  None  None  None
# 6911                   dinas  ...   None  None  None  None  None  None  None
# 6912            pembelajaran  ...   None  None  None  None  None  None  None
# 6913                    None  ...   None  None  None  None  None  None  None
# 6914                   ossim  ...   None  None  None  None  None  None  None
# 6915         radio_frequency  ...   None  None  None  None  None  None  None
# 6916         significant_bit  ...   None  None  None  None  None  None  None
# 6917                     api  ...   None  None  None  None  None  None  None
# 6918                    None  ...   None  None  None  None  None  None  None
# 6919             kepentingan  ...   None  None  None  None  None  None  None
# 6920                anggaran  ...   None  None  None  None  None  None  None
# 6921                    None  ...   None  None  None  None  None  None  None
# 6922     teknologi_informasi  ...   None  None  None  None  None  None  None
# 6923                    None  ...   None  None  None  None  None  None  None
# 6924                 layanan  ...   None  None  None  None  None  None  None
# 6925                    None  ...   None  None  None  None  None  None  None
# 6926                    None  ...   None  None  None  None  None  None  None
# 6927                    None  ...   None  None  None  None  None  None  None
# 6928      perlindungan_hukum  ...   None  None  None  None  None  None  None
# 6929                 persero  ...   None  None  None  None  None  None  None
# 6930                variabel  ...   None  None  None  None  None  None  None
# 6931                ditinjau  ...   None  None  None  None  None  None  None
#
#         34    35    36
# 0     None  None  None
# 1     None  None  None
# 2     None  None  None
# 3     None  None  None
# 4     None  None  None
# 5     None  None  None
# 6     None  None  None
# 7     None  None  None
# 8     None  None  None
# 9     None  None  None
# 10    None  None  None
# 11    None  None  None
# 12    None  None  None
# 13    None  None  None
# 14    None  None  None
# 15    None  None  None
# 16    None  None  None
# 17    None  None  None
# 18    None  None  None
# 19    None  None  None
# 20    None  None  None
# 21    None  None  None
# 22    None  None  None
# 23    None  None  None
# 24    None  None  None
# 25    None  None  None
# 26    None  None  None
# 27    None  None  None
# 28    None  None  None
# 29    None  None  None
# ...    ...   ...   ...
# 6902  None  None  None
# 6903  None  None  None
# 6904  None  None  None
# 6905  None  None  None
# 6906  None  None  None
# 6907  None  None  None
# 6908  None  None  None
# 6909  None  None  None
# 6910  None  None  None
# 6911  None  None  None
# 6912  None  None  None
# 6913  None  None  None
# 6914  None  None  None
# 6915  None  None  None
# 6916  None  None  None
# 6917  None  None  None
# 6918  None  None  None
# 6919  None  None  None
# 6920  None  None  None
# 6921  None  None  None
# 6922  None  None  None
# 6923  None  None  None
# 6924  None  None  None
# 6925  None  None  None
# 6926  None  None  None
# 6927  None  None  None
# 6928  None  None  None
# 6929  None  None  None
# 6930  None  None  None
# 6931  None  None  None
#
# [6932 rows x 37 columns]

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=1, no_above=0.5)
print(dictionary)
# Out:
# Dictionary(10557 unique tokens: ['certainty', 'factor', 'gangguan', 'jaringan', 'jaringan_lokal']...)

# %%
#build bag of words (corpus)
bow = [dictionary.doc2bow(doc) for doc in text_list]

print(len(bow))
# print(doc_term_matrix[100])

# calculate TF-IDF
tfidf = models.TfidfModel(bow)
corpus_tfidf = tfidf[bow]
# similarity = pd.DataFrame(corpus_tfidf, columns=['Topic']).to_csv("similarity.csv")

# print(corpus_tfidf)

# feature_names = tfidf.get_feature_names()
# corpus_index = [n for n in corpus_tfidf]

# showme = pd.DataFrame(tfs.T.todense(), index=feature_names, columns=corpus_index)
# print(showme)

# for i in corpus_tfidf:
#     result = pd.DataFrame()
#     result = result.append(pd.Series(corpus_tfidf), ignore_index=True)
#     print(result)
# Out:
# 6932

# %%
import numpy as np
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from numpy import array
#function to compute coherence values
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    coherence_values = []
    np.random.seed(9)
    model_list = []
    num_topics = []
    for num_topics in range(start, limit, step):
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, iterations=100)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
    return model_list, coherence_values

# num_topics

# %%
start=2
limit=20
step=2
model_list, coherence_values = compute_coherence_values(dictionary, corpus=corpus_tfidf, 
                                                        texts=text_list, start=start, limit=limit, step=step)

# %%
#show graphs
import matplotlib.pyplot as plt
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 10))

# %%
from pprint import pprint

model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=10)
pprint(model.print_topics())

# %%
model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=10)

for idx, topic in model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# %% [markdown]
# # Dominant topic and its percentage contribution in each document

# %%
def format_topics_sentences(ldamodel=None, corpus=bow, texts=text):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        # check notes 28/9
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(model, corpus=bow, texts=text_list)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['No_Dokumen', 'Topik_Dominan', 'Persentase_Kontribusi', 'Kata_Kunci', 'Teks']
df_dominant_topic.head(247)

# %%
# Generate dataframe from list and write to xlsx.
pd.DataFrame(df_dominant_topic, columns=['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']).to_excel('topics.xls', header=True, index=False)

# %%
count_topics = df_dominant_topic['Topik_Dominan'].value_counts()
count_topics

# %%
# matplotlib inline

# %%
count_topics.plot.bar()

plt.xlabel('Topik')
plt.ylabel('Banyak Judul')
plt.title('Persebaran Banyak Judul Penelitian Berdasarkan Topik')

# %% [markdown]
# # The most representative sentence for each topic

# %%
# Display setting to show more characters in column
# Mallet
pd.options.display.max_colwidth = 100

sent_topics_sorteddf = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf.head(20)

# %%
import gensim
import pyLDAvis.gensim;pyLDAvis.enable_notebook()

data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
print(data)
pyLDAvis.save_html(data, 'lda-gensim-2019.html')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wd

# # lower max_font_size, change the maximum number of word and lighten the background:
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

for t in range(model.num_topics):
    plt.figure(figsize=(7,6))
    plt.imshow(wd(max_font_size=50, max_words=20, background_color="white", min_font_size=10).fit_words(dict(model.show_topic(t,200))))
    plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.savefig("wcld-topic-"+str(t)+".png", facecolor='k')
#     plt.tight_layout(pad=0)
    plt.savefig("wcld-topic-"+str(t)+".png", facecolor='none', bbox_inches='tight')
    
# plt.show()

# %%
import pickle
filename = 'model2019.pkl'
pickle.dump(model, open(filename, 'wb'))

# %%
# menyimpan model LDA
model.save('lda.model')

# memuat model LDA
model =  models.LdaModel.load('lda.model')
